# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import itertools
import pandas as pd

#!pip install sentence_transformers
#!pip install konlpy
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# %%
df = pd.read_csv('/content/drive/MyDrive/AI/Deep-Learning/KeyBERT/CAI_data_006.csv')

# %%
print(len(df))
df.head()
# Out:
# 19997
#      본부  Target    Target_name                                sentence
# 0  서울남부      16   부팅중 오류메시지 발생        차동일 요청사항리셋 접수 수신 불수산 카드 오류리 셋 단말
# 1    전북      26  장비리셋 후 재사용 요청                          리셋 접수 채널 수신 불량
# 2    인천      18          수신 불량  특정 채널 수신 불법 나옴 재부팅하면 사용 가능하다가 다시 안됨 단말
# 3  경기남부      26  장비리셋 후 재사용 요청                리셋 접수 채널 수신 불량 인터넷 연결 오류
# 4    충남      18          수신 불량                         안됨 리셋 연락 우회선 단말

# %%
doc = df['sentence']

# %%
model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/574 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.06k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/527 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
tokenized_docs = []
no_token = []
tokenized_nounses = []
no_noun = []


for i in range(len(doc)) :
  okt = Okt()

  tokenized_doc = okt.pos(doc[i])
  if len(tokenized_doc) >= 2 : 
    tokenized_docs.append(tokenized_doc)

# tokenized_nouns = ' '.join([word[0] for word in tokenized_docs if word[1] == 'Noun'])
# if len(tokenized_doc) >= 2 :
#   tokenized_nounses.append(tokenized_nouns)

# %%
tokenized_nounses = []
for word_list in tokenized_docs:
  preprocess_list = []
  for word in word_list:
    preprocess_list.append(word[0])
  tokenized_nounses.append([' '.join(preprocess_list)])

# %%
def max_sum_sim(doc_embedding, candidate_embeddings, words, top_n, nr_candidates):
    # 문서와 각 키워드들 간의 유사도
    distances = cosine_similarity(doc_embedding, candidate_embeddings)

    # 각 키워드들 간의 유사도
    distances_candidates = cosine_similarity(candidate_embeddings, 
                                            candidate_embeddings)

    # 코사인 유사도에 기반하여 키워드들 중 상위 top_n개의 단어를 pick.
    words_idx = list(distances.argsort()[0][-nr_candidates:])
    words_vals = [candidates[index] for index in words_idx]
    distances_candidates = distances_candidates[np.ix_(words_idx, words_idx)]

    # 각 키워드들 중에서 가장 덜 유사한 키워드들간의 조합을 계산
    min_sim = np.inf
    candidate = None
    for combination in itertools.combinations(range(len(words_idx)), top_n):
        sim = sum([distances_candidates[i][j] for i in combination for j in combination if i != j])
        if sim < min_sim:
            candidate = combination
            min_sim = sim

    return [words_vals[idx] for idx in candidate]

# %%
def mmr(doc_embedding, candidate_embeddings, words, top_n, diversity):

    # 문서와 각 키워드들 간의 유사도가 적혀있는 리스트
    word_doc_similarity = cosine_similarity(candidate_embeddings, doc_embedding)

    # 각 키워드들 간의 유사도
    word_similarity = cosine_similarity(candidate_embeddings)

    # 문서와 가장 높은 유사도를 가진 키워드의 인덱스를 추출.
    # 만약, 2번 문서가 가장 유사도가 높았다면
    # keywords_idx = [2]
    keywords_idx = [np.argmax(word_doc_similarity)]

    # 가장 높은 유사도를 가진 키워드의 인덱스를 제외한 문서의 인덱스들
    # 만약, 2번 문서가 가장 유사도가 높았다면
    # ==> candidates_idx = [0, 1, 3, 4, 5, 6, 7, 8, 9, 10 ... 중략 ...]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]

    # 최고의 키워드는 이미 추출했으므로 top_n-1번만큼 아래를 반복.
    # ex) top_n = 5라면, 아래의 loop는 4번 반복됨.
    for _ in range(top_n - 1):
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        # MMR을 계산
        mmr = (1-diversity) * candidate_similarities - diversity * target_similarities.reshape(-1, 1)
        mmr_idx = candidates_idx[np.argmax(mmr)]

        # keywords & candidates를 업데이트
        keywords_idx.append(mmr_idx)
        candidates_idx.remove(mmr_idx)

    return [words[idx] for idx in keywords_idx]

# %%
for i in range(len(tokenized_nounses)) :
  try:
    n_gram_range = (0, 1)
    count = CountVectorizer(ngram_range=n_gram_range).fit(tokenized_nounses[i])
    candidates = count.get_feature_names_out()

    doc_embedding = model.encode([doc])
    candidate_embeddings = model.encode(candidates)

    top_n = 1
    distances = cosine_similarity(doc_embedding, candidate_embeddings)
    #keywords = [candidates[index] for index in distances.argsort()[0][-top_n:]]
    #keywords = max_sum_sim(doc_embedding, candidate_embeddings, candidates, top_n=1, nr_candidates=10)
    keywords = mmr(doc_embedding, candidate_embeddings, candidates, top_n=1, diversity=0.7)
    print('원본 :', doc[i]) 
    print('문장의 키워드 :' , keywords,)
        

    print('trigram 개수 :',len(candidates))
    print('후보군 단어 출력 :',candidates[:5])
    print('------------------------------------------------------------------------------------------------------') 
  except ValueError as e:
    print('불용어만 있습니다', e)
    print('------------------------------------------------------------------------------------------------------') 
  except TypeError as c:
    print('Nonetype이 존재합니다', c)
    print('------------------------------------------------------------------------------------------------------')
# Out:
# 원본 : 차동일 요청사항리셋 접수 수신 불수산 카드 오류리 셋 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 10
# Keyword 단어 출력 : ['단말' '동일' '리셋' '사항' '수산']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 채널 수신 불량
# 문장의 키워드 : ['채널']
# trigram 개수 : 5
# Keyword 단어 출력 : ['리셋' '불량' '수신' '접수' '채널']
# ------------------------------------------------------------------------------------------------------
# 원본 : 특정 채널 수신 불법 나옴 재부팅하면 사용 가능하다가 다시 안됨 단말
# 문장의 키워드 : ['가능하다가']
# trigram 개수 : 12
# Keyword 단어 출력 : ['가능하다가' '나옴' '다시' '단말' '불법']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 채널 수신 불량 인터넷 연결 오류
# 문장의 키워드 : ['채널']
# trigram 개수 : 8
# Keyword 단어 출력 : ['리셋' '불량' '수신' '연결' '오류']
# ------------------------------------------------------------------------------------------------------
# 원본 : 안됨 리셋 연락 우회선 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 5
# Keyword 단어 출력 : ['단말' '리셋' '안됨' '연락' '우회']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 안됨 신 없음 외부 입력 확인함 리셋
# 문장의 키워드 : ['입력']
# trigram 개수 : 7
# Keyword 단어 출력 : ['리셋' '안됨' '없음' '외부' '입력']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리모컨 일부 버튼 작동 불은 량 통합 리모컨 설정 수동 자동 모두 설정 안됨 접수 보류
# 문장의 키워드 : ['버튼']
# trigram 개수 : 12
# Keyword 단어 출력 : ['리모컨' '모두' '버튼' '보류' '설정']
# ------------------------------------------------------------------------------------------------------
# 원본 : 안됨 로딩 중리 셋만 접수 보류 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 6
# Keyword 단어 출력 : ['단말' '로딩' '보류' '안됨' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 일리셋 접수 티브이 수 신불 시청 멈춘 작동 됨라 이 셋인 입회선 단말
# 문장의 키워드 : ['시청']
# trigram 개수 : 9
# Keyword 단어 출력 : ['단말' '됨라' '리셋' '멈춘' '시청']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 채널 수신 불량
# 문장의 키워드 : ['채널']
# trigram 개수 : 5
# Keyword 단어 출력 : ['리셋' '불량' '수신' '접수' '채널']
# ------------------------------------------------------------------------------------------------------
# 원본 : 티브이 나 옴리셋 접수 보류 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 5
# Keyword 단어 출력 : ['단말' '리셋' '보류' '접수' '티브이']
# ------------------------------------------------------------------------------------------------------
# 원본 : 요청사항리셋 접수 수신 리셋 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 6
# Keyword 단어 출력 : ['단말' '리셋' '사항' '수신' '요청']
# ------------------------------------------------------------------------------------------------------
# 원본 : 요청사항리셋 접수 티브이 됨 인터넷 연결 오류 나옴 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 10
# Keyword 단어 출력 : ['나옴' '단말' '리셋' '사항' '연결']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 볼 셋탑박스 전원 작동 됨 연락 먼저 요 단말
# 문장의 키워드 : ['먼저']
# trigram 개수 : 7
# Keyword 단어 출력 : ['단말' '먼저' '셋탑박스' '수신' '연락']
# ------------------------------------------------------------------------------------------------------
# 원본 : 티브이 수 신불로 딩 중임의 접수회 선 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 5
# Keyword 단어 출력 : ['단말' '불로' '접수' '중임' '티브이']
# ------------------------------------------------------------------------------------------------------
# 원본 : 차 리셋 후에도 안됨 일시 이후 집중 실통화 예종 리셋 접수 됨
# 문장의 키워드 : ['통화']
# trigram 개수 : 9
# Keyword 단어 출력 : ['리셋' '안됨' '에도' '예종' '이후']
# ------------------------------------------------------------------------------------------------------
# 원본 : 화질 불량 위성채널도 일반 유선처럼 화질이 좋게 나온다고 한 회 선 단말
# 문장의 키워드 : ['채널']
# trigram 개수 : 10
# Keyword 단어 출력 : ['나온다고' '단말' '불량' '위성' '유선']
# ------------------------------------------------------------------------------------------------------
# 원본 : 차 리셋 후에도 안됨 리셋 접수 됨
# 문장의 키워드 : ['리셋']
# trigram 개수 : 4
# Keyword 단어 출력 : ['리셋' '안됨' '에도' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 차 리셋 동일 리셋 접수 사용 네트워크 오류
# 문장의 키워드 : ['리셋']
# trigram 개수 : 6
# Keyword 단어 출력 : ['네트워크' '동일' '리셋' '사용' '오류']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 불임의 접수함 카운터 신고 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 6
# Keyword 단어 출력 : ['단말' '불임' '수신' '신고' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 차 리셋 동일 꼭 연락 리세 접수 수신 리셋
# 문장의 키워드 : ['리세']
# trigram 개수 : 6
# Keyword 단어 출력 : ['동일' '리세' '리셋' '수신' '연락']
# ------------------------------------------------------------------------------------------------------
# 원본 : 차 리셋 동일 리셋 접수 채널 수신 불량
# 문장의 키워드 : ['채널']
# trigram 개수 : 6
# Keyword 단어 출력 : ['동일' '리셋' '불량' '수신' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 차 리셋 동일 차리 셋 접수 안됨 로딩 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 7
# Keyword 단어 출력 : ['단말' '동일' '로딩' '리셋' '안됨']
# ------------------------------------------------------------------------------------------------------
# 원본 : 차 리셋 동일 리셋 접수 안됨 인터넷 연결 오류리 셋
# 문장의 키워드 : ['리셋']
# trigram 개수 : 7
# Keyword 단어 출력 : ['동일' '리셋' '안됨' '연결' '오류']
# ------------------------------------------------------------------------------------------------------
# 원본 : 위성 신이 상 나옴 위성안테나가 옆 건물에 있다며 겨달라 함 옆 건물 철거 예정이라 함 날씨 이상 없음 단말
# 문장의 키워드 : ['있다며']
# trigram 개수 : 13
# Keyword 단어 출력 : ['건물' '나옴' '날씨' '단말' '달라']
# ------------------------------------------------------------------------------------------------------
# 원본 : 안됨 시청 끊김 화질이 삼 단말
# 문장의 키워드 : ['시청']
# trigram 개수 : 5
# Keyword 단어 출력 : ['끊김' '단말' '시청' '안됨' '화질']
# ------------------------------------------------------------------------------------------------------
# 원본 : 두 대중 거실 쪽 셋탑 화면만 나옴 컴포넌트 연결 확인함 셋탑 전원 재연결해 봄 단 말 연락처인 입번
# 문장의 키워드 : ['연결해']
# trigram 개수 : 12
# Keyword 단어 출력 : ['거실' '나옴' '대중' '셋탑' '연결']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 채널 수신 불량 네트워크 오류
# 문장의 키워드 : ['채널']
# trigram 개수 : 7
# Keyword 단어 출력 : ['네트워크' '리셋' '불량' '수신' '오류']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 실시간 채널만 나 옴리셋
# 문장의 키워드 : ['채널']
# trigram 개수 : 4
# Keyword 단어 출력 : ['리셋' '실시간' '접수' '채널']
# ------------------------------------------------------------------------------------------------------
# 원본 : 특정 채널이 없어 짐 조치 건 자연 회복됨
# 문장의 키워드 : ['채널']
# trigram 개수 : 6
# Keyword 단어 출력 : ['없어' '자연' '조치' '채널' '특정']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수 선불 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 2
# Keyword 단어 출력 : ['단말' '선불']
# ------------------------------------------------------------------------------------------------------
# 원본 : 요청사항리셋 접수 접속 리셋 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 6
# Keyword 단어 출력 : ['단말' '리셋' '사항' '요청' '접속']
# ------------------------------------------------------------------------------------------------------
# 원본 : 차 리셋 시도 동일 연 후반 리셋 접수 티브이 안됨 인터넷 연결 오류 나옴 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 12
# Keyword 단어 출력 : ['나옴' '단말' '동일' '리셋' '시도']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 차와 동일 리셋 접수 나옴 신 없음 시청 모드 외부 입력 확인 포트 리셋 단말
# 문장의 키워드 : ['시청']
# trigram 개수 : 12
# Keyword 단어 출력 : ['나옴' '단말' '동일' '리셋' '모드']
# ------------------------------------------------------------------------------------------------------
# 원본 : 요청사항리셋 접수 수신 불회선 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 7
# Keyword 단어 출력 : ['단말' '리셋' '사항' '수신' '요청']
# ------------------------------------------------------------------------------------------------------
# 원본 : 티브이 수 신불 접수 보류 정보 확인 전 전화 끊김
# 문장의 키워드 : ['전화']
# trigram 개수 : 7
# Keyword 단어 출력 : ['끊김' '보류' '전화' '접수' '정보']
# ------------------------------------------------------------------------------------------------------
# 원본 : 시청 불란 선을 확인하라 뜸 대중 대만 안됨 연 후방 단말
# 문장의 키워드 : ['시청']
# trigram 개수 : 9
# Keyword 단어 출력 : ['단말' '대만' '대중' '불란' '시청']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 설치한 달도 되었는데 몇 차례 고장 상태라고 불만 확실한 점검 요 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 12
# Keyword 단어 출력 : ['고장' '단말' '달도' '되었는데' '라고']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수회 부재 임의 접수니 셋 접수 수 선불 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 6
# Keyword 단어 출력 : ['단말' '리셋' '부재' '선불' '임의']
# ------------------------------------------------------------------------------------------------------
# 원본 : 매번 저녁만 되면 대화면 깨지고 리모컨 버튼 누르면 반응 속도도 느림 단말
# 문장의 키워드 : ['되면']
# trigram 개수 : 12
# Keyword 단어 출력 : ['깨지고' '누르면' '느림' '단말' '대화면']
# ------------------------------------------------------------------------------------------------------
# 원본 : 안됨 무선 와이파이도 안됨 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 4
# Keyword 단어 출력 : ['단말' '무선' '안됨' '와이파이']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 사용 인터넷전화도 됨
# 문장의 키워드 : ['전화']
# trigram 개수 : 5
# Keyword 단어 출력 : ['리셋' '사용' '인터넷' '전화' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 채널 수신 불량 로딩
# 문장의 키워드 : ['채널']
# trigram 개수 : 6
# Keyword 단어 출력 : ['로딩' '리셋' '불량' '수신' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 수 선불 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 4
# Keyword 단어 출력 : ['단말' '리셋' '선불' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 인터넷 연결 오류 나오며 수 선불 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 8
# Keyword 단어 출력 : ['나오며' '단말' '리셋' '선불' '연결']
# ------------------------------------------------------------------------------------------------------
# 원본 : 티브이 수 신불 셋 탑재 부팅
# 문장의 키워드 : ['탑재']
# trigram 개수 : 3
# Keyword 단어 출력 : ['부팅' '탑재' '티브이']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 수신 부을 채널 정보만 보이고 화면 나 옴리셋
# 문장의 키워드 : ['채널']
# trigram 개수 : 8
# Keyword 단어 출력 : ['리셋' '보이' '부을' '수신' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 수신 불수산 카드 오류 카스 전송함
# 문장의 키워드 : ['카스']
# trigram 개수 : 8
# Keyword 단어 출력 : ['리셋' '수산' '수신' '오류' '전송']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리모컨 작동 불구형 검정 셋탑 제어 셋탑 수동 제어는 됨셋 탑재 부팅 및 모드 스펙 설정해 봄 단말
# 문장의 키워드 : ['탑재']
# trigram 개수 : 13
# Keyword 단어 출력 : ['검정' '단말' '리모컨' '모드' '부팅']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 부을 작년 월부터 차례 동일 증상 잦은 고장 불만 단말 근본적인 원인 해결 원함 반드 시선을 새로 깔아달라 암
# 문장의 키워드 : ['원함']
# trigram 개수 : 20
# Keyword 단어 출력 : ['고장' '근본' '깔아' '단말' '달라']
# ------------------------------------------------------------------------------------------------------
# 원본 : 티브이 수 신불 셋 탑재 부팅
# 문장의 키워드 : ['탑재']
# trigram 개수 : 3
# Keyword 단어 출력 : ['부팅' '탑재' '티브이']
# ------------------------------------------------------------------------------------------------------
# 원본 : 전원 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 2
# Keyword 단어 출력 : ['단말' '전원']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 리셋 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 3
# Keyword 단어 출력 : ['단말' '리셋' '수신']
# ------------------------------------------------------------------------------------------------------
# 원본 : 세톱 전원 꺼짐 작동 됨 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 4
# Keyword 단어 출력 : ['꺼짐' '단말' '작동' '전원']
# ------------------------------------------------------------------------------------------------------
# 원본 : 실행 안됨 접수 보류
# 문장의 키워드 : ['접수']
# trigram 개수 : 4
# Keyword 단어 출력 : ['보류' '실행' '안됨' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 나옴 포트 리셋 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 5
# Keyword 단어 출력 : ['나옴' '단말' '리셋' '접수' '포트']
# ------------------------------------------------------------------------------------------------------
# 원본 : 요청사항리셋 접수 일부 채널 나 옴리셋 단말
# 문장의 키워드 : ['채널']
# trigram 개수 : 7
# Keyword 단어 출력 : ['단말' '리셋' '사항' '요청' '일부']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 불전원 꺼짐 수동으로도 안됨 방문해서 교체 원함 구분 안됨 대만 고장 김회선 단말
# 문장의 키워드 : ['원함']
# trigram 개수 : 15
# Keyword 단어 출력 : ['고장' '교체' '구분' '김회선' '꺼짐']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 부을 모뎀 빨간 불리 셋 단말
# 문장의 키워드 : ['불리']
# trigram 개수 : 6
# Keyword 단어 출력 : ['단말' '모뎀' '부을' '불리' '빨간']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 티브이 수 신불
# 문장의 키워드 : ['리셋']
# trigram 개수 : 3
# Keyword 단어 출력 : ['리셋' '접수' '티브이']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수회 부재 임의 접수 대만 수신 불인터넷 연결오류뜸리셋 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 10
# Keyword 단어 출력 : ['단말' '대만' '리셋' '부재' '수신']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 수신
# 문장의 키워드 : ['수신']
# trigram 개수 : 3
# Keyword 단어 출력 : ['리셋' '수신' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 전 원안 들어 온수신 연락 먼저 단말
# 문장의 키워드 : ['먼저']
# trigram 개수 : 6
# Keyword 단어 출력 : ['단말' '들어' '먼저' '수신' '연락']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 불로 딩 중에 더 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 3
# Keyword 단어 출력 : ['단말' '불로' '수신']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 인터넷 연결 오류 나오며 수 선불 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 8
# Keyword 단어 출력 : ['나오며' '단말' '리셋' '선불' '연결']
# ------------------------------------------------------------------------------------------------------
# 원본 : 시청 불에 더 뜸 연 후방인 입회선 단말
# 문장의 키워드 : ['시청']
# trigram 개수 : 4
# Keyword 단어 출력 : ['단말' '시청' '회선' '후방']
# ------------------------------------------------------------------------------------------------------
# 원본 : 차 리셋 여러 차례 연락드렸으나 통화 연결되지 않아 임의 접수 발송 드립 리셋 접수 수신 불회선 단말
# 문장의 키워드 : ['발송']
# trigram 개수 : 16
# Keyword 단어 출력 : ['단말' '되지' '드렸으나' '드립' '리셋']
# ------------------------------------------------------------------------------------------------------
# 원본 : 일리셋 접수 티브이 수 신불 스트리밍 댁 내 배선 확인 뜸리셋 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 7
# Keyword 단어 출력 : ['단말' '리셋' '배선' '스트리밍' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 됨
# 문장의 키워드 : ['리셋']
# trigram 개수 : 2
# Keyword 단어 출력 : ['리셋' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 시청은 가능하나 화면 끊김 전 엔지니어님 다른 세대가 이사를 가면 선을 건드려서 된다고 하였다고 한우 선 외부성을 점검 단말
# 문장의 키워드 : ['시청']
# trigram 개수 : 16
# Keyword 단어 출력 : ['가능하나' '가면' '건드려서' '끊김' '다른']
# ------------------------------------------------------------------------------------------------------
# 원본 : 티브이 수 신불 영상 케이블을 노트북에 연결했다가 다시 티브이에 연결했는데 안됨 평소에도 시 시로 되었다고 한 회 선 단말
# 문장의 키워드 : ['연결했다가']
# trigram 개수 : 13
# Keyword 단어 출력 : ['노트북' '다시' '단말' '되었다고' '시로']
# ------------------------------------------------------------------------------------------------------
# 원본 : 티브이 수 신불로인 이 정보 확인 전 조치 건 자연 회복됨
# 문장의 키워드 : ['티브이']
# trigram 개수 : 7
# Keyword 단어 출력 : ['불로' '자연' '정보' '조치' '티브이']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수대만 안됨 리셋 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 5
# Keyword 단어 출력 : ['단말' '대만' '리셋' '안됨' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 차 리셋 시도 동일 시 랜 케이블도 지 참 요청은 후반 리셋 접수 수신 불이 고객이 손 뺏다 꽂은 안됨 단말
# 문장의 키워드 : ['꽂은']
# trigram 개수 : 13
# Keyword 단어 출력 : ['고객' '꽂은' '단말' '동일' '리셋']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 네트워크 오류 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 4
# Keyword 단어 출력 : ['네트워크' '단말' '수신' '오류']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 대 안됨 인터넷 연결 오류리 셋
# 문장의 키워드 : ['리셋']
# trigram 개수 : 6
# Keyword 단어 출력 : ['리셋' '안됨' '연결' '오류' '인터넷']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 위성 신미약 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 4
# Keyword 단어 출력 : ['단말' '미약' '수신' '위성']
# ------------------------------------------------------------------------------------------------------
# 원본 : 재어 예약일 오후로 변경함
# 문장의 키워드 : ['예약']
# trigram 개수 : 4
# Keyword 단어 출력 : ['변경' '예약' '오후' '재어']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 불수산 카드 오류나 옴펜션 영업용 전달 예정 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 9
# Keyword 단어 출력 : ['단말' '수산' '수신' '영업' '예정']
# ------------------------------------------------------------------------------------------------------
# 원본 : 차 리셋 후에도 안됨망센터 블록 해제 리콜하니 잘 됨 리셋 접수 인터넷 연결 오류 나오며 수신
# 문장의 키워드 : ['리콜']
# trigram 개수 : 14
# Keyword 단어 출력 : ['나오며' '리셋' '리콜' '블록' '센터']
# ------------------------------------------------------------------------------------------------------
# 원본 : 요청사항기가 지니 전 원안 들어 옴회선 단말 연 후방
# 문장의 키워드 : ['지니']
# trigram 개수 : 8
# Keyword 단어 출력 : ['단말' '들어' '사항' '요청' '원안']
# ------------------------------------------------------------------------------------------------------
# 원본 : 티브이 수 신불 인터넷 연결 오류 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 5
# Keyword 단어 출력 : ['단말' '연결' '오류' '인터넷' '티브이']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 재부팅 안내 리콜하니 잘 됨
# 문장의 키워드 : ['리콜']
# trigram 개수 : 5
# Keyword 단어 출력 : ['리콜' '수신' '안내' '재부팅' '하니']
# ------------------------------------------------------------------------------------------------------
# 원본 : 재어 예약 변경함
# 문장의 키워드 : ['예약']
# trigram 개수 : 3
# Keyword 단어 출력 : ['변경' '예약' '재어']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 차와 동일 요청사항리셋 접수 일부 채널들 음성 나오나 화면 나 옴리셋 단말
# 문장의 키워드 : ['채널']
# trigram 개수 : 11
# Keyword 단어 출력 : ['나오나' '단말' '동일' '리셋' '사항']
# ------------------------------------------------------------------------------------------------------
# 원본 : 티브이 화면이 시청 나왔다 나왔다 함 케이블 셋톱 리셋 잘 됨 단말
# 문장의 키워드 : ['시청']
# trigram 개수 : 8
# Keyword 단어 출력 : ['나왔다' '단말' '리셋' '셋톱' '시청']
# ------------------------------------------------------------------------------------------------------
# 원본 : 화면이 나왔다 나왔다 끊김 리셋 잦은 고장 불만 근본 해결 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 10
# Keyword 단어 출력 : ['고장' '근본' '끊김' '나왔다' '단말']
# ------------------------------------------------------------------------------------------------------
# 원본 : 화질 불량 화면 깨짐 채널도 저절로 변경됨 리 세 단말
# 문장의 키워드 : ['채널']
# trigram 개수 : 8
# Keyword 단어 출력 : ['깨짐' '단말' '변경' '불량' '저절로']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 됨
# 문장의 키워드 : ['리셋']
# trigram 개수 : 2
# Keyword 단어 출력 : ['리셋' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 요청사항리셋 접수 안됨 로딩 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 7
# Keyword 단어 출력 : ['단말' '로딩' '리셋' '사항' '안됨']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 수신 리셋
# 문장의 키워드 : ['수신']
# trigram 개수 : 3
# Keyword 단어 출력 : ['리셋' '수신' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 사용 네트워크 오류
# 문장의 키워드 : ['리셋']
# trigram 개수 : 5
# Keyword 단어 출력 : ['네트워크' '리셋' '사용' '오류' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 오류 메시지 회 선 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 4
# Keyword 단어 출력 : ['단말' '메시지' '수신' '오류']
# ------------------------------------------------------------------------------------------------------
# 원본 : 셋탑 쪽으로 리모컨 작동 포트리 셋 장비니 셋 됨
# 문장의 키워드 : ['포트']
# trigram 개수 : 6
# Keyword 단어 출력 : ['리모컨' '셋탑' '으로' '작동' '장비']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 채널 수신 불량
# 문장의 키워드 : ['채널']
# trigram 개수 : 5
# Keyword 단어 출력 : ['리셋' '불량' '수신' '접수' '채널']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 수신 불이 고객이 손 뺏다 꽂은 됨
# 문장의 키워드 : ['꽂은']
# trigram 개수 : 6
# Keyword 단어 출력 : ['고객' '꽂은' '리셋' '뺏다' '수신']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 안됨 인터넷 연결 오류리 셋
# 문장의 키워드 : ['리셋']
# trigram 개수 : 6
# Keyword 단어 출력 : ['리셋' '안됨' '연결' '오류' '인터넷']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 불상당 아무 조치 없이 자연 회복됨 단말
# 문장의 키워드 : ['없이']
# trigram 개수 : 8
# Keyword 단어 출력 : ['단말' '불상' '수신' '아무' '없이']
# ------------------------------------------------------------------------------------------------------
# 원본 : 권우성 공리 셌 나 오긴 하나 일부 채널 깨짐 현상 리세 일부 채널 시청 안됨 신정상 셋 탑 재부팅 동일 리셋 모든 장비 재부팅 안내 리셋 회선단 말이 특이 사항 신정상
# 문장의 키워드 : ['시청']
# trigram 개수 : 21
# Keyword 단어 출력 : ['공리' '권우' '깨짐' '동일' '리세']
# ------------------------------------------------------------------------------------------------------
# 원본 : 쿡 스카이 신 미약해 부팅해도 동일 연후방 단말 연락처 일 오전 시
# 문장의 키워드 : ['부팅']
# trigram 개수 : 9
# Keyword 단어 출력 : ['단말' '동일' '미약' '부팅' '스카이']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수리요 화면이 너무 밝게 나와서 선결 라스 끼고 시청 한 다함 애들은 그렇게 못한다고 불만 심함 셋탑 교체 원함 단말
# 문장의 키워드 : ['원함']
# trigram 개수 : 16
# Keyword 단어 출력 : ['교체' '그렇게' '나와서' '너무' '단말']
# ------------------------------------------------------------------------------------------------------
# 원본 : 요청사항리셋 접수 수신 불자 등 채널 검색 단말
# 문장의 키워드 : ['채널']
# trigram 개수 : 9
# Keyword 단어 출력 : ['검색' '단말' '리셋' '불자' '사항']
# ------------------------------------------------------------------------------------------------------
# 원본 : 시추 화질 이상 재부팅 함
# 문장의 키워드 : ['시추']
# trigram 개수 : 4
# Keyword 단어 출력 : ['시추' '이상' '재부팅' '화질']
# ------------------------------------------------------------------------------------------------------
# 원본 : 안됨 수신카드 오류 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 5
# Keyword 단어 출력 : ['단말' '수신' '안됨' '오류' '카드']
# ------------------------------------------------------------------------------------------------------
# 원본 : 티브이 교체 후치 비수 신불 연결도 확인 요 연락 요청회 선 단말
# 문장의 키워드 : ['후치']
# trigram 개수 : 9
# Keyword 단어 출력 : ['교체' '단말' '비수' '연결' '연락']
# ------------------------------------------------------------------------------------------------------
# 원본 : 내용 대수선 불수산 카드 오류 재전송 번이나 했는데도 동일 증상임
# 문장의 키워드 : ['했는데도']
# trigram 개수 : 10
# Keyword 단어 출력 : ['내용' '동일' '수산' '수선' '오류']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 불로 딩 중회선 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 4
# Keyword 단어 출력 : ['단말' '불로' '수신' '회선']
# ------------------------------------------------------------------------------------------------------
# 원본 : 음성 불량 화면은 나오는데 음성은 나옴 음량 확인 리셋연 후방 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 10
# Keyword 단어 출력 : ['나오는데' '나옴' '단말' '리셋' '불량']
# ------------------------------------------------------------------------------------------------------
# 원본 : 안됨 리셋
# 문장의 키워드 : ['리셋']
# trigram 개수 : 2
# Keyword 단어 출력 : ['리셋' '안됨']
# ------------------------------------------------------------------------------------------------------
# 원본 : 요청사항 일 수신 불거 실세탑 수리 안방 티브이 됨 잦고 장으로 민원실 한 단말
# 문장의 키워드 : ['잦고']
# trigram 개수 : 12
# Keyword 단어 출력 : ['단말' '민원' '불거' '사항' '수리']
# ------------------------------------------------------------------------------------------------------
# 원본 : 개통 불만 수신 네트워크 오류리 셋 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 6
# Keyword 단어 출력 : ['개통' '네트워크' '단말' '불만' '수신']
# ------------------------------------------------------------------------------------------------------
# 원본 : 차 리셋 동일 리셋 접수 대 안됨 인터넷 연결 오류리 셋
# 문장의 키워드 : ['리셋']
# trigram 개수 : 7
# Keyword 단어 출력 : ['동일' '리셋' '안됨' '연결' '오류']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 불신 없음 셋 탑 외부 입력 확인 케이블 확인 포트 리셋 장비니 셋 후에도 동일 단말
# 문장의 키워드 : ['입력']
# trigram 개수 : 13
# Keyword 단어 출력 : ['단말' '동일' '리셋' '불신' '수신']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수 선불 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 2
# Keyword 단어 출력 : ['단말' '선불']
# ------------------------------------------------------------------------------------------------------
# 원본 : 시시 수신 불셋탑 점검해달라 김회선 단말
# 문장의 키워드 : ['불셋탑']
# trigram 개수 : 7
# Keyword 단어 출력 : ['김회선' '단말' '불셋탑' '수신' '시시']
# ------------------------------------------------------------------------------------------------------
# 원본 : 신 없음 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 2
# Keyword 단어 출력 : ['단말' '없음']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 나옴 네트워크 오류 뜸 신미약 나오기도 함포 프리셋 안내함
# 문장의 키워드 : ['나오기도']
# trigram 개수 : 9
# Keyword 단어 출력 : ['나오기도' '나옴' '네트워크' '리셋' '미약']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리모컨 작동 불가 교체 요청회 선 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 6
# Keyword 단어 출력 : ['교체' '단말' '리모컨' '불가' '요청']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 수신 리셋 안내 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 5
# Keyword 단어 출력 : ['단말' '리셋' '수신' '안내' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 화질 이상 모자이크 대회 선단 말 리셋도 동일 연락처인 입
# 문장의 키워드 : ['선단']
# trigram 개수 : 8
# Keyword 단어 출력 : ['대회' '동일' '리셋' '모자이크' '선단']
# ------------------------------------------------------------------------------------------------------
# 원본 : 대한 대만 셋탑 전 원안 들어 옴은 후방 단말
# 문장의 키워드 : ['대한']
# trigram 개수 : 7
# Keyword 단어 출력 : ['단말' '대만' '대한' '들어' '셋탑']
# ------------------------------------------------------------------------------------------------------
# 원본 : 시청 화면 끊김 음성이 끊김 포트리 셋재 연결 요청회 선 단말 올인 홈 정상기 타 연락처인
# 문장의 키워드 : ['시청']
# trigram 개수 : 12
# Keyword 단어 출력 : ['끊김' '단말' '셋재' '시청' '연결']
# ------------------------------------------------------------------------------------------------------
# 원본 : 차 리셋 전 리셋 접수 시청 화면 꺼짐 음성 단말
# 문장의 키워드 : ['시청']
# trigram 개수 : 7
# Keyword 단어 출력 : ['꺼짐' '단말' '리셋' '시청' '음성']
# ------------------------------------------------------------------------------------------------------
# 원본 : 신미약 수신 잦은 고장 불만 꼼꼼한 점검 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 8
# Keyword 단어 출력 : ['고장' '꼼꼼한' '단말' '미약' '불만']
# ------------------------------------------------------------------------------------------------------
# 원본 : 신미약 백업 채널로 넘어 감연 후방 단말
# 문장의 키워드 : ['채널']
# trigram 개수 : 7
# Keyword 단어 출력 : ['감연' '넘어' '단말' '미약' '백업']
# ------------------------------------------------------------------------------------------------------
# 원본 : 일리셋 접수 접속 불회선 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 5
# Keyword 단어 출력 : ['단말' '리셋' '접속' '접수' '회선']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수 선불 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 2
# Keyword 단어 출력 : ['단말' '선불']
# ------------------------------------------------------------------------------------------------------
# 원본 : 대중 대 수신 불대만 수신 불리 셋 회선단 말이 특이 사항
# 문장의 키워드 : ['불리']
# trigram 개수 : 7
# Keyword 단어 출력 : ['대만' '대중' '불리' '사항' '선단']
# ------------------------------------------------------------------------------------------------------
# 원본 : 안됨 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 2
# Keyword 단어 출력 : ['단말' '안됨']
# ------------------------------------------------------------------------------------------------------
# 원본 : 채널 수신 불량 잦은 고장 근본 해결 연락 먼저 요망 단말
# 문장의 키워드 : ['먼저']
# trigram 개수 : 11
# Keyword 단어 출력 : ['고장' '근본' '단말' '먼저' '불량']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 사용 불로딩
# 문장의 키워드 : ['리셋']
# trigram 개수 : 4
# Keyword 단어 출력 : ['로딩' '리셋' '사용' '접수']
# ------------------------------------------------------------------------------------------------------
# 원본 : 차 리셋해도 됨 요청사항리셋 접수 채널 수신 불량 시간 요 단말
# 문장의 키워드 : ['채널']
# trigram 개수 : 10
# Keyword 단어 출력 : ['단말' '리셋' '불량' '사항' '수신']
# ------------------------------------------------------------------------------------------------------
# 원본 : 번만 나옴 권한 자 송출 재부팅 안내 리모컨도 새것으로 바꿔달라고 한 단순 교체는 재구매 안내함 단말
# 문장의 키워드 : ['번만']
# trigram 개수 : 14
# Keyword 단어 출력 : ['교체' '권한' '나옴' '단말' '단순']
# ------------------------------------------------------------------------------------------------------
# 원본 : 안됨 인터넷 연결 오류리 셋 연락 우회선 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 7
# Keyword 단어 출력 : ['단말' '안됨' '연결' '연락' '오류']
# ------------------------------------------------------------------------------------------------------
# 원본 : 번 채널 등 일부 채널 버벅거리고 끊김리 셋 단말
# 문장의 키워드 : ['채널']
# trigram 개수 : 5
# Keyword 단어 출력 : ['끊김리' '단말' '버벅거리' '일부' '채널']
# ------------------------------------------------------------------------------------------------------
# 원본 : 점검 시청 부을 채널 전송 및 리셋 동일 단말
# 문장의 키워드 : ['시청']
# trigram 개수 : 8
# Keyword 단어 출력 : ['단말' '동일' '리셋' '부을' '시청']
# ------------------------------------------------------------------------------------------------------
# 원본 : 시청되나 키즈 관 창이 떠서 가리고 있다 심 재부팅 사용됨
# 문장의 키워드 : ['시청']
# trigram 개수 : 8
# Keyword 단어 출력 : ['가리고' '되나' '떠서' '사용' '시청']
# ------------------------------------------------------------------------------------------------------
# 원본 : 음성 끊겨 들림 화면은 잘 나 옴 포트리 셋셋 탑재 부팅해 보시고 사용 잘 되면 접수 취소하기로 함 시 시 사이 요청회 선 단말
# 문장의 키워드 : ['되면']
# trigram 개수 : 17
# Keyword 단어 출력 : ['끊겨' '단말' '되면' '들림' '보시']
# ------------------------------------------------------------------------------------------------------
# 원본 : 애플하우스 수신 부을 외부 신고 임의회 선 접수회 선 단말 올인 홈세탑 정상기 타
# 문장의 키워드 : ['올인']
# trigram 개수 : 11
# Keyword 단어 출력 : ['단말' '부을' '수신' '신고' '애플']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리콜 시청 위젯 사라져 화면 가름장 비리 셋 해결됨
# 문장의 키워드 : ['시청']
# trigram 개수 : 8
# Keyword 단어 출력 : ['가름' '리콜' '비리' '사라져' '시청']
# ------------------------------------------------------------------------------------------------------
# 원본 : 대만 시청 꺼짐 소리도 깨짐 리셋해 봐도 동일하다 김회선 단말
# 문장의 키워드 : ['시청']
# trigram 개수 : 10
# Keyword 단어 출력 : ['김회선' '깨짐' '꺼짐' '단말' '대만']
# ------------------------------------------------------------------------------------------------------
# 원본 : 리셋 접수 스카이 수신 불비상 채널로 시청 정상리 셋 포트 리셋
# 문장의 키워드 : ['시청']
# trigram 개수 : 9
# Keyword 단어 출력 : ['리셋' '비상' '수신' '스카이' '시청']
# ------------------------------------------------------------------------------------------------------
# 원본 : 권유 실패 리셋 동일 현상 수신 불이 요청사항리셋 안됨 인터넷 오류 신 정상 재부팅 동일 리셋 장비 재부팅 단말
# 문장의 키워드 : ['단말']
# trigram 개수 : 15
# Keyword 단어 출력 : ['권유' '단말' '동일' '리셋' '사항']
# ------------------------------------------------------------------------------------------------------
# 원본 : 아날로그 화질로 나온다고 하심 단말
# 문장의 키워드 : ['아날로그']
# trigram 개수 : 4
# Keyword 단어 출력 : ['나온다고' '단말' '아날로그' '화질']
# ------------------------------------------------------------------------------------------------------
# 원본 : 마지막 타임 방문요 위성채널 시청 불비 사용 채널로 시청됨 날씨 이상 없을 리셋 동일 단말
# 문장의 키워드 : ['시청']
# trigram 개수 : 14
# Keyword 단어 출력 : ['날씨' '단말' '동일' '리셋' '마지막']
# ------------------------------------------------------------------------------------------------------
# 원본 : 수신 리셋 거부 단말 임의 접수
# 문장의 키워드 : ['단말']
# trigram 개수 : 6
# Keyword 단어 출력 : ['거부' '단말' '리셋' '수신' '임의']
# ------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-8cdf46afb748> in <module>()
#       5     candidates = count.get_feature_names_out()
#       6
# ----> 7     doc_embedding = model.encode([doc])
#       8     candidate_embeddings = model.encode(candidates)
#       9
#
# /usr/local/lib/python3.7/dist-packages/sentence_transformers/SentenceTransformer.py in encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     163
#     164             with torch.no_grad():
# --> 165                 out_features = self.forward(features)
#     166
#     167                 if output_value == 'token_embeddings':
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/sentence_transformers/models/Transformer.py in forward(self, features)
#      64             trans_features['token_type_ids'] = features['token_type_ids']
#      65
# ---> 66         output_states = self.auto_model(**trans_features, return_dict=False)
#      67         output_tokens = output_states[0]
#      68
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     856             output_attentions=output_attentions,
#     857             output_hidden_states=output_hidden_states,
# --> 858             return_dict=return_dict,
#     859         )
#     860         sequence_output = encoder_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     529                     encoder_attention_mask,
#     530                     past_key_value,
# --> 531                     output_attentions,
#     532                 )
#     533
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     412             head_mask,
#     413             output_attentions=output_attentions,
# --> 414             past_key_value=self_attn_past_key_value,
#     415         )
#     416         attention_output = self_attention_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     341             encoder_attention_mask,
#     342             past_key_value,
# --> 343             output_attentions,
#     344         )
#     345         attention_output = self.output(self_outputs[0], hidden_states)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     236
#     237         # Take the dot product between "query" and "key" to get the raw attention scores.
# --> 238         attention_scores = torch.matmul(query_layer, key_layer.transpose(-1, -2))
#     239
#     240         if self.position_embedding_type == "relative_key" or self.position_embedding_type == "relative_key_query":
#
# KeyboardInterrupt:

# %%
mmr(doc_embedding, candidate_embeddings, candidates, top_n=5, diversity=0.2)
# Out:
# ['리셋 안내', '안내 단말', '단말', '버튼', '현재 외부']
