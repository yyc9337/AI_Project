# %%
import numpy as np
import pandas as pd
import itertools


from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ### 전처리가 이미 완료된 후의 데이터를 사용
# 보안상 데이터를 전체 공개 불가

# %%
df = pd.read_csv('../data/dataset/CAI_data_003.csv')

# %%
df['sentence'][1]
# Out:
# '고객 요청사항 수신불인터넷 연결오류 뜸재부팅해 봄 모텔 영업용 일중 꼭 점검원하여 지사 이관함회선 단말특이사항 진단 결과 기타 추가 연락처'

# %%
okt = Okt()

tokenized_doc = okt.pos(df['sentence'][1])
tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1] != 0])

print('품사 태깅 10개만 출력 :',tokenized_doc[:10])
print('추출 :',tokenized_nouns)
# Out:
# 품사 태깅 10개만 출력 : [('고객', 'Noun'), ('요청', 'Noun'), ('사항', 'Noun'), ('수', 'Modifier'), ('신', 'Modifier'), ('불', 'Noun'), ('인터넷', 'Noun'), ('연결', 'Noun'), ('오류', 'Noun'), ('뜸', 'Noun')]
# 추출 : 고객 요청 사항 수 신 불 인터넷 연결 오류 뜸 재부팅 해 봄 모텔 영업 용 일 중 꼭 점검 원하여 지사 이 관함 회선 단말 특이 사항 진단 결과 기타 추가 연락처

# %%
n_gram_range = (2, 3)

count = CountVectorizer(ngram_range=n_gram_range).fit([tokenized_nouns])
candidates = count.get_feature_names_out()

print('trigram 개수 :',len(candidates))
print('trigram 다섯개만 출력 :',candidates[:5])
# Out:
# trigram 개수 : 41
# trigram 다섯개만 출력 : ['결과 기타' '결과 기타 추가' '고객 요청' '고객 요청 사항' '관함 회선']

# %%
model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
doc_embedding = model.encode([df['sentence'][1]])
candidate_embeddings = model.encode(candidates)

# %%
top_n = 5
distances = cosine_similarity(doc_embedding, candidate_embeddings)
keywords = [candidates[index] for index in distances.argsort()[0][-top_n:]]
print(keywords)
# Out:
# ['점검 원하여', '연결 오류 재부팅', '원하여 지사 관함', '점검 원하여 지사', '영업 점검 원하여']

# %%
def max_sum_sim(doc_embedding, candidate_embeddings, words, top_n, nr_candidates):
    # 문서와 각 키워드들 간의 유사도
    distances = cosine_similarity(doc_embedding, candidate_embeddings)

    # 각 키워드들 간의 유사도
    distances_candidates = cosine_similarity(candidate_embeddings,
                                            candidate_embeddings)

    # 코사인 유사도에 기반하여 키워드들 중 상위 top_n개의 단어를 pick.
    words_idx = list(distances.argsort()[0][-nr_candidates:])
    words_vals = [candidates[index] for index in words_idx]
    distances_candidates = distances_candidates[np.ix_(words_idx, words_idx)]

    # 각 키워드들 중에서 가장 덜 유사한 키워드들간의 조합을 계산
    min_sim = np.inf
    candidate = None

    for combination in itertools.combinations(range(len(words_idx)), top_n):
        sim = sum([distances_candidates[i][j] for i in combination for j in combination if i != j])
        if sim < min_sim:
            candidate = combination
            min_sim = sim

    return [words_vals[idx] for idx in candidate]

def mmr(doc_embedding, candidate_embeddings, words, top_n, diversity):

    # 문서와 각 키워드들 간의 유사도가 적혀있는 리스트
    word_doc_similarity = cosine_similarity(candidate_embeddings, doc_embedding)

    # 각 키워드들 간의 유사도
    word_similarity = cosine_similarity(candidate_embeddings)

    # 문서와 가장 높은 유사도를 가진 키워드의 인덱스를 추출.
    # 만약, 2번 문서가 가장 유사도가 높았다면
    # keywords_idx = [2]
    keywords_idx = [np.argmax(word_doc_similarity)]

    # 가장 높은 유사도를 가진 키워드의 인덱스를 제외한 문서의 인덱스들
    # 만약, 2번 문서가 가장 유사도가 높았다면
    # ==> candidates_idx = [0, 1, 3, 4, 5, 6, 7, 8, 9, 10 ... 중략 ...]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]

    # 최고의 키워드는 이미 추출했으므로 top_n-1번만큼 아래를 반복.
    # ex) top_n = 5라면, 아래의 loop는 4번 반복됨.
    for _ in range(top_n - 1):
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        # MMR을 계산
        mmr = (1-diversity) * candidate_similarities - diversity * target_similarities.reshape(-1, 1)
        mmr_idx = candidates_idx[np.argmax(mmr)]

        # keywords & candidates를 업데이트
        keywords_idx.append(mmr_idx)
        candidates_idx.remove(mmr_idx)

    return [words[idx] for idx in keywords_idx]

# %%
sentences = []

stopwords = ['고객','요청사','항','요청사항','안심권유','기타 추가 연락처']

for sentence in df['sentence']:
    for word in stopwords:
        sentence = sentence.replace(word, '')
        sentence = sentence.lstrip()
    sentences.append(sentence)
df['sen'] = sentences

# %%
df['sen']
# Out:
# 0                                            안됨상담 중 자연회복됨
# 1       수신불인터넷 연결오류 뜸재부팅해 봄 모텔 영업용 일중 꼭 점검원하여 지사 이관함회선...
# 2                                  수신불회선 단말특이사 진단 결과  연후방
# 3                                       수신 불네트워크 오류 접수 보류
# 4                              수신불 연락 후회선 단말특이사 진단 결과 인 입
#                               ...
# 8661    화질 불량 시청 중 화면 멈추고 꺼졌다 켜지는 현상이 있다고 함 연락 후 방문요회선...
# 8662                       리콜넷플릭스 연령인증 문의 건 리콜하니 해결했다고 하심
# 8663                                           대수신불전송 후리셋
# 8664    빠른 점검 요청   시청 불인터넷 연결오류나 옴 모든 장비 재부팅 안내회선 단말특이...
# 8665      수신불 연락 후 방문지니 셋 탑 전원안 들어옴 교체 요청회 선 단말특이사 진단 결과
# Name: sen, Length: 8666, dtype: object

# %%
abstract_sen = []


for i in range(len(df)) :
    

    try :
        okt = Okt()

        tokenized_doc = okt.pos(df['sen'][i])
        tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1] != 0])

        n_gram_range = (1, 2)

        count = CountVectorizer(ngram_range=n_gram_range).fit([tokenized_nouns])
        candidates = count.get_feature_names_out()

        doc_embedding = model.encode([df['sen'][i]])
        candidate_embeddings = model.encode(candidates)

        distances = cosine_similarity(doc_embedding, candidate_embeddings)
        keywords = [candidates[index] for index in distances.argsort()[0][-top_n:]]
        
        
        keywords = max_sum_sim(doc_embedding, candidate_embeddings, candidates, top_n=3, nr_candidates=5)
        
        
        abstract_sen.append(keywords)
        print('----------------------------------------------------------')
        print('원본 : ', df['sen'][i])
        print('요약 : ', abstract_sen[i])
        print('----------------------------------------------------------')

    except :
        abstract_sen.append(df['sen'][i])
# Out:
# ----------------------------------------------------------
# 원본 :  안됨상담 중 자연회복됨
# 요약 :  ['자연 회복', '상담 자연', '안됨 상담']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불인터넷 연결오류 뜸재부팅해 봄 모텔 영업용 일중 꼭 점검원하여 지사 이관함회선 단말특이사 진단 결과
# 요약 :  ['재부팅 모텔 영업', '원하여 지사 관함', '연결 오류 재부팅']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과  연후방
# 요약 :  ['단말 특이 진단', '회선 단말', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불네트워크 오류 접수 보류
# 요약 :  ['수신 네트워크', '네트워크 오류 접수', '접수 보류']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불 연락 후회선 단말특이사 진단 결과 인 입
# 요약 :  ['회선 단말', '회선 단말 특이', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  채널은 정상 넷플릭스 안됨 포트리셋 미리 연락 후 방문 요망회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '정상 넷플릭스 안됨', '리셋 미리 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불서비스 시작 중 회선 단말특이사 진단 결과
# 요약 :  ['서비스 시작 회선', '단말 특이', '수신 서비스 시작']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  김현철 채팅지니 자체에서 잡음이 난다고 함고장 접수함   셋탑이상지니 자체에서 따다 다다 거리는 소리가 계속 나다고 함동일 증상으로 일경받았으나 또 소리가 난다고 함재부팅해도 동일 연후방 회선 단말특이사 진단 결과
# 요약 :  ['자체 에서 잡음', '김현철 채팅 지니', '받았으나 소리 난다고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  나오나 따닥거리는 소리가 난다함리셋 후 잘됨회선 단말특이사 진단 결과
# 요약 :  ['따닥거리 소리', '소리 난다 리셋', '나오나 따닥거리']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  화질 불량 시청 중 멈추는 증상 반복됨 연락 후회선 단말특이사 진단 결과 인 입
# 요약 :  ['화질 불량 시청', '반복 연락', '불량 시청 멈추는']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과  연후방
# 요약 :  ['단말 특이 진단', '회선 단말', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불 연락 후 최대한 빠른 방문 요망회선 단말특이사 진단 결과
# 요약 :  ['빠른 방문', '연락 최대한', '연락 최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  채널 정상넷플릭스만 안됨 포트리셋 연락 후 최대한 빠른 방문 요망회선 단말특이사 진단 결과
# 요약 :  ['최대한 빠른', '리셋 연락', '최대한 빠른 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불스트림에러 자 연회복회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '단말 특이 진단', '스트림 에러']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  안됨리셋 후 정상
# 요약 :  ['리셋 정상', '안됨 리셋', '안됨 리셋 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  인터넷 지킴이가 입수신불재부팅 안내 후 정상 사용됨
# 요약 :  ['지킴 입수 재부팅', '재부팅 안내', '인터넷 지킴 입수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  넷플릭스 실행 불가리셋 후 잘됨 회선 단말특이사 진단 결과
# 요약 :  ['리셋 회선 단말', '진단 결과', '불가 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불 최대한 빠른 점검 요회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '빠른 점검 회선', '최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 안됨 리모컨에 불계속 켜 짐 매장 안내
# 요약 :  ['리모컨 계속', '리모컨 안됨 리모컨', '매장 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불셋 탑재 부팅 정상 확인됨
# 요약 :  ['불셋 탑재', '수신 불셋 탑재', '탑재 부팅 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 불셋 탑재 부팅 후 정상 사용됨
# 요약 :  ['작동 불셋 탑재', '부팅 정상 사용', '리모컨 작동 불셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  전원안 들어옴 측의뢰
# 요약 :  ['들어옴 의뢰', '원안 들어옴', '원안 들어옴 의뢰']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  전원안 들어옴 측의뢰
# 요약 :  ['들어옴 의뢰', '원안 들어옴', '원안 들어옴 의뢰']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  채널 수신불량회선 단말특이사 시험 결과  코로나 미 대상
# 요약 :  ['회선 단말 특이', '결과 코로나 대상', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  안됨신 없음 외부 입력 확인 셋탑재 부팅해도 동일 보류
# 요약 :  ['안됨신 없음 외부', '부팅 해도 동일', '부팅 해도']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불되도록 일오전 방문 요청회 선 단말특이사 진단 결과
# 요약 :  ['요청 단말 특이', '오전 방문 요청', '되도록 오전']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  현재 수신 불평소 화면 끊어짐 코로나 미 대상회선 단말특이사 진단 결과
# 요약 :  ['끊어짐 코로나 대상', '평소 화면', '현재 수신 평소']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  안됨인터넷 연결오류재부팅해도 동일 방문시간 참고
# 요약 :  ['시간 참고', '해도 동일 방문', '오류 재부팅 해도']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불재부팅 후 정상 사용됨회선 단말특이사 진단 결과
# 요약 :  ['회선 단말 특이', '재부팅 정상 사용', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  안됨신 없음 외부 입력 변경 후 정상 사용됨
# 요약 :  ['정상 사용', '없음 외부 입력', '변경 정상 사용']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  올레티비 음향 안 들림셋탑리셋 이후 올레티비 정상음향 들림
# 요약 :  ['음향 들림 셋탑', '정상 음향 들림', '셋탑 리셋 이후']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불과 리모컨 반응 느림셋탑리셋 후 정상
# 요약 :  ['셋탑 리셋 정상', '불과 리모컨 반응', '리셋 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불인터넷 연결오류 뜸 급 점검지연된다고 민원심 최대한 빠른 점검 요회선 단말특이사 진단 결과
# 요약 :  ['빠른 점검 회선', '연결 오류 점검', '민원 최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  조회 안됨 전원 적색점 등 수동 눌러도 반응 없음셋탑재 부팅해도 동일 방문 시간 참고
# 요약 :  ['눌러도 반응', '눌러도 반응 없음', '부팅 해도 동일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불기가 지니 전원안 들어 옴기가 지니에 연결된 랜선도 헐거워져서 자꾸 빠진다고 랜선교체도 요청함 회선 단말특이사 진단 결과
# 요약 :  ['랜선 헐거워져서', '헐거워져서 자꾸 빠진다고', '랜선 헐거워져서 자꾸']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  큰 방수신불코로나미 대상회선 단말특이사 진단 결과
# 요약 :  ['나미 대상', '방수 코로 나미', '단말 특이 진단']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  안됨 방문해서 확인 요청함 연결된 지니대는 정상 방문 시간 참고인
# 요약 :  ['방문 해서', '연결 지니 정상', '안됨 방문 해서']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  올레티비 시청 안됨 티비전원 안켜 짐  측의뢰안내함
# 요약 :  ['전원 의뢰', '올레 티비 시청', '시청 안됨 티비']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  방수신불시 방문요회선 단말특이사 진단 결과
# 요약 :  ['단말 특이 진단', '방문 회선', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  채널 수신불량인터넷 연결오류회선 단말특이사 시험 결과  코로나 미 대상
# 요약 :  ['회선 단말 특이', '결과 코로나 대상', '연결 오류']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  차단기 내려간 후 수신불회선 단말특이사 진단 결과  코로나 미 대상
# 요약 :  ['진단 결과 코로나', '결과 코로나 대상', '차단기 내려간']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불네트워크 오류 최대한 빠른 점검 요청회선 단말특이사 진단 결과
# 요약 :  ['네트워크 오류 최대한', '빠른 점검 요청', '오류 최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불방쪽만 안됨 셋탑재 부팅 후 정상
# 요약 :  ['수신 불방쪽 안됨', '탑재 부팅', '부팅 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불인터넷 연결오류 뜸재부팅해 봄 연락 먼저 회선 단말특이사 진단 결과
# 요약 :  ['재부팅 연락', '먼저 회선 단말', '재부팅 연락 먼저']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  가능한 일방 요 분 정도 시청되면 화면 꺼짐 소리 정상회선 단말특이사 진단 결과  코로나 미 대상
# 요약 :  ['화면 꺼짐', '소리 정상 회선', '시청 되면 화면']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일반 아들 방안됨 전원 적색점 등재부팅해도 동일 기량 자 방문 요청함 방문 시간 참고
# 요약 :  ['기량 방문 요청', '해도 동일 기량', '재부팅 해도 동일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  안됨 셋 탑 전원 빨간불껏 다 켜도 아무 반응 없음 최대한 빠른 방문 요청
# 요약 :  ['켜도 아무 반응', '빨간 불껏 켜도', '없음 최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  원룸 새로 입주 후 수신불세탑이 전혀 연결되어 있지 않음 취소 건 있음 일 방문 요청일은 늦게 근무해서 수리를 받을 수 없다고 하심 회선 단말특이사 진단 결과
# 요약 :  ['받을 없다고 회선', '늦게 근무 해서', '수리 받을 없다고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  채팅 올레티비시청 안 됨셋탑 계속 꺼진다고 하심리셋해도 마찬가지 점검 요청 접수해 드림셋탑 교체도 원하심   회선 단말특이사 진단 결과 기타 추가 연락 처 방문 전 연락 요청
# 요약 :  ['시청 셋탑 계속', '꺼진다고 심리 해도', '심리 해도 마찬가지']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불셋탑이상 전원만 빨간불 들어오고 수동 조작도 안됨 안방 쪽만 안됨 코로나 이 상무연 후방 회선 단말특이사 진단 결과
# 요약 :  ['수신 불셋탑 이상', '빨간 들어오고', '들어오고 수동 조작']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 중 화면 흔들리고 블랙 화면으로 멈춰 진행 안됨재부팅해야 사용됨 리모컨 일부 버튼 작동 불방문 시간 참고
# 요약 :  ['화면 흔들리고 블랙', '재부팅 해야', '해야 사용 리모컨']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  스마트 셋탑 리모콘 안 됨기사 방문 요청함회선 단말특이사 진단 결과
# 요약 :  ['기사 방문', '요청 회선', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  안 됨 거실 인터넷 연결오류 최대한 독촉
# 요약 :  ['연결 오류', '최대한 독촉', '오류 최대한 독촉']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  미리 연 후방 요기가 지니 전원회선 단말 특이사 진단 결과
# 요약 :  ['후방 요기 지니', '진단 결과', '미리 후방']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  대 모두 수신 불인터넷 오류 최대한 빠른 점검 요청회선 단말특이사 진단 결과  연후방
# 요약 :  ['빠른 점검 요청', '오류 최대한', '오류 최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불 연락 후회선 단말특이사 진단 결과 인 입
# 요약 :  ['회선 단말', '회선 단말 특이', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  층수신 불조치 전 회복
# 요약 :  ['수신 조치', '수신 조치 회복', '조치 회복']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  접속 불정상리셋오후시 방문 요청함
# 요약 :  ['방문 요청', '정상 리셋 오후', '접속 정상 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불인터넷 지킴이와 안심가입회선 단말특이사 진단 결과
# 요약 :  ['가입 회선 단말', '진단 결과', '단말 특이 진단']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불재부팅 후 정상 사용됨회선 단말특이사 진단 결과
# 요약 :  ['회선 단말 특이', '재부팅 정상 사용', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불 외부에서 선 끊어짐 댁에 사람 없음 외부 점검요 방문 전 연락 요회선 단말특이사 진단 결과
# 요약 :  ['방문 연락', '외부 점검 방문', '점검 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시시수신 불네트워크 오류 뜸 여러 번 재부팅해야 된다고 함근 본점검 원함회선 단말특이사 진단 결과
# 요약 :  ['원함 회선 단말', '점검 원함 회선', '재부팅 해야 된다고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모콘 인식 안됨 교환 요청 택배 요청 택배 처리해 드림
# 요약 :  ['교환 요청 택배', '인식 안됨 교환', '택배 요청 택배']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불수신 카드 오류 전송 후 정상 사용됨
# 요약 :  ['불수신 카드', '전송 정상 사용', '카드 오류 전송']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  안됨인터넷 연결오류리셋
# 요약 :  ['오류 리셋', '연결 오류 리셋', '안됨 인터넷']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불네트워크 오류리셋 회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '리셋 회선 단말', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 안됨 건전지 부분 스프링 고장 게재
# 요약 :  ['건전지 부분', '부분 스프링 고장', '스프링 고장 게재']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  거실 수신불 업그레이드 오류 최대한 빠른 점검 요청일 중으로 처리되도록 요청함 회선 단말특이사 진단 결과  연후방
# 요약 :  ['업그레이드 오류 최대한', '빠른 점검 요청', '오류 최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모콘 인식 안됨 셋탑리셋 이후 리모콘 정상 사용됨
# 요약 :  ['이후 리모콘', '리모콘 정상 사용', '셋탑 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과  연후방
# 요약 :  ['단말 특이 진단', '회선 단말', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 안됨재부팅 후 정상
# 요약 :  ['안됨 재부팅', '안됨 재부팅 정상', '재부팅 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불급일 방문 가능하면 앞당겨와 달라 함일은 시 방문요 방문 일정은 안내함회선 단말특이사 진단 결과
# 요약 :  ['앞당겨와 달라', '불급 방문 가능하면', '가능하면 앞당겨와 달라']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불두대다동 일일까지 기다릴 수 없음 일 방문 요청 집중 실통화 의뢰 후문자전송 요청회선 단말특이사 진단 결과
# 요약 :  ['기다릴 없음 방문', '전송 요청', '방문 요청 집중']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  대안됨 댁내 배선 점검 요청함 스트림에러 방문시간 오후시시 방문 요청함 빠른 일정 확인 후 전송 안내 참고
# 요약 :  ['요청 빠른', '빠른 일정 확인', '전송 안내 참고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  음성은 나오나 화면 안나 옴재부팅해 봄 연락 먼저 회선 단말특이사 진단 결과
# 요약 :  ['나오나 화면 안나', '안나 재부팅 연락', '연락 먼저 회선']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불관리자 핀번 입력창뜸코로나 미 대상회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '관리자 핀번 입력', '입력 창뜸 코로나']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  끊김 미리 연락 후 방문 요망지킴이 가 입회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '방문 요망', '미리 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  큰 방수신불부 전원 안 켜짐 빨간불거실는 잘됨화요일 방문원함  인터넷 지킴이 실패회선 단말특이사 진단 결과
# 요약 :  ['빨간 불거실는', '단말 특이 진단', '방문 원함']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불 연락 후 잦은 고장불편 많음 교체 언급 요청회 선 단말특이사 진단 결과 인 입
# 요약 :  ['단말 특이', '연락 잦은', '요청 단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불네트워크 오류 메세지 최대한 빠른 점검 필요회선 단말특이사 진단 결과
# 요약 :  ['최대한 빠른', '오류 메세지 최대한', '빠른 점검 필요']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  채널 화질 불량 지직거림 빠른 방문 요청 근본 해결코로나미 대상회선 단말특이사 진단 결과
# 요약 :  ['직거림 빠른 방문', '빠른 방문 요청', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불인터넷 연결오류 단말 구별 불가 주소로 임의 접수회선 단말특이사 진단 결과
# 요약 :  ['구별 불가 주소', '임의 접수', '연결 오류 단말']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  화면 안 나옴 음성 정상셋 탑재부팅해도 동일 방문 시간 참고
# 요약 :  ['화면 나옴 음성', '해도 동일 방문', '부팅 해도 동일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불 연락 후 전원회선 단말특이사 진단 결과 인 입
# 요약 :  ['회선 단말', '연락 전원', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 불리모컨에 버튼을 안 눌러도 리모컨에 불이 계속 들어오면서 오작동이 됨연 후방 회선 단말특이사 진단 결과
# 요약 :  ['작동 리모컨', '리모컨 버튼', '리모컨 작동']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불인터넷 오류회선 단말특이사 진단 결과  연후방
# 요약 :  ['회선 단말', '오류 회선 단말', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불네트워크 오류 홈 너무 뜨겁다며 문제 있는 건 아닌 지 방문해서 확인 요회선 단말특이사 진단 결과
# 요약 :  ['방문 해서 확인', '문제 있는 아닌', '오류 너무 뜨겁다며']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 안됨 가까이에서는 되고 멀리서는 안됨 리모컨 페어링재부팅에 택배 접수함
# 요약 :  ['택배 접수', '에서는 되고', '에서는 되고 멀리']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  거실 화질이 상 시청 중 화면이 지 직거린 다 심회선 단말특이사 진단 결과
# 요약 :  ['진단 결과', '거실 화질 시청', '시청 화면 직거린']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불 최대한 빠른 점검 요청회선 단말특이사 진단 결과
# 요약 :  ['점검 요청', '빠른 점검', '최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  오전 정 전후 수신 불회선 단말특이사 진단 결과  코로나 미 대상
# 요약 :  ['진단 결과 코로나', '오전 전후 수신', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 불가설정 방법 문자 전송도 함회선 단말특이사 진단 결과
# 요약 :  ['회선 단말 특이', '불가 설정 방법', '설정 방법 문자']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 불비정상리셋코로나무 미리 연락 요회선 단말특이사 진단 결과 비정상기 타 추가 연락처
# 요약 :  ['미리 연락', '나무 미리 연락', '상기 추가 연락처']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시시로 안 됨 시청 중 끊김 현상 연락처 못 받을 시 추가 연락처로 해달라 함
# 요약 :  ['받을 추가 연락처', '추가 연락처 해달라', '현상 연락처 받을']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 불매장 안내 본인 회선 단말특이사 진단 결과
# 요약 :  ['본인 회선', '작동 불매 안내', '불매 안내 본인']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 수신 불리셋 회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '리셋 접수', '접수 수신 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 요청 코로나 이 상무   수신 불량 입력신 없음셋 탑 전원 확인재부팅해 봄 회선 단말특이사 진단 결과 연
# 요약 :  ['일시 요청', '단말 특이', '요청 코로나 상무']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  대다 안됨 시청 불광케이블 장애 안내장애 완료 후 연락요
# 요약 :  ['대다 안됨 시청', '장애 완료', '장애 완료 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 셋 탑 전원이 켜졌다 안 켜졌다 함 방문 전 연락 요회선 단말특이사 진단 결과
# 요약 :  ['방문 연락 회선', '전원 켜졌다 켜졌다', '켜졌다 방문 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 시간 내 외 리콜 안내   수신불회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '리셋 접수 시간', '리콜 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불로 딩 중뜸 연 후방 회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '회선 단말 특이', '수신 불로 중뜸']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['결과 정상기 추가', '단말 특이', '추가 연락처']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  대중대는 켜지는 속도 느림대는 선재연결 요청 위치 이동 없음 연락 후 방문회선 단말특이사 진단 결과
# 요약 :  ['요청 위치 이동', '대는 선재 연결', '선재 연결 요청']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 당일 예약 취소 건 있으면 방문해달라 심확답불가 일시시대 수신불올인 홈 정상포트리셋리 부팅 안내함
# 요약 :  ['포트 리셋 부팅', '독촉 당일 예약', '당일 예약 취소']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 수신불회선 단말특이사 진단 결과
# 요약 :  ['접수 회선 단말', '리셋 접수 회선', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '단말 특이 진단', '진단 결과']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과 비정상 기 타 추가 연락처
# 요약 :  ['회선 단말 특이', '비정상 추가', '추가 연락처']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉   시청 불스트링에러 포트리셋 회선 꼼꼼 점검 요청 세탑교체 수시 발행 불만 회선단말특이사 진단 결과 시험불기 타 추가 연락처
# 요약 :  ['점검 요청 교체', '교체 수시 발행', '독촉 시청 스트']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 극심   수신불회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '단말 특이 진단', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무   지니 사용 대 서비스 시작 중 문구에서 안 넘어간 다함 장비 재부팅 안내 배정시 미리 연 후방
# 요약 :  ['배정 미리', '안내 배정 미리', '넘어간 장비 재부팅']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불자연회복됨
# 요약 :  ['수신 불자 연회', '수신 불자', '연회 복됨']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 시간 내 외 리콜 안내   수신불회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '리셋 접수 시간', '리콜 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  빠른 방문 요청함임의회선티비수 신불주소 확인회선 단말특이사 진단 결과
# 요약 :  ['티비 주소 확인', '빠른 방문 요청', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시 처음 채널 만 나오고 채널 변경 안됨재부팅 확인함
# 요약 :  ['처음 채널', '채널 나오고 채널', '처음 채널 나오고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  추가일 오전 시시 방문 안내함 신미약
# 요약 :  ['추가 오전', '오전 시시 방문', '오전 시시']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 불기가 지니 전원 접촉 불량회선 단말특이사 진단 결과
# 요약 :  ['지니 전원 접촉', '불기 지니', '시청 불기']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수로딩 중 나오면서 수신불시간 내 외 안내회선 단말특이사 진단 결과
# 요약 :  ['로딩 나오면서', '리셋 접수 로딩', '로딩 나오면서 불시']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 전원 녹색 불에서 변동안됨연 후방 회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '단말 특이 진단', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무   임의회선이상회선 단말특이사 진단 결과
# 요약 :  ['코로나 상무 임의', '이상 회선 단말', '회선 이상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  셋 탑 전원안 들어 옴회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['들어 회선', '단말 특이', '정상기 추가 연락처']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 안내함 화면 안 나오면서 줄이 생긴 다함 재부팅 요망
# 요약 :  ['생긴 재부팅 요망', '일시 화면 나오면서', '나오면서 줄이 생긴']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  긴급 독촉 심함 차리셋 후 동일 빠른 방문원함 업무용 당일 취소 건 있을 경우 우선 방문원함  리셋 접수 수신 불리셋 회선 단말특이사 진단 결과
# 요약 :  ['독촉 심함 리셋', '빠른 방문 원함', '업무 당일 취소']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불인터넷 연결 상태 확인 메세지 접수 중 정상 사용됨회선 단말특이사 진단 결과
# 요약 :  ['접수 정상 사용', '연결 상태 확인', '메세지 접수 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불 외부 신고함
# 요약 :  ['외부 고함', '수신 외부 고함', '수신 외부']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시시 수신불올인 홈 정상포트리셋리 부팅 안내함
# 요약 :  ['정상 포트', '정상 포트 리셋', '시시 올인']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  자연회복회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '진단 결과', '회복 회선']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  장비 장애 안내
# 요약 :  ['장애 안내', '장비 장애', '장비 장애 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  화질이 상장비리셋 안내 후 정상회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['정상기 추가 연락처', '리셋 안내', '화질 장비 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  셋탑박스 전원선을 뺐다 꼽아야 전원이 켜진다고 함 연락 후 방문회선 단말 특이사 진단 결과
# 요약 :  ['전원 켜진다고 연락', '셋탑박스 원선 뺐다', '꼽아 전원 켜진다고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티비끊김회선 단말특이사 진단 결과
# 요약 :  ['끊김 회선 단말', '진단 결과', '단말 특이 진단']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불장 비리셋 동일회선단말특이사 진단 결과 비정상기 타 추가 연락처
# 요약 :  ['단말 특이', '비정 상기 추가', '추가 연락처']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 대중대 안됨수신 불신 없음 전원 선재부팅 후 동일
# 요약 :  ['전원 선재', '전원 선재 부팅', '일시 대중 안됨수신']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '단말 특이 진단', '진단 결과']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  전원이 상수동으로도 작동안됨 녹색 불이 안 들어 옴임의회선 최대한 빠른 방문 요청하심회선 단말특이사 진단 결과
# 요약 :  ['임의 회선 최대한', '최대한 빠른 방문', '회선 최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불대는 고장으로 확인 안됨회 선 구분 어려워 임의 접수함회선 단말특이사 진단 결과  연후방
# 요약 :  ['임의 접수 회선', '안됨 구분 어려워', '구분 어려워']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '단말 특이 진단', '진단 결과']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 불줄생 김 시청 중멈춤 반복됨 포트리셋 일정 점검했는데도 동일회선 단말특이사 진단 결과
# 요약 :  ['점검 했는데도', '점검 했는데도 동일', '했는데도 동일 회선']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불리모컨 작동 불가로 같이 점검 요청회선 단말특이사 진단 결과
# 요약 :  ['점검 요청', '작동 불가 같이', '점검 요청 회선']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나무   실시간 시청은 되나지니 음성 출시 인터넷 연결에 러 뜸 회선 단말 특이사 방문 전 연락원 함 진단 결과
# 요약 :  ['실시간 시청 되나지니', '단말 특이 방문', '되나지니 음성 출시']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 불로딩 중 포트리셋 회선 단말특이사 진단 결과 시험불기 타 추가 연락처
# 요약 :  ['단말 특이', '시청 로딩', '추가 연락처']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임의수신 불리셋
# 요약 :  ['수신 리셋', '임의 수신', '임의 수신 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '단말 특이 진단', '진단 결과']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  고령자 오전 취소 건 있을 경우 우선 방문 원함 독촉심함 차리셋 후 동일 빠른 방문원함리셋 접수시간 내외 리콜 안내   수신불회선 단말특이사 진단 결과
# 요약 :  ['독촉 심함 리셋', '내외 리콜 안내', '빠른 방문 원함']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  부주의 쥐가 선을 갉았다고 하심 회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['정상기 추가 연락처', '갉았다고 회선 단말', '부주의 갉았다고 회선']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  취소 건 있으면 당겨서 점검   시청 불리셋코로나무 미리 연락요회선 단말특이사 진단 결과
# 요약 :  ['당겨서 점검 시청', '취소 있으면', '취소 있으면 당겨서']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 수신 불리셋 회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '리셋 접수', '접수 수신 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  원리모컨 파손 구매 접수 및 통합설정 페어링 설정 문자 발송
# 요약 :  ['구매 접수 통합', '접수 통합 설정', '설정 문자 발송']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  김현철 채팅셋 탑 작동 이상 댁내셋탑대가 모두 자동으로 꺼졌다 켜진다고 함접수는 보류 요청함
# 요약 :  ['셋탑 모두 자동', '김현철 채팅', '작동 이상 셋탑']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 불외부 입력 설정 시청 안 됨셋탑리셋회선단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['설정 시청', '시청 외부 입력', '정상기 추가 연락처']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임 의회 선 선 연결 요청 방문점검 요청회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['요청 방문 점검', '추가 연락처', '정상기 추가 연락처']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임의 수신 불주소 확인회선 단말특이사 진단 결과
# 요약 :  ['확인 회선 단말', '단말 특이', '수신 주소 확인']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임의 수신 불 연락 후 방문회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '임의 수신 연락', '수신 연락 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불선 끊김
# 요약 :  ['수신 불선', '불선 끊김', '수신 불선 끊김']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  부팅 중멈춤 셋탑을 교체해 달라고 요청하 심회선 단말특이사 진단 결과
# 요약 :  ['달라 요청 회선', '교체 달라', '셋탑 교체 달라']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 영상 안 나옴 음성 정상
# 요약 :  ['나옴 음성', '영상 나옴', '음성 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  청소 후 화면 정상 음성안 나옴셋탑리셋 안내외부라고 접수해 달라 심회선 단말특이사 진단 결과
# 요약 :  ['정상 음성 나옴', '라고 접수 달라', '리셋 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 시간 내 외 리콜 안내   수신불회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '리셋 접수 시간', '리콜 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  추가일 오후 방문 안내함 음성이상 음성 송출됨셋탑재 부팅해도 동일 증상
# 요약 :  ['부팅 해도 동일', '탑재 부팅 해도', '음성 송출됨 탑재']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임의 화면 안나 옴 문제인 지 리모컨 문제인 지 점검 요청
# 요약 :  ['점검 요청', '임의 화면 안나', '안나 문제 리모컨']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '단말 특이 진단', '진단 결과']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  부재중이라 들어가서 하시면 된다며 연락 먼저 달라 함영상끊김 흔들림 연락 후 방문회선 단말특이사 진단 결과
# 요약 :  ['먼저 달라 영상', '된다며 연락 먼저', '들어가서 하시면 된다며']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티비인됨 케이블 연결 상태 오류 뜸 녹색 외부 입력 확인함 빠른 점검요
# 요약 :  ['외부 입력 확인', '입력 확인 빠른', '빠른 점검']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 불신없음기가 지니 외부 입력 후 동일기가 지니리셋 후 사용됨회선 단말특이사 진단 결과
# 요약 :  ['시청 불신 음기', '입력 일기', '리셋 사용']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일리셋 수신 불리셋
# 요약 :  ['수신 리셋', '리셋 수신', '리셋 수신 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불 연락 후 방문회선 단말특이사 진단 결과
# 요약 :  ['방문 회선 단말', '방문 회선', '연락 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  차리셋 후 동일 빠른 방문원함 잦은 고장 불만 꼼꼼하게 점검 요청 지난번 다녀간 엔지니어 말고 기술 뛰어난 엔지니어 방문원함 민원심함  리셋 접수 수신불회선 단말특이사 진단 결과
# 요약 :  ['말고 기술 뛰어난', '불만 꼼꼼하게', '불만 꼼꼼하게 점검']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필   티비수 신불회선 단말특이사 최대한 빠른 방문 희망매장 인터넷 진단 결과
# 요약 :  ['특이 최대한 빠른', '단말 특이', '방문 희망 매장']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 시청 불수신 미약회선 단말특이사 진단 결과
# 요약 :  ['시청 불수신 미약', '단말 특이', '리셋 시청']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불셋탑리셋동일회선단말특이사 진단 결과
# 요약 :  ['불셋탑 리셋', '리셋 동일', '수신 불셋탑 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨지참까지 해서 방문 요청함 추가일 오전 시시 방문 안내함수 신불 화면 안나 옴셋탑재 부팅해도 동일 증상 언급
# 요약 :  ['탑재 부팅 해도', '부팅 해도 동일', '참까지 해서 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  아트빌 수신불시 방문 요청 외부 회선 단말특이사 임의 코로나 이상무진단 결과
# 요약 :  ['요청 외부 회선', '임의 코로나 이상무', '방문 요청 외부']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 잘못 건드리고 수신 불회선 단말특이사 진단 결과  엔지니어 확인되면 연락 먼저 요청
# 요약 :  ['잘못 건드리고 수신', '연락 먼저 요청', '되면 연락 먼저']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 불화면 깨짐 연결오류셋 탑리셋 회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['추가 연락처', '깨짐 연결 오류', '시청 불화 깨짐']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필   회선 단말특이사 임의회선작은 방 진단 결과 정상기 타 추가 연락처인
# 요약 :  ['단말 특이', '회선 작은', '추가 연락처']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필   리모컨 버튼 누르면 초 뒤에 반응함 모뎀 셋톱재부팅해도 동일 현상 반복 방문 점검 요청회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['리모컨 버튼 누르면', '점검 요청 회선', '모뎀 셋톱 재부팅']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 시간 전후 안내화면 정상 음성안 나옴회선 단말특이사 진단 결과
# 요약 :  ['리셋 시간 전후', '안내 화면 정상', '정상 음성 나옴']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  유투브랑넷플릭스 안됨작은 방 노트북도 같이 안됨연 후방 회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '노트북 같이 안됨', '작은 노트북 같이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티비전부 안됨 빠른 점검 요인입
# 요약 :  ['티비 전부 안됨', '빠른 점검', '전부 안됨 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  취소 건 있을 시 챙겨서 방문 요청 독촉 코로나 이 상무재확인 필티 수신 불바코드 확인회선 단말특이사 진단 결과
# 요약 :  ['취소 있을 챙겨서', '필티 수신 바코드', '요청 독촉 코로나']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시시로 수신불회선 단말특이사 진단 결과
# 요약 :  ['시시 회선 단말', '진단 결과', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  차리셋 후 동일 빠른 방문원함 당일 취소 건 있을 경우 우선 방문 원함리셋 접수시간 내외 리콜 안내   수신불회선 단말특이사 진단 결과
# 요약 :  ['원함 리셋', '빠른 방문 원함', '있을 경우 우선']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수시간 화질이상 화면 계속 끊어짐 회선 단말특이사 진단 결과
# 요약 :  ['이상 화면', '끊어짐 회선 단말', '리셋 접수 시간']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티비교체 이후 티비수 신불주소 확인회선 단말특이사 진단 결과
# 요약 :  ['주소 확인 회선', '이후 티비 주소', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필   수신 불화면 안나옴회선 단말특이사 진단 결과 정상기 타 추가 연락처인
# 요약 :  ['코로나 상무 확인', '추가 연락처', '수신 불화 나옴']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 중 끊김 연후방 회선 단말특이사 진단 결과
# 요약 :  ['끊김 후방', '회선 단말 특이', '시청 끊김 후방']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  차리셋 후 동일부 재중이더라도 방문 요청 연락 주면 비번 확인해주신다고 함  리셋 접수로딩 중 나오면서 수신불시간 내 외 안내회선 단말특이사 진단 결과
# 요약 :  ['로딩 나오면서 불시', '해주신다고 리셋 접수', '비번 확인 해주신다고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필   티비셋 탑 전원 안 들어 옴회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['정상기 추가 연락처', '들어 회선', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필   볼륨이 상 방문점검요회선단말특이사 진단 결과
# 요약 :  ['확인 볼륨', '코로나 상무 확인', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  기가 지니리모컨 작동 불매장 안내
# 요약 :  ['지니 리모컨 작동', '지니 리모컨', '불매 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필티 수신 불인터넷 연결 불회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['코로나 상무 확인', '추가 연락처', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 시청 불셋 탑재 부팅해 보라 안내
# 요약 :  ['불셋 탑재', '일시 시청', '부팅 보라']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  빠른 방문 요청함 화질이 상장비리셋 이후 동일주소 확인회선 단말특이사 진단 결과
# 요약 :  ['이후 동일 주소', '방문 요청 화질', '화질 장비 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티비끊김회선 단말특이사 진단 결과
# 요약 :  ['끊김 회선 단말', '진단 결과', '단말 특이 진단']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무   인터넷 연결오유회선 단말특이사 진단 결과
# 요약 :  ['회선 단말 특이', '코로나 상무', '단말 특이 진단']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  봇  기가 지니 응답문의 리셋 진행회선 단말특이사 진단 결과 정상기 타 추가 연락처인
# 요약 :  ['추가 연락처', '지니 응답 문의', '문의 리셋 진행']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시대 모두 안됨재부팅 확인함
# 요약 :  ['재부팅 확인', '모두 안됨 재부팅', '시대 모두']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티비수 신불연 후방 회선 단말특이사 진단 결과
# 요약 :  ['진단 결과', '단말 특이 진단', '회선 단말']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 수신 불리셋 회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '리셋 접수', '접수 수신 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임의회 선셋탑 전원안 들어 옴 연락 후회선 단말특이사 진단 결과
# 요약 :  ['연락 회선 단말', '원안 들어 연락', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불셋탑 정상이나 초록빛으로 뜨고 안 나 옴셋탑재 부팅 후 정상회선 단말특이사 진단 결과
# 요약 :  ['부팅 정상 회선', '뜨고 옴셋 탑재', '수신 불셋탑 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 시간 내 외 리콜 안내   수신불회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '리셋 접수 시간', '리콜 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  지니시청 불대만 안됨엔지니어 접수해 놓으라고 했다 함 방문 전 연락 요청회 선 단말특이사 코로나 이 상무진단 결과
# 요약 :  ['했다 방문 연락', '시청 대만 안됨', '접수 놓으라고 했다']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  채널 전환 지연셋탑 점검 후 교체 요청 방문 전 연락요회선 단말특이사 진단 결과
# 요약 :  ['연락 회선 단말', '교체 요청 방문', '셋탑 점검 교체']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 불가 모든 버튼 사용 안됨 건전지 교체 이후 동일주소 확인 무료 배송 등록함회선 단말특이사 진단 결과
# 요약 :  ['주소 확인 무료', '이후 동일 주소', '배송 등록']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 대중 어머님 방티비 안됨 화면에 업그레이드합니다오류만 떠서 사라지지 않는 다심재부팅해도 안 됨
# 요약 :  ['않는 다심 재부팅', '떠서 사라지지 않는', '다심 재부팅 해도']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 고장까지 같이 점검 요청 함 추가일 오전 시시 방문 안내함 메뉴 실행 불가 네트워크 오류 송출됨 안됨 링크 비정상 확인됨
# 요약 :  ['같이 점검 요청', '까지 같이', '요청 추가 오전']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필   티비시청 불모뎀 셋톱재부팅해도 동일 현상 반복 방문점검 요청회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['방문 점검 요청', '시청 모뎀 셋톱', '셋톱 재부팅 해도']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['결과 정상기 추가', '단말 특이', '추가 연락처']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임 의회 선  세탑 작동 이상회선 단말특이사 진단 결과
# 요약 :  ['회선 단말 특이', '작동 이상 회선', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필   시청 불네트워크 오류 전체 리셋안내회선 단말특이사 진단 결과 모뎀 정상기 타 추가 연락처인
# 요약 :  ['단말 특이', '리셋 안내', '정상기 추가 연락처']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 중 화면 고정셋탑리셋동일회선 단말특이사 진단 결과
# 요약 :  ['수신 화면 고정', '리셋 동일 회선', '고정 셋탑 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불임의회선 접수 바코드 확인 안됨회선 단말특이사 진단 결과
# 요약 :  ['접수 바코드 확인', '회선 접수', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 불음성안 나온다고 하고 기가 지니리셋 후안됨회선 단말특이사 진단 결과
# 요약 :  ['성안 나온다고', '나온다고 하고 지니', '불음 성안 나온다고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무   얼마 전 리모컨 분실하여 새로 구매했는데 택배로 받으심 통합설정안 먹는다 하심 설정방법대로 확인 후 해봐도 동일하다 함수 동 방법동일 방문점검 요배정시 미리 연 후방 회선 단말특이사 대우기 타 추가 연락처
# 요약 :  ['대로 확인 해봐도', '상무 얼마 리모컨', '했는데 택배 받으']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 시 음성이상 화면 정상 음성안 나 옴재부팅해 봤다 심
# 요약 :  ['일시 음성', '음성 이상 화면', '재부팅 봤다']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불주소 확인회선 단말특이사 진단 결과
# 요약 :  ['확인 회선 단말', '수신 주소 확인', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  김현철 채팅셋 탑 작동 이상 고장 접수 함   댁내 셋탑대가 모두 저절로 꺼졌다 켜졌다 한다고 함셋탑에 자동 전원 설정은 안 되어 있다고 함연 후방 회선 단말특이사 진단 결과
# 요약 :  ['김현철 채팅', '함셋탑 자동', '함셋탑 자동 전원']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필 모니터 재설치 후 수신 불 연락 후 빠른 방문요회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['연락 빠른', '추가 연락처', '설치 수신 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 영업장 빠른 방문 요청   네트워크 오류도 접속 불회선 단말특이사 진단 결과 비정상 기 타 추가 연락처
# 요약 :  ['단말 특이', '영업 빠른 방문', '독촉 영업 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무   대 모두 인터넷 연결오유뜸 신비정상회선 단말특이사 진단 결과
# 요약 :  ['연결 오유', '코로나 상무', '단말 특이 진단']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필   티비수 신불회선 단말특이사 두 대다수 신불리셋 후에도 수신 불진단 결과 정상신기 타 추가 연락처
# 요약 :  ['추가 연락처', '정상 신기 추가', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불셋탑리셋동일회선단말특이사 진단 결과
# 요약 :  ['불셋탑 리셋', '리셋 동일', '수신 불셋탑 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 수신 불리셋 회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '리셋 접수', '접수 수신 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무    안내실임의회 선수신불인 입회선단말특이사 진단 결과
# 요약 :  ['선수 입회', '선단 특이 진단', '입회 선단 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불안 방안됨이 병인 직원 보내지 마라고함
# 요약 :  ['보내지 마라 고함', '직원 보내지', '병인 직원 보내지']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수로딩 증 상태로 수신불회선 단말특이사 진단 결과
# 요약 :  ['로딩 상태', '접수 로딩 상태', '리셋 접수 로딩']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임 의회 선  수신불회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '단말 특이 진단', '진단 결과']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  최대한 늦게 방문 요청리모컨 작동 불전원 깜빡거리면서 소리 난다며 교체 요청연 후방 회선 단말특이사 진단 결과
# 요약 :  ['면서 소리 난다며', '요청 리모컨', '최대한 늦게 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과  연후방
# 요약 :  ['단말 특이 진단', '회선 단말', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 중 음성이 상장비리셋 회선 단말특이사 진단 결과
# 요약 :  ['장비 리셋', '장비 리셋 회선', '수신 음성']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  최대한 빠른 점검요일 시신 미약 오류뜨면서 시청불
# 요약 :  ['오류 뜨면서 시청', '뜨면서 시청', '미약 오류 뜨면서']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 전환 지연회선 단말특이사 진단 결과
# 요약 :  ['지연 회선', '리모컨 전환', '회선 단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시기가 지니리모컨 일부 버튼 작동 불재부팅해도 안 됨
# 요약 :  ['버튼 작동', '시기 지니 리모컨', '시기 지니']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과
# ...
# 요약 :  ['계속 그렇다고 코로나', '추가 연락처', '끊김 태풍 오고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨기가 지니리모콘 작동 불배터리 방전이 빨리 된다고 함 교체해봐도 동일 택배 교체 요청 전 송 후 등록함
# 요약 :  ['빨리 된다고 교체', '해봐도 동일 택배', '된다고 교체 해봐도']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  화면이 시청 중 꺼졌다 켜졌다 반복됨 잦은 고장 꼼꼼하게 점검 요청회선 단말특이사 진단 결과
# 요약 :  ['고장 꼼꼼하게 점검', '켜졌다 반복 잦은', '잦은 고장 꼼꼼하게']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 일부 버튼 작동 불회선 단말특이사 진단 결과
# 요약 :  ['일부 버튼 작동', '작동 회선 단말', '리모컨 일부']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필  기가 지니리모컨 너무 뜨거워서 교체 요청회 선 단말특이사 진단 결과
# 요약 :  ['너무 뜨거워서', '지니 리모컨 너무', '너무 뜨거워서 교체']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임의   수신 불주인 분 대리신고 정확한 회선 고장 상태 확인 불회선 단말특이사 진단 결과 공동회선  일시 접수
# 요약 :  ['고장 상태 확인', '일시 접수', '회선 일시 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  오후 수신 불로 딩중올인 홈 정상리셋 약정기간 문의하여 전환
# 요약 :  ['기간 문의', '딩중올 정상', '딩중올 정상 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필   수신 불화면 안나옴회선 단말특이사 진단 결과 정상기 타 추가 연락처 요청인
# 요약 :  ['정상기 추가 연락처', '추가 연락처 요청', '수신 불화 나옴']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  멀고 객  수신불연결이 원활하지 않다고 뜬다심연 후방코로나무 회선 단말특이사 진단 결과
# 요약 :  ['회선 단말 특이', '심연 후방 코로', '원활하지 않다고 뜬다']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 중 화면 깨짐 회선 단말특이사 진단 결과
# 요약 :  ['회선 단말 특이', '시청 화면 깨짐', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  기가 지니 음성인식 불외부 신고 방문 점검 요청회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '음성인식 외부 신고', '외부 신고 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티수신불회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '진단 결과', '단말 특이 진단']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불 연락 후회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '회선 단말 특이', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 고장 고정 셋탑 변경 진행 중 되어 있음 안내하니 보류
# 요약 :  ['하니 보류', '있음 안내', '안내 하니 보류']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 최대 당겨 점검요시청 불어른 신만계시는 곳이라 빠른 방문 요청함회선 단말특이사 진단 결과 비정상기 타 추가 연락처
# 요약 :  ['독촉 최대 당겨', '빠른 방문 요청', '상기 추가 연락처']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 고장 배터리 교체 후에도 사용 불가 침수 파손이력 없다고 함엔지니 어 방문 점검 요청 고장 시 교체 요청회 선 단말특이사 기본 티비기가 지니 진단 결과
# 요약 :  ['지니 방문 점검', '지니 진단 결과', '이력 없다고 지니']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  용수평   세입자 이사 재연결 요청회선 단말특이사 진단 결과
# 요약 :  ['연결 요청 회선', '요청 회선 단말', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  본인인 티장비 회수 요청 당분간 정지되고 현재 장소 건물 부신다고 우선 장비 회수 요청하심 연락 바랍니다
# 요약 :  ['부신다고 우선', '장소 건물 부신다고', '건물 부신다고 우선']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 시시작동 불작동안 될 때 건전지 확인 함택배 요청 등록 리모컨
# 요약 :  ['작동 작동 건전지', '등록 리모컨', '택배 요청 등록']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  기가 지니 음성인식 안됨 셋탑재 부팅 음성인식 차단 해제 후 정상 ㅇ네 소리에서 띵소리 변경됨 안내
# 요약 :  ['탑재 부팅', '부팅 음성인식 차단', '탑재 부팅 음성인식']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나무   지상파만 시청되고 다른 채널은 시청 안됨 셋탑리셋 회선 단말특이사 진단 결과
# 요약 :  ['다른 채널 시청', '시청 안됨 셋탑', '지상파 시청 되고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋티비수 신불회선 단말특이사 진단 결과
# 요약 :  ['단말 특이 진단', '진단 결과', '회선 단말']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  사용 불가 안 켜짐 연후방코로나무 연 후방 회선 단말특이사 진단 결과
# 요약 :  ['켜짐 후방', '단말 특이', '불가 켜짐 후방']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티수신 불신 정상리셋안내현재 집에 없어 추후 시도 후 안 될 시 연락주시기로 함회 선 단말 특이사 진단 결과
# 요약 :  ['연락 주시기로 함회', '시도 연락 주시기로', '정상 리셋 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티비수 신불회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['결과 정상기 추가', '추가 연락처', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  요청 시간   수신불 연락 후회선 단말특이사 진단 결과
# 요약 :  ['연락 회선 단말', '단말 특이', '요청 시간 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  차리셋해도 동일 인터넷 연결오류 잦은 고장 불만 지연 불만 독촉 연락 후 방문요  리셋 접수 수신 불리셋 회선 단말특이사 진단 결과
# 요약 :  ['접수 수신 리셋', '방문 리셋 접수', '연결 오류 잦은']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필   티비수 신불회선 단말특이사 세입자 임의진단 결과 정상신기 타 추가 연락처
# 요약 :  ['상무 확인 티비', '추가 연락처', '정상 신기 추가']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티수신불회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '진단 결과', '단말 특이 진단']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  외부 신고지니 전원 버튼 고장 작동 이 상주 전원 버튼 튕겨져 나옴회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['신고 지니 전원', '튕겨져 나옴 회선', '전원 버튼 튕겨져']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  대선 분리 후 시청 불위치 변경 무회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '시청 위치 변경', '대선 분리 시청']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티접불회선 단말특이사 진단 결과
# 요약 :  ['진단 결과', '단말 특이 진단', '티접불 회선 단말']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  회선 단말특이사 진단 결과
# 요약 :  ['단말 특이 진단', '회선 단말', '진단 결과']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 일부 버튼 인식 잘 안됨 건전지 교체해 봄 안 될 때 소등택배 등록 리모컨
# 요약 :  ['소등 택배 등록', '인식 안됨 건전지', '택배 등록 리모컨']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티접속 불회선 전 부회선단말특이사 진단 결과
# 요약 :  ['접속 회선', '선단 특이', '선단 특이 진단']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '단말 특이 진단', '진단 결과']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나무기가 지니작동 불임의회선리셋 후 동일 방문 전선 연락회선 단말특이사 진단 결과
# 요약 :  ['회선 단말 특이', '코로나 무기 지니', '지니 작동 불임']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  대안방쪽 연결 잘 안 되고 색감 안 좋다고 함자가 격리 중으로 보류
# 요약 :  ['안방 연결', '연결 되고', '색감 좋다고 함자']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  대 모두 수신 불연 후방
# 요약 :  ['불연 후방', '수신 불연 후방', '모두 수신']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  되도록 늦은 방문 요청회 선 단말특이사 안방셋탑고장와이파이 연결 팝업진단 결과
# 요약 :  ['되도록 늦은', '방문 요청 단말', '요청 단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  부팅 중 오류 메세지회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['정상기 추가', '부팅 오류 메세지', '정상기 추가 연락처']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필   티 전원이 꺼짐 회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['코로나 상무 확인', '단말 특이', '추가 연락처']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  기가 지니리모컨 작동 불전원 버튼부터 채널버튼 등 다 안됨 불안 들어 옴건전지 교체해도 안됨 점검 요청회선 단말특이사 진단 결과
# 요약 :  ['해도 안됨 점검', '불안 들어 건전지', '건전지 교체 해도']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  대만 시청 중 끊김 현상점검 요청회선 단말특이사 진단 결과
# 요약 :  ['점검 요청 회선', '단말 특이', '대만 시청 끊김']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  무출동   리모컨 작동 불모든 버튼 안됨택배 배송 요청하여 처리 함회선 단말특이사 진단 결과
# 요약 :  ['불모 버튼 안됨', '배송 요청 하여', '택배 배송 요청']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 파손 배송 요청 본인 문자 발송 통합설정 문자 발송회선 단말특이사 진단 결과
# 요약 :  ['파손 배송 요청', '설정 문자 발송', '문자 발송 통합']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  셋탑이상 셋탑이 자꾸 다운됨연 후방 회선 단말특이사 진단 결과
# 요약 :  ['셋탑 자꾸', '단말 특이', '이상 셋탑']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 시간 내 외 리콜 안내   수신불회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '리셋 접수 시간', '리콜 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  회선 단말특이사 진단 결과  코로나 이 상무재확인 필기가 지니 수신 불리모컨 상세 점검 요청
# 요약 :  ['필기 지니 수신', '결과 코로나 상무', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  추티수신불회선 단말특이사 진단 결과
# 요약 :  ['단말 특이 진단', '추티 회선', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불 방문 전 연락요회선 단말특이사 진단 결과
# 요약 :  ['방문 연락', '연락 회선 단말', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시안됨재부팅해도 안 됨
# 요약 :  ['시안 재부팅', '시안 재부팅 해도', '재부팅 해도']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시시수신 불잦은 고장불만근본적인 해결 요청회선 단말특이사 진단 결과
# 요약 :  ['특이 진단', '수신 잦은', '진단 결과']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  멀티 수신 불리모컨 점검요올인 홈 정상리셋 동일연 후방 회선 단말특이사 진단 결과
# 요약 :  ['단말 특이', '점검 올인 정상', '리모컨 점검 올인']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  셋탑이상리셋 후 동일연 후방 회선 단말특이사 진단 결과
# 요약 :  ['리셋 일연 후방', '회선 단말 특이', '셋탑 이상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 불가농성동쪽도 교체 요청 매장 안내회선 단말특이사 진단 결과
# 요약 :  ['요청 매장', '매장 안내 회선', '요청 매장 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불셋탑박스 미설치 동시 점검 요청회선 단말특이사 진단 결과 정상시험 안됨  코로나 안내유료화 안내
# 요약 :  ['단말 특이', '안내 유료 안내', '셋탑박스 설치 동시']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  랜선 길게 연결 요청 댁내 이전 필요할 수도 있다고 안내드림회선 단말특이사 진단 결과
# 요약 :  ['수도 있다고', '이전 필요할 수도', '수도 있다고 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  멀코로나무셋톱 분실기가 지니 분실 보상금 발생 안내 오후 늦은 방문 요청   회선 단말특이사 진단 결과
# 요약 :  ['지니 분실 보상금', '안내 오후 늦은', '보상금 발생 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불량 넷플릭스 방문 전 연락 요청함 코로나무 회선 단말특이사 진단 결과
# 요약 :  ['방문 연락 요청', '넷플릭스 방문 연락', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신불회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '단말 특이 진단', '진단 결과']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일리셋이 관추가 티수신 불 상태 리모컨 불량인지도 확인 어렵다 함리셋 안내리셋해보고 접수한 다심회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['확인 어렵다', '인지도 확인 어렵다', '어렵다 리셋 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 불가리모컨 건전지 교체해도 동일함 지점 안내 받았으나 거절 택배 배송 등록함 통화 중 끊김 오비 진행 연락처 확인함 회선 단말특이사 진단 결과
# 요약 :  ['안내 받았으나 거절', '오비 진행 연락처', '건전지 교체 해도']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  월일시큰방에 설치된 셋 탑 선재 연결
# 요약 :  ['선재 연결', '일시 설치', '일시 설치 선재']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불네트워크 이상 구간 빨간불 장비리셋 동일회선 단말특이사 진단 결과
# 요약 :  ['리셋 동일', '빨간 장비 리셋', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  멀고 객  리모컨 깨짐 등록 전송회선 단말특이사 진단 결과  최지영
# 요약 :  ['회선 단말 특이', '깨짐 등록 전송', '진단 결과 최지영']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  명절 전에 아래 내용으로 요청했는데 아직도 조치 안 되어져 있어 불만이십니다 빠른 조치 요청하십니다 주소 강원도 원주시 귀래면 북원로 연락처 요청자 김정태 요청 내용 외부 인터넷선이나무에 칭칭감겨서 있다고 함 올라갈 수가 없다며 나와서 선정리해달라심
# 요약 :  ['칭칭 감겨 있다고', '김정태 요청 내용', '조치 요청 하십니다']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나무   세입자가 나가고 다른 세입자 받을려고 하니 연결선이 빠져 있다며 방문하여 연결 요청임의회선 접수회선 단말특이사 진단 결과
# 요약 :  ['하니 결선 빠져', '요청 임의 회선', '받을려고 하니']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  배송 접수 리모컨 작동 불등록해 드림
# 요약 :  ['작동 등록 드림', '배송 접수', '배송 접수 리모컨']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임의 수신 불주소 확인회선 단말특이사 진단 결과
# 요약 :  ['확인 회선 단말', '단말 특이', '수신 주소 확인']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티 시청 안됨 리모컨 작동안됨회선단말특이사 진단 결과
# 요약 :  ['회선 단말 특이', '작동 안됨 회선', '시청 안됨']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필   리모컨 교체기자니 지회선 단말특이사 진단 결과 인
# 요약 :  ['확인 리모컨', '코로나 상무 확인', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  작동 이상 지니주 전원 빨간불에서 흰불로 안 바뀜리셋 후 동일회선 단말특이사 진단 결과 정상기 타 추가 연락처
# 요약 :  ['작동 이상 지니주', '추가 연락처', '바뀜 리셋 동일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무재확인 필   티끊김회선 단말특이사 진단 결과
# 요약 :  ['확인 끊김', '확인 끊김 회선', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 불회선 단말특이사 진단 결과
# 요약 :  ['회선 단말', '시청 회선', '단말 특이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  장애 안내드림
# 요약 :  ['안내 드림', '장애 안내', '장애 안내 드림']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시수신 불셋 탑재 부팅인 입권유시  선 종료
# 요약 :  ['부팅 유시', '수신 불셋 탑재', '탑재 부팅 유시']
# ----------------------------------------------------------

# %%
df['sentence']

# %%
abstract_sen

# %% [markdown]
# ## Max Sum Similarity
# 데이터 쌍 사이의 최대 합 거리는 데이터 쌍 간의 거리가 최대화되는 데이터 쌍으로 정의됩니다. 여기서의 의도는 후보 간의 유사성을 최소화하면서 문서와의 후보 유사성을 극대화하고자 하는 것입니다.
