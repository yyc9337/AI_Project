# %% [markdown]
# # Abstract
# #### Setting
#
#         1. 1차 정제 데이터인 CAI_data_001.csv  데이터를 사용하여 2차 전처리 진행
#         2. 토큰화, 불용어 처리
#         3. 사전(vocab) word_to_index 구성
#         4. 문장 통계 분석 및 시각화
#         5. 모델링
#
# #### Method
#
#         1. VOC 유형 중 depth_1 유형을 예측하는 모델
#         2. model 폴더에 .h5파일로 모델 저장
#         3. 다른 모델(Kobert, Roberta)도 적용 예정
#
# #### Result
#         사용 모델 : LSTM
#                     loss: 0.5791 - accuracy: 0.8449

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.sequence import pad_sequences
import os
import tensorflow as tf

import warnings
warnings.filterwarnings('ignore')
import timeit

# 한국어 tokenizer
from konlpy.tag import Okt
tokenizer = Okt()
from collections import Counter

# %%
df = pd.read_csv("../data/dataset/CAI_data_001.csv")
print("df set: {}개".format(len(df)))
# Out:
# df set: 8186개

# %%
df.head(10)
# Out:
#                         Label  \
# 0             원인불명>조치 전 자연 회복
# 1              실시간 채널>네트워크 오류
# 2                실시간 채널>수신 불량
# 3              실시간 채널>네트워크 오류
# 4                실시간 채널>수신 불량
# 5                단말>STB(작동)이상
# 6  단말>STB(부팅) 이상>부팅중 오류메시지 발생
# 7                단말>STB(작동)이상
# 8                실시간 채널>음성 이상
# 9               VOD/컨텐츠>화질 이상
#
#                                             sentence
# 0                              고객 요청사 항 안됨상담 중 자연회복됨
# 1  고객 요청사항 수신불인터넷 연결오류 뜸재부팅해 봄 모텔 영업용 일 중 꼭 점검원하여...
# 2           고객 요청사항 수신불회선 단말특이사항 진단 결과 기타 추가 연락처 연후방
# 3                                 수신 불 네트워크 오류 접수 보류
# 4       고객 요청사항 수신불 연락 후 회선단말특이사항 진단 결과 기타 추가 연락처인 입
# 5  고객 요청사항 채널은 정상 넷플릭스 안됨 포트리셋 미리 연락 후 방문 요망 회선단말...
# 6    고객 요청사항 수신 불 서비스 시작 중 회선 단말특이사항 진단 결과 기타 추가 연락처
# 7  김현철 채팅 지니 자체에서 잡음이 난다고 함고장 접수 함 고객 요청사항 셋탑이상지니...
# 8  고객 요청사항 나오나 따닥거리는 소리가 난다함리셋 후 잘됨회선 단말특이사항 진단 결...
# 9  고객 요청사항 화질 불량 시청 중 멈추는 증상 반복됨 연락 후회선 단말특이사항 진단...

# %% [markdown]
# ## 2차 데이터 전처리

# %% [markdown]
# #### Label 지정 후 정제 (label Encoding) 및 시각화
#
#
# - 첫 실험을 위해 depth_1을 target으로 지정
# - '>' 기호를 기준으로 컬럼을 세개로 나눔

# %%
df['depth_1'] = df.Label.str.split('>').str[0]
df['depth_2'] = df.Label.str.split('>').str[1]
df['depth_3'] = df.Label.str.split('>').str[2]

# %%
# depth_1 시각화

df['depth_1'].value_counts().plot(kind = 'bar')

###폰트 깨짐 방지###
plt.rc('font', family='Gothic')
plt.rcParams['axes.unicode_minus'] = False
###

#수치로 표현
print(df['depth_1'].value_counts())
# Out:
# 실시간 채널       4046
# 단말           2460
# AS접수/변경       817
# 고객원인          547
# VOD/컨텐츠       123
# 원인불명           66
# 장애안내           38
# 양방향서비스         34
# 시설관리           21
# 데이터서비스         19
# 시설이전            7
# 부가/지능망서비스       4
# 지니뮤직            3
# 리콜/손해배상         1
# Name: depth_1, dtype: int64

# %%
# depth_2 시각화

df['depth_2'].value_counts().plot(kind = 'bar')

###폰트 깨짐 방지###
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
###

#수치로 표현
print(df['depth_2'].value_counts())
# Out:
# 수신 불량              2876
# 리모컨작동불가            1376
# STB(작동)이상           770
# 화질 이상               692
# 장비리셋 후 재사용 요청       567
# 부주의, ID/PW 분실 등     418
# 네트워크 오류             326
# 임대단말 분실/파손          196
# STB(부팅) 이상          163
# 음성 이상               137
# 음성인식이상(기가지니)        132
# 증설/구내선 정리요청         101
# 메뉴 실행 불가             83
# 조치 전 자연 회복           66
# 임대단말 회수요청            54
# 전환 지연                34
# 양방향서비스 사용불가          34
# 네트워크장비 장애            27
# 특이고장                 19
# 접속 지연/끊김             19
# 채널편성표 없음             19
# 기타 KT시설(상세메모기입)      16
# 스피커이상(기가지니)           9
# 타사 및 기타 장애            8
# 맨홀/전주/단자함/기타          7
# 전원, 충전 이상             7
# AS보류(유료화)             6
# 이용불가                  4
# 케이블(전송로) 장애           3
# IP 공유기 이상             3
# 지니뮤직이상(기가지니)          3
# 맨홀/전주                 3
# USB포트 인식 불가           3
# PIN 인증 오류             2
# 공사안내                  2
# 피해보상요구                1
# Name: depth_2, dtype: int64

# %%
# depth_3 시각화
df['depth_3'].value_counts().plot(kind = 'bar')

###폰트 깨짐 방지###
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
###

#수치로 표현
print(df['depth_3'].value_counts())
# Out:
# 택배발송              580
# 현장출동              453
# M&S내방안내           212
# 부팅중 오류메시지 발생      151
# 기타문의              131
# 부팅지연(오류메시지 없음)     12
# 이용 불가(유선)           4
# Name: depth_3, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
result = le.fit_transform(df['depth_1'])
print(result)
print(le.classes_)

df['depth_1'] = result
# Out:
# [11  9  9 ...  9  9  3]
# ['AS접수/변경' 'VOD/컨텐츠' '고객원인' '단말' '데이터서비스' '리콜/손해배상' '부가/지능망서비스' '시설관리'
#  '시설이전' '실시간 채널' '양방향서비스' '원인불명' '장애안내' '지니뮤직']

# %%
df.head()
# Out:
#              Label                                           sentence  \
# 0  원인불명>조치 전 자연 회복                             고객 요청사항 호안됨 상담 중 자연회복됨
# 1   실시간 채널>네트워크 오류  고객 요청사항 호수신불인터넷 연결오류 뜸재부팅해 봄 모텔 영업용 일 중 꼭 점검원하...
# 2     실시간 채널>수신 불량          고객 요청사항 호수신불회선 단말특이사항 진단 결과 기타 추가 연락처 연후방
# 3   실시간 채널>네트워크 오류                                 수신 불 네트워크 오류 접수 보류
# 4     실시간 채널>수신 불량       고객 요청사항 수신불 연락 후 회선단말특이사항 진단 결과 기타 추가 연락처인 입
#
#    depth_1     depth_2 depth_3
# 0       11  조치 전 자연 회복     NaN
# 1        9     네트워크 오류     NaN
# 2        9       수신 불량     NaN
# 3        9     네트워크 오류     NaN
# 4        9       수신 불량     NaN

# %% [markdown]
# #### Train, Valid 데이터 셋 나누기

# %%
X = df['sentence']
y = df['depth_1']

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=0)

# %%
X_valid
# Out:
# 757     고객 요청사항 전원 손띄면 꺼짐 스카치 테잎 임의 조치 중 리모컨도 고장 방문 시 ...
# 5015    티비에서 넷플릭스 유튜브 안됨 올인 홈 정상 인터넷 정상 티비 모두 정상으로 확인되...
# 1001    기가 지니에서 넷플릭스 실행 불가 리셋 권 유 고객 외부셔서 진행해 보시고 재연락 ...
# 8422                   일시 수신불 신호 없음 거실 티비 방에티비 번갈아가며 안 나옴
# 5259    고객 요청사항 재연결 해지 복구 임대장비 회수로 인하여 모뎀 및 회수 됨 장비 지 ...
#                               ...
# 7662    차위성 수신 불량 올레 관시청 중 날씨 괜찮을 때도 해당 증상 있다고 점검 요미리 ...
# 4280    고객 요청사항 배우자리모컨 일부 버튼 작동 불교체회선 단말 특이사항 진단 결과 기타...
# 6838                               호 임의 네트워크 오류 셋탑리셋해도 동일
# 4613                                     리모컨 작동안 딤 직영점 안내
# 2573    코로나 이 상무재확인 필 고객 요청사항기가 지니 음성인식 안됨 회선 단말특이사항 진...
# Name: sentence, Length: 1638, dtype: object

# %% [markdown]
# #### 불용어 처리 및 토큰화
#
# - Okt 형태소 분석 도구를 이용하여 단어 토큰화를 진행함.
# - stopwords를 직접 지정하여 제거하고 싶은 글자들을 선택
# - for문을 구성하여 토큰화와 불용어처리를 한번에 진행
# - 만들어야 하는 사전에 최대한 많은 단어를 담아야 하기 때문에 train, valid 나누지 않고 df_train라는 변수에 담음.

# %%
#불용어 지정
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도', '를','으로','자','에',
'와','한','하다','을','에서','해서', '고객 요청사항', '안심권유', '안심권 유']

# %%
df_train = []

for row in df.iterrows() :   
    sentence = tokenizer.morphs(row[1]['sentence']) #단어 토큰화
    sentence = [word for word in sentence if not word in stopwords] #불용어 제거  
     
    df_train.append(sentence)

# %%
df_train[:3]
# Out:
# [['고객', '요청', '사항', '호안', '됨', '상담', '중', '자연', '회복', '됨'],
#  ['고객',
#   '요청',
#   '사항',
#   '호수',
#   '신',
#   '불',
#   '인터넷',
#   '연결',
#   '오류',
#   '뜸',
#   '재부팅',
#   '해',
#   '봄',
#   '모텔',
#   '영업',
#   '용',
#   '일',
#   '중',
#   '꼭',
#   '점검',
#   '원하여',
#   '지',
#   '사이',
#   '관함',
#   '회선',
#   '단말',
#   '특이',
#   '사항',
#   '진단',
#   '결과',
#   '기타',
#   '추가',
#   '연락처'],
#  ['고객',
#   '요청',
#   '사항',
#   '호수',
#   '신',
#   '불',
#   '회선',
#   '단말',
#   '특이',
#   '사항',
#   '진단',
#   '결과',
#   '기타',
#   '추가',
#   '연락처',
#   '연',
#   '후방']]

# %% [markdown]
# #### 사전(vocab) word_to_index 구성 및 스트링 변환
#
# - 다양한 Tokenizer를 활용해서 데이터를 분석하기 위해 문자 데이터를 숫자로 바꿔줘야함
# - Counter를 사용해도 되고, okt Tokenizer로 fit_on_texts를 사용해도 정수 인코딩을 할 수 있음
# - word_to_index는 사전의 크기를 결정하는 인자이다. 따라서 words가 몇개 정도 있는지 보고 그에 따라 사전의 크기를 결정해주면 됨
# - 사전 크기 또한 조절할 수 있는 부분이다. 하지만 너무 크게하면 학습이 느려진다.

# %% [markdown]
# - word_to_index는 key값이 텍스트 스트링이다. 따라서 인덱스 역할을 하는 key값을 숫자이기 때문에 해당 값에서 숫자를 추출하기 위한 함수가 필요하다. => wordlist_to_indexlist

# %%
words = np.concatenate(df_train).tolist()
len(words)
# Out:
# 176526

# %%
vocab_size = 43800
counter = Counter(words)
counter = counter.most_common(vocab_size-4)
vocab = ['<PAD>', '<BOS>', '<UNK>', '<UNUSED>'] + [key for key, _ in counter]

word_to_index = {word:index for index, word in enumerate(vocab)}

# %%
type(word_to_index)
# Out:
# dict

# %%
len(word_to_index)
# Out:
# 5182

# %%
word_to_index
# Out:
# {'<PAD>': 0,
#  '<BOS>': 1,
#  '<UNK>': 2,
#  '<UNUSED>': 3,
#  '사항': 4,
#  '요청': 5,
#  '고객': 6,
#  '추가': 7,
#  '연락처': 8,
#  '진단': 9,
#  '결과': 10,
#  '단말': 11,
#  '특이': 12,
#  '회선': 13,
#  '기타': 14,
#  '불': 15,
#  '리모컨': 16,
#  '리셋': 17,
#  '방문': 18,
#  '수신': 19,
#  '코로나': 20,
#  '확인': 21,
#  '안': 22,
#  '접수': 23,
#  '후': 24,
#  '함': 25,
#  '작동': 26,
#  '안됨': 27,
#  '신': 28,
#  '상무': 29,
#  '시': 30,
#  '안내': 31,
#  '수': 32,
#  '교체': 33,
#  '시청': 34,
#  '재': 35,
#  '정상': 36,
#  '티비': 37,
#  '후방': 38,
#  '타': 39,
#  '연': 40,
#  '필': 41,
#  '선': 42,
#  '화면': 43,
#  '동일': 44,
#  '셋탑': 45,
#  '연락': 46,
#  '점검': 47,
#  '지니': 48,
#  '재부팅': 49,
#  '호': 50,
#  '심': 51,
#  '연결': 52,
#  '기': 53,
#  '일': 54,
#  '정상기': 55,
#  '중': 56,
#  '인': 57,
#  '됨': 58,
#  '대': 59,
#  '채널': 60,
#  '빠른': 61,
#  '하': 62,
#  '이상': 63,
#  '요': 64,
#  '버튼': 65,
#  '전원': 66,
#  '나옴': 67,
#  '임의': 68,
#  '오류': 69,
#  '택배': 70,
#  '사용': 71,
#  '고장': 72,
#  '독촉': 73,
#  '해도': 74,
#  '전': 75,
#  '신호': 76,
#  '만': 77,
#  '등록': 78,
#  '배송': 79,
#  '로': 80,
#  '내': 81,
#  '장비': 82,
#  '다': 83,
#  '건': 84,
#  '외부': 85,
#  '음성': 86,
#  '불가': 87,
#  '인터넷': 88,
#  '없음': 89,
#  '발송': 90,
#  '화질': 91,
#  '최대한': 92,
#  '넷플릭스': 93,
#  '회': 94,
#  '끊김': 95,
#  '신고': 96,
#  '포트': 97,
#  '불량': 98,
#  '문자': 99,
#  '설정': 100,
#  '리모콘': 101,
#  '셋': 102,
#  '보류': 103,
#  '부팅': 104,
#  '차': 105,
#  '입': 106,
#  '옴': 107,
#  '티': 108,
#  '시간': 109,
#  '모뎀': 110,
#  '문의': 111,
#  '매장': 112,
#  '오후': 113,
#  '임': 114,
#  '변경': 115,
#  '의회': 116,
#  '일시': 117,
#  '고': 118,
#  '증상': 119,
#  '홈': 120,
#  '올인': 121,
#  '통합': 122,
#  '소리': 123,
#  '된다고': 124,
#  '원': 125,
#  '실패': 126,
#  '일부': 127,
#  '비정상': 128,
#  '엔지니어': 129,
#  '번': 130,
#  '네트워크': 131,
#  '번호': 132,
#  '및': 133,
#  '음성인식': 134,
#  '다시': 135,
#  '불만': 136,
#  '건전지': 137,
#  '코로': 138,
#  '이후': 139,
#  '나무': 140,
#  '리콜': 141,
#  '전송': 142,
#  '모두': 143,
#  '뜸': 144,
#  '본인': 145,
#  '탑재': 146,
#  '파손': 147,
#  '해': 148,
#  '위치': 149,
#  '동': 150,
#  '된': 151,
#  '지': 152,
#  '입력': 153,
#  '나': 154,
#  '서비스': 155,
#  '권유': 156,
#  '취소': 157,
#  '현상': 158,
#  '쪽': 159,
#  '무': 160,
#  '다심': 161,
#  '장': 162,
#  '통화': 163,
#  '대리': 164,
#  '거실': 165,
#  '페어': 166,
#  '링': 167,
#  '문제': 168,
#  '발생': 169,
#  '같이': 170,
#  '분': 171,
#  '탑': 172,
#  '희망': 173,
#  '거부': 174,
#  '잦은': 175,
#  '꺼짐': 176,
#  '로딩': 177,
#  '상': 178,
#  '처리': 179,
#  '때': 180,
#  '오전': 181,
#  '대중': 182,
#  '들어': 183,
#  '미리': 184,
#  '방': 185,
#  '무료': 186,
#  '전체': 187,
#  '내용': 188,
#  '다른': 189,
#  '당일': 190,
#  '원함': 191,
#  '무재': 192,
#  '님': 193,
#  '실행': 194,
#  '접': 195,
#  '반복': 196,
#  '이용': 197,
#  '시시': 198,
#  '이동': 199,
#  '깨짐': 200,
#  '설치': 201,
#  '구매': 202,
#  '월': 203,
#  '거': 204,
#  '수건': 205,
#  '계속': 206,
#  '되어': 207,
#  '불연': 208,
#  '이상무': 209,
#  '여러': 210,
#  '직원': 211,
#  '화': 212,
#  '달라': 213,
#  '주소': 214,
#  '했으나': 215,
#  '접속': 216,
#  '해지': 217,
#  '분실': 218,
#  '하여': 219,
#  '올레': 220,
#  '적': 221,
#  '켜짐': 222,
#  '대만': 223,
#  '등': 224,
#  '안방': 225,
#  '케이블': 226,
#  '객': 227,
#  '면': 228,
#  '멀고': 229,
#  '요망': 230,
#  '있음': 231,
#  '메뉴': 232,
#  '되는': 233,
#  '호수': 234,
#  '안나': 235,
#  '라고': 236,
#  '전환': 237,
#  '메세지': 238,
#  '회수': 239,
#  '일반': 240,
#  '층': 241,
#  '하고': 242,
#  '지연': 243,
#  '업': 244,
#  '반응': 245,
#  '방법': 246,
#  '세': 247,
#  '상태': 248,
#  '대리인': 249,
#  '상담': 250,
#  '먼저': 251,
#  '기사': 252,
#  '오': 253,
#  '되고': 254,
#  '월일': 255,
#  '원안': 256,
#  '멈춤': 257,
#  '실시간': 258,
#  '모든': 259,
#  '제': 260,
#  '현재': 261,
#  '멀': 262,
#  '음량': 263,
#  '미약': 264,
#  '꼼꼼한': 265,
#  '함회': 266,
#  '두': 267,
#  '바코드': 268,
#  '꼭': 269,
#  '비': 270,
#  '청연': 271,
#  '나온': 272,
#  '못': 273,
#  '봇': 274,
#  '하니': 275,
#  '카드': 276,
#  '되나': 277,
#  '현장': 278,
#  '눌러야': 279,
#  '점': 280,
#  '되면': 281,
#  '나오고': 282,
#  '하십니다': 283,
#  '된다': 284,
#  '청사': 285,
#  '들어옴': 286,
#  '인식': 287,
#  '리': 288,
#  '있다고': 289,
#  '라': 290,
#  '용': 291,
#  '자체': 292,
#  '자동': 293,
#  '빨간': 294,
#  '새로': 295,
#  '인지': 296,
#  '입자': 297,
#  '위성': 298,
#  '하면': 299,
#  '직영': 300,
#  '내외': 301,
#  '것': 302,
#  '전화': 303,
#  '선재': 304,
#  '될': 305,
#  '이전': 306,
#  '개': 307,
#  '항': 308,
#  '장애': 309,
#  '기술': 310,
#  '한다고': 311,
#  '봄': 312,
#  '시험': 313,
#  '불기': 314,
#  '진행': 315,
#  '셋톱': 316,
#  '완료': 317,
#  '전후': 318,
#  '개통': 319,
#  '조사': 320,
#  '신청': 321,
#  '드림': 322,
#  '나온다고': 323,
#  '입주': 324,
#  '없다고': 325,
#  '해야': 326,
#  '에도': 327,
#  '수시로': 328,
#  '가능': 329,
#  '정보': 330,
#  '수시': 331,
#  '외': 332,
#  '서': 333,
#  '관련': 334,
#  '부탁드립니다': 335,
#  '초기': 336,
#  '누르면': 337,
#  '같다고': 338,
#  '출동': 339,
#  '불셋탑': 340,
#  '있는': 341,
#  '불로': 342,
#  '불임': 343,
#  '배정': 344,
#  '꺼졌다': 345,
#  '하는': 346,
#  '업데이트': 347,
#  '영업': 348,
#  '예약': 349,
#  '방향': 350,
#  '편성표': 351,
#  '수평': 352,
#  '조치': 353,
#  '유튜브': 354,
#  '재고': 355,
#  '니': 356,
#  '나왔다': 357,
#  '시작': 358,
#  '나오나': 359,
#  '측': 360,
#  '눌러도': 361,
#  '필요': 362,
#  '불셋': 363,
#  '부터': 364,
#  '그': 365,
#  '보기': 366,
#  '할': 367,
#  '상기': 368,
#  '회복': 369,
#  '있으면': 370,
#  '긴급': 371,
#  '이나': 372,
#  '성': 373,
#  '제어': 374,
#  '비정': 375,
#  '들림': 376,
#  '느림': 377,
#  '댁': 378,
#  '우선': 379,
#  '방송': 380,
#  '공유기': 381,
#  '수리': 382,
#  '해달라': 383,
#  '키': 384,
#  '하나': 385,
#  '전달': 386,
#  'ㅁ': 387,
#  '채팅': 388,
#  '또': 389,
#  '의뢰': 390,
#  '불편': 391,
#  '기능': 392,
#  '같다': 393,
#  '있다': 394,
#  '부분': 395,
#  '경우': 396,
#  '구성': 397,
#  '플라자': 398,
#  '다운': 399,
#  '유료': 400,
#  '이라고': 401,
#  '되다': 402,
#  '어려움': 403,
#  '민원': 404,
#  '않음': 405,
#  '가입': 406,
#  '너무': 407,
#  '노후': 408,
#  '올인원': 409,
#  '언급': 410,
#  '있을': 411,
#  '해달라고': 412,
#  '볼륨': 413,
#  '저절로': 414,
#  '지속': 415,
#  '사': 416,
#  '배터리': 417,
#  '오래': 418,
#  '게': 419,
#  '무선': 420,
#  '명의': 421,
#  '동안': 422,
#  '지사': 423,
#  '일정': 424,
#  '했다': 425,
#  '했는데': 426,
#  '망': 427,
#  '여': 428,
#  '호출': 429,
#  '자주': 430,
#  '새': 431,
#  '미': 432,
#  '참고': 433,
#  '수동': 434,
#  '불시': 435,
#  '정도': 436,
#  '해결': 437,
#  '나오면서': 438,
#  '고함': 439,
#  '이라': 440,
#  '어': 441,
#  '송출': 442,
#  '이사': 443,
#  '종료': 444,
#  '참': 445,
#  '뜬다고': 446,
#  '닷컴': 447,
#  '청구': 448,
#  '불전': 449,
#  '자연': 450,
#  '배선': 451,
#  '켜졌다': 452,
#  '심함': 453,
#  '박스': 454,
#  '뒤': 455,
#  '뜨면서': 456,
#  '갑자기': 457,
#  '공사': 458,
#  '결제': 459,
#  '관': 460,
#  '했다고': 461,
#  '바로': 462,
#  '요금': 463,
#  '중이': 464,
#  '비용': 465,
#  '사이': 466,
#  '선호': 467,
#  '됐다': 468,
#  '권한': 469,
#  'ㅇ': 470,
#  '동시': 471,
#  '시로': 472,
#  '무조건': 473,
#  '문': 474,
#  '명령': 475,
#  '간': 476,
#  '권': 477,
#  '켜면': 478,
#  '계약': 479,
#  '뜬': 480,
#  '작': 481,
#  '정': 482,
#  '잘못': 483,
#  '어플': 484,
#  '시티': 485,
#  '해당': 486,
#  '남': 487,
#  '적색': 488,
#  '주': 489,
#  '불안': 490,
#  '정리': 491,
#  '결선': 492,
#  '코스': 493,
#  '에는': 494,
#  '에러': 495,
#  '불수신': 496,
#  '까지': 497,
#  '부재': 498,
#  '대답': 499,
#  '혼자': 500,
#  '말': 501,
#  '집': 502,
#  '날씨': 503,
#  '쿠폰': 504,
#  '가지': 505,
#  '나오는데': 506,
#  '검색': 507,
#  '앞': 508,
#  '바람': 509,
#  '메시지': 510,
#  '없다': 511,
#  '짐': 512,
#  '기존': 513,
#  '늦게': 514,
#  '스마트': 515,
#  '직거림': 516,
#  '딩': 517,
#  '속도': 518,
#  '극심': 519,
#  '변동': 520,
#  '링크': 521,
#  '함연': 522,
#  '완': 523,
#  '빨리': 524,
#  '정확한': 525,
#  '해제': 526,
#  '있어': 527,
#  '마다': 528,
#  '되지': 529,
#  '예정': 530,
#  '원룸': 531,
#  '처음': 532,
#  '접촉': 533,
#  '구분': 534,
#  '댁내': 535,
#  '영상': 536,
#  '된다며': 537,
#  '필티': 538,
#  '합니다': 539,
#  '되': 540,
#  '와이파이': 541,
#  '조정': 542,
#  '하는데': 543,
#  '드렸으나': 544,
#  '임시': 545,
#  '카스': 546,
#  '몇': 547,
#  '안심': 548,
#  '후시': 549,
#  '멀리': 550,
#  '부주의': 551,
#  '말고': 552,
#  '뜨고': 553,
#  '동일함': 554,
#  '위': 555,
#  '기본': 556,
#  '차단': 557,
#  '되는데': 558,
#  '모자이크': 559,
#  '깨져서': 560,
#  '한다': 561,
#  '반': 562,
#  '양해': 563,
#  '모컨': 564,
#  '되서': 565,
#  '당': 566,
#  '중간': 567,
#  '씩': 568,
#  '방안': 569,
#  '꺼진다고': 570,
#  '대는': 571,
#  '줄': 572,
#  '해봐도': 573,
#  '앞당겨': 574,
#  '명': 575,
#  '안테나': 576,
#  '표시': 577,
#  '미납': 578,
#  '멤버십': 579,
#  '더': 580,
#  '켜': 581,
#  '없이': 582,
#  '그냥': 583,
#  '내부': 584,
#  '같은': 585,
#  '야간': 586,
#  '급': 587,
#  '근본': 588,
#  '줄이': 589,
#  '꼼꼼하게': 590,
#  '유투브': 591,
#  '불매': 592,
#  '아래': 593,
#  '불대': 594,
#  '관건': 595,
#  '스카이': 596,
#  '부탁드립니': 597,
#  '상품': 598,
#  '부서': 599,
#  '특정': 600,
#  '단자': 601,
#  '대신': 602,
#  '주소지': 603,
#  '함께': 604,
#  '인데': 605,
#  '유': 606,
#  '같다며': 607,
#  '요구사항': 608,
#  '팀': 609,
#  '방기': 610,
#  '거리': 611,
#  '함재': 612,
#  '끊어짐': 613,
#  '관리자': 614,
#  '확답': 615,
#  '네': 616,
#  '아': 617,
#  '안함': 618,
#  '도중': 619,
#  '조절': 620,
#  '장소': 621,
#  '없어': 622,
#  '음': 623,
#  '않는다고': 624,
#  '모드': 625,
#  '나오는': 626,
#  '자가': 627,
#  '복구': 628,
#  '원인': 629,
#  '손': 630,
#  '불건전': 631,
#  '임대': 632,
#  '부활': 633,
#  '기기': 634,
#  '내시': 635,
#  '숫자': 636,
#  '삼성': 637,
#  '받았으나': 638,
#  '자꾸': 639,
#  '불호': 640,
#  '마찬가지': 641,
#  '사람': 642,
#  '해드림': 643,
#  '실': 644,
#  '녹색': 645,
#  '야': 646,
#  '랑': 647,
#  '비번': 648,
#  '얼마': 649,
#  '김': 650,
#  '불위': 651,
#  '부': 652,
#  '불통': 653,
#  '감': 654,
#  '무상': 655,
#  '비리': 656,
#  '있고': 657,
#  '거림': 658,
#  '걸': 659,
#  '켜지고': 660,
#  '까맣게': 661,
#  '가능함': 662,
#  '비수': 663,
#  '소': 664,
#  '받음': 665,
#  '지금': 666,
#  '그런': 667,
#  '모텔': 668,
#  '가능한': 669,
#  '본': 670,
#  '대다': 671,
#  '리부팅': 672,
#  '입호': 673,
#  '응답': 674,
#  '고정': 675,
#  '대로': 676,
#  '동일하다': 677,
#  '모니터': 678,
#  '했던': 679,
#  '꺼져': 680,
#  '온': 681,
#  '유선': 682,
#  '인입': 683,
#  '건물': 684,
#  '보상금': 685,
#  '멀티': 686,
#  '아파트': 687,
#  '알려': 688,
#  '데': 689,
#  '나머지': 690,
#  '지지': 691,
#  '센서': 692,
#  '만원': 693,
#  '아예': 694,
#  '세게': 695,
#  '과장': 696,
#  '생기': 697,
#  '되었다고': 698,
#  '되었다': 699,
#  '해보셨다': 700,
#  '하신': 701,
#  '직': 702,
#  '깜박': 703,
#  '선로': 704,
#  '하였으나': 705,
#  '되다가': 706,
#  '차례': 707,
#  '톱': 708,
#  '스트림': 709,
#  '선도': 710,
#  '방수': 711,
#  '아무': 712,
#  '조작': 713,
#  '가능하면': 714,
#  '에서는': 715,
#  '문구': 716,
#  '엔': 717,
#  '시기': 718,
#  '신다고': 719,
#  '배우자': 720,
#  '곳': 721,
#  '격리': 722,
#  '셋탑박스': 723,
#  '거절': 724,
#  '헐': 725,
#  '최근': 726,
#  '하시고': 727,
#  '미가': 728,
#  '자녀': 729,
#  '들어온다고': 730,
#  '없': 731,
#  '불입': 732,
#  '오늘': 733,
#  '오프': 734,
#  '양': 735,
#  '근처': 736,
#  '켜진': 737,
#  '손실': 738,
#  '가까운': 739,
#  '쯤': 740,
#  '방쪽': 741,
#  '옴셋탑': 742,
#  '모름': 743,
#  '대상': 744,
#  '당겨서': 745,
#  '흔들림': 746,
#  '함수': 747,
#  '작은': 748,
#  '나오며': 749,
#  '불비': 750,
#  '며': 751,
#  '돼서': 752,
#  '팝업': 753,
#  '뜬다': 754,
#  '정지': 755,
#  '시도': 756,
#  '직접': 757,
#  '콜': 758,
#  '구': 759,
#  '구입': 760,
#  '처럼': 761,
#  '하지': 762,
#  '어르신': 763,
#  '빨간색': 764,
#  '력': 765,
#  '주신다고': 766,
#  '플레이': 767,
#  '사업': 768,
#  '램프': 769,
#  '코드': 770,
#  '길': 771,
#  '긍': 772,
#  '약': 773,
#  '받은': 774,
#  '노이즈': 775,
#  '품질': 776,
#  '종결': 777,
#  '하려': 778,
#  '시설': 779,
#  '어댑터': 780,
#  '수긍': 781,
#  '촉': 782,
#  '하면서': 783,
#  '여부': 784,
#  '조회': 785,
#  '전혀': 786,
#  '전부': 787,
#  '가입자': 788,
#  '셋톱박스': 789,
#  '스피커': 790,
#  '작업': 791,
#  '공동': 792,
#  '수도': 793,
#  '께': 794,
#  '호호': 795,
#  '준': 796,
#  '그대로': 797,
#  '제시': 798,
#  '들어온': 799,
#  '만나': 800,
#  '건지': 801,
#  '준비': 802,
#  '중대': 803,
#  '정확히': 804,
#  '조': 805,
#  '많이': 806,
#  '테이블': 807,
#  '지역': 808,
#  '랜선': 809,
#  '든': 810,
#  '받았다': 811,
#  '인해': 812,
#  '나서': 813,
#  '담당자': 814,
#  '인증': 815,
#  '다음': 816,
#  '생략': 817,
#  '안눌림': 818,
#  '비밀번호': 819,
#  '해봄': 820,
#  '한참': 821,
#  '이랑': 822,
#  '하며': 823,
#  '라는': 824,
#  '설명': 825,
#  '원하': 826,
#  '꼼꼼': 827,
#  '켤': 828,
#  '자막': 829,
#  '하셔서': 830,
#  '스카이라이프': 831,
#  '현': 832,
#  '늦은': 833,
#  '어렵다': 834,
#  '불리': 835,
#  '요구': 836,
#  '필요하다고': 837,
#  '영향': 838,
#  '오면': 839,
#  '익일': 840,
#  '강성': 841,
#  '영화': 842,
#  '먹통': 843,
#  '전주': 844,
#  '담당': 845,
#  '음으로': 846,
#  '의자': 847,
#  '항상': 848,
#  '센터': 849,
#  '상하': 850,
#  '않고': 851,
#  '없을': 852,
#  '청약': 853,
#  '건수': 854,
#  '주신': 855,
#  '하신다고': 856,
#  '알': 857,
#  '나오다': 858,
#  '않아': 859,
#  '부족': 860,
#  '때문': 861,
#  '가능하나': 862,
#  '아웃': 863,
#  '보임': 864,
#  '넷플': 865,
#  '대금': 866,
#  '들어오며': 867,
#  '노래': 868,
#  '컨텐츠': 869,
#  '어떻게': 870,
#  '따로': 871,
#  '무응': 872,
#  '지원': 873,
#  '조금': 874,
#  '있어서': 875,
#  '금': 876,
#  '어둡게': 877,
#  '공': 878,
#  '평소': 879,
#  '기량': 880,
#  '받을': 881,
#  '들어오고': 882,
#  '핀': 883,
#  '켜지는': 884,
#  '업무': 885,
#  '켜진다고': 886,
#  '청소': 887,
#  '들어가서': 888,
#  '초': 889,
#  '요일': 890,
#  '청': 891,
#  '오스': 892,
#  '없고': 893,
#  '보심': 894,
#  '선단': 895,
#  '보': 896,
#  '심연': 897,
#  '지상파': 898,
#  '추후': 899,
#  '소등': 900,
#  '좋다고': 901,
#  '해보고': 902,
#  '지점': 903,
#  '나와서': 904,
#  '당시': 905,
#  '토요일': 906,
#  '좋음': 907,
#  '준다': 908,
#  '되도': 909,
#  '이미': 910,
#  '제공': 911,
#  '어렵다고': 912,
#  '시안': 913,
#  '눌려': 914,
#  '신규': 915,
#  '재송출': 916,
#  '나오지': 917,
#  '프로그램': 918,
#  '누르고': 919,
#  '꾹': 920,
#  '눌러': 921,
#  '부산': 922,
#  '보냄': 923,
#  '비상': 924,
#  '소요': 925,
#  '있거나': 926,
#  '혹시': 927,
#  '중고': 928,
#  '앱': 929,
#  '전시': 930,
#  '발신': 931,
#  '사무실': 932,
#  '하단': 933,
#  '끊으': 934,
#  '단': 935,
#  '나왔다가': 936,
#  '둘': 937,
#  '안됨진단': 938,
#  '재생': 939,
#  '제품': 940,
#  '정검': 941,
#  '나오신다고': 942,
#  '끄면': 943,
#  '아니라': 944,
#  '받았는데': 945,
#  '갔다': 946,
#  '꺼지고': 947,
#  '지면': 948,
#  '불직': 949,
#  '영점': 950,
#  '추티업': 951,
#  '에서만': 952,
#  '하시며': 953,
#  '장님': 954,
#  '리퍼': 955,
#  '하기': 956,
#  '있는데': 957,
#  '빠르게': 958,
#  '성공': 959,
#  '가게': 960,
#  '호안': 961,
#  '잡음': 962,
#  '음향': 963,
#  '랜': 964,
#  '큰': 965,
#  '처': 966,
#  '업그레이드': 967,
#  '대안': 968,
#  '대가': 969,
#  '송출됨': 970,
#  '깜빡': 971,
#  '기건': 972,
#  '기간': 973,
#  '불지': 974,
#  '저녁': 975,
#  '주인': 976,
#  '원활하지': 977,
#  '않다고': 978,
#  '당겨': 979,
#  '인티': 980,
#  '분리': 981,
#  '길게': 982,
#  '빠져': 983,
#  '연결했는데': 984,
#  '꾹꾹': 985,
#  '뜨': 986,
#  '진입': 987,
#  '검게': 988,
#  '번쩍': 989,
#  '나온다': 990,
#  '이메일': 991,
#  '나중': 992,
#  '불일': 993,
#  '나온다며': 994,
#  '해봤다': 995,
#  '있어야': 996,
#  '인계': 997,
#  '각각': 998,
#  '와서': 999,
#  ...}

# %%
# 텍스트 스트링을 사전 인덱스 스트링으로 변환

def wordlist_to_indexlist(wordlist):
    return [word_to_index[word] if word in word_to_index else word_to_index['<UNK>'] for word in wordlist]

# %%
X_train = list(map(wordlist_to_indexlist, X_train))
X_valid = list(map(wordlist_to_indexlist, X_valid))

# %%
X_valid[:3]
# Out:
# [[118,
#   227,
#   2,
#   64,
#   891,
#   416,
#   308,
#   2,
#   75,
#   125,
#   2,
#   630,
#   2,
#   228,
#   2,
#   1733,
#   512,
#   2,
#   2156,
#   2140,
#   1410,
#   2,
#   3569,
#   2,
#   2,
#   114,
#   2,
#   2,
#   805,
#   1410,
#   2,
#   56,
#   2,
#   288,
#   2161,
#   2372,
#   2,
#   2,
#   118,
#   162,
#   2,
#   185,
#   474,
#   2,
#   30,
#   2,
#   3709,
#   2,
#   2,
#   1683,
#   1772,
#   2,
#   64,
#   891],
#  [108,
#   270,
#   2,
#   333,
#   2,
#   1839,
#   2785,
#   2,
#   2156,
#   2,
#   606,
#   2,
#   2,
#   2,
#   22,
#   58,
#   2,
#   1679,
#   57,
#   2,
#   120,
#   2,
#   482,
#   178,
#   2,
#   57,
#   2857,
#   1839,
#   2,
#   482,
#   178,
#   2,
#   108,
#   270,
#   2,
#   2161,
#   267,
#   2,
#   482,
#   178,
#   2,
#   80,
#   2,
#   2297,
#   57,
#   540,
#   441,
#   2,
#   118,
#   227,
#   2,
#   360,
#   2,
#   108,
#   270,
#   80,
#   2,
#   2297,
#   57,
#   2,
#   22,
#   616],
#  [53,
#   2,
#   2,
#   152,
#   356,
#   2,
#   333,
#   2,
#   1839,
#   2785,
#   2,
#   2156,
#   2,
#   644,
#   3214,
#   2,
#   15,
#   2,
#   2,
#   288,
#   102,
#   2,
#   477,
#   2,
#   606,
#   2,
#   118,
#   227,
#   2,
#   332,
#   652,
#   4818,
#   333,
#   2,
#   1048,
#   3214,
#   148,
#   2,
#   896,
#   30,
#   118,
#   2,
#   35,
#   40,
#   2,
#   2,
#   489,
#   28,
#   2,
#   83,
#   51]]

# %% [markdown]
# #### 데이터 셋 내 문장 길이 분포

# %%
print(X_train[0])  # 1번째 리뷰데이터
print('라벨: ', y_train[0])  # 1번째 리뷰데이터의 라벨
print('1번째 리뷰 문장 길이: ', len(X_train[0]))
print('2번째 리뷰 문장 길이: ', len(X_train[1]))
# Out:
# [288, 2161, 2372, 2, 481, 150, 22, 2, 58, 2, 160, 4722, 2, 224, 2, 25]
# 라벨:  11
# 1번째 리뷰 문장 길이:  16
# 2번째 리뷰 문장 길이:  66

# %%
total_data_text = list(X_train) + list(X_valid)

# 텍스트데이터 문장길이의 리스트를 생성한 후
num_tokens = [len(tokens) for tokens in total_data_text]
num_tokens = np.array(num_tokens)

# %%
# 문장길이의 평균값, 최대값, 표준편차를 계산해 본다. 
print('문장길이 평균 : ', np.mean(num_tokens))
print('문장길이 최대 : ', np.max(num_tokens))
print('문장길이 표준편차 : ', np.std(num_tokens))
# Out:
# 문장길이 평균 :  58.21903249450281
# 문장길이 최대 :  474
# 문장길이 표준편차 :  28.13411624330434

# %% [markdown]
# #### 적절한 문장 최대 길이 지정
# - 분포를 통해 확인하여 문장 최대길이를 정해야함

# %%
print('리뷰의 최대 길이 :', np.max(num_tokens))
print('리뷰의 평균 길이 :', np.mean(num_tokens))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 474
# 리뷰의 평균 길이 : 58.21903249450281

# %% [markdown]
# - 문장 최대길이가 114일때 전체 문장의 96%를 포함하는 것으로 보아 문장 최대길이는 114로 설정 MAX_LENTH = 114

# %%
# 예를들어, 최대 길이를 (평균 + 2*표준편차)로 한다면,  
max_tokens = np.mean(num_tokens) + 2 * np.std(num_tokens)
max_len = int(max_tokens)
print('pad_sequences maxlen : ', max_len)
print('전체 문장의 {}%가 maxlen 설정값 이내에 포함됩니다. '.format(np.sum(num_tokens < max_tokens) / len(num_tokens)))
# Out:
# pad_sequences maxlen :  114
# 전체 문장의 0.9651844612753482%가 maxlen 설정값 이내에 포함됩니다.

# %% [markdown]
# #### keras.preprocessing.sequence.pad_sequences 을 활용한 패딩 추가

# %%
X_train = pad_sequences(X_train, 
                        maxlen = max_len,
                        value=word_to_index["<PAD>"],
                        padding='pre')
X_valid = pad_sequences(X_valid, 
                       maxlen = max_len,
                       value=word_to_index["<PAD>"],
                       padding='pre')

# %%
print(X_train.shape)
print(X_valid.shape)
# Out:
# (6548, 114)
# (1638, 114)

# %% [markdown]
# ### Modeling

# %%
total_cnt = len(word_to_index)  # 어휘 사전의 크기입니다

print(total_cnt, '개')
# Out:
# 5182 개

# %%
word_vector_dim = 50

# %%
from tensorflow import keras

tf.random.set_seed(0)
model = keras.Sequential()
model.add(keras.layers.Embedding(vocab_size, word_vector_dim, input_shape=(None,)))
model.add(keras.layers.LSTM(128))   # 가장 널리 쓰이는 RNN인 LSTM 레이어를 사용하였습니다. 이때 LSTM state 벡터의 차원수는 64로 하였습니다. (변경가능)
# model.add(keras.layers.Dense(8, activation='relu')) # 안해도 됨
model.add(keras.layers.Dense(14, activation='softmax'))  # 최종 출력은 긍정/부정을 나타내는 1dim 입니다.

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 50)          2190000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               91648
# _________________________________________________________________
# dense_1 (Dense)              (None, 14)                1806
# =================================================================
# Total params: 2,283,454
# Trainable params: 2,283,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
# validation set 29300건 분리
X_val = X_valid
y_val = y_valid

# validation set을 제외한 나머지 
partial_X_train = X_train
partial_y_train = y_train

print(partial_X_train.shape)
print(partial_y_train.shape)
# Out:
# (6548, 114)
# (6548,)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
mc = ModelCheckpoint('C:/Users/inp032/Desktop/채널 AI/channel-ai/model/best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
              
epochs=20  # 몇 epoch를 훈련하면 좋을지 결과를 보면서 바꾸어 봅시다. 

history = model.fit(partial_X_train,
                    partial_y_train,
                    epochs=epochs,
                    batch_size=60, # 512, 100, 60 
                    validation_data=(X_val, y_val),
                    verbose=1,
                    callbacks = [es, mc])
                    
model.save('C:/Users/inp032/Desktop/채널 AI/channel-ai/model/best_model.h5')
# Out:
# Epoch 1/20
# 110/110 [==============================] - 25s 209ms/step - loss: 0.6082 - accuracy: 0.8261 - val_loss: 0.6736 - val_accuracy: 0.8114
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/20
# 110/110 [==============================] - 23s 208ms/step - loss: 0.5608 - accuracy: 0.8418 - val_loss: 0.6392 - val_accuracy: 0.8205
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/20
# 110/110 [==============================] - 22s 203ms/step - loss: 0.5375 - accuracy: 0.8526 - val_loss: 0.6078 - val_accuracy: 0.8376
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/20
# 110/110 [==============================] - 21s 194ms/step - loss: 0.4916 - accuracy: 0.8658 - val_loss: 0.5776 - val_accuracy: 0.8437
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/20
# 110/110 [==============================] - 21s 188ms/step - loss: 0.4818 - accuracy: 0.8690 - val_loss: 0.6267 - val_accuracy: 0.8309
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/20
# 110/110 [==============================] - 20s 183ms/step - loss: 0.4642 - accuracy: 0.8710 - val_loss: 0.5630 - val_accuracy: 0.8474
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/20
# 110/110 [==============================] - 20s 181ms/step - loss: 0.4434 - accuracy: 0.8775 - val_loss: 0.5653 - val_accuracy: 0.8474
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/20
# 110/110 [==============================] - 21s 187ms/step - loss: 0.4314 - accuracy: 0.8832 - val_loss: 0.5645 - val_accuracy: 0.8535
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/20
# 110/110 [==============================] - 20s 183ms/step - loss: 0.4128 - accuracy: 0.8833 - val_loss: 0.5801 - val_accuracy: 0.8449
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/20
# 110/110 [==============================] - 20s 181ms/step - loss: 0.4033 - accuracy: 0.8864 - val_loss: 0.5482 - val_accuracy: 0.8510
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/20
# 110/110 [==============================] - 20s 184ms/step - loss: 0.3887 - accuracy: 0.8931 - val_loss: 0.5350 - val_accuracy: 0.8639
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/20
# 110/110 [==============================] - 21s 190ms/step - loss: 0.3777 - accuracy: 0.8963 - val_loss: 0.5245 - val_accuracy: 0.8571
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/20
# 110/110 [==============================] - 22s 196ms/step - loss: 0.3645 - accuracy: 0.9018 - val_loss: 0.5388 - val_accuracy: 0.8578
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/20
# 110/110 [==============================] - 23s 210ms/step - loss: 0.3514 - accuracy: 0.9046 - val_loss: 0.5426 - val_accuracy: 0.8602
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/20
# 110/110 [==============================] - 22s 197ms/step - loss: 0.3386 - accuracy: 0.9046 - val_loss: 0.5345 - val_accuracy: 0.8565
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/20
# 110/110 [==============================] - 21s 191ms/step - loss: 0.3260 - accuracy: 0.9088 - val_loss: 0.5294 - val_accuracy: 0.8565
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/20
# 110/110 [==============================] - 20s 186ms/step - loss: 0.3271 - accuracy: 0.9073 - val_loss: 0.5108 - val_accuracy: 0.8578
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/20
# 110/110 [==============================] - 20s 185ms/step - loss: 0.3141 - accuracy: 0.9125 - val_loss: 0.5331 - val_accuracy: 0.8590
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/20
# 110/110 [==============================] - 21s 191ms/step - loss: 0.3006 - accuracy: 0.9134 - val_loss: 0.5445 - val_accuracy: 0.8559
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/20
# 110/110 [==============================] - 22s 199ms/step - loss: 0.2882 - accuracy: 0.9177 - val_loss: 0.5388 - val_accuracy: 0.8584
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.

# %% [markdown]
# #### Loss, Accuracy 그래프 시각화

# %%
results = model.evaluate(X_valid,  y_valid, verbose=2)

print(results)
# Out:
# 52/52 - 2s - loss: 0.7325 - accuracy: 0.8016
# [0.7324643731117249, 0.8015872836112976]

# %%
history_dict = history.history
print(history_dict.keys()) # epoch에 따른 그래프를 그려볼 수 있는 항목들
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# - 학습이 진행 될 수록 Loss 가 떨어짐.
# - epoch을 더 늘려도 될 것 같다고 생각함.

# %%
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

# "bo"는 "파란색 점"입니다
plt.plot(epochs, loss, 'bo', label='Training loss')
# b는 "파란 실선"입니다
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
