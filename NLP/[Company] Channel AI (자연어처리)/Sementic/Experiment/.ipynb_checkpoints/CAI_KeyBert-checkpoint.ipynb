# %%
import numpy as np
import pandas as pd
import itertools


from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ### 전처리가 이미 완료된 후의 데이터를 사용
# 보안상 데이터를 전체 공개 불가

# %%
df = pd.read_csv('../data/dataset/CAI_data_001.csv')

# %%
df
# Out:
#                                                sentence
# 0                                     tv 안됨 상담 중 자연 회복됨
# 1     TV 수신 불이 인터넷 연결 오류 뜸 재부팅해 봄 모텔 영업용 일중 꼭 점검 원하여...
# 2                                      tv 수신 불 said 연후방
# 3                                 tv 수신 불 네트워크 오류 접수 보류
# 4                                       TV 수신 불 연락 후인 입
# ...                                                 ...
# 8661  안심권 유 tv 화질 불량 시청 중 화면 멈추고 tv 꺼졌다 켜지는 현상이 있다고 ...
# 8662                   리콜 넷플릭스 연령 인증 문의 건 리콜하니 해결했다고 하심
# 8663                                  대주신 불 cas 전 송후 리셋
# 8664  안심 권유 빠른 점검 요청 tv 시청 불이 인터넷 연결 오류나 옴 모든 장비 재부팅 안내
# 8665              TV 수신 불 연락 후 방문 지니 셋 탑 전 원안 들어옴 교체 요청
#
# [8666 rows x 1 columns]

# %%
df['sentence'][0]
# Out:
# 'tv 안됨 상담 중 자연 회복됨'

# %%
okt = Okt()

tokenized_doc = okt.pos(df['sentence'][0])
tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1] != 0])

print('품사 태깅 10개만 출력 :',tokenized_doc[:10])
print('추출 :',tokenized_nouns)
# Out:
# 품사 태깅 10개만 출력 : [('tv', 'Alpha'), ('안됨', 'Adjective'), ('상담', 'Noun'), ('중', 'Noun'), ('자연', 'Noun'), ('회복', 'Noun'), ('됨', 'Verb')]
# 추출 : tv 안됨 상담 중 자연 회복 됨

# %%
n_gram_range = (2, 3)

count = CountVectorizer(ngram_range=n_gram_range).fit([tokenized_nouns])
candidates = count.get_feature_names_out()

print('trigram 개수 :',len(candidates))
print('trigram 다섯개만 출력 :',candidates[:5])
# Out:
# trigram 개수 : 7
# trigram 다섯개만 출력 : ['tv 안됨' 'tv 안됨 상담' '상담 자연' '상담 자연 회복' '안됨 상담']

# %%
model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
doc_embedding = model.encode(df['sentence'][0])
candidate_embeddings = model.encode(candidates)

# %%
def max_sum_sim(doc_embedding, candidate_embeddings, words, top_n, nr_candidates):
    # 문서와 각 키워드들 간의 유사도
    distances = cosine_similarity(doc_embedding, candidate_embeddings)

    # 각 키워드들 간의 유사도
    distances_candidates = cosine_similarity(candidate_embeddings,
                                            candidate_embeddings)

    # 코사인 유사도에 기반하여 키워드들 중 상위 top_n개의 단어를 pick.
    words_idx = list(distances.argsort()[0][-nr_candidates:])
    words_vals = [candidates[index] for index in words_idx]
    distances_candidates = distances_candidates[np.ix_(words_idx, words_idx)]

    # 각 키워드들 중에서 가장 덜 유사한 키워드들간의 조합을 계산
    min_sim = np.inf
    candidate = None

    for combination in itertools.combinations(range(len(words_idx)), top_n):
        sim = sum([distances_candidates[i][j] for i in combination for j in combination if i != j])
        if sim < min_sim:
            candidate = combination
            min_sim = sim

    return [words_vals[idx] for idx in candidate]

def mmr(doc_embedding, candidate_embeddings, words, top_n, diversity):

    # 문서와 각 키워드들 간의 유사도가 적혀있는 리스트
    word_doc_similarity = cosine_similarity(candidate_embeddings, doc_embedding)

    # 각 키워드들 간의 유사도
    word_similarity = cosine_similarity(candidate_embeddings)

    # 문서와 가장 높은 유사도를 가진 키워드의 인덱스를 추출.
    # 만약, 2번 문서가 가장 유사도가 높았다면
    # keywords_idx = [2]
    keywords_idx = [np.argmax(word_doc_similarity)]

    # 가장 높은 유사도를 가진 키워드의 인덱스를 제외한 문서의 인덱스들
    # 만약, 2번 문서가 가장 유사도가 높았다면
    # ==> candidates_idx = [0, 1, 3, 4, 5, 6, 7, 8, 9, 10 ... 중략 ...]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]

    # 최고의 키워드는 이미 추출했으므로 top_n-1번만큼 아래를 반복.
    # ex) top_n = 5라면, 아래의 loop는 4번 반복됨.
    for _ in range(top_n - 1):
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        # MMR을 계산
        mmr = (1-diversity) * candidate_similarities - diversity * target_similarities.reshape(-1, 1)
        mmr_idx = candidates_idx[np.argmax(mmr)]

        # keywords & candidates를 업데이트
        keywords_idx.append(mmr_idx)
        candidates_idx.remove(mmr_idx)

    return [words[idx] for idx in keywords_idx]

# %%
abstract_sen = []


for i in range(len(df)) :
    

    try :
        okt = Okt()

        tokenized_doc = okt.pos(df['sentence'][i])
        tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1] != 0])

        n_gram_range = (2, 3)

        count = CountVectorizer(ngram_range=n_gram_range).fit([tokenized_nouns])
        candidates = count.get_feature_names_out()

        doc_embedding = model.encode([df['sentence'][i]])
        candidate_embeddings = model.encode(candidates)

        distances = cosine_similarity(doc_embedding, candidate_embeddings)
        keywords = [candidates[index] for index in distances.argsort()[0][-top_n:]]
        
        
        keywords = max_sum_sim(doc_embedding, candidate_embeddings, candidates, top_n=3, nr_candidates=10)
        
        
        abstract_sen.append(keywords)
        print('----------------------------------------------------------')
        print('원본 : ', df['sentence'][i])
        print('요약 : ', abstract_sen[i])
        print('----------------------------------------------------------')

    except :
        abstract_sen.append(df['sentence'][i])
# Out:
# ----------------------------------------------------------
# 원본 :  tv 안됨 상담 중 자연 회복됨
# 요약 :  ['자연 회복', '상담 자연', '안됨 상담']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  TV 수신 불이 인터넷 연결 오류 뜸 재부팅해 봄 모텔 영업용 일중 꼭 점검 원하여 지사 이관함
# 요약 :  ['원하여 지사', '오류 재부팅 모텔', '재부팅 모텔 영업']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불 said 연후방
# 요약 :  ['tv 수신', '수신 said', '수신 said 후방']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불 네트워크 오류 접수 보류
# 요약 :  ['네트워크 오류', 'tv 수신', '접수 보류']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  TV 수신 불 연락 후인 입
# 요약 :  ['tv 수신', 'tv 수신 연락', '수신 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 채널은 정상 넷플릭스 안됨 포트 리셋 미리 연락 후 방문 요망
# 요약 :  ['포트 리셋', '미리 연락', '채널 정상 넷플릭스']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 풀 서비스 시작 중
# 요약 :  ['tv 수신', '수신 서비스', '서비스 시작']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  김현철 채팅 AS 지니 자체에서 잡음이 난다고 함 소장 접수함 셋탑 이상 지니 자체에서 따다 다다 거리는 소리가 계속 나다고 합동일 증상으로 일경 as 받았으나 또 소리가 난다고 함재 부팅해도 동일 연후방
# 요약 :  ['김현철 채팅', '김현철 채팅 as', '받았으나 소리 난다고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  saidtv 나오나 따닥거리는 소리가 난다 한 리셋 후 잘 됨
# 요약 :  ['saidtv 나오나', '난다 리셋', '따닥거리 소리 난다']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 화질 불량 시청 중 멈추는 증상 반복됨 연락 후인 입
# 요약 :  ['화질 불량', '시청 멈추는 증상', '반복 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불연 후방
# 요약 :  ['불연 후방', '수신 불연 후방', 'tv 수신']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불 said 연락 후 최대한 빠른 방문 요망
# 요약 :  ['tv 수신 said', 'said 연락', '빠른 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 채널 정상 넷플릭스만 안됨 포트 리셋 연락 후 최대한 빠른 방문 요망
# 요약 :  ['빠른 방문 요망', '연락 최대한', '넷플릭스 안됨 포트']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불 스트림 에러 자 연회복
# 요약 :  ['에러 회복', '스트림 에러 회복', 'tv 수신']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 안됨 리셋 후 정상
# 요약 :  ['안됨 리셋', '안됨 리셋 정상', '리셋 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  안심 권유 인터넷 지킴이가 입 tv 수신 불 stb 재부팅 안내 후 정상 사용됨
# 요약 :  ['정상 사용', '지킴 tv', '재부팅 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  넷플릭스 실행 불가리 셋 후 잘 됨 안심 권유
# 요약 :  ['불가리 안심 권유', '실행 불가리', '넷플릭스 실행 불가리']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불 최대한 빠른 점검요
# 요약 :  ['tv 수신', '빠른 점검', '수신 최대한']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  otv 리모컨 안됨 리모컨에 분 계속 켜짐 MS 매장 안내
# 요약 :  ['리모컨 계속', '켜짐 ms', 'otv 리모컨 안됨']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불세 탑재 부팅 정상 확인됨
# 요약 :  ['tv 수신 불세', '정상 확인', '불세 탑재 부팅']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  HD 리모컨 작동 뿔 셋 탑재 부팅 후 정상 사용됨
# 요약 :  ['부팅 정상', '리모컨 작동', 'hd 리모컨']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 전 원안 들어옴 고객 측 의뢰
# 요약 :  ['고객 의뢰', 'tv 원안', '원안 들어옴']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 전 원안 들어옴 고객 측 의뢰
# 요약 :  ['고객 의뢰', 'tv 원안', '원안 들어옴']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  TV 채널 수신 불량 시험 결과 코로나 미 대상
# 요약 :  ['tv 채널', '수신 불량 시험', '코로나 대상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 안됨 신 없음 외부 입력 확인 셋탑재 부팅해도 동일 as 보류
# 요약 :  ['외부 입력 확인', '동일 as 보류', '부팅 해도']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불되도록 일 오전 방문 요청
# 요약 :  ['불되 도록', '오전 방문', '수신 불되 도록']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  현재 수신 불평도 화면 끊어짐 코로나 미 대상
# 요약 :  ['불평 화면 끊어짐', '수신 불평 화면', '현재 수신']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  요청사항 tv 안됨 인터넷 연결 오류 재부팅해도 동일 방문 시간 참고
# 요약 :  ['요청 사항', '동일 방문 시간', '해도 동일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불 재부팅 후 정상 사용됨
# 요약 :  ['정상 사용', 'tv 수신', '수신 재부팅']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  요청사항 tv 안됨 신 없음 외부 입력 변경 후 정상 사용됨
# 요약 :  ['요청 사항', '없음 외부 입력', '정상 사용']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  HD 올레티브이 음향 안들림셋탑리셋 이후 올레티브이 정상 음향 들림
# 요약 :  ['들림 셋탑 리셋', 'hd 올레', '정상 음향 들림']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불과 리모컨 반응 느림셋탑리셋 후 정상
# 요약 :  ['리모컨 반응', '느림 셋탑 리셋', '셋탑 리셋 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불이 인터넷 연결 오류 뜸 급 점검 지연된다고 민원실 최대한 빠른 점검요
# 요약 :  ['된다고 민원', '연결 오류 점검', '민원 최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  요청사항 조회 tv 안됨 stb 전원 적색점 등 수동 눌러도 반응 없음셋탑재 부팅해도 동일 방문 시간 참고
# 요약 :  ['수동 눌러도 반응', '해도 동일 방문', '눌러도 반응 없음']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불기가 지니 전 원안 들어 옴기가 지니에 연결된 랜선도 헐거워져서 자꾸 빠진다고 랜선 교체도 요청함
# 요약 :  ['지니 연결 랜선', '헐거워져서 자꾸', '헐거워져서 자꾸 빠진다고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  큰 방 tv 수신 불 코로나 미 대상 said
# 요약 :  ['tv 수신', '수신 코로나 대상', '코로나 대상 said']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  요청사항 tv 안됨 방문해서 확인 요청함 연결된 지니 stb 대는 정상 방문 시간 참고인
# 요약 :  ['대는 정상 방문', '연결 지니 stb', '해서 확인']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  HD 올레티브이 시청 안됨 티브이 전원 안 켜짐 고객 측 의뢰 안내함
# 요약 :  ['티브이 시청 안됨', '켜짐 고객', 'hd 올레 티브이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  방 tv 수신 불시 방문요
# 요약 :  ['tv 수신', '수신 불시', '불시 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  TV 채널 수신 불량 인터넷 연결 오류 시험 결과 코로나 미 대상
# 요약 :  ['tv 채널 수신', '오류 시험', '결과 코로나 대상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  차단기 내려간 후 수신 불 코로나 미 대상
# 요약 :  ['수신 코로나 대상', '코로나 대상', '차단기 내려간']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불 네트워크 오류 최대한 빠른 점검 요청
# 요약 :  ['수신 네트워크 오류', '수신 네트워크', '빠른 점검']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불방 쪽만 안됨 셋탑재 부팅 후 정상
# 요약 :  ['안됨 탑재', 'tv 수신 불방', '탑재 부팅 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불이 인터넷 연결 오류 뜸 재부팅해 봄 연락 먼저
# 요약 :  ['수신 인터넷 연결', 'tv 수신', '오류 재부팅']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  가능한 일방 요 분 정도 시청되면 화면 꺼짐 소리 정상 코로나 미 대상
# 요약 :  ['정상 코로나 대상', '정도 시청 되면', '화면 꺼짐 소리']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  요청사항 일반 stb 아들 방 tv 안됨 stb 전원 적색점 등재 부팅해도 동일 기량 자 방문 요청함 방문 시간 참고
# 요약 :  ['일반 stb 아들', '요청 사항 일반', '동일 기량 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 안됨셋 탑 전원 빨간 불 것 다 켜도 아무 반응 없음 최대한 빠른 방문 요청
# 요약 :  ['빠른 방문 요청', '켜도 아무 반응', '없음 최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  원룸 새로 입주 후 수신 불세 탑이 전혀 연결되어 있지 않음 취소 건 있음 일 방문 요청일은 늦게 근무해서 수리를 받을 수 없다고 하심
# 요약 :  ['전혀 연결 되어', '근무 해서 수리', '수리 받을 없다고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  채팅 AS 올레티브이 시청 안 됨 셋탑 계속 꺼진다고 하심 리셋해도 마찬가지 점검 요청 접수해 드림 셋탑 교체도 원하심 방문 전 연락 요청
# 요약 :  ['교체 원하', '셋탑 교체 원하', '리셋 해도 마찬가지']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불세 탑이 상 전원만 빨간불 들어오고 수동 조작도 안됨 안방 쪽만 안됨 코로나 이 상무역 후방
# 요약 :  ['수동 조작 안됨', '수신 불세 전원', '빨간 들어오고 수동']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  요청사항 tv 시청 중 화면 흔들리고 블랙 화면으로 멈춰 진행 안됨 재부팅해야 사용됨 리모컨 일부 버튼 작동 불 방문 시간 참고
# 요약 :  ['안됨 재부팅 해야', '버튼 작동 방문', '해야 사용 리모컨']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  스마트 셋탑 리모컨 안 됨이 사 방문 요청함
# 요약 :  ['리모컨 됨이', '스마트 셋탑', '됨이 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 안 됨 거실 인터넷 연결 오류 최대한 독촉
# 요약 :  ['인터넷 연결', 'tv 거실', '오류 최대한 독촉']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  미리 연 후방 요기가 지니 전원 off
# 요약 :  ['후방 요기', '요기 지니 전원', '전원 off']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  대 모두 수신 불이 인터넷 오류 최대한 빠른 점검 요청 연 후방
# 요약 :  ['점검 요청', '인터넷 오류 최대한', '오류 최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  TV 수신 불 연락 후인 입
# 요약 :  ['tv 수신', 'tv 수신 연락', '수신 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  층 tv 수신 불 조치 전 회복
# 요약 :  ['tv 수신', '조치 회복', '수신 조치']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  접속 불 ad 정상 리셋 오후 시 방문 요청함
# 요약 :  ['ad 정상', '오후 방문', '접속 ad']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불이 인터넷 지킴이와 pc 안심 가입
# 요약 :  ['수신 인터넷', '인터넷 지킴 pc', 'pc 안심 가입']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불 재부팅 후 정상 사용됨
# 요약 :  ['정상 사용', 'tv 수신', '수신 재부팅']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불 외부에서 선 끊어짐 댁에 사람 없음 외부 점검요 방문 전 연락요
# 요약 :  ['수신 외부', '에서 끊어짐 사람', '방문 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시시 수신 불 네트워크 오류 뜸 여러 번 재부팅해야 된다고 합근 본 점검 원함
# 요약 :  ['시시 수신', '해야 된다고', '합근 점검 원함']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 인식 안됨 교환 요청 택배 요청 택배 처리해 드림
# 요약 :  ['처리 드림', '인식 안됨', '택배 요청']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불수산 카드 오류 cas 전 송 후 정상 사용됨
# 요약 :  ['카드 오류 cas', '정상 사용', '수신 수산']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 안됨 인터넷 연결 오류리 셋
# 요약 :  ['인터넷 연결 오류', '인터넷 연결', '안됨 인터넷 연결']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불 네트워크 오류리 셋
# 요약 :  ['네트워크 오류', 'tv 수신', '수신 네트워크']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 안 됨 건전지 부분 스프링 고장 COP 게재
# 요약 :  ['부분 스프링 고장', '작동 건전지', 'cop 게재']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  거실 tv 수신 불 업그레이드 오류 최대한 빠른 점검 요청일 중으로 처리되도록 요청함 연후방
# 요약 :  ['되도록 요청', '빠른 점검 요청', '오류 최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  HD 리모컨 인식 안됨셋탑리셋 이후 리모컨 정상 사용됨
# 요약 :  ['셋탑 리셋', 'hd 리모컨', '리모컨 정상 사용']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불연 후방
# 요약 :  ['불연 후방', '수신 불연 후방', 'tv 수신']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  HDotv 리모컨 안됨 stb 재부팅 후 정상
# 요약 :  ['hdotv 리모컨', '안됨 stb', '재부팅 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불급일 방문 가능하면 앞당겨와 달라 합일은 시 방문요 방문 일정은 안내함
# 요약 :  ['방문 일정', '수신 불급 방문', '가능하면 앞당겨와 달라']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불두 대 다동 일일까지 기다릴 수 없음 일 방문 요청 집중 실통화 의뢰 후 문자 전송 요청
# 요약 :  ['의뢰 문자', '집중 통화', '까지 기다릴']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  요청사항 tv 대 안됨 댁내 배선 점검 요청함 스트림 에러 방문 시간 오후 시시 방문 요청함 빠른 일정 fm 확인 후 sms 전송 안내 참고
# 요약 :  ['배선 점검 요청', 'sms 전송 안내', '요청 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 음성은 나오나 화면 안 나옴 재부팅해 봄 연락 먼저
# 요약 :  ['나오나 화면', '음성 나오나 화면', '재부팅 연락 먼저']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불 관리자 빈번 입력창뜸코로나 미 대상
# 요약 :  ['창뜸 코로나', '수신 관리자', '관리자 빈번']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 끊김 미리 연락 후 방문 요망 지킴이가 입
# 요약 :  ['요망 지킴', '방문 요망', '연락 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  큰 방 tv 수신 불 stb 부 전원 안 켜짐 빨간 불 거 싫 tv는 잘 됨 화요일 방문 원함 안심 권유 인터넷 지킴이 실패
# 요약 :  ['켜짐 빨간', '수신 stb', '원함 안심 권유']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  TV 수신 불 연락 후 잦은 고장 불편 많음 stb 교체 언급 요청인 입
# 요약 :  ['stb 교체', '불편 많음 stb', 'tv 수신 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불 네트워크 오류 메시지 최대한 빠른 점검 필요
# 요약 :  ['수신 네트워크', '오류 메시지', '최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  TV 채널 화질 불량 지직 거림 빠른 방문 요청 근본 해결 코로나 미 대상
# 요약 :  ['요청 근본', '빠른 방문', '화질 불량 거림']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불이 인터넷 연결 오류 단말 구별 불가 주소로 임의 접수
# 요약 :  ['단말 구별', '불가 주소 임의', '주소 임의 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  요청사항 tv 화면 안 나옴 음성 정상셋 탑재 부팅해도 동일 방문 시간 참고
# 요약 :  ['정상 탑재 부팅', '동일 방문', '나옴 음성 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  TV 수신 불 연락 후 stb 전원 off인 입
# 요약 :  ['tv 수신', '전원 off', '연락 stb 전원']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 불 otsu hd 리모컨에 버튼을 안 눌러도 리모컨 led에 불이 계속 들어오면서 오작동이 됨은 후방
# 요약 :  ['otsu hd 리모컨', '리모컨 led 계속', '리모컨 버튼']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  안심권 유 tv 수신 불이 인터넷 오류역 후방
# 요약 :  ['인터넷 오류역 후방', 'tv 수신', '오류역 후방']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불 네트워크 오류 홈 ap 너무 뜨겁다며 문제 있는 건 아닌지 방문해서 확인요
# 요약 :  ['문제 있는', '해서 확인', '아닌지 방문 해서']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  otv 리모컨 안됨 stb 가까이에서는 되고 멀리서는 안됨 리모컨 페어링 stb 재부팅 cop에 택배 접수함
# 요약 :  ['리모컨 페어 stb', 'cop 택배 접수', 'stb 가까이 에서는']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  거실 화질이 상 시청 중 화면이 지 직거린 다심
# 요약 :  ['거실 화질', '시청 화면', '직거린 다심']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불 최대한 빠른 점검 요청
# 요약 :  ['점검 요청', '수신 최대한', '수신 최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  오전 정 전후 수신 불 코로나 미 대상 안심 권유
# 요약 :  ['대상 안심 권유', '전후 수신 코로나', '오전 전후']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 불가 otp 설정 방법 문자 전송도 함
# 요약 :  ['불가 otp', 'otp 설정 방법', '문자 전송']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 불비 정상 리셋 코로나 무 미리 연락요 비 정상
# 요약 :  ['정상 리셋', '정상 리셋 코로나', '시청 불비']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 시시로 안됨 시청 중 끊김 현상 연락처 못 받을 시 추가 연락처로 해달라 함
# 요약 :  ['추가 연락처', '끊김 현상 연락처', '현상 연락처 받을']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 부을 매장 안내 본인
# 요약 :  ['리모컨 작동', '안내 본인', '부을 매장 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 TV 수신 불 리셋
# 요약 :  ['tv 수신', '수신 리셋', '리셋 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 요청 코로나 이 상무 ots 수신 불량 입력 신 없음 셋 탑 전원 확인 재부팅해 봄 연
# 요약 :  ['없음 전원 확인', '상무 ots 수신', '코로나 상무 ots']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 대다 안됨 otv 시청 불광 케이블 장애 안내 장애 완료 후 연락요
# 요약 :  ['장애 안내', '시청 불광 케이블', '장애 완료']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 셋 탑 전원이 켜졌다 안 켜졌다 함 방문 전 연락요
# 요약 :  ['전원 켜졌다', '독촉 전원', '방문 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 시간 내 외 리콜 안내 수신 불
# 요약 :  ['시간 리콜', '리콜 안내 수신', '리셋 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불로 딩 중뜸 연 후방
# 요약 :  ['불로 중뜸 후방', '수신 불로', '중뜸 후방']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  대 중대는 TV 켜지는 속도 느림 대는 선재 연결 요청 위치 이동 없음 연락 후 방문
# 요약 :  ['이동 없음 연락', '요청 위치', '대는 선재 연결']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 당일 예약 취소 건 있으면 방문해달라 심확답불가 일시 시 tv 대순 신불 올인 홈 정상 포트리 셋 리 부팅 안내함
# 요약 :  ['취소 있으면 방문', 'tv 대순 올인', '독촉 당일 예약']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 수신 불
# 요약 :  ['리셋 접수', '접수 수신', '리셋 접수 수신']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불비 정상
# 요약 :  ['수신 불비', '불비 정상', '수신 불비 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 otv 시청 불스 트링 에러 포트 리셋 회선 꼼꼼 점검 요청 세톱 교체 수시 발행 불만 시험 불
# 요약 :  ['점검 요청 교체', '트링 에러 포트', '독촉 otv 시청']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 극심 수신 불
# 요약 :  ['극심 수신', '독촉 극심', '독촉 극심 수신']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 지니 사용 tv 대 서비스 시작 중 문구에서 안 넘어간 다함 장비 재부팅 안내 배정 시 미리 연 후방
# 요약 :  ['장비 재부팅 안내', '코로나 상무 지니', '안내 배정 미리']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 부을 자연 회복됨
# 요약 :  ['수신 부을', '부을 자연', '자연 회복']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 시간 내 외 리콜 안내 수신 불
# 요약 :  ['시간 리콜', '리콜 안내 수신', '리셋 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  빠른 방문 요청함 임의 회선 티브이 수 신불 주소 확인
# 요약 :  ['요청 임의', '빠른 방문', '임의 회선 티브이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시 처음 채널 만 나오고 채널 변경 안됨 stb 재부팅 확인함
# 요약 :  ['채널 변경 안됨', '재부팅 확인', '채널 나오고 채널']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  추가 x 일 오전 시시 방문 안내함 신미약
# 요약 :  ['방문 미약', '추가 오전', '오전 시시 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  otv 시청 불기가 지니 전원 접촉 불량
# 요약 :  ['접촉 불량', 'otv 시청', '지니 전원 접촉']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 로딩 중 나오면서 tv 수신 불시 간 내 외 안내
# 요약 :  ['수신 불시', '로딩 나오면서 tv', '로딩 나오면서']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 stb 전원 녹색 불에서 변동 안됨 연 후방
# 요약 :  ['녹색 에서', '변동 안됨', '에서 변동']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 임의 회선 otvstb 이상
# 요약 :  ['임의 회선', '상무 임의', 'otvstb 이상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  셋탑 전 원안 들어옴 정상
# 요약 :  ['셋탑 원안', '들어옴 정상', '원안 들어옴 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 안내함 otv 화면 안 나오면서 줄이 생긴 다함 stb 재부팅 요망
# 요약 :  ['stb 재부팅', 'otv 화면 나오면서', '나오면서 줄이 생긴']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  긴급 독촉 심함 차 리셋 후 동일 빠른 방문 원함 업무용 당일 취소 건 있을 경우 우선 방문 원함 리 셋 접수 TV 수신 불 리셋
# 요약 :  ['경우 우선 방문', '접수 tv 수신', '당일 취소']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불이 인터넷 연결 상태 확인 메시지 접수 중 정상 사용됨
# 요약 :  ['수신 인터넷', '확인 메시지', '정상 사용']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불 외부 신고함
# 요약 :  ['외부 고함', '수신 외부 고함', '수신 외부']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 시 tv 수신 부을 올인 홈 정상 포트리 셋 리 부팅 안내함
# 요약 :  ['부을 올인 정상', 'tv 수신 부을', '포트 부팅']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  자연 회복 osst
# 요약 :  ['회복 osst', '자연 회복', '자연 회복 osst']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  장비 장애 안내
# 요약 :  ['장애 안내', '장비 장애', '장비 장애 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  화질이 상장 비리 셋 안내 후 정상 정상
# 요약 :  ['정상 정상', '화질 상장 비리', '비리 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  셋탑박스 전원 선을 뺐다 꼽아야 전원이 켜진다고 함 연락 후 방문
# 요약 :  ['꼽아 전원', '켜진다고 연락 방문', '꼽아 전원 켜진다고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불장 비리 셋 동일 비정상
# 요약 :  ['동일 비정상', '수신 비리 동일', '수신 비리']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 대중 대 안됨 수신 불신 없음 전원 선 재부팅 후 동일
# 요약 :  ['불신 없음', '일시 대중', '전원 재부팅 동일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  stb 전원 이상 수동으로도 작동 안 됨 녹색 불이 안 들어 온 임의 회선 최대한 빠른 방문 요청하심
# 요약 :  ['으로도 작동', '빠른 방문', '빠른 방문 요청']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불대는 tv 고장으로 확인 안됨회 선 구분 어려워 임의 접수함 연후방
# 요약 :  ['고장 으로 확인', '구분 어려워 임의', '임의 접수 후방']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  otv 시청 불줄 생 김 시청 중멈춤 반복됨 포트 리셋 일정 점검했는데도 동일 wjdtkd
# 요약 :  ['불줄 시청 멈춤', '포트 리셋 일정', '점검 했는데도 동일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 부을 리모컨 작동 불가로 같이 점검 요청
# 요약 :  ['부을 리모컨 작동', '점검 요청', '불가 같이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로 나무 ots 실시간 시청은 되나 지니 음성 출시 인터넷 연결에 러뜸 방문 전 연락 원함
# 요약 :  ['나무 ots 실시간', '방문 연락 원함', '지니 음성 출시']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  otv 시청 불로딩 중 포트 리셋 시험 불
# 요약 :  ['리셋 시험', '로딩 포트', 'otv 시청']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임의 수신 불 stb 리 셋
# 요약 :  ['임의 수신', '수신 stb', '임의 수신 stb']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불 osst
# 요약 :  ['수신 osst', 'tv 수신', 'tv 수신 osst']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  고령자 오전 취소 건 있을 경우 우선 방문 원함 독촉 심함 차 리셋 후 동일 빠른 방문 원함 리 셋 접수시간 내외 리콜 안내 수신 불
# 요약 :  ['독촉 심함 리셋', '있을 경우 우선', '내외 리콜 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  부주의 쥐가 선을 갉았다고 하심 정상
# 요약 :  ['갉았다고 정상', '부주의 갉았다고 정상', '부주의 갉았다고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  취소 건 있으면 당겨서 점검 시청 불 리셋 코로나무 미리 연락요
# 요약 :  ['점검 시청 리셋', '미리 연락', '취소 있으면 당겨서']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 TV 수신 불 리셋
# 요약 :  ['tv 수신', '수신 리셋', '리셋 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  안 리모컨 파손 구매 접수 및 통합 설정 페어링 설정 문자 발송
# 요약 :  ['문자 발송', '파손 구매 접수', '접수 통합 설정']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  김현철 채팅 AS 셋 탑 작동 이상 댁내 셋탑 대가 모두 자동으로 꺼졌다 켜진다고 한 접수는 보류 요청함
# 요약 :  ['꺼졌다 켜진다고 접수', '댁내 셋탑', '김현철 채팅']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  otv 시청 부을 외부 입력 설정 시청 안 됨 셋톱 리셋 정상
# 요약 :  ['부을 외부', '입력 설정 시청', '셋톱 리셋 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임 의회 선 tv선 연결 요청 방문점검 요청 정상
# 요약 :  ['방문 점검', 'tv 연결 요청', '요청 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임의 수신 불주소 확인
# 요약 :  ['임의 수신', '임의 수신 주소', '수신 주소 확인']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임의 tv 수신 불 연락 후 방문
# 요약 :  ['임의 tv', 'tv 수신', '연락 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불선 끊김
# 요약 :  ['수신 불선', '불선 끊김', '수신 불선 끊김']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  부팅 중멈춤 셋탑을 교체해달라고 요청하심
# 요약 :  ['셋탑 교체', '부팅 멈춤', '셋탑 교체 해달라고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일리셋tv 대구 신불리 셋인 입
# 요약 :  ['리셋 tv', '대구 불리', 'tv 대구 불리']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 영상 안 나옴 음성 정상
# 요약 :  ['일시 영상', '나옴 음성', '음성 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  청소 후 화면 정상 음성은 나옴셋탑리셋 안내 외부라고 접수해 달라심
# 요약 :  ['나옴 셋탑 리셋', '화면 정상 음성', '청소 화면']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 시간 내 외 리콜 안내 수신 불
# 요약 :  ['시간 리콜', '리콜 안내 수신', '리셋 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  추가 x 일 오후 방문 안내함 음성이 상 tv 음성 송출됨셋탑재 부팅해도 동일 증상
# 요약 :  ['방문 음성', '해도 동일 증상', '음성 송출됨 탑재']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임의 화면 안 나옴 stb 문제인 게 리모컨 문제인 지 점검 요청
# 요약 :  ['문제 점검', '임의 화면 나옴', '나옴 stb']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  부재중이라 들어가서 하시면 된다며 연락 먼저 달라 함 tv 영상 끊김 흔들림 연락 후 방문
# 요약 :  ['하시면 된다며 연락', '들어가서 하시면', '먼저 달라 tv']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  이비인 됨 케이블 연결 상태 오류 뜸 녹색 외부 입력 확인함 빠른 점검요
# 요약 :  ['연결 상태 오류', '외부 입력 확인', '입력 확인 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  TV 시청 불신 없이 기가 지니 on 외부 입력 후 동일기가 지니 리셋 후 사용됨
# 요약 :  ['불신 없이 지니', 'tv 시청 불신', '지니 리셋 사용']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일리 셋 tv 수신 불 리셋
# 요약 :  ['tv 수신', '수신 리셋', '일리 tv']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 t v 수신 불
# 요약 :  ['리셋 접수 수신', '접수 수신', '리셋 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  TV 수신 불 연락 후 방문
# 요약 :  ['tv 수신', '연락 방문', '수신 연락 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  차 리셋 후 동일 빠른 방문 원함 잦은 고장 불만 꼼꼼하게 점검 요청 지난번 다녀간 엔지니어 말고 기술 뛰어난 엔지니어 방문 원함 민원 심함 리 셋 접수 수신 불
# 요약 :  ['엔지니어 방문 원함', '말고 기술 뛰어난', '불만 꼼꼼하게 점검']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필이 비수 신불 최대한 빠른 방문 희망 매장 인터넷 CableDown
# 요약 :  ['코로나 상무', '매장 인터넷', '비수 최대한 빠른']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 ots 시청 불수산 미약
# 요약 :  ['리셋 ots', '수산 미약', '시청 수산 미약']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불셋탑리셋 동일
# 요약 :  ['리셋 동일', '수신 불셋탑', '불셋탑 리셋 동일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 지참까지 해서 방문 요청함 추가 x 일 오전 시시 방문 안내 함수 신불 화면 안 나 옴셋탑재 부팅해도 동일 증상 언급
# 요약 :  ['해서 방문', '해도 동일 증상', '참까지 해서 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  아르빌 수 신불 시 방문 요청 외부 임의 코로나 이 상무
# 요약 :  ['외부 임의 코로나', '코로나 상무', '방문 요청']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 잘못 건드리고 tv 수신 불 엔지니어 확인되면 연락 먼저 요청
# 요약 :  ['먼저 요청', '리모컨 잘못 건드리고', '되면 연락 먼저']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  otv 시청 풀 화면 깨짐 연결 오류 세트 탑리 셋 정상
# 요약 :  ['otv 시청', '탑리 정상', '오류 세트 탑리']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필임의 회선 작은방 정상인
# 요약 :  ['임의 회선 작은방', '코로나 상무', '상무 확인 임의']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 피울 리모컨 버튼 누르면 초 뒤에 반응함 모뎀 셋톱 재부팅해도 동일 현상 반복 방문 점검 요청 정상
# 요약 :  ['반복 방문 점검', '셋톱 재부팅 해도', '반응 모뎀 셋톱']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 시간 전후 안내 화면 정상 음성 안 나옴
# 요약 :  ['안내 화면', '화면 정상 음성', '리셋 시간 전후']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  유튜브랑 넷플릭스 안됨 작은방 노트북도 같이 안됨 연 후방
# 요약 :  ['안됨 후방', '넷플릭스 안됨', '작은방 노트북 같이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티브이 전부 안됨 빠른 점검 요 인입
# 요약 :  ['전부 안됨', '점검 인입', '티브이 전부']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  취소 건 있을 시 챙겨서 방문 요청 독촉 코로나 이 상무 재확인 필 티 수신 불 바코드 확인
# 요약 :  ['요청 독촉 코로나', '챙겨서 방문', '취소 있을 챙겨서']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시시로 tv 수신 불
# 요약 :  ['tv 수신', '시시 tv', '시시 tv 수신']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  차 리셋 후 동일 빠른 방문 원함 당일 취소 건 있을 경우 우선 방문 원한 리셋 접수시간 내외 리콜 안내 수신 불
# 요약 :  ['원한 리셋', '취소 있을 경우', '내외 리콜 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 시간 화질 이상 화면 계속 끊어짐
# 요약 :  ['이상 화면', '화면 계속 끊어짐', '리셋 접수 시간']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티브이 교체 이후 티브이 수 신불 주소 확인
# 요약 :  ['이후 티브이 주소', '주소 확인', '교체 이후 티브이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필수신 불 화면 안 나옴 정상인
# 요약 :  ['필수 화면', '상무 확인', '나옴 정상인']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 중 끊김 연후방
# 요약 :  ['끊김 후방', '시청 끊김', '시청 끊김 후방']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  차 리셋 후 등 일부 재중이더라도 방문 요청 연락 주면 비번 확인해주신다고 함리셋 접수 로딩 중 나오면서 tv 수신 불시 간 내 외 안내
# 요약 :  ['리셋 일부 재중이', '확인 해주신다고', '재중이 더라도 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필티비셋 탑 전 원안 들어옴 정상
# 요약 :  ['코로나 상무', '티비 원안 들어옴', '원안 들어옴 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필 tv 볼륨이 상 방문점검요
# 요약 :  ['tv 볼륨 방문', '방문 점검', '코로나 상무']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  기가 지니 리모컨 작동 불 mns 매장 안내
# 요약 :  ['리모컨 작동', '지니 리모컨', '작동 mns 매장']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필 티 수신 불이 인터넷 연결 불 net 정상
# 요약 :  ['수신 인터넷', '연결 net 정상', '코로나 상무']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 otv 시청 뿔 셋 탑재 부팅해 보라 안내
# 요약 :  ['일시 otv 시청', 'otv 시청 탑재', '보라 안내']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  빠른 방문 요청함 화질이 상장 비리 셋 이후 동일 주소 확인
# 요약 :  ['주소 확인', '상장 비리 이후', '빠른 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 otv 인터넷 연결 오유
# 요약 :  ['인터넷 연결 오유', '코로나 상무', '코로나 상무 otv']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  벗기가 지니 응답 문의 리셋 진행 정상인
# 요약 :  ['지니 응답', '진행 정상인', '지니 응답 문의']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시 tv 대 모두 안됨 stb 재부팅 확인함
# 요약 :  ['모두 안됨', '재부팅 확인', 'tv 모두']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티브이 수 신불연 후방
# 요약 :  ['불연 후방', '티브이 불연', '티브이 불연 후방']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 TV 수신 불 리셋
# 요약 :  ['tv 수신', '수신 리셋', '리셋 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임 의회 선셋 탑 전 원안 들어옴 연락 후
# 요약 :  ['의회 선셋 원안', '선셋 원안', '들어옴 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불셋탑 정상이나 초록빛으로 뜨고 안 나 옴셋탑재 부팅 후 정상
# 요약 :  ['뜨고 옴셋', '불셋탑 정상 이나', '옴셋 탑재 부팅']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 시간 내 외 리콜 안내 수신 불
# 요약 :  ['시간 리콜', '리콜 안내 수신', '리셋 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  otv 지니 시청 불대만 안됨 엔지니어 접수해 놓으라고 했다 함 방문 전 연락 요청 코로나 이 상무
# 요약 :  ['지니 시청', '방문 연락 요청', '접수 놓으라고 했다']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  채널 전환 지연 셋탑 점검 후 교체 요청 방문 전 연락요
# 요약 :  ['채널 전환', '셋탑 점검', '방문 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 불가 모든 버튼 사용 안 됨 건전지 교체 이후 동일 주소 확인 무료 배송 등록함
# 요약 :  ['불가 모든 버튼', '무료 배송 등록', '교체 이후 동일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 대중 어머님 방이 비 안됨 화면에 업그레이드합니다 오류만 떠서 사라지지 않는 다심 재부팅해도 안 됨
# 요약 :  ['일시 대중 어머님', '사라지지 않는 다심', '화면 업그레이드 합니다']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 고장까지 같이 점검 요청함 추가 x 일 오전 시시 방문 안내함 메뉴 실행 불가 네트워크 오류 송출됨 안됨 said 링크 비정상 확인됨
# 요약 :  ['오전 시시 방문', 'said 링크 비정상', '까지 같이']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필 티브이 시청 부을 모뎀 셋톱 재부팅해도 동일 현상 반복 방문점검 요청 정상
# 요약 :  ['방문 점검 요청', '셋톱 재부팅 해도', '부을 모뎀 셋톱']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임 의회 선사탑 작동 이상
# 요약 :  ['작동 이상', '의회 선사', '선사 작동']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필 otv 시청 불 네트워크 오류 전체 리셋 안내 모뎀 정상인
# 요약 :  ['상무 확인 otv', '오류 전체 리셋', '리셋 안내 모뎀']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 중 화면 고정 셋톱 리셋 동일
# 요약 :  ['수신 화면', '리셋 동일', '화면 고정 셋톱']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불임의 회선 접수 바코드 확인 안됨
# 요약 :  ['확인 안됨', '수신 불임 회선', '접수 바코드 확인']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  TV 시청 불음 성안 나온다고 하고 기가 지니 리셋 후안 됨
# 요약 :  ['tv 시청', '시청 불음 성안', '나온다고 하고 지니']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상 무얼 아 전 리모컨 분실하여 새로 구매했는데 택배로 받으심 통합 설정한 먹는다 하심 설정 방법대로 확인 후해봐도 동일하다 함수 동 방법 동일 방문점검 요배 정시 미리 연 후방 대우 tv
# 요약 :  ['구매 했는데 택배', '통합 설정 먹는다', '했는데 택배 받으']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 시 tv 음성이 상 화면 정상 음성은 나 옴 stb 재부팅해봤다 심
# 요약 :  ['일시 tv 음성', '음성 화면 정상', '재부팅 해봤다']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 otv 시청 불
# 요약 :  ['otv 시청', '일시 otv 시청', '일시 otv']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불주소 확인
# 요약 :  ['수신 주소', '주소 확인', '수신 주소 확인']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  김현철 채팅 AS 셋 탑 작동 이상 고장 접수함 댁내 셋탑 대가 모두 저절로 꺼졌다 켜졌다 한다고 함 셋톱에 자동 전원 설정은 안 되어 있다고 함은 후방
# 요약 :  ['채팅 as 작동', '김현철 채팅 as', '작동 이상 고장']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필 tv 모니터 재설치 후 수신 불 연락 후 빠른 방문 요정상
# 요약 :  ['방문 정상', '상무 확인', '빠른 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 영업장 빠른 방문 요청 네트워크 오류 AD도 접속 불비 정상
# 요약 :  ['오류 ad 접속', '독촉 영업 빠른', 'ad 접속']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 otv 대 모두 인터넷 연결오유뜸 신비 정상
# 요약 :  ['연결 오유 신비', '신비 정상', '코로나 상무 otv']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필이 비수 신불도 대다수 신불 리셋 후에도 수신 불 정상인
# 요약 :  ['리셋 에도 수신', '확인 비수', '수신 정상인']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불셋탑리셋 동일
# 요약 :  ['리셋 동일', '수신 불셋탑', '불셋탑 리셋 동일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 TV 수신 불 리셋
# 요약 :  ['tv 수신', '수신 리셋', '리셋 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 otv 안내실 임의 회 선수 신분인 입
# 요약 :  ['내실 임의', '선수 신분', '코로나 상무 otv']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불안방 tv 안됨이 병인 직원 보내지 마라고 함
# 요약 :  ['tv 안됨이', '병인 직원', '수신 안방']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 로딩 증 상태로 수신 불
# 요약 :  ['로딩 상태 수신', '상태 수신', '접수 로딩 상태']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  최대한 늦게 방문 요청 리모컨 작동 불전원 led 깜빡거리면서 소리 난다며 교체 요청은 후방
# 요약 :  ['리모컨 작동', '소리 난다며 교체', '최대한 늦게 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불연 후방
# 요약 :  ['불연 후방', '수신 불연', '수신 불연 후방']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 중 음성이 상장 비리 셋
# 요약 :  ['상장 비리', '수신 음성', '수신 음성 상장']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  최대한 빠른 점검 요일 시 ots 신미약 오류 뜨면서 시청 불
# 요약 :  ['빠른 점검 요일', '요일 ots 미약', '오류 뜨면서']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 전환 지연
# 요약 :  ['리모컨 전환', '전환 지연', '리모컨 전환 지연']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시기가 지니 리모컨 일부 버튼 작동 불 stb 재부팅해도 안 됨
# 요약 :  ['지니 리모컨', '버튼 작동', 'stb 재부팅 해도']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  시청 중 끊김 임의
# 요약 :  ['끊김 임의', '시청 끊김', '시청 끊김 임의']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  급취소나 연기건 있음 앞당겨 요청 코로나 이 상무 otv 대중 대안방 수신 불량 최대한 빠른 방문 요청은
# 요약 :  ['기건 있음 앞당겨', 'otv 대중 안방', '코로나 상무 otv']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필 빠른 방문 요청 t v 볼륨이 상 방문점검요
# 요약 :  ['요청 볼륨 방문', '상무 확인', '빠른 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  원리모콘 파손 kos 등록 리모컨
# 요약 :  ['리모콘 파손', '등록 리모컨', 'kos 등록']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 취소 건이나 연기건 있으면 빠른 방문 요청 코로나 이 상무 otv 스트링 에러 m 시청 불포트리셋재부팅 네오스망 구성도 모뎀 정상
# 요약 :  ['방문 요청 코로나', '재부팅 오스 구성', '상무 otv 스트링']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  서비스 번 가입자 명이 문경아 연락처 인터넷 복명 확인됨 빠른 개통 희망
# 요약 :  ['복명 확인', '개통 희망', '빠른 개통']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불임의 stb 연 후방 엔지니어 배정 즉시 연락 요청
# 요약 :  ['수신 불임', '불임 stb 후방', '즉시 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  채널 전환 지연 티브이 켤 때도 늦게 켜진다며 방문 시 전체적 점검 요청 방문했던 엔지니어 말고 다른 엔지니어 방문 요청
# 요약 :  ['켜진다며 방문 전체', '방문 했던 엔지니어', '지연 티브이 늦게']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 TV 수신 불이 인터넷 연결 오류 메시지
# 요약 :  ['수신 인터넷 연결', '오류 메시지', '일시 tv 수신']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  최현재 셋탑 자동 이상 셋 탑 전원 적색불 수동으로 해도 동일함 셋탑 음성인식도 안됨 리셋 접수 TV 수신 불 리셋
# 요약 :  ['접수 tv', '동일함 셋탑 음성인식', '최현재 셋탑']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 otv 시청 뿔 셋 탑재 부팅해 봄
# 요약 :  ['일시 otv 시청', '탑재 부팅', 'otv 시청 탑재']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수방 TV 수신 불 리셋
# 요약 :  ['tv 수신', '수신 리셋', '리셋 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 부을 채널 아래 방향 버튼 작동 불 stb 재부팅 안내함 외부 신고 교체 요청 플라자 내방 가능하다 심으로 문자 전송함 페어링 통합 설정 문자 전송 함 대리인으로 otp 안 내 안함
# 요약 :  ['문자 전송 대리인', '요청 플라자 가능하다', '리모컨 작동 부을']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  Tv 시청 부을 번 전화하라고 나옴
# 요약 :  ['tv 시청', '전화하라고 나옴', '시청 부을 전화하라고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  넷플릭스 안됨 외부 신고함 보류셋 탑재 부팅 안내
# 요약 :  ['외부 고함 보류', '부팅 안내', '넷플릭스 안됨']
# ...
# 원본 :  멀 mt 화면 안 나 옴리셋
# 요약 :  ['화면 리셋', 'mt 화면', 'mt 화면 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  번 채널 만 화면이 번쩍거림 포트 리셋 장비 재부팅 안내 접수 보류
# 요약 :  ['포트 리셋 장비', '화면 번쩍 거림', '안내 접수 보류']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 방문 전 재확인 요망 tv 수신 불 리셋 안내 올인 홈 모뎀 정상인 입
# 요약 :  ['코로나 상무', '확인 요망 tv', '안내 올인 모뎀']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 건수신 불당일 ICOD 셋 탑 변경등록됨 고장 접수는 보류 안내함
# 요약 :  ['리셋 수신 당일', '당일 icod', '등록 고장 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  기가 지니 셋 탑 전원 접촉 불량 as 안내 주소가 상이하여 접수 불가 낼 다시 연락 주신다고 함
# 요약 :  ['지니 전원 접촉', '하여 접수 불가', '다시 연락 주신다고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  빠른 방문요 otv 화질 이상 화면이 녹색으로 만나오고 소리도 삑 소음이 들린다 심 여러 번 껐다 켰다 하면 다시 복구는 되나 동일 중상자 주 발생됨 일시 접수
# 요약 :  ['으로 만나오고', '소리 소음 들린다', '만나오고 소리 소음']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  기가 지니 리모컨 교체 문의 시 이후 아웃콜 예정
# 요약 :  ['지니 리모컨', '아웃 예정', '교체 문의 이후']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  vod 안됨 외부 임의 코로나 이 상무
# 요약 :  ['외부 임의', 'vod 안됨', '임의 코로나 상무']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필이 비 잘 켜지지 않음 자주 끊김 정상
# 요약 :  ['코로나 상무', '자주 끊김', '상무 확인']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  네트워크 오류 뜨면서 VOD 시청 안 됨
# 요약 :  ['뜨면서 vod', '뜨면서 vod 시청', '네트워크 오류']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일리셋 접수 tv 시청 불안방 tv만 안 됨선재 연결 메세지뜸올인 홈 모뎀 신정 상장 비리 셋
# 요약 :  ['상장 비리', '시청 안방 tv', '올인 모뎀 신정']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필 일시 이후 늦은 점검 요청함 이 수신 불 상태 인터넷 연결 오류 세트 탑리 셋 비정상
# 요약 :  ['요청 수신', '일시 이후 늦은', '오류 세트 탑리']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 수신 불 연락 후 건수무 가능한 빠른 점검 요청
# 요약 :  ['수신 연락', '가능한 빠른 점검', '연락 수무']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임의 수신 불연 후방
# 요약 :  ['불연 후방', '수신 불연', '임의 수신']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  멀티 빈 리모컨 일부 버튼 작동 부을 교체 요청은 후방 코로 나무 재탐색 필일 오전인 티 댁내 이전 접수됨 동시 처리 바람
# 요약 :  ['필일 오전 댁내', '버튼 작동 부을', '이전 접수 동시']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필봇티비수 신분 리모컨 작동 부을 리모컨이 됐다가 안됐다가 한다고 하시고 티브이도 나왔다가 안 나왔다가 하신 다 심정 상신
# 요약 :  ['나왔다가 하신 심정', '하시고 티브이 나왔다가', '됐다가 됐다가 한다고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  TV 화질 이상 화면 깨짐 방문 전 연락요
# 요약 :  ['tv 화질 이상', '화질 이상 화면', '방문 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  지니 전원 버튼 불량 뒤쪽 전원 누르면 적색 들어오다 손만 때면 전원 나감 지니 새 거로 교체요 연 후방일 오후 시
# 요약 :  ['나감 지니', '들어오다 전원', '전원 누르면 적색']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  멀 코로나 이 상무 재확인 필 티 수신 불 포트리 셋 영업용 포트 확인 불가
# 요약 :  ['포트 확인 불가', '코로나 상무', '수신 포트 영업']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  stb 작동 이상기가 지니 수 동작동 되다 안 되다 함 음성인식도 잘 안되고 다른 쪽 tv 리모컨도 잘 안 먹는 것 같다며 방문 요청은 후방
# 요약 :  ['되다 되다 음성인식', '음성인식 안되고 다른', 'tv 리모컨 먹는']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 안내 함대 대 안됨 otv 시청 부을 외부 기기 잘못됨 외부 신고 재부팅해도 안됨 금요일 저녁부터 안 됨
# 요약 :  ['외부 신고 재부팅', '해도 안됨', '해도 안됨 금요일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불리모콘 작동 이상인지 같이 점검 요청 연락 후 방문
# 요약 :  ['이상 인지 같이', '연락 방문', '점검 요청']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 안됨 연 후방
# 요약 :  ['안됨 후방', '리모컨 안됨', '리모컨 안됨 후방']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  STB 전원 OFF
# 요약 :  ['stb 전원', 'stb 전원 off', '전원 off']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불 파워 오프
# 요약 :  ['수신 파워', '파워 오프', '수신 파워 오프']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 tv 시청 부을 외부 입력 확인 셋톱 리셋 동일 링크 정상 fm 확인 시 당일 어렵다 함
# 요약 :  ['fm 확인', '셋톱 리셋 동일', '당일 어렵다']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상 무안 방수 시 수신 불망 구성도 셋탑 정상 초기화인
# 요약 :  ['정상 초기 화인', '수신 불망 구성', '불망 구성 셋탑']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 건수신 불 네트워크 오류 재부팅 후 동일 오늘만 시간 됨 부서 전달 시간 변경 못함 고객은 당일만 시간 됨 연 후방
# 요약 :  ['고객 당일 시간', '부서 전달', '변경 고객 당일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  TV 네트워크 오류역 후방 무선 와이파이도 같이 점검 요청 KT 공유기라고 함어 실패
# 요약 :  ['후방 무선', '같이 점검', '오류역 후방 무선']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  기가 지니 음성명령으로 TV 온 오프 시 셋탑만 꺼짐이 전 설치 이후 증상 발생 연 후방
# 요약 :  ['지니 음성 명령', 'tv 오프 셋탑', '설치 이후']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 시시 수신 불량 둘 다 점검 요청 임의 회선 코로나 증상무
# 요약 :  ['일시 시시 수신', '불량 점검', '회선 코로나 증상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티브이 화면에 업데이트 메시지 지속적으로 뜨며 리모컨 작동 안 된다고 하심 티브이 문제인 지 방문점검요
# 요약 :  ['뜨며 리모컨 작동', '업데이트 메시지 지속', '티브이 문제 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 시간 내외 tv 시청 중 화면 지지직거림
# 요약 :  ['tv 시청', '리셋 접수', '접수 시간 내외']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  수신 불일 시 요망 코로 나무
# 요약 :  ['불일 요망 코로', '수신 불일 요망', '코로 나무']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 빠른 방문 요청 취소나 우선 방문 가능 시에 먼저 방문 요청 일시 안내 대다수 신불 리셋 안내
# 요약 :  ['독촉 빠른 방문', '요청 일시 안내', '가능 먼저']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  멀 TV 수신 불 코로나 이 상 아무 월일 목요일 시시 사이 방문 요청
# 요약 :  ['사이 방문 요청', '목요일 시시', 'tv 수신 코로나']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 tv 수신 불 재부팅 후에도 동일 코로 나무
# 요약 :  ['재부팅 에도', '동일 코로 나무', '일시 tv 수신']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 택배 대리인
# 요약 :  ['택배 대리인', '리모컨 택배', '리모컨 택배 대리인']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일리셋 접수 tv 영상만 시청 불음 성나 옴 초기화
# 요약 :  ['불음 성나 초기', '접수 tv 영상', '시청 불음 성나']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필 안방 tv 수신 불
# 요약 :  ['tv 수신', '코로나 상무', '확인 안방']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수건 tv 수신 불 재부팅 후 동일 증상 연후방
# 요약 :  ['tv 수신 재부팅', '리셋 수건', '동일 증상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  AS 리 셋이 관 TV 수신 불 리셋
# 요약 :  ['as tv', 'tv 수신', '수신 리셋']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  차 리셋해도 동일 연락 후 방문 요리 셋 접수 시간 내외 티브이 수 신불
# 요약 :  ['요리 접수 시간', '시간 내외 티브이', '리셋 해도 동일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  재연결 후 일부 채널 안 나옴 연 후방
# 요약 :  ['일부 채널', '나옴 후방', '채널 나옴']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  차 tv 화질이 상 줄 그어지는 증상 있음 접수 보류 리세 접수 tv 화질이 상 화면에 줄 그어져 있고 파랗게 뜸
# 요약 :  ['증상 있음 접수', '접수 보류 리세', '화질 화면 있고']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임의 수신 불주소 확인
# 요약 :  ['임의 수신', '임의 수신 주소', '수신 주소 확인']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  월 일리 셋 접수 시청 불로딩 나오다 아무것도 안 나오며 시청 불
# 요약 :  ['시청 로딩', '일리 접수', '로딩 나오다 아무']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  쿠폰기가 지니 음성인식 잘 안됨
# 요약 :  ['음성인식 안됨', '쿠폰 지니 음성인식', '지니 음성인식']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  최대한 빠른 방문 요청 거실 티브이신 미약 수신 불인
# 요약 :  ['티브이 미약 수신', '요청 거실 티브이', '빠른 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필수신 불 화면 안 나 옴 셋탑 교체 요청인 부재 시
# 요약 :  ['코로나 상무', '요청 부재', '필수 화면 셋탑']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  tv 수신 불연 후방 가능하다면 오늘 방문 요청하심
# 요약 :  ['수신 불연', '수신 불연 후방', '가능하다면 오늘 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필 셋탑 노후되어 교체 요 청동 일 김종임 안내
# 요약 :  ['코로나 상무 확인', '청동 김종', '교체 청동 김종']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티브이 선재 연결 위치 이동 없음
# 요약 :  ['선재 연결', '이동 없음', '티브이 선재']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  채널 전환 지연 방문 전 연락요
# 요약 :  ['채널 전환 지연', '지연 방문', '방문 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 작동 부을 본인 직영점 otp 안내
# 요약 :  ['리모컨 작동 부을', 'otp 안내', '부을 본인 직영']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  TV 화질 이상 TV 시청 중 시시 끊김 방문 전 연락요 시쯤 방문 요청
# 요약 :  ['화질 이상', '연락 방문', '시시 끊김 방문']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일리셋 접수 tv 시청 불 초기화
# 요약 :  ['tv 시청', 'tv 시청 초기', '리셋 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수건 TV 대 모두 수신 불
# 요약 :  ['수건 tv', '리셋 수건', '모두 수신']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 tv 시청 불대주대만 안 됨
# 요약 :  ['tv 시청', '대주 대만', '코로나 상무']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  층 TV 수신 부을 외부 신고 임의 접수연 후방
# 요약 :  ['외부 신고 임의', 'tv 수신 부을', '임의 접수 후방']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  댁에 없으시니 전화 방문 전 필수 지니 전원 빨간불 흰 불로 안 바뀜 리셋 후 동일 정상
# 요약 :  ['불로 바뀜 리셋', '없으시니 전화 방문', '리셋 동일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  월 일시 거실에 설치된 tv소리는 나오는 대화면 안 나옴
# 요약 :  ['설치 tv 소리', '일시 거실 설치', '소리 나오는 대화면']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  임의 일시 셋탑 불이 안 들어온 다 함수인 불
# 요약 :  ['임의 일시 셋탑', '들어온 함수', '일시 셋탑 들어온']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 고장 일반 리모컨 받고 싶다 심 opt 거 q n 통합발송완
# 요약 :  ['opt 통합 발송', '일반 리모컨', '받고 싶다']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리모컨 안됨 m ns 매장 확인하니 재고 없다고 한 택배 배송 otp 통합 설정 sms 발송함
# 요약 :  ['통합 설정 sms', '하니 재고 없다고', '배송 otp 통합']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 시간 내외 tv 시청 중 끊김
# 요약 :  ['내외 tv', 'tv 시청', '리셋 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  채팅셋 탑 전 원안 들어옴 전원 선뺐 다 꽂아도 동일
# 요약 :  ['채팅 원안', '들어옴 전원', '전원 꽂아도 동일']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  화면에 가운뎃줄이 생기고 화면이 흔들린다고 합동일 증상으로 TV 쪽으로 문의했으나 이상 없다고 재방문 요청은 후방
# 요약 :  ['으로 tv 으로', '흔들린다고 동일 증상', '문의 했으나 이상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 건 접수 지니 수신 불
# 요약 :  ['접수 지니', '지니 수신', '리셋 접수']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 tv 교체 후 stb 재 연결 요청 위치 이동 x 배정 시 미리 연 후방 정상
# 요약 :  ['연결 요청 위치', 'tv 교체 stb', '미리 후방 정상']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  코로나 이 상무 재확인 필 화면 안 나옴 연락 후
# 요약 :  ['확인 화면', '코로나 상무', '나옴 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  일시 안내 빠른 방문 요청일 개통으로 불만 잦은 고장 보임 mt 시청 부을 올인 홈 정상
# 요약 :  ['보임 mt 시청', '일시 안내 빠른', '으로 불만 잦은']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  스카이라이프팀 대 모두 수신 불연 방문 전 연락요
# 요약 :  ['불연 방문', '스카이라이프 모두 수신', '방문 연락']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  티브이 수 신불 fm 통화 연후방
# 요약 :  ['통화 후방', 'fm 통화', '티브이 fm']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  네트워크 오류 진단 정상
# 요약 :  ['네트워크 오류', '진단 정상', '네트워크 오류 진단']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 접수 이 채널 돌릴 때마다 화질 흔들리고 깨짐
# 요약 :  ['마다 화질', '리셋 접수 채널', '흔들리고 깨짐']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  멀티비 안됨 임의 접수 코로나 무임 규동 직원이 접수함
# 요약 :  ['코로나 무임 규동', '멀티 안됨', '접수 코로나 무임']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  리셋 건층 수신 불 재부팅 후 동이연 후방
# 요약 :  ['수신 재부팅', '이연 후방', '리셋 건층']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  독촉 빠른 방문 요청 임의 회선 넷 플리스 시청 불가 fm 현장 전달 오후에만 가능하다 심정상
# 요약 :  ['현장 전달 오후', '에만 가능하다', 'fm 현장 전달']
# ----------------------------------------------------------
# ----------------------------------------------------------
# 원본 :  방문 전 연락 필 일이 전 중기가 지니 리모컨 파손 교체 비용 청구 안내와는 코로나 이 상무
# 요약 :  ['코로나 상무', '청구 안내', '일이 중기 지니']
# ----------------------------------------------------------

# %%
df['sentence']

# %%
abstract_sen
# Out:
# [['자연 회복', '상담 자연', '안됨 상담'],
#  ['오류 재부팅 모텔', '점검 원하여', '모텔 영업 점검'],
#  ['특이 진단 결과', '결과 후방', '회선 단말'],
#  ['네트워크 오류', '수신 네트워크', '접수 보류'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['포트 리셋', '미리 연락', '정상 넷플릭스 안됨'],
#  ['단말 특이 진단', '수신 서비스', '시작 회선'],
#  ['김현철 채팅', '자체 에서 잡음', '받았으나 소리 난다고'],
#  ['진단 결과', '난다 리셋', '따닥거리 소리'],
#  ['반복 연락 회선', '불량 시청', '화질 불량 시청'],
#  ['특이 진단 결과', '결과 후방', '회선 단말'],
#  ['방문 요망 회선', '진단 결과', '빠른 방문'],
#  ['포트 리셋', '빠른 방문', '리셋 연락 최대한'],
#  ['스트림 에러 회복', '진단 결과', '회선 단말'],
#  ['리셋 정상', '안됨 리셋', '안됨 리셋 정상'],
#  ['입수 재부팅', '정상 사용', '인터넷 지킴 입수'],
#  ['실행 불가', '리셋 회선', '진단 결과'],
#  ['회선 단말 특이', '진단 결과', '최대한 빠른'],
#  ['안됨 리모컨', '리모컨 계속 매장', '매장 안내'],
#  ['수신 불셋', '정상 확인', '수신 불셋 탑재'],
#  ['정상 사용', '작동 불셋 탑재', '리모컨 작동 불셋'],
#  ['들어옴 의뢰', '원안 들어옴', '원안 들어옴 의뢰'],
#  ['들어옴 의뢰', '원안 들어옴', '원안 들어옴 의뢰'],
#  ['단말 특이 시험', '회선 단말', '코로나 대상'],
#  ['탑재 부팅', '해도 동일 보류', '안됨신 없음 외부'],
#  ['진단 결과', '요청 단말 특이', '되도록 오전'],
#  ['끊어짐 코로나', '회선 단말 특이', '수신 평소 화면'],
#  ['연결 오류 재부팅', '동일 방문', '연결 오류'],
#  ['회선 단말', '진단 결과', '정상 사용'],
#  ['외부 입력', '안됨신 없음', '정상 사용'],
#  ['올레 티비 정상', '음향 들림 셋탑', '정상 음향 들림'],
#  ['리모컨 반응 느림', '셋탑 리셋 정상', '불과 리모컨 반응'],
#  ['민원 최대한', '빠른 점검 회선', '연결 오류 점검'],
#  '안 됨',
#  ['조회 안됨 전원', '해도 동일 방문', '눌러도 반응'],
#  ['수신 불기', '랜선교체 요청 회선', '헐거워져서 자꾸 빠진다고'],
#  ['대상 회선 단말', '진단 결과', '방수 코로 나미'],
#  ['방문 해서 확인', '연결 지니 정상', '안됨 방문 해서'],
#  ['티비 전원 의뢰', '안됨 티비 전원', '전원 의뢰 안내'],
#  ['방수 불시', '회선 단말 특이', '진단 결과'],
#  ['연결 오류 회선', '단말 특이 시험', '코로나 대상'],
#  ['회선 단말', '코로나 대상', '차단기 내려간'],
#  '안 됨',
#  ['단말 특이', '점검 요청 회선', '오류 최대한 빠른'],
#  ['안됨 탑재', '수신 불방쪽', '탑재 부팅 정상'],
#  ['진단 결과', '연결 오류 재부팅', '먼저 회선'],
#  ['진단 결과 코로나', '정도 시청 되면', '화면 꺼짐 소리'],
#  ['일반 아들 방안', '동일 기량 방문', '기량 방문 요청'],
#  ['최대한 빠른 방문', '없음 최대한', '켜도 아무 반응'],
#  ['요청 늦게', '근무 해서 수리', '수리 받을 없다고'],
#  ['점검 요청 접수', '시청 셋탑 계속', '심리 해도 마찬가지'],
#  ['단말 특이 진단', '빨간 들어오고 수동', '들어오고 수동'],
#  ['흔들리고 블랙 화면', '버튼 작동 방문', '해야 사용 리모컨'],
#  ['회선 단말 특이', '리모콘 기사 방문', '방문 요청'],
#  ['인터넷 연결', '인터넷 연결 오류', '최대한 독촉'],
#  ['지니 전원 회선', '요기 지니', '진단 결과'],
#  ['요청 회선', '빠른 점검', '인터넷 오류 최대한'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['수신 조치', '수신 조치 회복', '조치 회복'],
#  ['정상 리셋', '오후 방문', '방문 요청'],
#  ['특이 진단 결과', '가입 회선 단말', '안심 가입 회선'],
#  ['회선 단말', '진단 결과', '정상 사용'],
#  ['단말 특이 진단', '진단 결과', '끊어짐 사람 없음'],
#  ['원함 회선', '해야 된다고', '점검 원함'],
#  ['인식 안됨', '처리 드림', '택배 요청'],
#  ['수신 불수신 카드', '정상 사용', '오류 전송'],
#  ['인터넷 연결', '오류 리셋', '안됨 인터넷 연결'],
#  ['수신 네트워크', '오류 리셋', '진단 결과'],
#  ['안됨 건전지', '스프링 고장', '스프링 고장 게재'],
#  ['업그레이드 오류', '되도록 요청 회선', '오류 최대한 빠른'],
#  ['리셋 이후 리모콘', '리모콘 정상 사용', '셋탑 리셋'],
#  ['특이 진단 결과', '결과 후방', '회선 단말'],
#  ['안됨 재부팅', '안됨 재부팅 정상', '재부팅 정상'],
#  ['단말 특이 진단', '방문 일정', '가능하면 앞당겨와 달라'],
#  ['수신 대다 일일', '요청 회선', '기다릴 없음 방문'],
#  ['스트림 에러 방문', '댁내 배선 점검', '요청 빠른'],
#  ['먼저 회선', '음성 나오나 화면', '안나 재부팅 연락'],
#  ['회선 단말 특이', '창뜸 코로나', '관리자 핀번'],
#  ['요망 지킴 회선', '방문 요망 지킴', '연락 방문'],
#  ['특이 진단 결과', '원함 인터넷 지킴', '빨간 불거실는'],
#  ['고장 불편', '불편 많음', '언급 요청'],
#  ['필요 회선 단말', '메세지 최대한', '빠른 점검'],
#  ['나미 대상', '방문 요청', '직거림 빠른 방문'],
#  ['주소 임의 접수', '단말 특이 진단', '연결 오류 단말'],
#  ['시간 참고', '동일 방문', '음성 정상 탑재'],
#  ['특이 진단', '전원 회선 단말', '연락 전원'],
#  ['리모컨 계속 들어오면서', '작동 후방 회선', '리모컨 버튼'],
#  ['진단 결과', '오류 회선', '회선 단말'],
#  ['있는 아닌 방문', '해서 확인', '오류 너무 뜨겁다며'],
#  ['서는 안됨 리모컨', '재부팅 택배 접수', '택배 접수'],
#  ['시청 화면', '단말 특이 진단', '화면 직거린 회선'],
#  ['회선 단말 특이', '점검 요청 회선', '최대한 빠른'],
#  ['수신 회선 단말', '코로나 대상', '오전 전후'],
#  ['진단 결과', '전송 회선 단말', '작동 불가 설정'],
#  ['시청 비정상', '비정 상기 추가', '미리 연락'],
#  ['추가 연락처', '끊김 현상 연락처', '현상 연락처 받을'],
#  ['회선 단말', '안내 본인', '불매 안내 본인'],
#  ['수신 리셋', '진단 결과', '단말 특이'],
#  ['코로나 상무 수신', '전원 확인 재부팅', '수신 불량 입력'],
#  ['장애 안내', '시청 불광 케이블', '장애 완료'],
#  ['방문 연락', '연락 회선 단말', '전원 켜졌다 켜졌다'],
#  ['리콜 안내 회선', '접수 시간', '단말 특이'],
#  ['후방 회선 단말', '진단 결과', '단말 특이'],
#  ['회선 단말', '진단 결과', '결과 정상기'],
#  ['요청 위치', '방문 회선 단말', '대는 선재 연결'],
#  ['해달라 확답 불가', '있으면 방문 해달라', '독촉 당일 예약'],
#  ['특이 진단', '진단 결과', '회선 단말'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['특이 진단 결과', '회선 단말', '추가 연락처'],
#  ['꼼꼼 점검 요청', '교체 수시 발행', '독촉 시청 스트'],
#  ['독촉 극심', '진단 결과', '회선 단말'],
#  ['장비 재부팅 안내', '코로나 상무 지니', '안내 배정 미리'],
#  ['수신 불자 연회', '수신 불자', '연회 복됨'],
#  ['리콜 안내 회선', '접수 시간', '단말 특이'],
#  ['요청 임의', '주소 확인', '빠른 방문'],
#  ['안됨 재부팅 확인', '나오고 채널 변경', '처음 채널 나오고'],
#  ['방문 미약', '추가 오전', '오전 시시 방문'],
#  ['회선 단말', '전원 접촉', '시청 불기 지니'],
#  ['불시 안내 회선', '리셋 접수', '접수 로딩 나오면서'],
#  ['에서 변동 안됨', '후방 회선 단말', '진단 결과'],
#  ['회선 이상 회선', '진단 결과', '코로나 상무'],
#  ['회선 단말 특이', '결과 정상기 추가', '원안 들어'],
#  ['재부팅 요망', '줄이 생긴', '나오면서 줄이 생긴'],
#  ['접수 수신 리셋', '독촉 심함 리셋', '업무 당일 취소'],
#  ['상태 확인', '메세지 접수', '접수 정상 사용'],
#  ['외부 고함', '수신 외부 고함', '수신 외부'],
#  ['시시 올인 정상', '리셋 부팅', '시시 올인'],
#  ['특이 진단', '회선 단말', '자연 회복'],
#  ['장애 안내', '장비 장애', '장비 장애 안내'],
#  ['안내 정상 회선', '추가 연락처', '화질 장비 리셋'],
#  ['꼽아 전원', '셋탑박스 원선 뺐다', '꼽아 전원 켜진다고'],
#  ['티비 끊김 회선', '특이 진단 결과', '회선 단말'],
#  ['회선 단말', '결과 비정 상기', '추가 연락처'],
#  ['불신 없음 전원', '없음 전원 선재', '전원 선재'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['빠른 방문', '방문 요청 회선', '으로도 작동'],
#  ['단말 특이 진단', '회선 단말 특이', '안됨 구분 어려워'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['불줄 시청 멈춤', '리셋 일정 점검', '점검 했는데도 동일'],
#  ['요청 회선 단말', '불가 같이', '점검 요청 회선'],
#  ['코로 나무 실시간', '시청 되나지니', '되나지니 음성 출시'],
#  ['포트 리셋 회선', '시청 로딩 포트', '불기 추가 연락처'],
#  ['수신 리셋', '임의 수신', '임의 수신 리셋'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['있을 경우 우선', '독촉 심함 리셋', '내외 리콜 안내'],
#  '수신불',
#  ['진단 결과 정상기', '추가 연락처', '부주의 갉았다고 회선'],
#  ['미리 연락', '점검 시청 리셋', '취소 있으면 당겨서'],
#  ['수신 리셋', '진단 결과', '단말 특이'],
#  ['문자 발송', '파손 구매 접수', '접수 통합 설정'],
#  ['으로 꺼졌다 켜진다고', '김현철 채팅', '작동 이상 셋탑'],
#  ['설정 시청 셋탑', '정상기 추가', '추가 연락처'],
#  '수신불',
#  ['정상기 추가', '점검 요청 회선', '정상기 추가 연락처'],
#  ['회선 단말 특이', '임의 수신', '주소 확인'],
#  ['회선 단말 특이', '임의 수신', '연락 방문'],
#  ['수신 불선', '불선 끊김', '수신 불선 끊김'],
#  ['진단 결과', '멈춤 셋탑 교체', '셋탑 교체 달라'],
#  '일리셋대수신불리셋인 입',
#  ['일시 영상', '나옴 음성', '음성 정상'],
#  ['청소 화면 정상', '음성 나옴', '진단 결과'],
#  ['리콜 안내 회선', '접수 시간', '단말 특이'],
#  ['음성 이상 음성', '부팅 해도 동일', '음성 송출됨 탑재'],
#  ['문제 리모컨', '임의 화면', '화면 안나'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['흔들림 연락', '들어가서 하시면', '먼저 달라 영상'],
#  ['연결 상태 오류', '외부 입력 확인', '입력 확인 빠른'],
#  ['음기 지니 외부', '리셋 사용 회선', '일기 지니 리셋'],
#  ['수신 리셋', '리셋 수신', '리셋 수신 리셋'],
#  '리셋 접수 수신불',
#  ['특이 진단', '회선 단말', '연락 방문'],
#  ['심함 리셋 접수', '꼼꼼하게 점검', '말고 기술 뛰어난'],
#  ['상무 확인 티비', '특이 최대한 빠른', '방문 희망 매장'],
#  ['회선 단말', '미약 회선 단말', '시청 불수신 미약'],
#  ['단말 특이 진단', '수신 불셋탑', '리셋 동일 회선'],
#  ['방문 안내 함수', '부팅 해도 동일', '참까지 해서'],
#  ['코로나 이상무', '수신 불시 방문', '요청 외부'],
#  ['건드리고 수신 회선', '리모컨 잘못 건드리고', '되면 연락 먼저'],
#  ['연결 오류 리셋', '정상기 추가 연락처', '시청 불화 깨짐'],
#  ['상무 확인', '단말 특이', '회선 작은'],
#  ['반복 방문 점검', '셋톱 재부팅 해도', '반응 모뎀 셋톱'],
#  ['음성 나옴 회선', '리셋 시간 전후', '안내 화면 정상'],
#  ['작은 노트북', '회선 단말 특이', '넷플릭스 안됨'],
#  ['점검 요인', '빠른 점검 요인', '전부 안됨'],
#  ['취소 있을', '취소 있을 챙겨서', '필티 수신 바코드'],
#  ['특이 진단 결과', '시시 회선', '단말 특이'],
#  ['내외 리콜 안내', '원함 리셋', '있을 경우 우선'],
#  ['화면 계속 끊어짐', '이상 화면', '리셋 접수 시간'],
#  ['회선 단말', '확인 회선 단말', '이후 티비 주소'],
#  ['확인 수신 불화', '단말 특이', '정상기 추가 연락처'],
#  ['후방 회선 단말', '진단 결과', '시청 끊김 후방'],
#  ['나오면서 불시 안내', '리셋 일부 재중이', '비번 확인 해주신다고'],
#  ['상무 확인 티비', '전원 들어', '단말 특이'],
#  ['점검 회선 단말', '코로나 상무', '볼륨 방문'],
#  ['리모컨 작동 불매', '지니 리모컨', '불매 안내'],
#  ['상무 확인', '코로나 상무', '추가 연락처'],
#  ['일시 시청 불셋', '일시 시청', '부팅 보라'],
#  ['빠른 방문 요청', '이후 동일 주소', '화질 장비 리셋'],
#  ['티비 끊김 회선', '특이 진단 결과', '회선 단말'],
#  ['연결 오유 회선', '진단 결과', '코로나 상무'],
#  ['단말 특이', '지니 응답', '정상기 추가 연락처'],
#  '독촉 수신불',
#  ['모두 안됨', '재부팅 확인', '시대 모두'],
#  ['티비 불연 후방', '후방 회선', '진단 결과'],
#  ['수신 리셋', '진단 결과', '단말 특이'],
#  ['회선 단말 특이', '원안 들어', '선셋탑 원안'],
#  ['회선 단말 특이', '수신 불셋탑', '탑재 부팅 정상'],
#  ['리콜 안내 회선', '접수 시간', '단말 특이'],
#  ['요청 단말 특이', '지니 시청', '접수 놓으라고 했다'],
#  ['요청 방문 연락', '연락 회선', '셋탑 점검 교체'],
#  ['교체 이후 동일', '불가 모든 버튼', '배송 등록'],
#  ['사라지지 않는 다심', '떠서 사라지지', '화면 업그레이드 합니다'],
#  ['오전 시시 방문', '링크 비정상 확인', '까지 같이'],
#  ['현상 반복 방문', '시청 모뎀 셋톱', '셋톱 재부팅 해도'],
#  ['회선 단말', '진단 결과', '결과 정상기'],
#  ['특이 진단', '회선 단말', '작동 이상'],
#  ['상무 확인 시청', '모뎀 정상기 추가', '오류 전체 리셋'],
#  ['진단 결과', '리셋 동일 회선', '화면 고정 셋탑'],
#  ['확인 안됨 회선', '회선 단말 특이', '접수 바코드 확인'],
#  ['리셋 후안', '지니 리셋 후안', '나온다고 하고 지니'],
#  ['통합 설정 먹는다', '상무 얼마 리모컨', '했는데 택배 받으'],
#  ['정상 음성 재부팅', '이상 화면', '일시 음성'],
#  '일시 시청불',
#  ['단말 특이 진단', '회선 단말', '주소 확인'],
#  ['저절로 꺼졌다 켜졌다', '작동 이상 고장', '김현철 채팅'],
#  ['상무 확인 모니터', '연락 빠른 방문', '설치 수신 연락'],
#  ['추가 연락처', '오류 접속', '독촉 영업 빠른'],
#  ['특이 진단', '회선 단말', '상무 모두'],
#  ['에도 수신', '신기 추가', '코로나 상무'],
#  ['단말 특이 진단', '수신 불셋탑', '리셋 동일 회선'],
#  ['수신 리셋', '진단 결과', '단말 특이'],
#  ['상무 내실', '진단 결과', '선수 입회 선단'],
#  ['방안 됨이 병인', '보내지 마라 고함', '직원 보내지'],
#  ['로딩 상태 회선', '회선 단말 특이', '접수 로딩 상태'],
#  ['의회 회선 단말', '특이 진단 결과', '회선 단말'],
#  ['소리 난다며 교체', '요청 리모컨', '최대한 늦게 방문'],
#  ['특이 진단 결과', '결과 후방', '회선 단말'],
#  ['진단 결과', '리셋 회선 단말', '수신 음성 장비'],
#  ['점검 요일', '요일 시신 미약', '오류 뜨면서'],
#  ['전환 지연', '단말 특이 진단', '리모컨 전환'],
#  ['지니 리모컨 일부', '일부 버튼 작동', '시기 지니'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['진단 결과', '단말 특이 임의', '끊김 회선'],
#  ['불량 최대한 빠른', '단말 특이', '요청 코로나 상무'],
#  ['요청 볼륨', '코로나 상무 확인', '상무 확인 빠른'],
#  ['리모콘 파손', '파손 등록', '등록 리모컨'],
#  ['오스 구성 모뎀', '포트 리셋 재부팅', '기건 있으면 빠른'],
#  ['개통 희망', '명문 경아', '빠른 개통'],
#  ['단말 특이', '즉시 연락', '요청 단말 특이'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['방문 전체 점검', '엔지니어 방문 요청', '티비 늦게 켜진다며'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['인터넷 연결', '오류 메세지', '연결 오류 메세지'],
#  ['셋탑 음성인식 안됨', '리셋 접수', '동일함 셋탑 음성인식'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['일시 시청', '불셋 탑재 부팅', '일시 시청 불셋'],
#  ['진단 결과', '리셋 회선 단말', '접수 방수'],
#  ['요청 플라자', '전송 페어 통합', '외부 신고 교체'],
#  ['회선 단말 특이', '시청 번전', '시청 번전 화하라고'],
#  ['안됨 외부 고함', '고함 보류', '고함 보류 탑재'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['회선 단말 특이', '부팅 해도 동일', '화면 나오고 소리'],
#  ['탑재 부팅', '요청 티비 발생', '영업 최대한 빠른'],
#  ['시간 전후 리콜', '화면 나옴 소리', '들림 회선 단말'],
#  ['됐다 됐다 반복', '티비 됐다 됐다', '단말 특이'],
#  ['진단 결과', '회선 단말 특이', '리셋 시간 전후'],
#  ['없고 부리 않아도', '문제 요청 길범', '길범 수기 요청'],
#  ['특이 진단', '진단 결과', '회선 단말'],
#  ['회선 단말 특이', '단말 특이 진단', '화면 정상'],
#  ['선재 연결', '원안 들어', '오후 원안'],
#  ['회선 단말', '단말 특이 진단', '접수 거실'],
#  ['이상무 진단', '특이 임의 코로나', '회선 단말'],
#  ['진단 결과', '단말 특이 진단', '정상 제분 대리'],
#  ['외부 신고', '구매 설치', '단말 특이'],
#  ['단말 특이', '안되 신다고', '연결했는데 안되 신다고'],
#  ['셋탑 리셋', '접수 보류', '접수 보류 셋탑'],
#  ['회선 단말 특이', '빠른 방문', '요청 수신 진단'],
#  ['특이 진단', '회선 단말', '방문 연락'],
#  ['전원 회선 단말', '특이 진단 결과', '단말 특이'],
#  ['교체 원함 회선', '원함 진단 결과', '장비 케이블 문제'],
#  ['접수 화면', '포트 리셋 재부팅', '접수 화면 자막'],
#  ['결과 후방', '방문 점검', '회선 단말'],
#  ['진단 결과', '안내 정상', '음성 장비 리셋'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['불임 의회', '특이 진단 결과', '선회 선단 특이'],
#  ['특이 진단', '회선 단말', '원안 들어'],
#  ['안내 수신 회선', '진단 결과', '시간 안내'],
#  ['오류 회선 단말', '코로나 상무 인터넷', '진단 결과'],
#  ['이용 방법 발송', '조작 불량', '조작 불량 발생'],
#  ['보심 회선', '시청 불위 오류', '불위 오류 리셋'],
#  ['회선 단말 특이', '결과 정상기 추가', '추가 연락처'],
#  ['결과 정상기 추가', '어두워짐 단말 리셋', '추가 연락처'],
#  ['셋탑 꺼짐 현상', '현상 독촉', '불수 시로 셋탑'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['특이 진단', '진단 결과', '전원 이상 회선'],
#  ['수신 리셋', '리셋 접수', '접수 수신'],
#  ['회선 단말 특이', '수신 불신', '오전 수신'],
#  ['시청 불부 전원', '정상 리셋 코로', '나무 미리 연락'],
#  ['일시 안내 화면', '일시 안내', '화면 떨림'],
#  ['요청 티거', '택배 발송', '택배 발송 요청'],
#  ['수신 불안 되는', '확인 잦은 고장', '점검 요청 회선'],
#  ['진단 결과', '회선 단말 특이', '코로나 상무'],
#  ['불연 후방 회선', '특이 진단 결과', '단말 특이'],
#  ['단말 특이 진단', '회선 단말 특이', '미리 연락'],
#  ['티비 장비', '장비 재부팅', '재부팅 안내'],
#  ['리모컨 고장', '고장 매장', '안내 문자 발송'],
#  ['회선 단말 특이', '들어 방문', '방문 연락'],
#  ['시청 갑자기 끊기거나', '버린다며 점검', '있는 티비 시청'],
#  ['특이 진단', '회선 단말', '대만 시청 회선'],
#  ['특이 진단', '진단 결과', '회선 단말'],
#  ['특이 진단 결과', '수신 코로 나무', '후방 회선 단말'],
#  ['결과 정상기', '회선 단말 특이', '방문 독촉 회선'],
#  ['먼저 요청 회선', '최대한 빠른 방문', '취소 있을 먼저'],
#  ['요청 티비', '시청 끊김', '정상기 추가 연락처'],
#  ['보고 계시다며', '단말 특이 코로나', '빠른 방문 요청'],
#  ['점검 요청', '회선 단말 특이', '수시로 네트워크 오류'],
#  ['채널 수신 불번', '리셋 접수 시간', '불번 나오고 모든'],
#  ['리모컨 고장', '고장 매장', '매장 안내'],
#  ['부팅 확인', '들어왔다 들어왔다 함재', '시대 거실 대고'],
#  ['특이 진단', '회선 단말', '불비 정상'],
#  ['특이 진단', '후방 회선', '진단 결과'],
#  ['요청 방문 연락', '요청 회선', '단말 특이'],
#  ['회선 단말', '원안 들어', '수신 불셋 원안'],
#  ['화면 깨짐', '지니 시청 화면', '방문 점검'],
#  ['요청 독촉 빠른', '점검 요청 독촉', '불편하다며 불만 방문'],
#  ['회선 단말 특이', '소모 심함 새로', '방문 해서 점검'],
#  ['특이 진단', '회선 단말', '화질 이상'],
#  ['연결 있는 리모컨', '배터리 바꿨는데도', '내용 리모콘 작동'],
#  ['부탁드립니 추가 문의', '공사 스카이라이프', '스카이라이프 안테나 당일'],
#  ['단말 특이 진단', '회선 단말', '끊김리 안내'],
#  ['로딩 회선 단말', '진단 결과', '접수 시간 내외'],
#  ['회선 단말', '택배 배송', '리모컨 택배 배송'],
#  ['연결 스피커 전원', '진단 결과', '단말 특이'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['내외 리콜', '접수 시간', '리콜 안내 수신'],
#  ['진단 결과', '후방 회선', '접속 불연 후방'],
#  ['진단 결과', '동일 회선 단말', '멀고 수신 재부팅'],
#  ['회선 단말', '진단 결과', '결과 정상기'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['안내 연회', '접수 시간', '단말 특이 안방'],
#  ['멀고 수신 리셋', '진단 결과', '수신 리셋 회선'],
#  ['의회 선수 회선', '특이 진단 결과', '회선 단말'],
#  ['빠른 방문', '진단 결과 포트', '수신 취소 발생'],
#  ['빠른 방문', '방문 요청 코로', '추가 연락처'],
#  ['단말 특이 진단', '코로나 무임 의회', '선동 연결'],
#  ['상무 확인 수신', '수신 불기사 빠른', '요청 단말 특이'],
#  ['코로나 상무', '결과 모뎀 정상기', '추가 연락처'],
#  ['멀고 회선 단말', '진단 결과', '최대한 빨리'],
#  ['월요일 부터 금요일', '쓰다 니까 리모컨', '넣을려 지거든 방문'],
#  ['어플 문자 발송', '문제 리모컨', '리모컨 문제 점검'],
#  ['회선 단말 특이', '빠른 방문', '티비 안됨 코로나'],
#  ['리모컨 작동', '작동 배송', '배송 등록'],
#  ['진단 결과', '부탁드립니다 후방', '꼼꼼한 점검'],
#  ['특이 진단', '안됨 회선', '회선 단말'],
#  ['단말 특이 원안', '들어옴 진단', '지니 회선 단말'],
#  ['임의 수신', '결과 정상기 추가', '수신 외부 신고'],
#  ['화질 불량 멈추는', '요청 단말 특이', '현상 있음 리모컨'],
#  '대수신불 연락 후 방문',
#  ['오류 팝업 후방', '최대한 빠른 방문', '팝업 후방 당일'],
#  ['상무 확인 빠른', '추가 연락처', '단말 특이'],
#  ['접수 코로', '코로 나무', '임의 접수'],
#  ['외부 입력 변환', '소리 들리신 다심', '일반 유선 채널'],
#  ['회선 단말 특이', '조작 된다고', '조절 기능 조작'],
#  ['구분 안됨 회선', '단말 특이', '후방 최대한 빠른'],
#  ['단말 특이 진단', '수신 네트워크 확인', '회선 단말 특이'],
#  ['셋탑 작동', '월일 셋탑', '월일 셋탑 작동'],
#  ['단말 특이 진단', '수신 외부', '회선 단말'],
#  ['수신 리셋', '리셋 안내', '인입 거실'],
#  ['정상 코로나', '올인 정상', '코로나 안내 방문'],
#  ['진단 결과', '단말 특이 진단', '작동 거부 방문'],
#  ['코로나 상무 선재', '확인 진단 결과', '단말 특이 주소'],
#  ['듯이 나온다고', '화면 줄이 듯이', '모뎀 셋톱 재부팅'],
#  ['코로나 상무', '회선 단말 특이', '단말 특이 정상'],
#  ['에서 편성표', '안됨 비정상 모든', '비정상 모든 버튼'],
#  ['불통 회선', '코로 나무 회선', '진단 결과'],
#  ['태풍 오고 계속', '그렇다고 코로나 상무', '단말 특이'],
#  ['동일 택배 교체', '교체 요청 등록', '된다고 교체 해봐도'],
#  ['꺼졌다 켜졌다 반복', '점검 요청 회선', '고장 꼼꼼하게 점검'],
#  ['회선 단말', '일부 버튼 작동', '리모컨 일부'],
#  ['요청 단말 특이', '리모컨 너무', '너무 뜨거워서 교체'],
#  ['정확한 회선', '주인 대리', '회선 일시 접수'],
#  ['기간 문의 하여', '오후 수신 불로', '딩중올 정상 리셋'],
#  ['정상기 추가', '상무 확인 수신', '수신 불화 나옴'],
#  ['단말 특이 진단', '코로 나무 회선', '원활하지 않다고 뜬다'],
#  ['시청 화면', '회선 단말', '단말 특이 진단'],
#  ['지니 음성인식 외부', '요청 회선', '외부 신고 방문'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['진행 되어', '있음 안내', '안내 하니 보류'],
#  ['추가 연락처', '방문 요청 회선', '독촉 최대 당겨'],
#  ['점검 요청 고장', '지니 진단 결과', '이력 없다고 지니'],
#  ['수평 입자 이사', '회선 단말 특이', '이사 연결 요청'],
#  ['연락 바랍니다', '회수 요청 당분간', '건물 부신다고 우선'],
#  ['리모컨 작동 작동', '택배 요청', '등록 리모컨'],
#  ['변경 안내', '지니 음성인식', '탑재 부팅 음성인식'],
#  ['셋탑 리셋 회선', '지상파 시청', '채널 시청 안됨'],
#  ['티비 회선 단말', '특이 진단 결과', '회선 단말'],
#  ['단말 특이 진단', '회선 단말', '사용 불가 켜짐'],
#  ['안내 현재 없어', '함회 단말 특이', '정상 리셋 안내'],
#  ['단말 특이 진단', '결과 정상기', '회선 단말'],
#  ['진단 결과', '회선 단말 특이', '시간 연락'],
#  ['리셋 해도 동일', '접수 수신 리셋', '연결 오류 잦은'],
#  ['회선 단말 특이', '신기 추가', '코로나 상무'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['추가 연락처', '신고 지니 전원', '전원 버튼 튕겨져'],
#  ['위치 변경 회선', '단말 특이', '대선 분리 시청'],
#  ['특이 진단 결과', '티접불 회선', '단말 특이'],
#  ['특이 진단 결과', '단말 특이', '회선 단말'],
#  ['교체 소등 택배', '등록 리모컨', '인식 안됨 건전지'],
#  ['특이 진단 결과', '부회 선단 특이', '접속 회선'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['리셋 동일 방문', '회선 단말 특이', '코로나 무기 지니'],
#  ['으로 보류', '되고 색감 좋다고', '안방 연결'],
#  ['불연 후방', '수신 불연 후방', '모두 수신'],
#  ['연결 팝업', '단말 특이 안방', '되도록 늦은'],
#  ['결과 정상기', '회선 단말 특이', '메세지 회선 단말'],
#  ['상무 확인', '단말 특이', '추가 연락처'],
#  ['불안 들어', '채널 버튼 안됨', '건전지 교체 해도'],
#  ['회선 단말 특이', '대만 시청', '현상 점검 요청'],
#  ['택배 배송', '버튼 안됨 택배', '요청 하여 처리'],
#  ['본인 문자 발송', '리모컨 파손 배송', '문자 발송 통합'],
#  ['회선 단말', '셋탑 이상 셋탑', '다운 후방'],
#  ['리콜 안내 회선', '접수 시간', '단말 특이'],
#  ['코로나 상무', '점검 요청', '필기 지니 수신'],
#  ['특이 진단 결과', '진단 결과', '추티 회선 단말'],
#  ['특이 진단', '회선 단말', '방문 연락'],
#  ['시안 재부팅', '시안 재부팅 해도', '재부팅 해도'],
#  ['요청 회선', '수신 잦은 고장', '진단 결과'],
#  ['올인 정상', '회선 단말 특이', '정상 리셋 일연'],
#  ['회선 단말', '단말 특이 진단', '셋탑 이상 리셋'],
#  ['동쪽 교체 요청', '안내 회선 단말', '요청 매장'],
#  ['점검 요청 회선', '코로나 안내', '셋탑박스 설치 동시'],
#  ['연결 요청 댁내', '있다고 안내', '이전 필요할 수도'],
#  ['오후 늦은 방문', '방문 요청 회선', '지니 분실 보상금'],
#  ['수신 불량 넷플릭스', '회선 단말 특이', '방문 연락'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['정상기 추가 연락처', '리셋 해보고 접수', '인지도 확인 어렵다'],
#  ['진행 연락처', '교체 해도 동일함', '안내 받았으나 거절'],
#  ['선재 연결', '일시 설치', '일시 설치 선재'],
#  ['동일 회선 단말', '단말 특이 진단', '빨간 장비 리셋'],
#  ['리모컨 깨짐 등록', '전송 회선 단말', '진단 결과 최지영'],
#  ['했는데 아직도 조치', '아직도 조치 되어져', '김정태 요청 내용'],
#  ['회선 단말 특이', '요청 임의 회선', '받을려고 하니'],
#  ['리모컨 작동', '등록 드림', '배송 접수 리모컨'],
#  ['회선 단말 특이', '임의 수신', '주소 확인'],
#  ['진단 결과', '안됨 회선 단말', '회선 단말'],
#  ['회선 단말 특이', '리모컨 교체 기자', '상무 확인'],
#  ['바뀜 리셋', '작동 이상 지니주', '정상기 추가 연락처'],
#  ['회선 단말', '코로나 상무', '상무 확인'],
#  ['특이 진단 결과', '회선 단말', '시청 회선'],
#  ['안내 드림', '장애 안내', '장애 안내 드림'],
#  ['일시 수신 불셋', '유시 종료', '탑재 부팅 유시'],
#  ['한다고 보류', '티비 교체 접수', '교체 한다고 보류'],
#  ['리셋 재사용', '재사용 요청', '리셋 재사용 요청'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['진단 결과', '회선 단말', '비정상 추가'],
#  ['단말 특이 진단', '셋탑 고장 원안', '들어옴 후방'],
#  ['없어 시청', '함선 연결했는데 청안', '없어 시청 없었다'],
#  ['지니 회선 단말', '방문 지니 회선', '상무 확인'],
#  ['처리 해달라고 회선', '빼놓으라고 하여 빼놨다고', '빼놓으면 처리 해주겠다고'],
#  ['리모컨 작동', '요청 하여 등록', '배송 요청'],
#  ['진단 결과 정상기', '회선 단말 특이', '추가 연락처'],
#  ['시청 정상기 지니', '높낮이 불량 회선', '정상기 지니 음성'],
#  ['연락 방문', '정상기 추가', '단말 특이'],
#  ['회선 단말 특이', '사용 리셋', '사용 된다고'],
#  ['특이 대중 대만', '시청 회선', '대만 안됨진단'],
#  ['코로 빠른', '원함 회선 단말', '방문 원함'],
#  ['전원 작동', '안됨 회선', '진단 결과'],
#  ['확인 의회 선수', '회선 단말 특이', '꺼지지 않는다고'],
#  ['시간 회선 단말', '단말 특이 진단', '진단 결과'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['회선 단말 특이', '확인 티비', '코로나 상무'],
#  ['화면 입력', '입력 신가 없습니다', '수신 불수'],
#  ['셋탑 전원', '일시 셋탑 전원', '일시 셋탑'],
#  ['해도 계속 뜨고', '건전지 제거', '들어간다고 취소 해도'],
#  ['후회 선단', '특이 진단 결과', '선단 특이'],
#  ['단말 특이 진단', '회선 단말', '멀고 수신 점검'],
#  ['시기 지니', '시기 지니 작동', '불만 정확한 점검'],
#  ['수신 불리', '리셋 접수', '접수 수신 불리'],
#  ['회선 단말', '단말 특이 진단', '대만 화면 나옴'],
#  ['특이 진단 결과', '리모콘 작동', '작동 불임'],
#  ['단말 특이 진단', '회선 단말', '주소 확인'],
#  ['특이 진단', '회선 단말', '연결 요청'],
#  ['안됨 회선 단말', '단말 특이 진단', '후티 사용'],
#  ['리모컨 작동 사용', '문자 전송 회선', '사용 방법'],
#  ['배송 안내 본인', '안내 본인 통합', '힘줘서 눌러야 눌려짐'],
#  ['단말 특이 진단', '회선 단말 특이', '결과 정상기'],
#  ['안됨 회선 단말', '회선 단말', '진단 결과'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['바코드 확인', '후방 독촉', '독촉 취소 앞당겨주세요'],
#  ['일시 교체 연결', '접수 미납', '연결 요청 고장'],
#  ['티비 불월 엔지니어', '접수 해도 된다고', '받았으나 티비 이용'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['없음 회선 단말', '회선 단말', '요청 위치 변동'],
#  ['교체 요청 하여', '하여 배송', '작동 불시'],
#  ['상무 확인 최대한', '요청 시청 회선', '최대한 빠른 방문'],
#  ['정상기 추가', '추가 연락처', '점검 필요하다고 나온다고'],
#  ['신고 장비', '외부 신고', '채널 시청 케이블'],
#  ['회선 단말', '단말 특이 진단', '진단 결과'],
#  ['단말 특이 진단', '나무 대신', '회선 단말 특이'],
#  ['집셋 탑재', '방문 요청 진단', '목요일 오후 방문'],
#  ['발생 오래되었다며 리모컨', '방향 버튼 작동', '문자 발송 실패'],
#  ['작동 방문', '해달라고 함문 자회', '해서 교체 해달라고'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['작동 불가', '진단 결과', '회선 단말'],
#  ['원함 니코 나무', '일부 버튼 작동', '리모컨 음량'],
#  ['포트 리셋 회선', '결과 정상기 추가', '추가 연락처'],
#  ['회선 단말', '택배 배송', '리모컨 택배 배송'],
#  ['무재 확인 회선', '요망 코로나 이상', '위치 전화 요망'],
#  ['다시 보기 안됨', '리콜 안내', '안내 다시 보기'],
#  ['출하 정상', '지니 음성인식', '쿠폰 지니 음성인식'],
#  ['진단 결과', '요청 단말', '교체 이후 연결'],
#  ['단말 특이 진단', '되는 같다', '아파트 여러'],
#  ['모뎀 정상기 추가', '상무 확인 화질', '화면 흔들린'],
#  ['되는데 이런', '단말 특이 진단', '증상 계속 있다'],
#  ['단말 특이 진단', '회선 단말', '장애 안내'],
#  ['작동 이상', '작동 이상 등록', '리모컨 작동'],
#  ['진단 결과', '선재 연결', '요청 위치 변동'],
#  ['회선 단말', '불만 들어', '불셋 전원 빨간'],
#  ['임의 숙박업소 주말', '참고 회선 단말', '불만 무조건 당일'],
#  ['요청 코로 나무', '회선 단말 특이', '방문 연락'],
#  ['단말 특이 진단', '회선 단말', '택배 수령'],
#  ['상무 확인', '불가 회선 단말', '멤버십 코로나 상무'],
#  ['방문 해서 점검', '요청 탑가지고 방문', '시청 갑자기 꺼지면서'],
#  ['리모컨 분실 접수', '일반 문의 서비스', '문의 내용'],
#  ['끊어졌다 코로나 상무', '빠른 방문 회선', '방문 회선 단말'],
#  ['진단 결과', '회선 단말 특이', '독촉 불임 연락'],
#  ['요청 티비 회선', '코로나 상무', '확인 시시 요청'],
#  ['리셋 불임 회선', '정상 포트', '입자 접수 일시'],
#  ['상무 지니 리모컨', '추가 연락처', '건전지 교체 해도'],
#  ['준다 고함', '연락 준다 고함', '다시 연락'],
#  ['시험 불기 추가', '모두 비만 오면', '추가 연락처'],
#  ['장비 재부팅', '임의 안됨', '재부팅 확인'],
#  ['포트 리셋 전원', '최대한 빠른 방문', '요청 통화 독촉'],
#  ['정상 포트', '포트 리셋 회선', '접수 수신 불신'],
#  '리셋 수신불',
#  ['임의 코로나', '방문 요청 단말', '리모컨 작동'],
#  ['코로나 상무', '원안 들어', '상무 확인'],
#  ['방문 요청 강성', '온라인 수업 해야', '오후 방문 된다고'],
#  ['불간 증상 후방', '단말 특이 진단', '회선 단말'],
#  ['해보고 재연', '추가 연락처', '고장 대화면 안나'],
#  ['단말 특이 진단', '접수 회선 단말', '후방 불임 접수'],
#  ['의회 선수', '불연 후방', '선수 불연 후방'],
#  ['특이 진단', '리모컨 매장', '회선 단말'],
#  ['회선 단말', '진단 결과', '단말 특이 진단'],
#  ['특이 진단', '회선 단말', '화질 이상'],
#  ['코로나 상무', '상무 확인', '추가 연락처'],
#  ['단말 특이', '사용 정확한 회선', '리셋 접수 사용'],
#  '리셋티비수 신불',
#  ['셋탑 확인', '티비 화면 나옴와', '요청 단말 특이'],
#  ['지니 리셋 해봄', '계신다고 방문 요청', '해도 안됨 지니'],
#  ['회선 단말 특이', '단말 특이 진단', '색감 좋다고 함연'],
#  ['확인 회선 단말', '티비 켜진다고 주소', '셋톱 작동 이상'],
#  ['리모컨 파손', '플라자 안내', '리모컨 파손 플라자'],
#  ['특이 진단', '진단 결과', '회선 단말'],
#  ['단말 특이 진단', '일부 채널', '수신 리모컨 작동'],
#  ['소리 나옴', '후방 빠른 방문', '요청 지니 음성인식'],
#  ['리모컨 분실', '코스 접수', '분실 코스 접수'],
#  ['위치 변경', '변경 없음', '없음 방문'],
#  ['새로 입주', '회선 단말 특이', '티비 연결 요청'],
#  ['나옴 음성', '리셋 완료', '음성 만들 리셋'],
#  ['받았으나 동일', '꼼꼼한 점검 요청', '요청 취소 생길'],
#  ['화면 깨짐', '동일 진단', '장비 리셋'],
#  ['상무 회선 단말', '회선 단말 특이', '전체 버튼 셋탑'],
#  ['상무 재부팅 동일', '월일 수신 올인원', '증상 시적 으로'],
#  ['모뎀 정상기 추가', '추가 연락처', '이라고 신다고'],
#  ['인터넷 된다고', '이상기 지니 찾음', '독촉 화질 이상기'],
#  ['결과 포트 정상기', '추가 연락처', '리셋 접수 리모컨'],
#  ['나온다고 다른 티비', '나온다고 다른', '빠른 방문 부탁드립니'],
#  ['티비 접속 후방', '후방 회선 단말', '특이 진단'],
#  ['불가 교체', '셋탑 음성인식 된다고', '점검 요청 리모컨'],
#  ['변경 어렵고 취소', '어렵고 취소 있으면', '현장 전달 화질'],
#  ['리셋 안내', '시청 불번 나옴', '이미 했다'],
#  ['특이 정상 진단', '리셋 리모컨', '단말 특이'],
#  ['채널 돌리기만 하면', '시작 되면서 화면', '돌리기만 하면 방송'],
#  ['리모콘 음성 검색', '작동 된다고', '버튼 작동'],
#  ['음성 이상', '정상 사용', '음성 이상 재부팅'],
#  ['회선 단말', '단말 특이 진단', '연결 요청'],
#  ['다른 으로 연결하면', '정상 회선 단말', '전원 작동'],
#  ['요청 회선', '딧는 회선 같이', '선동 주소 티비'],
#  ['불연 후방', '특이 진단', '후방 회선'],
#  ['구입 선재 연결', '빠른 점검 원함', '청연 후방 늦다고'],
#  ['불량 계속 깜박이면서', '접수 통합', '배송 접수 통합'],
#  ['회선 단말', '단말 특이 진단', '셋탑 이상 리셋'],
#  ['리모컨 분실', '택배 등록', '코스 택배'],
#  ['했으나 바꾸고', '사용 방법 잘아는', '요청 모컨 사용'],
#  ['진단 결과', '회선 단말 특이', '변경 안됨 회선'],
#  ['정상 사용', '정상 탑재 부팅', '리모컨 작도 불량'],
#  ['안됨 켜짐', '음성인식 안됨', '지니 음성인식'],
#  ['회선 단말 특이', '결과 올인 모뎀', '접수 월일 티비'],
#  ['상무 확인', '비정 상기 추가', '단말 특이'],
#  ['특이 진단', '회선 단말', '코로나 상무'],
#  ['단말 특이 진단', '끊김 회선 단말', '이상 시청 끊김'],
#  ['진단 결과', '후방 회선', '작동 불가 후방'],
#  ['불가 원안 들어', '지니 작동 불가', '교체 요청 빠른'],
#  ['수신 리셋', '리셋 수신', '리셋 완료'],
#  ['회선 단말 특이', '코로나 상무', '확인 지니'],
#  ['무조건 방문', '요청 회선', '진입 불가 유튜브'],
#  ['불초 기화', '접수 시청', '시청 불초 기화'],
#  ['단말 특이', '방문 연락 요시', '외부 신고 방문'],
#  ['진단 결과', '빠른 방문', '요청 단말 특이'],
#  ['단말 특이', '동일 연락 방문', '리셋 접수 로딩'],
#  ['특이 진단', '안됨 회선', '회선 단말'],
#  ['회선 단말', '임의 입주', '단말 특이 진단'],
#  ['방문 요청 건임', '수신 채널 불가', '불가 셋탑 리셋'],
#  ['상무 확인', '연락 회선 단말', '선재 연결 방문'],
#  ['부주의 인한 환불', '했다고 함환 요청', '영화 구매 했다고'],
#  ['발생 우선 방문', '회선 단말 특이', '결과 취소 발생'],
#  ['회선 단말 특이', '셋탑 먹통', '추가 연락처'],
#  ['연락 방문 요청', '시청 지상파', '채널 시청 지상파'],
#  ['접수 보류', '수신 접수', '수신 접수 보류'],
#  ['점검 원함 회선', '원함 회선', '시청 안됨 셋탑'],
#  ['단말 특이 진단', '그대로 연결', '심선 길어서 그대로'],
#  ['내용 리모컨 방문', '문의 내용', '일반 문의 서비스'],
#  ['단말 특이 진단', '진단 결과', '검게 나온다고 함회'],
#  ['코로 나무', '티비 코로', '연락 받을'],
#  ['티비 화면', '번안 재부팅', '채널 번안'],
#  ['코로나 상무', '수신 불셋탑 반응', '불셋탑 반응 없음'],
#  ['빠른 방문', '정상기 추가', '요청 접속 불수신'],
#  ['특이 코로나', '증상 회선 단말', '넷플릭스 시청 끊김'],
#  ['거실 티비 화질', '회선 단말', '화질 이상'],
#  ['다른 옮겨', '전남 영암군', '달라 담당 부서'],
#  ['교체 회선 단말', '이동 없음 교체', '요청 위치'],
#  ['단말 특이 진단', '대만 시청 회선', '대중 대만 시청'],
#  ['잦은 고장 으로', '진단 결과', '거실 마다 끊김'],
#  ['불위 오류', '불위 오류 확인', '월일 불위'],
#  ['정상 이용', '정상 이용 재부팅', '작동 불셋 탑재'],
#  ['안내 회선 단말', '리셋 접수 화면', '끊겼다가 나옴'],
#  ['설정 바로', '설정 바로 풀림', '요청 단말 특이'],
#  ['단말 특이', '만나 늦게', '재부팅 동일 자막'],
#  ['특이 진단', '회선 단말', '원안 들어'],
#  ['안됨 탑재 부팅', '시청 대중', '시간 시청 대중'],
#  ['연락 빠른 방문', '추가 연락처', '리셋 접수 불위'],
#  ['정상 재부팅', '재부팅 외부 인터넷', '진단 결과 모뎀'],
#  ['방문 달라', '상무 확인 리모컨', '단말 특이 어르신'],
#  ['해제 정상', '정상 확인', '쿠폰 마이크 차단'],
#  ['시안 티비', '부서 이혜인 대리', '작동 불가해지'],
#  ['오전 타임', '희망 최대한 빠른', '단말 특이 리셋'],
#  ['일시 음성', '화면 안나 옴셋', '나오나 화면 안나'],
#  ['이후 택배 배송', '전송 했음 하고', '리모컨 택배 배송'],
#  ['진단 결과', '주세요 회선', '불량 모뎀 체크'],
#  ['조사 확인 요청', '티비 전원 들어온다고', '단말 특이 티비'],
#  ['수신 네트워크', '오류 리셋', '리셋 접수'],
#  ['접수 회선 단말', '비대 채널', '채널 나옴'],
#  ['단말 특이 진단', '진단 결과', '요청 임의'],
#  ['안됨 외부', '임의 오후', '오후 안됨 외부'],
#  ['매장 안내', '작동 불가 지니', '지니 접수 안내'],
#  ['티비 회선 모두', '수신 코로나 이상', '이상 회선 단말'],
#  ['단말 특이 진단', '번쩍 거림', '화면 흐리게 되고'],
#  ['코로나 상무', '확인 수신 리모컨', '비정 상기 추가'],
#  ['진단 결과', '등록 회선', '리모컨 작동 비리'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['에서 편성표', '채널 에서', '리셋 특정'],
#  ['요청 꼼꼼한 점검', '독촉 최대한 빠른', '측의뢰했 지만 방문'],
#  ['방문 확인', '뭉게져 나온다', '점검 요청 회선'],
#  ['한다고 함연', '유투브 시청', '불대 수시로 재부팅'],
#  ['불어 되는', '정상기 추가', '불어 되는 같다고'],
#  ['진단 결과', '회선 단말', '수신 바코드'],
#  ['고장 원인 같다', '화질 깨져서 점검', '꼼꼼한 점검 부탁드립니다'],
#  ['후티 안나 임의', '티비 교체 후티', '진단 결과'],
#  ['동일 회선 단말', '회선 단말 특이', '변경 안됨 리셋'],
#  ['요청 단말', '연결 요청', '임의 접수 주선'],
#  ['소리 옴셋 탑재', '불만 꼼꼼한 점검', '부팅 동일 동일한'],
#  ['회선 단말 특이', '진단 결과', '유튜브 실행 불연'],
#  ['지연 넘어간다며', '리모컨 혹은 셋탑', '채널 전환 지연'],
#  ['좋다고 함회', '함회 단말 특이', '화면 화질 좋다고'],
#  ['불가 버튼 눌려', '무료 배송 등록', '눌려 진다고'],
#  ['도중 음으로 나오고', '심셋탑 교체', '시청 되신 심셋탑'],
#  ['올인 정상', '코로나 내연', '재부팅 해도 동일'],
#  ['동일 무조건 기사', '회선 단말 특이', '멀티 채널'],
#  ['단말 특이 진단', '해도 동일 회선', '수신 불화 직거림'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['진단 결과 후방', '회선 단말 특이', '불도 안됨'],
#  ['진단 결과', '회선 단말 특이', '약하다고 나옴'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['확인 리모컨', '요청 일시', '단말 특이'],
#  ['리모컨 작동 불가', '리모컨 작동', '연락 방문'],
#  ['해제 음성인식', '쿠폰 지니 음성인식', '쿠폰 지니'],
#  ['메뉴 실행', '진단 결과 추가', '외부 신고 재부팅'],
#  ['불입 없음', '수신 불입', '해도 동일'],
#  ['오류 음성인식 안됨', '진단 결과', '메뉴 실행'],
#  ['특이 진단 결과', '화면 끊김 회선', '단말 특이'],
#  ['실패 리모컨', '기술 리콜', '파손 없음 리모컨'],
#  ['시간 전후 리콜', '단말 특이', '리콜 안내 수신'],
#  ['결과 코로나 상무', '함회 단말', '수신 할하 않다고'],
#  ['임의 시청 회선', '연락 방문 요청', '원룸 임의 시청'],
#  ['안내 드림', '매장 재고 확인', '문자 요청 안내'],
#  ['리모컨 파손', '파손 접수', '접수 대리인'],
#  ['진단 결과', '연결했으나 회선 단말', '티비 처음 연결했으나'],
#  ['티비 신규 개통', '모뎀 전기 선보', '가셨던 엔지니어 께서'],
#  ['리모컨 전원 된다', '된다 되다', '배송 등록'],
#  ['장애 독촉 원안', '원안 들어온 방문', '지니 리모컨 교체'],
#  ['회선 단말', '부터 발생', '닷컴 접수 화면'],
#  ['셋탑 교체', '요청 단말', '연결 오류 셋탑'],
#  ['수신 불량 코로', '나무 빠른', '요청 하는 방문'],
#  ['진단 결과', '구분 안됨', '회선 단말 특이'],
#  ['일부 채널 수신', '수신 재부팅', '안내 정상'],
#  ['가능한 지문 신청', '셋톱 교체 가능한', '임대료 출동 안내'],
#  ['들어 옴연', '옴연 후방 회선', '티비 불셋 원안'],
#  ['셋탑 반응 속도', '반응 속도 느림', '단말 특이 진단'],
#  ['리셋 시간 전후', '리셋 동일', '빠른 방문 원함'],
#  ['수신 회선 단말', '모두 수신', '리셋 접수 티비'],
#  ['오류 모뎀', '모뎀 전원', '해보겠다 접수'],
#  ['고장 근본 해결', '문의 전환', '혜택 문의 전환'],
#  ['요청 방문 연락', '단말 특이', '요청 부정정 회선'],
#  ['고장 불만 당일', '단말 특이 진단', '요청 접수'],
#  ['같이 점검 요청', '대는 음량 조절', '화면 만나 같이'],
#  ['결과 모뎀', '추가 연락처', '수신 불티 접수'],
#  ['단말 특이 진단', '신다 방문 추후', '양해 회선 단말'],
#  ['수신 불화', '진단 결과', '회선 단말 특이'],
#  ['단말 특이 진단', '접수 음성 이상', '음성 이상 화면'],
#  ['함수 불연 후방', '회선 단말', '진단 결과'],
#  ['화면 울트라 전체', '다시 보기 수신', '장비 리셋 안내'],
#  ['특이 진단', '회선 단말', '불임 정상'],
#  ['진단 결과', '재부팅 일연 후방', '단말 특이'],
#  ['후방 회선 단말', '특이 진단 결과', '티비 불연 후방'],
#  ['티비 끊김 회선', '특이 진단 결과', '회선 단말'],
#  ['시청 권한 송출해', '되면 다시 연락', '다시 연락 주신다고'],
#  ['독촉 최대', '점검 시청 회선', '시청 회선 단말'],
#  ['라지 대신', '접수 임의', '접수 시청 리모컨'],
#  ['외부 회선 단말', '안됨 외부 회선', '특이 진단 결과'],
#  ['독촉 리셋', '해도 안됨', '빠른 방문 독촉'],
#  ['확인 티비', '회선 단말 특이', '특이 임의 접수'],
#  ['화질 이상 멈춤', '연락 방문 회선', '애도 동일 연락'],
#  ['사용 된다고 함회', '정상기 추가 연락처', '전혀 나오지'],
#  ['거실 티비', '티비 임의 등록', '꺼짐 티비 임의'],
#  ['요청 회선', '결선 지저분해서 정리', '꺼짐 결선 지저분해서'],
#  ['결과 정상기', '리셋 접수 회선', '추가 연락처'],
#  ['작동 안됨 이상', '티비 이상 리모컨', '되는 건지 모르겠다고'],
#  ['점검 요청 리셋', '만나오다가 안됨 리셋', '접수 다시 보기'],
#  ['신고 회선', '직거린 다심', '다심 외부 신고'],
#  ['재부팅 외부', '넷플릭스 안됨', '접수 보류'],
#  ['동일 주소', '이후 동일', '단말 특이'],
#  ['시청 교체 후신', '부전 정상', '추가 연락처'],
#  ['문제 있다며 점검', '방문 수신 채널', '오후 늦게'],
#  ['코로나 상무', '온다며 연결 요청', '단말 특이 진단'],
#  ['시청 끊김', '결과 연락 방문', '연락 방문 요청'],
#  ['시간 회선 단말', '단말 특이 진단', '진단 결과'],
#  ['점검 독촉', '독촉 일시 시청', '최대한 빠른'],
#  ['작동 불가 교체', '등록 통합 페어', '플레이 문자 발송'],
#  ['리셋 후방', '회선 단말 특이', '빠른 방문'],
#  ['특이 진단 결과', '없음 회선', '프로그램 정보'],
#  ['준비 독촉', '요청 방문 연락', '독촉 최대한 빠른'],
#  ['안내 접속', '접속 불수신 회선', '긴급 독촉 테더링'],
#  ['해도 안됨', '수신 불셋 탑재', '부팅 해도 안됨'],
#  ['중대 안됨 회선', '상무 확인 대리', '대리 신고 수신'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['동일 인터넷 된다고', '된다고 하고 같이', '취소 발생 방문'],
#  ['회선 단말', '진단 결과', '결과 정상기'],
#  ['단말 특이 진단', '메세지 나옴', '티비 로딩 메세지'],
#  ['접수 티비', '회선 단말', '접수 티비 불연'],
#  ['정상 사용', '외부 입력 문제', '리모컨 작동'],
#  ['문의 안내', '하는 방법', '방법 문의 조사'],
#  ['작동 불가 버튼', '버튼 눌림 매장', '했으나 거부 배송'],
#  ['추가 연락처', '안나 리셋', '자막 나오고 화면'],
#  ['임의 조치', '조치 리모컨', '방문 같이'],
#  ['비리 동일 회선', '수신 비리', '결과 정상기 추가'],
#  ['정상 재부팅', '해도 동일', '네트워크 오류 올인'],
#  ['수신 리셋', '리셋 접수', '접수 수신'],
#  ['부팅 안내 리모컨', '무료 발송', '발송 안내 등록'],
#  ['시간 전후 리콜', '단말 특이', '리콜 안내 수신'],
#  ['불건전 교체 해도', '발송 회선 단말', '안내 발송 통합'],
#  ['되면 다시 전화', '되는데 장비 재부팅', '대로 커서 두고'],
#  ['안됨네 소리 에서', '에서 띵소리 변경', '지니 음성인식'],
#  ['안됨 후방 회선', '회선 단말', '티비 불량 셋탑'],
#  ['빠른 방문 요청', '방문 꼼꼼하게 점검', '최대한 빠른'],
#  ['구매 유정', '리모컨 구매', '리모컨 구매 유정'],
#  ['리모컨 작동 이상', '요청 거절', '교체 요청'],
#  ['회선 단말', '요청 민원 잦은', '요청 민원'],
#  ['리모컨 교체', '교체 문의', '리모컨 교체 문의'],
#  ['독촉 연락 최대한', '영업 초초초 긴급', '오류 영업 초초초'],
#  ['리모컨 작동', '교체 청연 후방', '고장 리모컨'],
#  ['꺼짐 증상 회선', '방문 요청 작동', '독촉 연락 해서'],
#  ['분실 택배 접수', '일반 문의 서비스', '문의 내용 리모컨'],
#  ['수신 리셋', '단말 특이 진단', '모두 수신'],
#  ['확인 시청', '함회 단말 특이', '에선 끊어졌다고'],
#  ['리셋 택배 등록', '정상 건전지', '버튼 인식 불가'],
#  ['정상기 추가', '연락처 연락', '흔들림 리셋 해도'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['특이 진단', '회선 단말', '시청 끊김'],
#  ['동일 최대한', '빠른 방문 독촉', '독촉 리셋'],
#  ['지니 종종 작동', '으로 신를 없다고', '깨져서 보인 함기'],
#  ['방문 확인', '요청 회선 단말', '불셋탑 박스 접촉'],
#  ['스마트 인터넷', '외부 입력 넘겨도', '유튜브 사용'],
#  ['단말 특이 진단', '수신 불셋탑', '리셋 동일 회선'],
#  ['접수 리모컨 버튼', '접수 리모컨', '아주 꾹꾹 눌러야'],
#  ['정상기 추가', '추가 연락처', '요청 코로나 상무'],
#  '음성안 나 옴거실',
#  ['음성 시청', '재부팅 동일', '끊김까지 교체 봤다'],
#  ['특이 진단 결과', '오류 회선 단말', '회선 단말'],
#  ['수신 리셋', '리셋 수신', '리셋 수신 리셋'],
#  ['안내 외부', '외부 신고', '티비 불티 대전'],
#  ['특이 진단', '회선 단말', '결과 직원'],
#  ['나옴 외부 스피커', '다시 락준 회선', '해보고 되면 다시'],
#  ['진단 정상', '수신 진단', '포트 리셋 사용'],
#  ['혼자 꺼졌다', '셋탑 계속', '혼자 꺼졌다 켜졌다'],
#  ['리셋 안내 회선', '검색 외부 입력', '시청 채널'],
#  ['일시 음성인식', '되고 저절로 음악', '음악 틀어지고 다심'],
#  ['단말 특이 진단', '셋탑 있다', '사왔는데 셋탑 있다'],
#  ['티비 불티', '단말 특이 진단', '회선 단말'],
#  ['따님 대리', '대리 신고 회선', '된다고 따님 대리'],
#  ['자택 계신다고 음성', '음성 맞다고', '그때 자택 계신다고'],
#  ['으로 수신', '지니 고장', '확인 회선 단말'],
#  ['모뎀 정상기 추가', '방문 해서 점검', '나온다고 방문 해서'],
#  ['코로나 상무 시청', '점검 코로나 상무', '안꺼지고 화면 안나'],
#  ['확인 연락 드림', '본인 셀프', '본인 셀프 개통'],
#  ['상무 확인 의회', '단말 특이 진단', '회선 단말'],
#  ['이상 전원', '이상 전원 버튼', '누르고 있어야 켜져'],
#  ['되는 셋탑 확인', '불안 되는', '리셋 접수 수신'],
#  ['단말 특이 진단', '회선 단말 특이', '라고 음성'],
#  ['회선 단말', '단말 특이 진단', '음성 나온'],
#  ['회선 단말', '진단 결과', '임의 외부 신고'],
#  ['회선 단말', '음성 이상연 후방', '진단 결과 직원'],
#  ['원안 들어옴', '들어옴 인계', '원안 들어옴 인계'],
#  ['진단 결과 정상기', '회선 단말 특이', '추가 연락처'],
#  ['특이 진단 결과', '회선 단말', '미약 리셋'],
#  ['사이 방문 요청', '없다고 방문', '수신 불오 후시'],
#  ['오전 어려움', '놓겟다고 하고 손님', '어려움 양해 했으나'],
#  ['상무 확인 티비', '방문 희망', '특이 방문 전화'],
#  ['리셋 회선', '접수 시간', '접수 시간 내외'],
#  ['다른 시청 안됨', '티비 대동시', '하면 다른'],
#  ['이상 회선', '코로나 상무', '확인 이상 회선'],
#  ['완본 매장 방문', '켜지 심자가 조치', '요청 리모컨'],
#  ['접수 셋톱 정확히', '원함 회선 단말', '점검 원함 회선'],
#  ['지니 전원', '임대 빠른 점검', '단말 특이'],
#  ['안됨 연락 회선', '단말 특이 진단', '실시간 정상'],
#  ['전원 껐다 켰다', '문두 드리거나 누르시면', '어르신 계심 계셔'],
#  ['점검 요청', '자동 꺼짐 현상', '현상 리모컨'],
#  ['진단 결과', '불신 정상 리셋', '회선 단말 특이'],
#  ['수행 안함 후방', '지니 음성', '음성 명령 으로'],
#  ['리모컨 작동 불매', '불매 방문 안내', '방문 안내'],
#  ['일부 채널 시청', '회선 단말 특이', '시청 불연'],
#  ['시지 이상 원안', '이상 원안', '원안 들어'],
#  ['특이 진단', '전원 작동 회선', '단말 특이'],
#  ['회선 단말 특이', '작동 불불 계속', '성제 배우 신청'],
#  ['상무 회선', '회선 단말 특이', '원안 들어'],
#  ['임의 수신', '리셋 임의', '연락 방문'],
#  ['불매 택배 안내', '문자 안내 발송', '안내 통합 설정'],
#  ['바람 안테나', '으로 늘어졌다고', '정리 요청 회선'],
#  ['단말 특이 진단', '코로나 이행 임의', '방문 연락'],
#  ['교체 요청', '정상 받아 봤는데', '봤는데 상무 심셋탑'],
#  ['반복 회선', '놨다 반복', '시청 화면 꺼졌다'],
#  ['음성 들림', '음성 들림 리셋', '리셋 완료'],
#  ['수신 불리', '리셋 접수', '접수 수신 불리'],
#  ['단말 특이 진단', '추가 티비', '시작 동안 리모컨'],
#  ['외부 입력 전환', '안내 정상', '교체 수신'],
#  ['수신 리셋', '회선 단말', '단말 특이'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['여러 눌러야', '리모콘 일부 작동', '택배 교체'],
#  ['구성 셋탑', '단말 특이 진단', '코로나 상무'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['채팅 리모컨', '없음 명의 센터', '부탁 안내'],
#  ['확인 리셋', '단말 특이', '추가 연락처'],
#  ['단말 특이 진단', '회선 단말', '원함 연락'],
#  ['지니 리모콘 작동', '센서 켜지고 작동', '기술 리콜'],
#  ['선재 연결 동일', '화면 나옴 소리', '동일 증상'],
#  ['단말 특이 진단', '된다고 임의 접수', '회선 단말 특이'],
#  ['회선 단말 특이', '신기 추가', '코로나 상무'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['코로나 상무', '단말 특이 정상', '추가 연락처'],
#  ['장비 회수 요청', '요청 연락처 당일', '하시니 연락 부탁드립니다'],
#  ['신규 입주 티비', '요청 회선 단말', '멀티 신규 입주'],
#  ['리모컨 문자', '고장 매장 안내', '문자 발송 리모컨'],
#  ['방문 사전 연락', '사전 연락', '점검 요청 회선'],
#  ['티비 불연 후방', '후방 회선', '진단 결과'],
#  ['지니 음성인식', '쿠폰 지니 음성인식', '쿠폰 지니'],
#  ['코로나 상무', '확인 수신 음향', '정상기 추가 연락처'],
#  ['위치 변동', '변동 후방', '교체 위치'],
#  ['회선 단말', '수신 불전 켜짐', '진단 결과'],
#  ['했다 직영 거부', '이미 했다', '리모컨 눌러야 된다'],
#  ['만원 청구 안내', '멀리 모컨', '청구 안내'],
#  ['연결 랜선 확인', '시청 노트북', '단말 특이'],
#  ['단말 특이 진단', '결선 끊어져서 티비', '시청 안됨다고'],
#  ['시시 안내', '안내 불량', '안내 불량 연결해도'],
#  ['수신 포트 리셋', '코로나 상무', '상무 확인'],
#  ['회선 단말', '불연 방임 의회', '시청 불연 방임'],
#  ['리모컨 작동', '작동 불건전', '확인 매장 안내'],
#  ['후방 회선 단말', '진단 결과', '안됨 후방'],
#  ['결과 정상기 추가', '대만 시청 리셋', '리셋 접수 티비'],
#  ['특이 진단', '진단 결과', '회선 단말'],
#  ['단말 특이', '함꼭 연락', '독촉 티비 해지'],
#  ['시청 회선 단말', '미약 코드', '진단 결과 확인'],
#  ['후방 회선', '단말 특이 진단', '티비 채널 나옴'],
#  ['하얗게 만나 옴셋', '동일 리모컨', '진단 결과'],
#  ['회선 단말', '단말 특이 진단', '코로나 상무'],
#  ['끊김 연락 방문', '회선 단말 특이', '진단 결과'],
#  ['일시 외부', '일시 외부 설치', '외부 설치'],
#  ['점검 원함', '원함 진단', '특이 최대한'],
#  ['내심 미리 연락', '수신 잦은 증상', '꼼꼼한 수리 요청'],
#  ['인터넷 확인', '티비 모두 끊김', '리셋 동일'],
#  ['특이 진단 결과', '회선 단말', '단말 특이'],
#  ['안됨네 소리 에서', '에서 띵소리 변경', '지니 음성인식'],
#  ['채널 시청', '자주 멈춤 회선', '진단 결과'],
#  ['수시 인식 작동', '동일 증상', '반복 회선 단말'],
#  ['거부 방문', '요청 통합 설정', '방법 문자 발송'],
#  ['상무 확인 리모컨', '연락 방문 요청', '단말 특이'],
#  ['선회 선단 특이', '진단 결과', '수신 불셋탑'],
#  ['시청 인터넷 오류', '동일 증상 반복', '회선 단말 특이'],
#  ['확인 티비', '코로나 상무', '추가 연락처'],
#  ['들어 방문 점검', '요청 회선', '지니 작동 불가'],
#  ['오후 시시', '방문 화질 이상', '송출되 화면 나옴'],
#  ['시청 화면', '회선 단말', '단말 특이 진단'],
#  ['정상기 추가 연락처', '정상기 추가', '요청 코로나 회선'],
#  ['접속 회선', '시간 수신 불도', '불도 접속'],
#  ['스마트 메뉴', '넷플릭스 사용', '상무 인터넷 연결'],
#  ['리셋 접수', '불시 내외 리콜', '리셋 접수 티비'],
#  ['진단 결과', '수신 외부 독촉', '회선 단말'],
#  ['확인 리셋', '단말 특이', '추가 연락처'],
#  ['작은 방수 다른', '나옴 함께 점검', '오후 상주 티비'],
#  ['코로나 안내', '버튼 눌러진 입시', '로딩 오래 걸림'],
#  ['회선 단말 특이', '잦은 발생 회선', '멈춤 상세'],
#  ['불가 실시간', '접수 보류 회선', '넷플릭스 이용 불가'],
#  ['코로나 상무', '결과 포트 정상기', '추가 연락처'],
#  ['회선 단말 특이', '방수 불량 셋탑', '전원 확인'],
#  ['방문 리셋 접수', '리셋 접수 시간', '리셋 해도 동일'],
#  ['특이 진단', '연회 단말', '모두 수신 연회'],
#  ['요청 확인', '장비 빠른 회수', '연락 부탁드립니다'],
#  ['임의 화면', '교체 요청', '정지 셋탑'],
#  ['신기 추가 연락처', '너무 느리고 리모컨', '단말 특이 티비'],
#  ['의회 선층', '특이 진단 결과', '회선 단말'],
#  ['회선 단말 특이', '진단 결과', '화면 멈췄다'],
#  ['회선 단말', '진단 결과', '결과 정상기'],
#  ['회선 단말 특이', '재부팅 안내', '안됨 재부팅 안내'],
#  ['상무 확인 시시', '결과 연락', '정상 시청 연결'],
#  ['회선 단말 특이', '전후 안내 수신', '접수 시간'],
#  ['탑재 부팅', '이용 방법 발송', '발송 등록'],
#  ['특이 진단 결과', '회선 단말', '모두 회선'],
#  ['회선 단말', '테이블 전원', '시청 불지'],
#  ['정확한 회선', '외부 신고', '확인 불가하여 임의'],
#  ['특이 진단 결과', '끊김 회선', '단말 특이'],
#  ['단말 특이 진단', '이상화 뿌옇다 음성', '리셋 접수 시간'],
#  ['단말 특이 진단', '회선 단말', '확인 지니'],
#  ['넘어가지 않고', '진단 결과 올인', '부산 사용 상품'],
#  ['단말 특이 진단', '끊김 회선 단말', '이상 시청 끊김'],
#  ['불가 셋탑', '리셋 안내', '접수 시청'],
#  ['교체 했으나 연결하니', '했으나 연결하니 자동', '시청 불새 교체'],
#  ['리모콘 작동', '코로나 상무', '무료 배송 리모콘'],
#  ['보냄 리셋 접수', '부터 나와야 정상', '봤었는데 결제 뜬다고'],
#  ['티비 안됨 테이프', '함선 교체 요청', '요청 코로나 안내'],
#  ['블루투스 연결', '안됨 블루투스', '셋탑 교체 리모컨'],
#  ['정상 복구 회선', '복구 회선 단말', '하니까 켜도가 나오거든'],
#  ['정상 작동', '작동 재부팅', '리모컨 작동'],
#  ['이상 건전 지동', '요청 사전 연락', '반응 느림으로 같이'],
#  ['연락 방문', '임의 연락', '임의 연락 방문'],
#  ['시청 화면', '엔지니어 방문 요청', '멈춤 코로나'],
#  ['요청 회선', '부러 다심', '지니 결선 하나'],
#  ['리모컨 교체 원함', '원함 빠른 점검', '해줬는데 똑같이 된다고'],
#  ['특이 진단', '무연 후방 회선', '진단 결과'],
#  ['리모컨 작동', '설정 전송', '본인 리모컨'],
#  ['확인 에게', '회선 단말 특이', '특이 진단 결과'],
#  ['수신 회선 단말', '진단 결과', '모두 수신'],
#  ['인재 연결', '회선 단말', '원룸 입주 인재'],
#  ['수신 장비 재부팅', '수신 장비', '된다고 접수'],
#  ['특이 진단', '코로나 상무 의회', '회선 단말'],
#  ['회선 단말', '지연 시청', '시청 끊김 후방'],
#  ['시간 내외 안내', '안내 회선 단말', '접수 로딩 이라고'],
#  ['회선 단말', '단말 특이 진단', '코로나 상무'],
#  ['방문 요망', '코로나 상무', '상대 안됨 회선'],
#  ['특이 진단 결과', '시불 회선 단말', '임의 시불'],
#  ['단말 특이 진단', '회선 단말', '아예 들어'],
#  ['리셋 문자 전송', '교체 요청 전체', '단말 특이'],
#  ['방문 연락', '작동 없이', '연락 회선'],
#  ['청약 정용', '파손 청약', '파손 청약 정용'],
#  ['단말 특이 진단', '회선 단말 특이', '으로 접수'],
#  ['회선 단말 특이', '입선 끊어졌다', '독촉 수신 작업'],
#  ['문자 남겨', '지니 점검 요망', '남겨 달라 하십니다'],
#  ['회선 단말 특이', '임의 접수 후방', '음성 나옴대 임의'],
#  ['입자 입주 교체', '회선 단말 특이', '요청 위치'],
#  ['진단 결과', '빨리 방문', '요청 단말 특이'],
#  ['화면 멈춤 회선', '회선 단말 특이', '안내 시청 화면'],
#  ['꺼짐 리모컨 모든', '독촉 시청', '리모컨 함께 점검'],
#  ['리모컨 전원 버튼', '연락 방문', '눌러야 켜진다고 연락'],
#  ['불임 회선', '특이 진단 결과', '진단 결과'],
#  ['등록 회선 단말', '진단 결과', '리모컨 작동'],
#  ['택배 접수 설정', '없음 택배 접수', '결제 본인 리모컨'],
#  ['빠른 방문', '요청 단말 특이', '점검 독촉 빠른'],
#  ['리모컨 고장', '고장 매장', '매장 안내'],
#  ['진단 결과', '회선 단말 특이', '시청 안됨'],
#  ['진단 결과', '동일 리셋', '단말 특이'],
#  ['특이 진단', '회선 단말', '독촉 시청 검정색'],
#  ['회선 단말', '특이 진단 결과', '교체 위치 변경'],
#  '일리셋대수신불',
#  ['지니 수신 불지', '불안 들어옴와 연결', '인터넷 불안 들어옴와'],
#  ['켜졌다 방문 연락', '으로 꺼졌다 켜졌다', '요청 단말 특이'],
#  ['단말 특이 진단', '지속 발생 점검', '회선 단말 특이'],
#  ['리콜 안내 회선', '리셋 접수 일부', '불번 만나'],
#  ['통화 안내 드림', '불만 심함 해지', '김혜영 대리 신고'],
#  ['매장 따라서 재고', '되는데 되더라고요 그럼', '하시면 가능한데 매장'],
#  ['검게 나온 후방', '진단 결과', '회선 단말 특이'],
#  ['나오는데요 그러니까 공사', '말년 님성함 같네요', '했고요 어떡해안 나와요'],
#  ['코로나 상무', '상무 확인', '추가 연락처'],
#  ['리모컨 고장', '고장 매장', '안내 문자 발송'],
#  ['단말 특이 안방', '리셋 일차 리셋', '리콜 안내'],
#  ['리셋 회선', '진단 결과', '접수 시간 내외'],
#  ['다시 전원', '지켜진 다심', '지켜진 다심 회선'],
#  ['불량 건전지 교체', '리셋 리모컨 작동', '증상 반복 통합'],
#  ['진단 결과', '된다고 리모컨 버튼', '회선 단말 특이'],
#  ['취소 건수 있을', '셋탑박스 원안', '임의 영업 취소'],
#  ...]

# %% [markdown]
# ## Max Sum Similarity
# 데이터 쌍 사이의 최대 합 거리는 데이터 쌍 간의 거리가 최대화되는 데이터 쌍으로 정의됩니다. 여기서의 의도는 후보 간의 유사성을 최소화하면서 문서와의 후보 유사성을 극대화하고자 하는 것입니다.
