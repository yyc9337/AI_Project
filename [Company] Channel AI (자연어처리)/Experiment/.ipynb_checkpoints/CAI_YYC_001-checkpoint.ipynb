# %% [markdown]
# # Abstract
# #### Setting
#
#         1. 1차 정제 데이터인 CAI_data_001.csv  데이터를 사용하여 2차 전처리 진행
#         2. 토큰화, 불용어 처리
#         3. 사전(vocab) word_to_index 구성
#         4. 문장 통계 분석 및 시각화
#         5. 모델링
#
# #### Method
#
#         1. VOC 유형 중 depth_1 유형을 예측하는 모델
#         2. model 폴더에 .h5파일로 모델 저장
#         3. 다른 모델(Kobert, Roberta)도 적용 예정
#
# #### Result
#         사용 모델 : LSTM
#                     loss: 0.5791 - accuracy: 0.8449

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.sequence import pad_sequences
import os
import tensorflow as tf

import warnings
warnings.filterwarnings('ignore')
import timeit

# 한국어 tokenizer
from konlpy.tag import Okt
tokenizer = Okt()
from collections import Counter

# %%
df = pd.read_csv('../data/dataset/CAI_data_001.csv', index_col=0)
print("df set: {}개".format(len(df)))
# Out:
# df set: 8186개

# %%
df.head(10)
# Out:
#                         Label  \
# 0             원인불명>조치 전 자연 회복
# 1              실시간 채널>네트워크 오류
# 2                실시간 채널>수신 불량
# 3              실시간 채널>네트워크 오류
# 4                실시간 채널>수신 불량
# 5                단말>STB(작동)이상
# 6  단말>STB(부팅) 이상>부팅중 오류메시지 발생
# 7                단말>STB(작동)이상
# 8                실시간 채널>음성 이상
# 9               VOD/컨텐츠>화질 이상
#
#                                             sentence
# 0                             고객 요청사항 호안됨 상담 중 자연회복됨
# 1  고객 요청사항 호수신불인터넷 연결오류 뜸재부팅해 봄 모텔 영업용 일 중 꼭 점검원하...
# 2          고객 요청사항 호수신불회선 단말특이사항 진단 결과 기타 추가 연락처 연후방
# 3                                 수신 불 네트워크 오류 접수 보류
# 4       고객 요청사항 수신불 연락 후 회선단말특이사항 진단 결과 기타 추가 연락처인 입
# 5  고객 요청사항 채널은 정상 넷플릭스 안됨 포트리셋 미리 연락 후 방문 요망 회선단말...
# 6    고객 요청사항 호수신불 서비스 시작 중 회선 단말특이사항 진단 결과 기타 추가 연락처
# 7  김현철 채팅 지니 자체에서 잡음이 난다고 함고장 접수 함 고객 요청사항 셋탑이상지니...
# 8  고객 요청사항 나오나 따닥거리는 소리가 난다함리셋 후 잘됨회선 단말특이사항 진단 결...
# 9  고객 요청사항 화질 불량 시청 중 멈추는 증상 반복됨 연락 후회선 단말특이사항 진단...

# %% [markdown]
# ## 2차 데이터 전처리

# %% [markdown]
# #### Label 지정 후 정제 (label Encoding) 및 시각화
#
#
# - 첫 실험을 위해 depth_1을 target으로 지정
# - '>' 기호를 기준으로 컬럼을 세개로 나눔

# %%
df['depth_1'] = df.Label.str.split('>').str[0]
df['depth_2'] = df.Label.str.split('>').str[1]
df['depth_3'] = df.Label.str.split('>').str[2]

# %%
# depth_1 시각화

df['depth_1'].value_counts().plot(kind = 'bar')

###폰트 깨짐 방지###
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
###

#수치로 표현
print(df['depth_1'].value_counts())
# Out:
# 실시간 채널       4046
# 단말           2460
# AS접수/변경       817
# 고객원인          547
# VOD/컨텐츠       123
# 원인불명           66
# 장애안내           38
# 양방향서비스         34
# 시설관리           21
# 데이터서비스         19
# 시설이전            7
# 부가/지능망서비스       4
# 지니뮤직            3
# 리콜/손해배상         1
# Name: depth_1, dtype: int64

# %%
# depth_2 시각화

df['depth_2'].value_counts().plot(kind = 'bar')

###폰트 깨짐 방지###
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
###

#수치로 표현
print(df['depth_2'].value_counts())
# Out:
# 수신 불량              2876
# 리모컨작동불가            1376
# STB(작동)이상           770
# 화질 이상               692
# 장비리셋 후 재사용 요청       567
# 부주의, ID/PW 분실 등     418
# 네트워크 오류             326
# 임대단말 분실/파손          196
# STB(부팅) 이상          163
# 음성 이상               137
# 음성인식이상(기가지니)        132
# 증설/구내선 정리요청         101
# 메뉴 실행 불가             83
# 조치 전 자연 회복           66
# 임대단말 회수요청            54
# 전환 지연                34
# 양방향서비스 사용불가          34
# 네트워크장비 장애            27
# 특이고장                 19
# 접속 지연/끊김             19
# 채널편성표 없음             19
# 기타 KT시설(상세메모기입)      16
# 스피커이상(기가지니)           9
# 타사 및 기타 장애            8
# 맨홀/전주/단자함/기타          7
# 전원, 충전 이상             7
# AS보류(유료화)             6
# 이용불가                  4
# 케이블(전송로) 장애           3
# IP 공유기 이상             3
# 지니뮤직이상(기가지니)          3
# 맨홀/전주                 3
# USB포트 인식 불가           3
# PIN 인증 오류             2
# 공사안내                  2
# 피해보상요구                1
# Name: depth_2, dtype: int64

# %%
# depth_3 시각화
df['depth_3'].value_counts().plot(kind = 'bar')

###폰트 깨짐 방지###
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
###

#수치로 표현
print(df['depth_3'].value_counts())
# Out:
# 택배발송              580
# 현장출동              453
# M&S내방안내           212
# 부팅중 오류메시지 발생      151
# 기타문의              131
# 부팅지연(오류메시지 없음)     12
# 이용 불가(유선)           4
# Name: depth_3, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
result = le.fit_transform(df['depth_1'])
print(result)
print(le.classes_)
# Out:
# [11  9  9 ...  9  9  3]
# ['AS접수/변경' 'VOD/컨텐츠' '고객원인' '단말' '데이터서비스' '리콜/손해배상' '부가/지능망서비스' '시설관리'
#  '시설이전' '실시간 채널' '양방향서비스' '원인불명' '장애안내' '지니뮤직']

# %%
df['depth_1'] = result

# %%
df.head()
# Out:
#              Label                                           sentence  \
# 0  원인불명>조치 전 자연 회복                             고객 요청사항 호안됨 상담 중 자연회복됨
# 1   실시간 채널>네트워크 오류  고객 요청사항 호수신불인터넷 연결오류 뜸재부팅해 봄 모텔 영업용 일 중 꼭 점검원하...
# 2     실시간 채널>수신 불량          고객 요청사항 호수신불회선 단말특이사항 진단 결과 기타 추가 연락처 연후방
# 3   실시간 채널>네트워크 오류                                 수신 불 네트워크 오류 접수 보류
# 4     실시간 채널>수신 불량       고객 요청사항 수신불 연락 후 회선단말특이사항 진단 결과 기타 추가 연락처인 입
#
#    depth_1     depth_2 depth_3
# 0       11  조치 전 자연 회복     NaN
# 1        9     네트워크 오류     NaN
# 2        9       수신 불량     NaN
# 3        9     네트워크 오류     NaN
# 4        9       수신 불량     NaN

# %% [markdown]
# #### Train, Valid 데이터 셋 나누기

# %%
X = df['sentence']
y = df['depth_1']

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=0)

# %%
X_valid
# Out:
# 757     고객 요청사항 전원 손띄면 꺼짐 스카치 테잎 임의 조치 중 리모컨도 고장 방문 시 ...
# 5015    티비에서 넷플릭스 유튜브 안됨 올인 홈 정상 인터넷 정상 티비 모두 정상으로 확인되...
# 1001    기가 지니에서 넷플릭스 실행 불가 리셋 권 유 고객 외부셔서 진행해 보시고 재연락 ...
# 8422                   일시 수신불 신호 없음 거실 티비 방에티비 번갈아가며 안 나옴
# 5259    고객 요청사항 재연결 해지 복구 임대장비 회수로 인하여 모뎀 및 회수 됨 장비 지 ...
#                               ...
# 7662    차위성 수신 불량 올레 관시청 중 날씨 괜찮을 때도 해당 증상 있다고 점검 요미리 ...
# 4280    고객 요청사항 배우자리모컨 일부 버튼 작동 불교체회선 단말 특이사항 진단 결과 기타...
# 6838                               호 임의 네트워크 오류 셋탑리셋해도 동일
# 4613                                     리모컨 작동안 딤 직영점 안내
# 2573    코로나 이 상무재확인 필 고객 요청사항기가 지니 음성인식 안됨 회선 단말특이사항 진...
# Name: sentence, Length: 1638, dtype: object

# %% [markdown]
# #### 불용어 처리 및 토큰화
#
# - Okt 형태소 분석 도구를 이용하여 단어 토큰화를 진행함.
# - stopwords를 직접 지정하여 제거하고 싶은 글자들을 선택
# - for문을 구성하여 토큰화와 불용어처리를 한번에 진행
# - 만들어야 하는 사전에 최대한 많은 단어를 담아야 하기 때문에 train, valid 나누지 않고 df_train라는 변수에 담음.

# %%
#불용어 지정
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도', '를','으로','자','에',
'와','한','하다','을','에서','해서', '고객', '요청', '안심권유', '안심권 유']

# %%
df_train = []

for row in df.iterrows() :   
    sentence = tokenizer.morphs(row[1]['sentence']) #단어 토큰화
    sentence = [word for word in sentence if not word in stopwords] #불용어 제거  
     
    df_train.append(sentence)

# %%
df_train[:3]

# %% [markdown]
# #### 사전(vocab) word_to_index 구성 및 스트링 변환
#
# - 다양한 Tokenizer를 활용해서 데이터를 분석하기 위해 문자 데이터를 숫자로 바꿔줘야함
# - Counter를 사용해도 되고, okt Tokenizer로 fit_on_texts를 사용해도 정수 인코딩을 할 수 있음
# - word_to_index는 사전의 크기를 결정하는 인자이다. 따라서 words가 몇개 정도 있는지 보고 그에 따라 사전의 크기를 결정해주면 됨
# - 사전 크기 또한 조절할 수 있는 부분이다. 하지만 너무 크게하면 학습이 느려진다.

# %% [markdown]
# - word_to_index는 key값이 텍스트 스트링이다. 따라서 인덱스 역할을 하는 key값을 숫자이기 때문에 해당 값에서 숫자를 추출하기 위한 함수가 필요하다. => wordlist_to_indexlist

# %%
words = np.concatenate(df_train).tolist()
len(words)
# Out:
# 182925

# %%
vocab_size = 43800
counter = Counter(words)
counter = counter.most_common(vocab_size-4)
vocab = ['<PAD>', '<BOS>', '<UNK>', '<UNUSED>'] + [key for key, _ in counter]

word_to_index = {word:index for index, word in enumerate(vocab)}

# %%
type(word_to_index)
# Out:
# dict

# %%
len(word_to_index)
# Out:
# 5203

# %%
word_to_index
# Out:
# {'<PAD>': 0,
#  '<BOS>': 1,
#  '<UNK>': 2,
#  '<UNUSED>': 3,
#  '사항': 4,
#  '요청': 5,
#  '고객': 6,
#  '추가': 7,
#  '연락처': 8,
#  '진단': 9,
#  '결과': 10,
#  '단말': 11,
#  '특이': 12,
#  '회선': 13,
#  '기타': 14,
#  '불': 15,
#  '리모컨': 16,
#  '리셋': 17,
#  '이': 18,
#  '방문': 19,
#  '수신': 20,
#  '코로나': 21,
#  '확인': 22,
#  '안': 23,
#  '접수': 24,
#  '후': 25,
#  '함': 26,
#  '작동': 27,
#  '안됨': 28,
#  '신': 29,
#  '상무': 30,
#  '시': 31,
#  '안내': 32,
#  '수': 33,
#  '교체': 34,
#  '시청': 35,
#  '재': 36,
#  '정상': 37,
#  '티비': 38,
#  '후방': 39,
#  '타': 40,
#  '가': 41,
#  '연': 42,
#  '필': 43,
#  '선': 44,
#  '화면': 45,
#  '동일': 46,
#  '셋탑': 47,
#  '연락': 48,
#  '점검': 49,
#  '지니': 50,
#  '재부팅': 51,
#  '호': 52,
#  '심': 53,
#  '연결': 54,
#  '기': 55,
#  '일': 56,
#  '정상기': 57,
#  '중': 58,
#  '인': 59,
#  '됨': 60,
#  '대': 61,
#  '채널': 62,
#  '빠른': 63,
#  '하': 64,
#  '으로': 65,
#  '이상': 66,
#  '요': 67,
#  '버튼': 68,
#  '에': 69,
#  '도': 70,
#  '전원': 71,
#  '나옴': 72,
#  '임의': 73,
#  '오류': 74,
#  '택배': 75,
#  '사용': 76,
#  '고장': 77,
#  '독촉': 78,
#  '해도': 79,
#  '전': 80,
#  '신호': 81,
#  '만': 82,
#  '등록': 83,
#  '배송': 84,
#  '로': 85,
#  '내': 86,
#  '장비': 87,
#  '다': 88,
#  '건': 89,
#  '외부': 90,
#  '음성': 91,
#  '잘': 92,
#  '불가': 93,
#  '인터넷': 94,
#  '없음': 95,
#  '발송': 96,
#  '은': 97,
#  '화질': 98,
#  '최대한': 99,
#  '넷플릭스': 100,
#  '회': 101,
#  '끊김': 102,
#  '신고': 103,
#  '포트': 104,
#  '불량': 105,
#  '문자': 106,
#  '설정': 107,
#  '리모콘': 108,
#  '셋': 109,
#  '보류': 110,
#  '부팅': 111,
#  '차': 112,
#  '입': 113,
#  '한': 114,
#  '옴': 115,
#  '티': 116,
#  '시간': 117,
#  '모뎀': 118,
#  '문의': 119,
#  '매장': 120,
#  '오후': 121,
#  '임': 122,
#  '변경': 123,
#  '의회': 124,
#  '일시': 125,
#  '고': 126,
#  '증상': 127,
#  '홈': 128,
#  '을': 129,
#  '올인': 130,
#  '통합': 131,
#  '소리': 132,
#  '된다고': 133,
#  '원': 134,
#  '는': 135,
#  '실패': 136,
#  '일부': 137,
#  '비정상': 138,
#  '엔지니어': 139,
#  '번': 140,
#  '네트워크': 141,
#  '번호': 142,
#  '및': 143,
#  '음성인식': 144,
#  '다시': 145,
#  '불만': 146,
#  '건전지': 147,
#  '에서': 148,
#  '코로': 149,
#  '이후': 150,
#  '나무': 151,
#  '리콜': 152,
#  '전송': 153,
#  '모두': 154,
#  '뜸': 155,
#  '본인': 156,
#  '탑재': 157,
#  '파손': 158,
#  '해': 159,
#  '위치': 160,
#  '동': 161,
#  '된': 162,
#  '지': 163,
#  '해서': 164,
#  '입력': 165,
#  '나': 166,
#  '서비스': 167,
#  '권유': 168,
#  '취소': 169,
#  '현상': 170,
#  '쪽': 171,
#  '무': 172,
#  '다심': 173,
#  '장': 174,
#  '통화': 175,
#  '자': 176,
#  '대리': 177,
#  '거실': 178,
#  '페어': 179,
#  '링': 180,
#  '문제': 181,
#  '발생': 182,
#  '같이': 183,
#  '분': 184,
#  '탑': 185,
#  '희망': 186,
#  '거부': 187,
#  '잦은': 188,
#  '꺼짐': 189,
#  '로딩': 190,
#  '상': 191,
#  '처리': 192,
#  '때': 193,
#  '오전': 194,
#  '대중': 195,
#  '들어': 196,
#  '미리': 197,
#  '방': 198,
#  '무료': 199,
#  '전체': 200,
#  '내용': 201,
#  '다른': 202,
#  '당일': 203,
#  '원함': 204,
#  '무재': 205,
#  '님': 206,
#  '실행': 207,
#  '접': 208,
#  '반복': 209,
#  '이용': 210,
#  '시시': 211,
#  '이동': 212,
#  '깨짐': 213,
#  '설치': 214,
#  '구매': 215,
#  '월': 216,
#  '거': 217,
#  '수건': 218,
#  '계속': 219,
#  '되어': 220,
#  '불연': 221,
#  '를': 222,
#  '이상무': 223,
#  '여러': 224,
#  '직원': 225,
#  '화': 226,
#  '달라': 227,
#  '주소': 228,
#  '했으나': 229,
#  '접속': 230,
#  '해지': 231,
#  '분실': 232,
#  '하여': 233,
#  '올레': 234,
#  '적': 235,
#  '켜짐': 236,
#  '대만': 237,
#  '등': 238,
#  '안방': 239,
#  '케이블': 240,
#  '객': 241,
#  '면': 242,
#  '멀고': 243,
#  '요망': 244,
#  '있음': 245,
#  '메뉴': 246,
#  '되는': 247,
#  '호수': 248,
#  '안나': 249,
#  '라고': 250,
#  '전환': 251,
#  '메세지': 252,
#  '회수': 253,
#  '일반': 254,
#  '층': 255,
#  '하고': 256,
#  '지연': 257,
#  '업': 258,
#  '반응': 259,
#  '방법': 260,
#  '세': 261,
#  '상태': 262,
#  '대리인': 263,
#  '상담': 264,
#  '먼저': 265,
#  '기사': 266,
#  '오': 267,
#  '되고': 268,
#  '월일': 269,
#  '원안': 270,
#  '멈춤': 271,
#  '실시간': 272,
#  '모든': 273,
#  '의': 274,
#  '제': 275,
#  '현재': 276,
#  '멀': 277,
#  '음량': 278,
#  '미약': 279,
#  '꼼꼼한': 280,
#  '함회': 281,
#  '두': 282,
#  '바코드': 283,
#  '꼭': 284,
#  '비': 285,
#  '청연': 286,
#  '나온': 287,
#  '못': 288,
#  '봇': 289,
#  '하니': 290,
#  '카드': 291,
#  '되나': 292,
#  '현장': 293,
#  '눌러야': 294,
#  '점': 295,
#  '되면': 296,
#  '나오고': 297,
#  '하십니다': 298,
#  '된다': 299,
#  '청사': 300,
#  '들어옴': 301,
#  '인식': 302,
#  '리': 303,
#  '있다고': 304,
#  '라': 305,
#  '용': 306,
#  '자체': 307,
#  '와': 308,
#  '자동': 309,
#  '빨간': 310,
#  '새로': 311,
#  '인지': 312,
#  '입자': 313,
#  '위성': 314,
#  '하면': 315,
#  '직영': 316,
#  '내외': 317,
#  '것': 318,
#  '전화': 319,
#  '선재': 320,
#  '될': 321,
#  '이전': 322,
#  '개': 323,
#  '항': 324,
#  '장애': 325,
#  '기술': 326,
#  '한다고': 327,
#  '과': 328,
#  '봄': 329,
#  '시험': 330,
#  '불기': 331,
#  '진행': 332,
#  '셋톱': 333,
#  '완료': 334,
#  '전후': 335,
#  '개통': 336,
#  '조사': 337,
#  '신청': 338,
#  '드림': 339,
#  '나온다고': 340,
#  '입주': 341,
#  '없다고': 342,
#  '해야': 343,
#  '에도': 344,
#  '수시로': 345,
#  '가능': 346,
#  '정보': 347,
#  '수시': 348,
#  '외': 349,
#  '서': 350,
#  '관련': 351,
#  '부탁드립니다': 352,
#  '초기': 353,
#  '누르면': 354,
#  '같다고': 355,
#  '출동': 356,
#  '불셋탑': 357,
#  '있는': 358,
#  '불로': 359,
#  '불임': 360,
#  '배정': 361,
#  '꺼졌다': 362,
#  '하는': 363,
#  '업데이트': 364,
#  '영업': 365,
#  '예약': 366,
#  '방향': 367,
#  '편성표': 368,
#  '수평': 369,
#  '조치': 370,
#  '유튜브': 371,
#  '재고': 372,
#  '니': 373,
#  '나왔다': 374,
#  '시작': 375,
#  '나오나': 376,
#  '측': 377,
#  '눌러도': 378,
#  '필요': 379,
#  '불셋': 380,
#  '부터': 381,
#  '그': 382,
#  '보기': 383,
#  '할': 384,
#  '상기': 385,
#  '회복': 386,
#  '있으면': 387,
#  '긴급': 388,
#  '이나': 389,
#  '성': 390,
#  '제어': 391,
#  '비정': 392,
#  '들림': 393,
#  '느림': 394,
#  '댁': 395,
#  '우선': 396,
#  '방송': 397,
#  '공유기': 398,
#  '수리': 399,
#  '해달라': 400,
#  '키': 401,
#  '하나': 402,
#  '전달': 403,
#  'ㅁ': 404,
#  '채팅': 405,
#  '또': 406,
#  '의뢰': 407,
#  '불편': 408,
#  '기능': 409,
#  '같다': 410,
#  '있다': 411,
#  '부분': 412,
#  '경우': 413,
#  '구성': 414,
#  '플라자': 415,
#  '다운': 416,
#  '유료': 417,
#  '이라고': 418,
#  '되다': 419,
#  '어려움': 420,
#  '민원': 421,
#  '않음': 422,
#  '가입': 423,
#  '너무': 424,
#  '노후': 425,
#  '올인원': 426,
#  '언급': 427,
#  '있을': 428,
#  '해달라고': 429,
#  '볼륨': 430,
#  '저절로': 431,
#  '지속': 432,
#  '사': 433,
#  '배터리': 434,
#  '오래': 435,
#  '게': 436,
#  '무선': 437,
#  '명의': 438,
#  '동안': 439,
#  '지사': 440,
#  '일정': 441,
#  '했다': 442,
#  '했는데': 443,
#  '망': 444,
#  '여': 445,
#  '호출': 446,
#  '자주': 447,
#  '새': 448,
#  '미': 449,
#  '참고': 450,
#  '수동': 451,
#  '불시': 452,
#  '정도': 453,
#  '해결': 454,
#  '나오면서': 455,
#  '고함': 456,
#  '이라': 457,
#  '어': 458,
#  '송출': 459,
#  '이사': 460,
#  '종료': 461,
#  '참': 462,
#  '뜬다고': 463,
#  '닷컴': 464,
#  '청구': 465,
#  '불전': 466,
#  '자연': 467,
#  '배선': 468,
#  '켜졌다': 469,
#  '심함': 470,
#  '박스': 471,
#  '뒤': 472,
#  '뜨면서': 473,
#  '갑자기': 474,
#  '공사': 475,
#  '결제': 476,
#  '관': 477,
#  '했다고': 478,
#  '바로': 479,
#  '요금': 480,
#  '중이': 481,
#  '비용': 482,
#  '사이': 483,
#  '선호': 484,
#  '됐다': 485,
#  '권한': 486,
#  'ㅇ': 487,
#  '동시': 488,
#  '시로': 489,
#  '무조건': 490,
#  '문': 491,
#  '명령': 492,
#  '간': 493,
#  '권': 494,
#  '켜면': 495,
#  '계약': 496,
#  '뜬': 497,
#  '작': 498,
#  '정': 499,
#  '잘못': 500,
#  '어플': 501,
#  '시티': 502,
#  '해당': 503,
#  '남': 504,
#  '적색': 505,
#  '주': 506,
#  '불안': 507,
#  '정리': 508,
#  '결선': 509,
#  '코스': 510,
#  '에는': 511,
#  '에러': 512,
#  '불수신': 513,
#  '까지': 514,
#  '부재': 515,
#  '대답': 516,
#  '혼자': 517,
#  '말': 518,
#  '집': 519,
#  '날씨': 520,
#  '쿠폰': 521,
#  '가지': 522,
#  '나오는데': 523,
#  '검색': 524,
#  '앞': 525,
#  '바람': 526,
#  '메시지': 527,
#  '없다': 528,
#  '짐': 529,
#  '기존': 530,
#  '늦게': 531,
#  '스마트': 532,
#  '직거림': 533,
#  '딩': 534,
#  '속도': 535,
#  '극심': 536,
#  '변동': 537,
#  '링크': 538,
#  '함연': 539,
#  '완': 540,
#  '빨리': 541,
#  '정확한': 542,
#  '해제': 543,
#  '있어': 544,
#  '마다': 545,
#  '들': 546,
#  '되지': 547,
#  '예정': 548,
#  '원룸': 549,
#  '처음': 550,
#  '접촉': 551,
#  '구분': 552,
#  '댁내': 553,
#  '영상': 554,
#  '된다며': 555,
#  '필티': 556,
#  '합니다': 557,
#  '되': 558,
#  '와이파이': 559,
#  '조정': 560,
#  '하는데': 561,
#  '드렸으나': 562,
#  '임시': 563,
#  '카스': 564,
#  '몇': 565,
#  '안심': 566,
#  '후시': 567,
#  '멀리': 568,
#  '부주의': 569,
#  '말고': 570,
#  '뜨고': 571,
#  '동일함': 572,
#  '위': 573,
#  '기본': 574,
#  '차단': 575,
#  '되는데': 576,
#  '모자이크': 577,
#  '깨져서': 578,
#  '한다': 579,
#  '반': 580,
#  '양해': 581,
#  '모컨': 582,
#  '되서': 583,
#  '당': 584,
#  '중간': 585,
#  '씩': 586,
#  '방안': 587,
#  '꺼진다고': 588,
#  '대는': 589,
#  '줄': 590,
#  '해봐도': 591,
#  '앞당겨': 592,
#  '명': 593,
#  '안테나': 594,
#  '표시': 595,
#  '미납': 596,
#  '멤버십': 597,
#  '더': 598,
#  '켜': 599,
#  '없이': 600,
#  '그냥': 601,
#  '내부': 602,
#  '같은': 603,
#  '야간': 604,
#  '급': 605,
#  '근본': 606,
#  '줄이': 607,
#  '꼼꼼하게': 608,
#  '유투브': 609,
#  '불매': 610,
#  '아래': 611,
#  '불대': 612,
#  '관건': 613,
#  '스카이': 614,
#  '부탁드립니': 615,
#  '상품': 616,
#  '부서': 617,
#  '특정': 618,
#  '단자': 619,
#  '대신': 620,
#  '주소지': 621,
#  '함께': 622,
#  '인데': 623,
#  '유': 624,
#  '같다며': 625,
#  '요구사항': 626,
#  '팀': 627,
#  '방기': 628,
#  '거리': 629,
#  '함재': 630,
#  '끊어짐': 631,
#  '관리자': 632,
#  '확답': 633,
#  '네': 634,
#  '아': 635,
#  '안함': 636,
#  '도중': 637,
#  '조절': 638,
#  '장소': 639,
#  '없어': 640,
#  '음': 641,
#  '않는다고': 642,
#  '모드': 643,
#  '나오는': 644,
#  '자가': 645,
#  '복구': 646,
#  '원인': 647,
#  '손': 648,
#  '불건전': 649,
#  '임대': 650,
#  '부활': 651,
#  '기기': 652,
#  '내시': 653,
#  '숫자': 654,
#  '삼성': 655,
#  '받았으나': 656,
#  '자꾸': 657,
#  '불호': 658,
#  '마찬가지': 659,
#  '사람': 660,
#  '해드림': 661,
#  '실': 662,
#  '녹색': 663,
#  '야': 664,
#  '랑': 665,
#  '비번': 666,
#  '얼마': 667,
#  '김': 668,
#  '불위': 669,
#  '부': 670,
#  '불통': 671,
#  '감': 672,
#  '무상': 673,
#  '비리': 674,
#  '있고': 675,
#  '거림': 676,
#  '걸': 677,
#  '켜지고': 678,
#  '까맣게': 679,
#  '가능함': 680,
#  '비수': 681,
#  '소': 682,
#  '받음': 683,
#  '지금': 684,
#  '그런': 685,
#  '모텔': 686,
#  '가능한': 687,
#  '본': 688,
#  '대다': 689,
#  '리부팅': 690,
#  '입호': 691,
#  '응답': 692,
#  '고정': 693,
#  '대로': 694,
#  '동일하다': 695,
#  '모니터': 696,
#  '했던': 697,
#  '꺼져': 698,
#  '온': 699,
#  '유선': 700,
#  '인입': 701,
#  '건물': 702,
#  '보상금': 703,
#  '멀티': 704,
#  '아파트': 705,
#  '알려': 706,
#  '데': 707,
#  '나머지': 708,
#  '지지': 709,
#  '센서': 710,
#  '만원': 711,
#  '아예': 712,
#  '세게': 713,
#  '과장': 714,
#  '생기': 715,
#  '되었다고': 716,
#  '되었다': 717,
#  '해보셨다': 718,
#  '하신': 719,
#  '직': 720,
#  '깜박': 721,
#  '선로': 722,
#  '하였으나': 723,
#  '되다가': 724,
#  '차례': 725,
#  '톱': 726,
#  '스트림': 727,
#  '선도': 728,
#  '방수': 729,
#  '아무': 730,
#  '조작': 731,
#  '가능하면': 732,
#  '에서는': 733,
#  '문구': 734,
#  '엔': 735,
#  '시기': 736,
#  '신다고': 737,
#  '배우자': 738,
#  '곳': 739,
#  '격리': 740,
#  '셋탑박스': 741,
#  '거절': 742,
#  '헐': 743,
#  '최근': 744,
#  '하시고': 745,
#  '미가': 746,
#  '자녀': 747,
#  '들어온다고': 748,
#  '없': 749,
#  '불입': 750,
#  '오늘': 751,
#  '오프': 752,
#  '양': 753,
#  '근처': 754,
#  '켜진': 755,
#  '손실': 756,
#  '가까운': 757,
#  '쯤': 758,
#  '방쪽': 759,
#  '옴셋탑': 760,
#  '모름': 761,
#  '대상': 762,
#  '당겨서': 763,
#  '흔들림': 764,
#  '함수': 765,
#  '작은': 766,
#  '나오며': 767,
#  '불비': 768,
#  '며': 769,
#  '돼서': 770,
#  '팝업': 771,
#  '뜬다': 772,
#  '정지': 773,
#  '시도': 774,
#  '직접': 775,
#  '콜': 776,
#  '구': 777,
#  '구입': 778,
#  '처럼': 779,
#  '하지': 780,
#  '어르신': 781,
#  '빨간색': 782,
#  '력': 783,
#  '주신다고': 784,
#  '플레이': 785,
#  '사업': 786,
#  '램프': 787,
#  '코드': 788,
#  '길': 789,
#  '긍': 790,
#  '약': 791,
#  '받은': 792,
#  '노이즈': 793,
#  '품질': 794,
#  '종결': 795,
#  '하려': 796,
#  '시설': 797,
#  '어댑터': 798,
#  '수긍': 799,
#  '촉': 800,
#  '하면서': 801,
#  '여부': 802,
#  '조회': 803,
#  '전혀': 804,
#  '전부': 805,
#  '가입자': 806,
#  '셋톱박스': 807,
#  '스피커': 808,
#  '작업': 809,
#  '공동': 810,
#  '수도': 811,
#  '께': 812,
#  '호호': 813,
#  '준': 814,
#  '그대로': 815,
#  '제시': 816,
#  '들어온': 817,
#  '만나': 818,
#  '건지': 819,
#  '준비': 820,
#  '중대': 821,
#  '정확히': 822,
#  '조': 823,
#  '많이': 824,
#  '테이블': 825,
#  '지역': 826,
#  '랜선': 827,
#  '든': 828,
#  '받았다': 829,
#  '인해': 830,
#  '나서': 831,
#  '담당자': 832,
#  '인증': 833,
#  '다음': 834,
#  '생략': 835,
#  '안눌림': 836,
#  '비밀번호': 837,
#  '해봄': 838,
#  '한참': 839,
#  '이랑': 840,
#  '하며': 841,
#  '라는': 842,
#  '설명': 843,
#  '원하': 844,
#  '꼼꼼': 845,
#  '켤': 846,
#  '자막': 847,
#  '하셔서': 848,
#  '스카이라이프': 849,
#  '현': 850,
#  '늦은': 851,
#  '어렵다': 852,
#  '불리': 853,
#  '요구': 854,
#  '필요하다고': 855,
#  '영향': 856,
#  '오면': 857,
#  '익일': 858,
#  '강성': 859,
#  '영화': 860,
#  '먹통': 861,
#  '전주': 862,
#  '담당': 863,
#  '음으로': 864,
#  '의자': 865,
#  '항상': 866,
#  '센터': 867,
#  '상하': 868,
#  '않고': 869,
#  '없을': 870,
#  '청약': 871,
#  '건수': 872,
#  '주신': 873,
#  '하신다고': 874,
#  '알': 875,
#  '나오다': 876,
#  '않아': 877,
#  '부족': 878,
#  '때문': 879,
#  '가능하나': 880,
#  '아웃': 881,
#  '보임': 882,
#  '넷플': 883,
#  '대금': 884,
#  '들어오며': 885,
#  '노래': 886,
#  '컨텐츠': 887,
#  '어떻게': 888,
#  '따로': 889,
#  '무응': 890,
#  '지원': 891,
#  '조금': 892,
#  '있어서': 893,
#  '금': 894,
#  '어둡게': 895,
#  '좀': 896,
#  '공': 897,
#  '평소': 898,
#  '기량': 899,
#  '받을': 900,
#  '들어오고': 901,
#  '핀': 902,
#  '켜지는': 903,
#  '업무': 904,
#  '켜진다고': 905,
#  '청소': 906,
#  '들어가서': 907,
#  '초': 908,
#  '요일': 909,
#  '청': 910,
#  '오스': 911,
#  '없고': 912,
#  '보심': 913,
#  '선단': 914,
#  '보': 915,
#  '심연': 916,
#  '지상파': 917,
#  '추후': 918,
#  '소등': 919,
#  '좋다고': 920,
#  '해보고': 921,
#  '지점': 922,
#  '나와서': 923,
#  '당시': 924,
#  '토요일': 925,
#  '좋음': 926,
#  '준다': 927,
#  '되도': 928,
#  '이미': 929,
#  '제공': 930,
#  '어렵다고': 931,
#  '시안': 932,
#  '눌려': 933,
#  '신규': 934,
#  '재송출': 935,
#  '나오지': 936,
#  '프로그램': 937,
#  '누르고': 938,
#  '꾹': 939,
#  '눌러': 940,
#  '부산': 941,
#  '보냄': 942,
#  '비상': 943,
#  '소요': 944,
#  '있거나': 945,
#  '혹시': 946,
#  '중고': 947,
#  '앱': 948,
#  '전시': 949,
#  '발신': 950,
#  '사무실': 951,
#  '하단': 952,
#  '끊으': 953,
#  '단': 954,
#  '나왔다가': 955,
#  '둘': 956,
#  '안됨진단': 957,
#  '재생': 958,
#  '제품': 959,
#  '정검': 960,
#  '나오신다고': 961,
#  '끄면': 962,
#  '아니라': 963,
#  '받았는데': 964,
#  '갔다': 965,
#  '꺼지고': 966,
#  '지면': 967,
#  '불직': 968,
#  '영점': 969,
#  '추티업': 970,
#  '에서만': 971,
#  '하시며': 972,
#  '장님': 973,
#  '리퍼': 974,
#  '하기': 975,
#  '있는데': 976,
#  '빠르게': 977,
#  '성공': 978,
#  '가게': 979,
#  '호안': 980,
#  '잡음': 981,
#  '음향': 982,
#  '랜': 983,
#  '큰': 984,
#  '처': 985,
#  '업그레이드': 986,
#  '대안': 987,
#  '대가': 988,
#  '송출됨': 989,
#  '깜빡': 990,
#  '기건': 991,
#  '기간': 992,
#  '불지': 993,
#  '저녁': 994,
#  '주인': 995,
#  '원활하지': 996,
#  '않다고': 997,
#  '당겨': 998,
#  '인티': 999,
#  ...}

# %%
# 텍스트 스트링을 사전 인덱스 스트링으로 변환

def wordlist_to_indexlist(wordlist):
    return [word_to_index[word] if word in word_to_index else word_to_index['<UNK>'] for word in wordlist]

# %%
X_train = list(map(wordlist_to_indexlist, X_train))
X_valid = list(map(wordlist_to_indexlist, X_valid))

# %%
X_valid[:3]
# Out:
# [[126,
#   241,
#   2,
#   67,
#   910,
#   433,
#   324,
#   2,
#   80,
#   134,
#   2,
#   648,
#   2,
#   242,
#   2,
#   1753,
#   529,
#   2,
#   2176,
#   2160,
#   1430,
#   2,
#   3590,
#   2,
#   2,
#   122,
#   274,
#   2,
#   823,
#   1430,
#   2,
#   58,
#   2,
#   303,
#   2181,
#   2392,
#   70,
#   2,
#   126,
#   174,
#   2,
#   198,
#   491,
#   2,
#   31,
#   2,
#   3730,
#   18,
#   2,
#   1703,
#   1792,
#   2,
#   67,
#   910],
#  [116,
#   285,
#   69,
#   350,
#   2,
#   1859,
#   2805,
#   2,
#   2176,
#   2,
#   624,
#   2,
#   2,
#   2,
#   23,
#   60,
#   2,
#   1699,
#   59,
#   2,
#   128,
#   2,
#   499,
#   191,
#   2,
#   59,
#   2877,
#   1859,
#   2,
#   499,
#   191,
#   2,
#   116,
#   285,
#   2,
#   2181,
#   282,
#   2,
#   499,
#   191,
#   2,
#   85,
#   2,
#   2317,
#   59,
#   558,
#   458,
#   2,
#   126,
#   241,
#   2,
#   377,
#   2,
#   116,
#   285,
#   85,
#   2,
#   2317,
#   59,
#   2,
#   23,
#   634],
#  [55,
#   41,
#   2,
#   163,
#   373,
#   69,
#   350,
#   2,
#   1859,
#   2805,
#   2,
#   2176,
#   2,
#   662,
#   3235,
#   2,
#   15,
#   41,
#   2,
#   303,
#   109,
#   2,
#   494,
#   2,
#   624,
#   2,
#   126,
#   241,
#   2,
#   349,
#   670,
#   4839,
#   350,
#   2,
#   1067,
#   3235,
#   159,
#   2,
#   915,
#   31,
#   126,
#   2,
#   36,
#   42,
#   2,
#   2,
#   506,
#   29,
#   2,
#   88,
#   53]]

# %% [markdown]
# #### 데이터 셋 내 문장 길이 분포

# %%
print(X_train[0])  # 1번째 리뷰데이터
print('라벨: ', y_train[0])  # 1번째 리뷰데이터의 라벨
print('1번째 리뷰 문장 길이: ', len(X_train[0]))
print('2번째 리뷰 문장 길이: ', len(X_train[1]))
# Out:
# [303, 2181, 2392, 2, 498, 161, 23, 2, 60, 2, 172, 4743, 2, 238, 2, 26]
# 라벨:  11
# 1번째 리뷰 문장 길이:  16
# 2번째 리뷰 문장 길이:  66

# %%
total_data_text = list(X_train) + list(X_valid)

# 텍스트데이터 문장길이의 리스트를 생성한 후
num_tokens = [len(tokens) for tokens in total_data_text]
num_tokens = np.array(num_tokens)

# %%
# 문장길이의 평균값, 최대값, 표준편차를 계산해 본다. 
print('문장길이 평균 : ', np.mean(num_tokens))
print('문장길이 최대 : ', np.max(num_tokens))
print('문장길이 표준편차 : ', np.std(num_tokens))
# Out:
# 문장길이 평균 :  58.21903249450281
# 문장길이 최대 :  474
# 문장길이 표준편차 :  28.13411624330434

# %% [markdown]
# #### 적절한 문장 최대 길이 지정
# - 분포를 통해 확인하여 문장 최대길이를 정해야함

# %%
print('리뷰의 최대 길이 :', np.max(num_tokens))
print('리뷰의 평균 길이 :', np.mean(num_tokens))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 474
# 리뷰의 평균 길이 : 58.21903249450281

# %% [markdown]
# - 문장 최대길이가 114일때 전체 문장의 96%를 포함하는 것으로 보아 문장 최대길이는 114로 설정 MAX_LENTH = 114

# %%
# 예를들어, 최대 길이를 (평균 + 2*표준편차)로 한다면,  
max_tokens = np.mean(num_tokens) + 2 * np.std(num_tokens)
max_len = int(max_tokens)
print('pad_sequences maxlen : ', max_len)
print('전체 문장의 {}%가 maxlen 설정값 이내에 포함됩니다. '.format(np.sum(num_tokens < max_tokens) / len(num_tokens)))
# Out:
# pad_sequences maxlen :  114
# 전체 문장의 0.9651844612753482%가 maxlen 설정값 이내에 포함됩니다.

# %% [markdown]
# #### keras.preprocessing.sequence.pad_sequences 을 활용한 패딩 추가

# %%
X_train = pad_sequences(X_train, 
                        maxlen = max_len,
                        value=word_to_index["<PAD>"],
                        padding='pre')
X_valid = pad_sequences(X_valid, 
                       maxlen = max_len,
                       value=word_to_index["<PAD>"],
                       padding='pre')

# %%
print(X_train.shape)
print(X_valid.shape)
# Out:
# (6548, 114)
# (1638, 114)

# %% [markdown]
# ### Modeling

# %%
total_cnt = len(word_to_index)  # 어휘 사전의 크기입니다

print(total_cnt, '개')
# Out:
# 5203 개

# %%
word_vector_dim = 50

# %%
from tensorflow import keras

model = keras.Sequential()
model.add(keras.layers.Embedding(vocab_size, word_vector_dim, input_shape=(None,)))
model.add(keras.layers.LSTM(128))   # 가장 널리 쓰이는 RNN인 LSTM 레이어를 사용하였습니다. 이때 LSTM state 벡터의 차원수는 64로 하였습니다. (변경가능)
# model.add(keras.layers.Dense(8, activation='relu')) # 안해도 됨
model.add(keras.layers.Dense(14, activation='softmax'))  # 최종 출력은 긍정/부정을 나타내는 1dim 입니다.

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 50)          2190000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               91648
# _________________________________________________________________
# dense_1 (Dense)              (None, 14)                1806
# =================================================================
# Total params: 2,283,454
# Trainable params: 2,283,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
# validation set 29300건 분리
X_val = X_valid
y_val = y_valid

# validation set을 제외한 나머지 
partial_X_train = X_train
partial_y_train = y_train

print(partial_X_train.shape)
print(partial_y_train.shape)
# Out:
# (6548, 114)
# (6548,)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
mc = ModelCheckpoint('C:/Users/inp032/Desktop/채널 AI/channel-ai/model/best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
              
epochs=20  # 몇 epoch를 훈련하면 좋을지 결과를 보면서 바꾸어 봅시다. 

history = model.fit(partial_X_train,
                    partial_y_train,
                    epochs=epochs,
                    batch_size=60, # 512, 100, 60 
                    validation_data=(X_val, y_val),
                    verbose=1,
                    callbacks = [es, mc])
                    
model.save('C:/Users/inp032/Desktop/채널 AI/channel-ai/model/best_model.h5')
# Out:
# Epoch 1/20
# 110/110 [==============================] - 24s 198ms/step - loss: 1.4405 - accuracy: 0.4808 - val_loss: 1.3019 - val_accuracy: 0.5421
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/20
# 110/110 [==============================] - 22s 199ms/step - loss: 1.2846 - accuracy: 0.5281 - val_loss: 1.2738 - val_accuracy: 0.5507
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/20
# 110/110 [==============================] - 22s 197ms/step - loss: 1.2552 - accuracy: 0.5467 - val_loss: 1.2269 - val_accuracy: 0.5690
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/20
# 110/110 [==============================] - 24s 214ms/step - loss: 1.2457 - accuracy: 0.5559 - val_loss: 1.2522 - val_accuracy: 0.5604
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/20
# 110/110 [==============================] - 27s 243ms/step - loss: 1.1634 - accuracy: 0.6078 - val_loss: 1.0946 - val_accuracy: 0.6618
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/20
# 110/110 [==============================] - 23s 206ms/step - loss: 1.0208 - accuracy: 0.6982 - val_loss: 0.9856 - val_accuracy: 0.7186
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/20
# 110/110 [==============================] - 24s 219ms/step - loss: 0.9354 - accuracy: 0.7257 - val_loss: 0.9845 - val_accuracy: 0.7002
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/20
# 110/110 [==============================] - 24s 222ms/step - loss: 0.8748 - accuracy: 0.7491 - val_loss: 1.0340 - val_accuracy: 0.6966
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/20
# 110/110 [==============================] - 23s 207ms/step - loss: 0.9258 - accuracy: 0.7312 - val_loss: 0.9708 - val_accuracy: 0.6996
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/20
# 110/110 [==============================] - 24s 223ms/step - loss: 0.8571 - accuracy: 0.7486 - val_loss: 0.8369 - val_accuracy: 0.7656
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/20
# 110/110 [==============================] - 24s 216ms/step - loss: 0.7268 - accuracy: 0.7969 - val_loss: 0.7606 - val_accuracy: 0.7918
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/20
# 110/110 [==============================] - 25s 226ms/step - loss: 0.6656 - accuracy: 0.8132 - val_loss: 0.6779 - val_accuracy: 0.8083
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/20
# 110/110 [==============================] - 25s 228ms/step - loss: 0.6152 - accuracy: 0.8215 - val_loss: 0.7034 - val_accuracy: 0.7985
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/20
# 110/110 [==============================] - 25s 224ms/step - loss: 0.6057 - accuracy: 0.8209 - val_loss: 0.6707 - val_accuracy: 0.8126
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/20
# 110/110 [==============================] - 25s 225ms/step - loss: 0.5592 - accuracy: 0.8419 - val_loss: 0.6406 - val_accuracy: 0.8175
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/20
# 110/110 [==============================] - 24s 223ms/step - loss: 0.5305 - accuracy: 0.8538 - val_loss: 0.6239 - val_accuracy: 0.8199
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/20
# 110/110 [==============================] - 28s 252ms/step - loss: 0.5168 - accuracy: 0.8577 - val_loss: 0.6229 - val_accuracy: 0.8175
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/20
# 110/110 [==============================] - 28s 259ms/step - loss: 0.4906 - accuracy: 0.8679 - val_loss: 0.5699 - val_accuracy: 0.8425
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/20
# 110/110 [==============================] - 26s 235ms/step - loss: 0.4807 - accuracy: 0.8719 - val_loss: 0.6112 - val_accuracy: 0.8455
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/20
# 110/110 [==============================] - 27s 243ms/step - loss: 0.4746 - accuracy: 0.8722 - val_loss: 0.5791 - val_accuracy: 0.8449
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.

# %% [markdown]
# #### Loss, Accuracy 그래프 시각화

# %%
results = model.evaluate(X_valid,  y_valid, verbose=2)

print(results)
# Out:
# 52/52 - 3s - loss: 0.5791 - accuracy: 0.8449
# [0.5790765881538391, 0.8449328541755676]

# %%
history_dict = history.history
print(history_dict.keys()) # epoch에 따른 그래프를 그려볼 수 있는 항목들
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# - 학습이 진행 될 수록 Loss 가 떨어짐.
# - epoch을 더 늘려도 될 것 같다고 생각함.

# %%
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

# "bo"는 "파란색 점"입니다
plt.plot(epochs, loss, 'bo', label='Training loss')
# b는 "파란 실선"입니다
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
