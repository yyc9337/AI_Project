# %%
import os
import pandas as pd
import numpy as np

import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from tensorflow.python.keras.models import load_model

import tensorflow as tf
from tensorflow import keras

# %%
## 경로 재설정
os.chdir('../../home/innerwave/ailab/채널AI/L3/Experiment/')
path = '../Processing/bps_in/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')] ## 파일명 끝이 .csv인 경우

# %%
file_list_py
# Out:
# ['172.17.28.215_bpsin.csv',
#  '172.17.28.184_bpsin.csv',
#  '172.17.28.233_bpsin.csv',
#  '172.17.28.182_bpsin.csv',
#  '172.17.28.234_bpsin.csv',
#  '172.17.28.198_bpsin.csv',
#  '172.17.28.191_bpsin.csv',
#  '172.17.28.183_bpsin.csv',
#  '172.17.28.216_bpsin.csv',
#  '172.17.28.222_bpsin.csv',
#  '172.17.28.192_bpsin.csv',
#  '172.17.28.190_bpsin.csv',
#  '172.17.28.181_bpsin.csv',
#  '172.17.28.186_bpsin.csv',
#  '172.17.28.231_bpsin.csv',
#  '172.17.28.185_bpsin.csv',
#  '172.17.28.189_bpsin.csv',
#  '172.17.28.197_bpsin.csv',
#  '172.17.28.188_bpsin.csv',
#  '172.17.28.193_bpsin.csv',
#  '172.17.28.232_bpsin.csv',
#  '172.17.28.194_bpsin.csv',
#  '172.17.28.221_bpsin.csv',
#  '172.17.28.187_bpsin.csv']

# %%
def make_vector(X, Y, time_steps=1):
    Xs, Ys = [], []
    for i in range(len(X) - time_steps):
        value = X.iloc[i:(i + time_steps)].values
        Xs.append(value)        
        Ys.append(Y.iloc[i + time_steps])
    return np.array(Xs), np.array(Ys)

# %%
for i in file_list_py:
    ## 데이터 초기화
    ticket = None

    # 데이터 로드
    df = pd.read_csv(path + i)
    ticket = pd.read_csv(path + i)
    time_temp = pd.to_datetime(ticket['stat_dt'])
    level_temp = ticket['bps_in']
    time_temp.name = 'date'
    level_temp.name = 'bps_in'

    ticket = pd.concat([time_temp, level_temp ], axis = 1)
    ticket = ticket.set_index("date")
    print(ticket.shape)
    ticket.head(5)

    plt.rcParams["figure.figsize"] = (20,10)
    ticket.plot()

    # Set Anomaly
    span_start = time_temp[4950].to_pydatetime()
    span_end = time_temp[5150].to_pydatetime()
    plt.axvspan(span_start, span_end, facecolor='r', alpha=0.5)

    plt.title("bps_in")
    plt.xlabel("Time")
    plt.ylabel("bps_in")
    plt.show()

    train_size = int(len(ticket) * 0.7)
    test_size = len(ticket) - train_size
    train, test = ticket.iloc[0:train_size], ticket.iloc[train_size:len(ticket)]
    print(train.shape, test.shape)

    from sklearn.preprocessing import StandardScaler

    scaler = StandardScaler()
    scaler = scaler.fit(train[['bps_in']])

    train['bps_in'] = scaler.transform(train[['bps_in']])
    test['bps_in'] = scaler.transform(test[['bps_in']])

    TIME_STEPS = 30

    X_train, Y_train = make_vector(train[['bps_in']], train.bps_in, TIME_STEPS)
    X_test, Y_test = make_vector(test[['bps_in']], test.bps_in, TIME_STEPS)

    model = keras.Sequential()
    model.add(keras.layers.LSTM(units=64, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(keras.layers.Dropout(rate=0.2))
    model.add(keras.layers.RepeatVector(n=X_train.shape[1]))
    model.add(keras.layers.LSTM(units=64, return_sequences=True))
    model.add(keras.layers.Dropout(rate=0.2))
    model.add(keras.layers.TimeDistributed(keras.layers.Dense(units=X_train.shape[2])))
    model.compile(loss='mae', optimizer='adam')

    history = model.fit(X_train, X_train, epochs=10, batch_size=32, validation_split=0.1, shuffle=False)
    
    X_pred = model.predict(X_train)
    train_mae_loss = np.mean(np.abs(X_pred - X_train), axis=1)

    sns.distplot(train_mae_loss, bins=50, kde=True);

    X_pred = model.predict(X_test)
    test_mae_loss = np.mean(np.abs(X_pred - X_test), axis=1)

    THRESHOLD = 0.3 # Manual Setting

    test_score_df = pd.DataFrame(index=test[TIME_STEPS:].index)
    test_score_df['loss'] = test_mae_loss
    test_score_df['threshold'] = THRESHOLD
    test_score_df['anomaly'] = test_score_df.loss > test_score_df.threshold
    test_score_df['bps_in'] = test[TIME_STEPS:].bps_in

    anomalies = test_score_df[test_score_df.anomaly == True]
    print(anomalies.head())



    model.save('../Model/bps_in/' +str(df['ip'][0])+'_bpsin.h5')
    ## MLflow Logging
    #os.chdir('/mlflow-management/L3-mlflow/')
# Out:
# (5663, 1)
# (3964, 1) (1699, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 7s 41ms/step - loss: 0.1899 - val_loss: 0.1096
# Epoch 2/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1592 - val_loss: 0.0670
# Epoch 3/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.0967 - val_loss: 0.0770
# Epoch 4/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.2023 - val_loss: 0.1190
# Epoch 5/10
# 111/111 [==============================] - 4s 38ms/step - loss: 0.1368 - val_loss: 0.0701
# Epoch 6/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.2284 - val_loss: 0.1503
# Epoch 7/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1831 - val_loss: 0.0481
# Epoch 8/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.2576 - val_loss: 0.1585
# Epoch 9/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1745 - val_loss: 0.0862
# Epoch 10/10
# 111/111 [==============================] - 4s 37ms/step - loss: 0.2600 - val_loss: 0.1313
# 123/123 [==============================] - 2s 11ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 12ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-15 08:02:00  0.300241        0.3     True  1.781777
# 2022-08-15 08:03:00  0.301001        0.3     True  1.782424
# 2022-08-15 08:04:00  0.301755        0.3     True  1.783152
# 2022-08-15 08:06:00  0.302413        0.3     True  1.783786
# 2022-08-15 08:07:00  0.302989        0.3     True  1.785240
# (5718, 1)
# (4002, 1) (1716, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 112/112 [==============================] - 9s 42ms/step - loss: 0.2035 - val_loss: 0.1099
# Epoch 2/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.1642 - val_loss: 0.1032
# Epoch 3/10
# 112/112 [==============================] - 4s 33ms/step - loss: 0.0973 - val_loss: 0.0727
# Epoch 4/10
# 112/112 [==============================] - 4s 32ms/step - loss: 0.1917 - val_loss: 0.1048
# Epoch 5/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.1377 - val_loss: 0.0513
# Epoch 6/10
# 112/112 [==============================] - 4s 37ms/step - loss: 0.2053 - val_loss: 0.0944
# Epoch 7/10
# 112/112 [==============================] - 4s 36ms/step - loss: 0.1815 - val_loss: 0.0782
# Epoch 8/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.2343 - val_loss: 0.1261
# Epoch 9/10
# 112/112 [==============================] - 4s 33ms/step - loss: 0.2066 - val_loss: 0.0570
# Epoch 10/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.2594 - val_loss: 0.1175
# 125/125 [==============================] - 2s 11ms/step
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-16 01:23:00  0.300185        0.3     True  2.503175
# 2022-08-16 01:24:00  0.300318        0.3     True  2.503915
# 2022-08-16 01:25:00  0.300411        0.3     True  2.504539
# 2022-08-16 01:27:00  0.300492        0.3     True  2.505902
# 2022-08-16 01:28:00  0.300701        0.3     True  2.506641
# (5662, 1)
# (3963, 1) (1699, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 7s 39ms/step - loss: 0.1660 - val_loss: 0.0996
# Epoch 2/10
# 111/111 [==============================] - 4s 32ms/step - loss: 0.1410 - val_loss: 0.0909
# Epoch 3/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.0880 - val_loss: 0.1065
# Epoch 4/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1795 - val_loss: 0.0793
# Epoch 5/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1242 - val_loss: 0.0592
# Epoch 6/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.2429 - val_loss: 0.0730
# Epoch 7/10
# 111/111 [==============================] - 4s 37ms/step - loss: 0.1979 - val_loss: 0.0645
# Epoch 8/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.2503 - val_loss: 0.2755
# Epoch 9/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1871 - val_loss: 0.0887
# Epoch 10/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.3020 - val_loss: 0.0518
# 123/123 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-16 06:46:00  0.300071        0.3     True  2.785897
# 2022-08-16 06:47:00  0.300257        0.3     True  2.787322
# 2022-08-16 06:48:00  0.300586        0.3     True  2.787952
# 2022-08-16 06:49:00  0.300871        0.3     True  2.788727
# 2022-08-16 06:51:00  0.301114        0.3     True  2.789496
# (5711, 1)
# (3997, 1) (1714, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 112/112 [==============================] - 8s 44ms/step - loss: 0.1951 - val_loss: 0.1063
# Epoch 2/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.1643 - val_loss: 0.0622
# Epoch 3/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.1068 - val_loss: 0.0623
# Epoch 4/10
# 112/112 [==============================] - 4s 36ms/step - loss: 0.1867 - val_loss: 0.0806
# Epoch 5/10
# 112/112 [==============================] - 4s 36ms/step - loss: 0.1498 - val_loss: 0.0756
# Epoch 6/10
# 112/112 [==============================] - 4s 33ms/step - loss: 0.2333 - val_loss: 0.0895
# Epoch 7/10
# 112/112 [==============================] - 4s 33ms/step - loss: 0.2285 - val_loss: 0.1238
# Epoch 8/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.2565 - val_loss: 0.0903
# Epoch 9/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.2175 - val_loss: 0.0918
# Epoch 10/10
# 112/112 [==============================] - 4s 33ms/step - loss: 0.2546 - val_loss: 0.0572
# 124/124 [==============================] - 2s 10ms/step
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 12ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-15 20:55:00  0.300189        0.3     True  2.318546
# 2022-08-15 20:57:00  0.300496        0.3     True  2.319909
# 2022-08-15 20:58:00  0.300894        0.3     True  2.320532
# 2022-08-15 20:59:00  0.301241        0.3     True  2.321280
# 2022-08-15 21:00:00  0.301546        0.3     True  2.322010
# (5662, 1)
# (3963, 1) (1699, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 8s 41ms/step - loss: 0.1657 - val_loss: 0.1327
# Epoch 2/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1466 - val_loss: 0.1269
# Epoch 3/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.0882 - val_loss: 0.0719
# Epoch 4/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1739 - val_loss: 0.0693
# Epoch 5/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.1145 - val_loss: 0.1221
# Epoch 6/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.1816 - val_loss: 0.0520
# Epoch 7/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1271 - val_loss: 0.0636
# Epoch 8/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.2082 - val_loss: 0.0612
# Epoch 9/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1452 - val_loss: 0.1111
# Epoch 10/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.2352 - val_loss: 0.0663
# 123/123 [==============================] - 2s 11ms/step
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
# Empty DataFrame
# Columns: [loss, threshold, anomaly, bps_in]
# Index: []
# (5666, 1)
# (3966, 1) (1700, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 8s 42ms/step - loss: 0.1853 - val_loss: 0.1051
# Epoch 2/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1583 - val_loss: 0.1028
# Epoch 3/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1055 - val_loss: 0.0699
# Epoch 4/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1932 - val_loss: 0.0520
# Epoch 5/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1378 - val_loss: 0.0650
# Epoch 6/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.2169 - val_loss: 0.1238
# Epoch 7/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1638 - val_loss: 0.0373
# Epoch 8/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.2816 - val_loss: 0.0767
# Epoch 9/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1973 - val_loss: 0.0406
# Epoch 10/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.2513 - val_loss: 0.1600
# 123/123 [==============================] - 2s 11ms/step
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-15 08:18:00  0.300102        0.3     True  1.792849
# 2022-08-15 08:19:00  0.300691        0.3     True  1.793472
# 2022-08-15 08:21:00  0.301146        0.3     True  1.794219
# 2022-08-15 08:22:00  0.301551        0.3     True  1.795575
# 2022-08-15 08:23:00  0.302144        0.3     True  1.796314
# (5720, 1)
# (4003, 1) (1717, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 112/112 [==============================] - 9s 45ms/step - loss: 0.1738 - val_loss: 0.1256
# Epoch 2/10
# 112/112 [==============================] - 4s 37ms/step - loss: 0.1589 - val_loss: 0.0600
# Epoch 3/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.0882 - val_loss: 0.0883
# Epoch 4/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.1710 - val_loss: 0.0963
# Epoch 5/10
# 112/112 [==============================] - 4s 33ms/step - loss: 0.1148 - val_loss: 0.1482
# Epoch 6/10
# 112/112 [==============================] - 4s 33ms/step - loss: 0.2078 - val_loss: 0.0623
# Epoch 7/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.1691 - val_loss: 0.1305
# Epoch 8/10
# 112/112 [==============================] - 4s 37ms/step - loss: 0.2640 - val_loss: 0.0509
# Epoch 9/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.2322 - val_loss: 0.0753
# Epoch 10/10
# 112/112 [==============================] - 4s 33ms/step - loss: 0.2363 - val_loss: 0.1381
# 125/125 [==============================] - 2s 11ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-15 17:49:00  0.300159        0.3     True  2.194185
# 2022-08-15 17:50:00  0.300220        0.3     True  2.194924
# 2022-08-15 17:52:00  0.300240        0.3     True  2.196287
# 2022-08-15 17:53:00  0.300408        0.3     True  2.197020
# 2022-08-15 17:54:00  0.300573        0.3     True  2.197651
# (5705, 1)
# (3993, 1) (1712, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 112/112 [==============================] - 8s 39ms/step - loss: 0.1937 - val_loss: 0.1163
# Epoch 2/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.1597 - val_loss: 0.0914
# Epoch 3/10
# 112/112 [==============================] - 4s 33ms/step - loss: 0.0929 - val_loss: 0.2153
# Epoch 4/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.1971 - val_loss: 0.0625
# Epoch 5/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.1330 - val_loss: 0.0518
# Epoch 6/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.1425 - val_loss: 0.0509
# Epoch 7/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.1456 - val_loss: 0.1052
# Epoch 8/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.1700 - val_loss: 0.1000
# Epoch 9/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.1444 - val_loss: 0.1582
# Epoch 10/10
# 112/112 [==============================] - 4s 33ms/step - loss: 0.1582 - val_loss: 0.1080
# 124/124 [==============================] - 2s 11ms/step
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-15 13:57:00  0.300090        0.3     True  2.029993
# 2022-08-15 13:58:00  0.300282        0.3     True  2.030622
# 2022-08-15 13:59:00  0.300562        0.3     True  2.031361
# 2022-08-15 14:00:00  0.300843        0.3     True  2.032077
# 2022-08-15 14:02:00  0.301152        0.3     True  2.033461
# (5662, 1)
# (3963, 1) (1699, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 8s 46ms/step - loss: 0.1860 - val_loss: 0.1664
# Epoch 2/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.1606 - val_loss: 0.0731
# Epoch 3/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1079 - val_loss: 0.0587
# Epoch 4/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.1966 - val_loss: 0.0710
# Epoch 5/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1626 - val_loss: 0.0733
# Epoch 6/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.2572 - val_loss: 0.2455
# Epoch 7/10
# 111/111 [==============================] - 4s 35ms/step - loss: 1.0610 - val_loss: 1.2988
# Epoch 8/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.8407 - val_loss: 1.3786
# Epoch 9/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.8226 - val_loss: 1.4195
# Epoch 10/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.8140 - val_loss: 1.4500
# 123/123 [==============================] - 2s 11ms/step
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-15 07:16:00  1.646872        0.3     True  1.749084
# 2022-08-15 07:17:00  1.647726        0.3     True  1.750447
# 2022-08-15 07:18:00  1.648604        0.3     True  1.751185
# 2022-08-15 07:19:00  1.649483        0.3     True  1.751809
# 2022-08-15 07:21:00  1.650337        0.3     True  1.752548
# (6384, 1)
# (4468, 1) (1916, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 125/125 [==============================] - 8s 40ms/step - loss: 0.1840 - val_loss: 0.1598
# Epoch 2/10
# 125/125 [==============================] - 4s 36ms/step - loss: 0.1407 - val_loss: 0.1650
# Epoch 3/10
# 125/125 [==============================] - 4s 36ms/step - loss: 0.1021 - val_loss: 0.0694
# Epoch 4/10
# 125/125 [==============================] - 4s 36ms/step - loss: 0.1690 - val_loss: 0.0746
# Epoch 5/10
# 125/125 [==============================] - 4s 34ms/step - loss: 0.1693 - val_loss: 0.1353
# Epoch 6/10
# 125/125 [==============================] - 4s 33ms/step - loss: 0.2310 - val_loss: 0.0548
# Epoch 7/10
# 125/125 [==============================] - 4s 30ms/step - loss: 0.2345 - val_loss: 0.0716
# Epoch 8/10
# 125/125 [==============================] - 4s 30ms/step - loss: 0.2296 - val_loss: 0.0577
# Epoch 9/10
# 125/125 [==============================] - 4s 31ms/step - loss: 0.1717 - val_loss: 0.0486
# Epoch 10/10
# 125/125 [==============================] - 4s 30ms/step - loss: 0.2368 - val_loss: 0.0650
# 139/139 [==============================] - 2s 10ms/step
#  1/59 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 59/59 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-16 04:15:00  0.300150        0.3     True  2.629605
# 2022-08-16 04:16:00  0.300425        0.3     True  2.630278
# 2022-08-16 04:17:00  0.300644        0.3     True  2.630985
# 2022-08-16 04:18:00  0.300831        0.3     True  2.631677
# 2022-08-16 04:19:00  0.300988        0.3     True  2.632388
# (5662, 1)
# (3963, 1) (1699, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 7s 40ms/step - loss: 0.1822 - val_loss: 0.1016
# Epoch 2/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1517 - val_loss: 0.0626
# Epoch 3/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.0936 - val_loss: 0.2160
# Epoch 4/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.2122 - val_loss: 0.0372
# Epoch 5/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1627 - val_loss: 0.0787
# Epoch 6/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1405 - val_loss: 0.0437
# Epoch 7/10
# 111/111 [==============================] - 4s 32ms/step - loss: 0.1958 - val_loss: 0.0565
# Epoch 8/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1600 - val_loss: 0.0338
# Epoch 9/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1777 - val_loss: 0.0822
# Epoch 10/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1399 - val_loss: 0.1058
# 123/123 [==============================] - 2s 11ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-15 23:04:00  0.300158        0.3     True  2.410666
# 2022-08-15 23:06:00  0.300392        0.3     True  2.411410
# 2022-08-15 23:07:00  0.300658        0.3     True  2.412835
# 2022-08-15 23:08:00  0.300752        0.3     True  2.413481
# 2022-08-15 23:09:00  0.300943        0.3     True  2.414150
# (5664, 1)
# (3964, 1) (1700, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 8s 42ms/step - loss: 0.1941 - val_loss: 0.1450
# Epoch 2/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1663 - val_loss: 0.1387
# Epoch 3/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1128 - val_loss: 0.2009
# Epoch 4/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.2118 - val_loss: 0.0666
# Epoch 5/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1295 - val_loss: 0.0685
# Epoch 6/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.2147 - val_loss: 0.0471
# Epoch 7/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1874 - val_loss: 0.1437
# Epoch 8/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.2650 - val_loss: 0.0654
# Epoch 9/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1863 - val_loss: 0.0651
# Epoch 10/10
# 111/111 [==============================] - 4s 32ms/step - loss: 0.2403 - val_loss: 0.1107
# 123/123 [==============================] - 2s 11ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-15 11:37:00  0.300119        0.3     True  1.931156
# 2022-08-15 11:38:00  0.300559        0.3     True  1.931895
# 2022-08-15 11:39:00  0.301027        0.3     True  1.932620
# 2022-08-15 11:41:00  0.301409        0.3     True  1.933257
# 2022-08-15 11:42:00  0.301727        0.3     True  1.934619
# (5742, 1)
# (4019, 1) (1723, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 113/113 [==============================] - 7s 40ms/step - loss: 0.1882 - val_loss: 0.1616
# Epoch 2/10
# 113/113 [==============================] - 4s 36ms/step - loss: 0.1485 - val_loss: 0.1285
# Epoch 3/10
# 113/113 [==============================] - 4s 35ms/step - loss: 0.0835 - val_loss: 0.1533
# Epoch 4/10
# 113/113 [==============================] - 4s 36ms/step - loss: 0.1646 - val_loss: 0.1040
# Epoch 5/10
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1114 - val_loss: 0.1491
# Epoch 6/10
# 113/113 [==============================] - 4s 35ms/step - loss: 0.1873 - val_loss: 0.0524
# Epoch 7/10
# 113/113 [==============================] - 4s 35ms/step - loss: 0.1524 - val_loss: 0.0860
# Epoch 8/10
# 113/113 [==============================] - 4s 36ms/step - loss: 0.2435 - val_loss: 0.0473
# Epoch 9/10
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1931 - val_loss: 0.1224
# Epoch 10/10
# 113/113 [==============================] - 4s 35ms/step - loss: 0.2150 - val_loss: 0.0476
# 125/125 [==============================] - 2s 11ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-16 07:57:00  0.300135        0.3     True  2.771052
# 2022-08-16 07:58:00  0.300462        0.3     True  2.771776
# 2022-08-16 07:59:00  0.300740        0.3     True  2.772412
# 2022-08-16 08:00:00  0.300936        0.3     True  2.773142
# 2022-08-16 08:02:00  0.301089        0.3     True  2.774510
# (5662, 1)
# (3963, 1) (1699, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 8s 42ms/step - loss: 0.1723 - val_loss: 0.0984
# Epoch 2/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.1590 - val_loss: 0.0944
# Epoch 3/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.0982 - val_loss: 0.1210
# Epoch 4/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1779 - val_loss: 0.1706
# Epoch 5/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1173 - val_loss: 0.0482
# Epoch 6/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.2369 - val_loss: 0.0749
# Epoch 7/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1768 - val_loss: 0.0751
# Epoch 8/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.2622 - val_loss: 0.0918
# Epoch 9/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1905 - val_loss: 0.0846
# Epoch 10/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.2504 - val_loss: 0.0609
# 123/123 [==============================] - 2s 11ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-16 00:47:00  0.300133        0.3     True  2.477717
# 2022-08-16 00:48:00  0.300489        0.3     True  2.478340
# 2022-08-16 00:49:00  0.300807        0.3     True  2.479079
# 2022-08-16 00:51:00  0.301040        0.3     True  2.479818
# 2022-08-16 00:52:00  0.301235        0.3     True  2.481180
# (5662, 1)
# (3963, 1) (1699, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 7s 40ms/step - loss: 0.1854 - val_loss: 0.0974
# Epoch 2/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1648 - val_loss: 0.0976
# Epoch 3/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.0964 - val_loss: 0.0616
# Epoch 4/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.2018 - val_loss: 0.1027
# Epoch 5/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1330 - val_loss: 0.0680
# Epoch 6/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1883 - val_loss: 0.0397
# Epoch 7/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1839 - val_loss: 0.0809
# Epoch 8/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.2494 - val_loss: 0.0334
# Epoch 9/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.1738 - val_loss: 0.0522
# Epoch 10/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.2101 - val_loss: 0.0617
# 123/123 [==============================] - 2s 11ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 12ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-15 23:13:00  0.300079        0.3     True  2.414275
# 2022-08-15 23:14:00  0.300319        0.3     True  2.414970
# 2022-08-15 23:16:00  0.300480        0.3     True  2.415669
# 2022-08-15 23:17:00  0.300590        0.3     True  2.417062
# 2022-08-15 23:18:00  0.300810        0.3     True  2.417757
# (5663, 1)
# (3964, 1) (1699, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 7s 41ms/step - loss: 0.1941 - val_loss: 0.1613
# Epoch 2/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1558 - val_loss: 0.0603
# Epoch 3/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.0873 - val_loss: 0.0940
# Epoch 4/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.1929 - val_loss: 0.0453
# Epoch 5/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1488 - val_loss: 0.1202
# Epoch 6/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1990 - val_loss: 0.0531
# Epoch 7/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.1789 - val_loss: 0.0923
# Epoch 8/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.2528 - val_loss: 0.0883
# Epoch 9/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.1622 - val_loss: 0.1221
# Epoch 10/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.2217 - val_loss: 0.0612
# 123/123 [==============================] - 2s 12ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
# Empty DataFrame
# Columns: [loss, threshold, anomaly, bps_in]
# Index: []
# (5666, 1)
# (3966, 1) (1700, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 7s 41ms/step - loss: 0.1900 - val_loss: 0.1421
# Epoch 2/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1570 - val_loss: 0.0803
# Epoch 3/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.0959 - val_loss: 0.2024
# Epoch 4/10
# 111/111 [==============================] - 4s 37ms/step - loss: 0.1677 - val_loss: 0.0691
# Epoch 5/10
# 111/111 [==============================] - 4s 38ms/step - loss: 0.1239 - val_loss: 0.0500
# Epoch 6/10
# 111/111 [==============================] - 4s 39ms/step - loss: 0.1875 - val_loss: 0.0782
# Epoch 7/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1465 - val_loss: 0.0631
# Epoch 8/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.2432 - val_loss: 0.0573
# Epoch 9/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.1631 - val_loss: 0.0413
# Epoch 10/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.2438 - val_loss: 0.0973
# 123/123 [==============================] - 2s 11ms/step
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 2s 12ms/step
# Empty DataFrame
# Columns: [loss, threshold, anomaly, bps_in]
# Index: []
# (5665, 1)
# (3965, 1) (1700, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 8s 43ms/step - loss: 0.2002 - val_loss: 0.1022
# Epoch 2/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1679 - val_loss: 0.1848
# Epoch 3/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1047 - val_loss: 0.0848
# Epoch 4/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.2227 - val_loss: 0.0537
# Epoch 5/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.1345 - val_loss: 0.0952
# Epoch 6/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1915 - val_loss: 0.0539
# Epoch 7/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1651 - val_loss: 0.0967
# Epoch 8/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.2617 - val_loss: 0.0593
# Epoch 9/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1729 - val_loss: 0.1313
# Epoch 10/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.2328 - val_loss: 0.0705
# 123/123 [==============================] - 2s 11ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-15 21:39:00  0.300115        0.3     True  2.341781
# 2022-08-15 21:41:00  0.300225        0.3     True  2.342434
# 2022-08-15 21:42:00  0.300287        0.3     True  2.343648
# 2022-08-15 21:43:00  0.300462        0.3     True  2.344300
# 2022-08-15 21:44:00  0.300660        0.3     True  2.344871
# (5718, 1)
# (4002, 1) (1716, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 112/112 [==============================] - 9s 38ms/step - loss: 0.1842 - val_loss: 0.1152
# Epoch 2/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.1611 - val_loss: 0.0771
# Epoch 3/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.0923 - val_loss: 0.0628
# Epoch 4/10
# 112/112 [==============================] - 4s 37ms/step - loss: 0.1920 - val_loss: 0.0939
# Epoch 5/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.1215 - val_loss: 0.0728
# Epoch 6/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.2241 - val_loss: 0.1175
# Epoch 7/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.1873 - val_loss: 0.0614
# Epoch 8/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.2841 - val_loss: 0.0677
# Epoch 9/10
# 112/112 [==============================] - 4s 33ms/step - loss: 0.1762 - val_loss: 0.0412
# Epoch 10/10
# 112/112 [==============================] - 4s 36ms/step - loss: 0.2417 - val_loss: 0.0864
# 125/125 [==============================] - 2s 10ms/step
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-15 13:48:00  0.300410        0.3     True  2.001563
# 2022-08-15 13:49:00  0.300865        0.3     True  2.002293
# 2022-08-15 13:50:00  0.301244        0.3     True  2.002908
# 2022-08-15 13:52:00  0.301524        0.3     True  2.004368
# 2022-08-15 13:53:00  0.302056        0.3     True  2.004983
# (5663, 1)
# (3964, 1) (1699, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 8s 43ms/step - loss: 0.1794 - val_loss: 0.1267
# Epoch 2/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1557 - val_loss: 0.0664
# Epoch 3/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1145 - val_loss: 0.1547
# Epoch 4/10
# 111/111 [==============================] - 4s 37ms/step - loss: 0.1915 - val_loss: 0.0518
# Epoch 5/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1901 - val_loss: 0.1220
# Epoch 6/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.2733 - val_loss: 0.0943
# Epoch 7/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.2885 - val_loss: 0.0714
# Epoch 8/10
# 111/111 [==============================] - 4s 37ms/step - loss: 0.2732 - val_loss: 0.0506
# Epoch 9/10
# 111/111 [==============================] - 4s 32ms/step - loss: 0.2225 - val_loss: 0.0902
# Epoch 10/10
# 111/111 [==============================] - 4s 32ms/step - loss: 0.2774 - val_loss: 0.0807
# 123/123 [==============================] - 2s 10ms/step
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-16 00:33:00  0.300209        0.3     True  2.468119
# 2022-08-16 00:34:00  0.300460        0.3     True  2.468742
# 2022-08-16 00:36:00  0.300604        0.3     True  2.469481
# 2022-08-16 00:37:00  0.300708        0.3     True  2.470843
# 2022-08-16 00:38:00  0.300937        0.3     True  2.471570
# (5662, 1)
# (3963, 1) (1699, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 9s 41ms/step - loss: 0.1774 - val_loss: 0.1503
# Epoch 2/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1538 - val_loss: 0.0695
# Epoch 3/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.0852 - val_loss: 0.0933
# Epoch 4/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1581 - val_loss: 0.0738
# Epoch 5/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.0873 - val_loss: 0.0418
# Epoch 6/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1661 - val_loss: 0.0748
# Epoch 7/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1105 - val_loss: 0.0662
# Epoch 8/10
# 111/111 [==============================] - 4s 32ms/step - loss: 0.2074 - val_loss: 0.0571
# Epoch 9/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1295 - val_loss: 0.0862
# Epoch 10/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.2197 - val_loss: 0.0793
# 123/123 [==============================] - 2s 11ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
# Empty DataFrame
# Columns: [loss, threshold, anomaly, bps_in]
# Index: []
# (5665, 1)
# (3965, 1) (1700, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 111/111 [==============================] - 8s 43ms/step - loss: 0.1841 - val_loss: 0.1250
# Epoch 2/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1609 - val_loss: 0.1032
# Epoch 3/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.0986 - val_loss: 0.1749
# Epoch 4/10
# 111/111 [==============================] - 4s 37ms/step - loss: 0.1858 - val_loss: 0.0636
# Epoch 5/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.1476 - val_loss: 0.0861
# Epoch 6/10
# 111/111 [==============================] - 4s 36ms/step - loss: 0.2336 - val_loss: 0.0566
# Epoch 7/10
# 111/111 [==============================] - 4s 35ms/step - loss: 0.2284 - val_loss: 0.1434
# Epoch 8/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.2283 - val_loss: 0.0644
# Epoch 9/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1939 - val_loss: 0.0516
# Epoch 10/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.2445 - val_loss: 0.0755
# 123/123 [==============================] - 2s 11ms/step
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
# Empty DataFrame
# Columns: [loss, threshold, anomaly, bps_in]
# Index: []
# (6118, 1)
# (4282, 1) (1836, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 120/120 [==============================] - 8s 43ms/step - loss: 0.1654 - val_loss: 0.0990
# Epoch 2/10
# 120/120 [==============================] - 4s 33ms/step - loss: 0.1455 - val_loss: 0.1028
# Epoch 3/10
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0901 - val_loss: 0.1563
# Epoch 4/10
# 120/120 [==============================] - 4s 35ms/step - loss: 0.1810 - val_loss: 0.0903
# Epoch 5/10
# 120/120 [==============================] - 4s 35ms/step - loss: 0.1281 - val_loss: 0.0541
# Epoch 6/10
# 120/120 [==============================] - 4s 33ms/step - loss: 0.1885 - val_loss: 0.1048
# Epoch 7/10
# 120/120 [==============================] - 4s 35ms/step - loss: 0.1603 - val_loss: 0.0750
# Epoch 8/10
# 120/120 [==============================] - 4s 36ms/step - loss: 0.2325 - val_loss: 0.0680
# Epoch 9/10
# 120/120 [==============================] - 4s 34ms/step - loss: 0.1778 - val_loss: 0.0654
# Epoch 10/10
# 120/120 [==============================] - 4s 33ms/step - loss: 0.2500 - val_loss: 0.0437
# 133/133 [==============================] - 2s 11ms/step
#  1/57 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 57/57 [==============================] - 1s 10ms/step
# Empty DataFrame
# Columns: [loss, threshold, anomaly, bps_in]
# Index: []
# (5715, 1)
# (4000, 1) (1715, 1)
# /tmp/ipykernel_3408918/1071213619.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_in'] = scaler.transform(train[['bps_in']])
# /tmp/ipykernel_3408918/1071213619.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_in'] = scaler.transform(test[['bps_in']])
# Epoch 1/10
# 112/112 [==============================] - 8s 40ms/step - loss: 0.2039 - val_loss: 0.1169
# Epoch 2/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.1591 - val_loss: 0.0969
# Epoch 3/10
# 112/112 [==============================] - 4s 36ms/step - loss: 0.0913 - val_loss: 0.1665
# Epoch 4/10
# 112/112 [==============================] - 4s 33ms/step - loss: 0.2076 - val_loss: 0.0576
# Epoch 5/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.1352 - val_loss: 0.0525
# Epoch 6/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.1607 - val_loss: 0.0527
# Epoch 7/10
# 112/112 [==============================] - 4s 36ms/step - loss: 0.1861 - val_loss: 0.0935
# Epoch 8/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.1472 - val_loss: 0.0801
# Epoch 9/10
# 112/112 [==============================] - 4s 36ms/step - loss: 0.2018 - val_loss: 0.0643
# Epoch 10/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.1434 - val_loss: 0.2469
# 125/125 [==============================] - 2s 11ms/step
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly    bps_in
# date
# 2022-08-15 07:07:00  0.384286        0.3     True  1.736494
# 2022-08-15 07:08:00  0.384846        0.3     True  1.737135
# 2022-08-15 07:09:00  0.385457        0.3     True  1.737844
# 2022-08-15 07:10:00  0.386079        0.3     True  1.738576
# 2022-08-15 07:12:00  0.386718        0.3     True  1.739926
