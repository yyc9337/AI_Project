# %%
import os
import pandas as pd
import numpy as np

import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from tensorflow.python.keras.models import load_model

import tensorflow as tf
from tensorflow import keras
# Out:
# 2022-08-22 15:35:55.386401: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# !pwd
# Out:
# /home/innerwave/ailab/채널AI/L3/Experiment

# %%
os.chdir('/mlflow-management/L3-mlflow/')

# %%
path = '../Processing/bps_in/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')] ## 파일명 끝이 .csv인 경우
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/innerwave/ailab/채널AI/L3/Experiment/L3_YYC_002.ipynb 셀 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Binnerwave@office.innerwave.co.kr:50023/home/innerwave/ailab/%EC%B1%84%EB%84%90AI/L3/Experiment/L3_YYC_002.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> path = '../Processing/bps_in/'
# ----> <a href='vscode-notebook-cell://ssh-remote%2Binnerwave@office.innerwave.co.kr:50023/home/innerwave/ailab/%EC%B1%84%EB%84%90AI/L3/Experiment/L3_YYC_002.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> file_list = os.listdir(path)
#       <a href='vscode-notebook-cell://ssh-remote%2Binnerwave@office.innerwave.co.kr:50023/home/innerwave/ailab/%EC%B1%84%EB%84%90AI/L3/Experiment/L3_YYC_002.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> file_list_py = [file for file in file_list if file.endswith('.csv')]
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Processing/bps_in/'

# %%
file_list_py
# Out:
# ['172.17.28.191_bpsout.csv',
#  '172.17.28.193_bpsout.csv',
#  '172.17.28.185_bpsout.csv',
#  '172.17.28.197_bpsout.csv',
#  '172.17.28.198_bpsout.csv',
#  '172.17.28.221_bpsout.csv',
#  '172.17.28.234_bpsout.csv',
#  '172.17.28.186_bpsout.csv',
#  '172.17.28.184_bpsout.csv',
#  '172.17.28.189_bpsout.csv',
#  '172.17.28.181_bpsout.csv',
#  '172.17.28.182_bpsout.csv',
#  '172.17.28.231_bpsout.csv',
#  '172.17.28.233_bpsout.csv',
#  '172.17.28.194_bpsout.csv',
#  '172.17.28.190_bpsout.csv',
#  '172.17.28.232_bpsout.csv',
#  '172.17.28.215_bpsout.csv',
#  '172.17.28.192_bpsout.csv',
#  '172.17.28.216_bpsout.csv',
#  '172.17.28.188_bpsout.csv',
#  '172.17.28.183_bpsout.csv',
#  '172.17.28.222_bpsout.csv',
#  '172.17.28.187_bpsout.csv']

# %%
def make_vector(X, Y, time_steps=1):
    Xs, Ys = [], []
    for i in range(len(X) - time_steps):
        value = X.iloc[i:(i + time_steps)].values
        Xs.append(value)        
        Ys.append(Y.iloc[i + time_steps])
    return np.array(Xs), np.array(Ys)

# %%
for i in file_list_py:
    ## 데이터 초기화
    ticket = None

    # 데이터 로드
    df = pd.read_csv(path + i)
    ticket = pd.read_csv(path + i)
    time_temp = pd.to_datetime(ticket['stat_dt'])
    level_temp = ticket['bps_in']
    time_temp.name = 'date'
    level_temp.name = 'bps_in'

    ticket = pd.concat([time_temp, level_temp ], axis = 1)
    ticket = ticket.set_index("date")
    print(ticket.shape)
    ticket.head(5)

    plt.rcParams["figure.figsize"] = (20,10)
    ticket.plot()

    # Set Anomaly
    span_start = time_temp[4950].to_pydatetime()
    span_end = time_temp[5150].to_pydatetime()
    plt.axvspan(span_start, span_end, facecolor='r', alpha=0.5)

    plt.title("bps_in")
    plt.xlabel("Time")
    plt.ylabel("bps_in")
    plt.show()

    train_size = int(len(ticket) * 0.7)
    test_size = len(ticket) - train_size
    train, test = ticket.iloc[0:train_size], ticket.iloc[train_size:len(ticket)]
    print(train.shape, test.shape)

    from sklearn.preprocessing import StandardScaler

    scaler = StandardScaler()
    scaler = scaler.fit(train[['bps_in']])

    train['bps_in'] = scaler.transform(train[['bps_in']])
    test['bps_in'] = scaler.transform(test[['bps_in']])

    TIME_STEPS = 30

    X_train, Y_train = make_vector(train[['bps_in']], train.bps_in, TIME_STEPS)
    X_test, Y_test = make_vector(test[['bps_in']], test.bps_in, TIME_STEPS)

    model = keras.Sequential()
    model.add(keras.layers.LSTM(units=64, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(keras.layers.Dropout(rate=0.2))
    model.add(keras.layers.RepeatVector(n=X_train.shape[1]))
    model.add(keras.layers.LSTM(units=64, return_sequences=True))
    model.add(keras.layers.Dropout(rate=0.2))
    model.add(keras.layers.TimeDistributed(keras.layers.Dense(units=X_train.shape[2])))
    model.compile(loss='mae', optimizer='adam')

    history = model.fit(X_train, X_train, epochs=10, batch_size=32, validation_split=0.1, shuffle=False)
    
    X_pred = model.predict(X_train)
    train_mae_loss = np.mean(np.abs(X_pred - X_train), axis=1)

    sns.distplot(train_mae_loss, bins=50, kde=True);

    X_pred = model.predict(X_test)
    test_mae_loss = np.mean(np.abs(X_pred - X_test), axis=1)

    THRESHOLD = 0.3 # Manual Setting

    test_score_df = pd.DataFrame(index=test[TIME_STEPS:].index)
    test_score_df['loss'] = test_mae_loss
    test_score_df['threshold'] = THRESHOLD
    test_score_df['anomaly'] = test_score_df.loss > test_score_df.threshold
    test_score_df['bps_in'] = test[TIME_STEPS:].bps_in

    anomalies = test_score_df[test_score_df.anomaly == True]
    print(anomalies.head())



    model.save('../Model/bps_in/' +str(df['ip'][0])+'_bpsin.h5')
# Out:
# (5720, 1)
# (4003, 1) (1717, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 112/112 [==============================] - 7s 36ms/step - loss: 0.1735 - val_loss: 0.1292
# Epoch 2/10
# 112/112 [==============================] - 3s 29ms/step - loss: 0.1639 - val_loss: 0.0761
# Epoch 3/10
# 112/112 [==============================] - 3s 31ms/step - loss: 0.1063 - val_loss: 0.1465
# Epoch 4/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.1909 - val_loss: 0.1153
# Epoch 5/10
# 112/112 [==============================] - 3s 29ms/step - loss: 0.1687 - val_loss: 0.0700
# Epoch 6/10
# 112/112 [==============================] - 3s 29ms/step - loss: 0.2515 - val_loss: 0.1121
# Epoch 7/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2166 - val_loss: 0.0395
# Epoch 8/10
# 112/112 [==============================] - 3s 29ms/step - loss: 0.2202 - val_loss: 0.0573
# Epoch 9/10
# 112/112 [==============================] - 3s 29ms/step - loss: 0.1719 - val_loss: 0.0612
# Epoch 10/10
# 112/112 [==============================] - 3s 29ms/step - loss: 0.1924 - val_loss: 0.0486
# 125/125 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 9ms/step
# Empty DataFrame
# Columns: [loss, threshold, anomaly, bps_out]
# Index: []
# (5663, 1)
# (3964, 1) (1699, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 7s 37ms/step - loss: 0.2034 - val_loss: 0.1592
# Epoch 2/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1737 - val_loss: 0.0785
# Epoch 3/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1020 - val_loss: 0.0539
# Epoch 4/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1884 - val_loss: 0.0506
# Epoch 5/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1218 - val_loss: 0.0758
# Epoch 6/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2214 - val_loss: 0.0546
# Epoch 7/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1365 - val_loss: 0.0845
# Epoch 8/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2215 - val_loss: 0.1208
# Epoch 9/10
# 111/111 [==============================] - 4s 32ms/step - loss: 0.1492 - val_loss: 0.1159
# Epoch 10/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2326 - val_loss: 0.0929
# 123/123 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-16 03:09:00  0.300075        0.3     True  2.576029
# 2022-08-16 03:11:00  0.300117        0.3     True  2.576762
# 2022-08-16 03:12:00  0.300124        0.3     True  2.578112
# 2022-08-16 03:13:00  0.300272        0.3     True  2.578774
# 2022-08-16 03:14:00  0.300404        0.3     True  2.579486
# (5663, 1)
# (3964, 1) (1699, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 7s 39ms/step - loss: 0.1820 - val_loss: 0.0947
# Epoch 2/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1527 - val_loss: 0.0638
# Epoch 3/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.0904 - val_loss: 0.1386
# Epoch 4/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1887 - val_loss: 0.0518
# Epoch 5/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1346 - val_loss: 0.0627
# Epoch 6/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2130 - val_loss: 0.0933
# Epoch 7/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1855 - val_loss: 0.0684
# Epoch 8/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2594 - val_loss: 0.2066
# Epoch 9/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1881 - val_loss: 0.0537
# Epoch 10/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2565 - val_loss: 0.0977
# 123/123 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-15 10:28:00  0.300550        0.3     True  1.883070
# 2022-08-15 10:29:00  0.301150        0.3     True  1.883812
# 2022-08-15 10:31:00  0.301658        0.3     True  1.884542
# 2022-08-15 10:32:00  0.302114        0.3     True  1.885934
# 2022-08-15 10:33:00  0.302763        0.3     True  1.886583
# (5665, 1)
# (3965, 1) (1700, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 8s 39ms/step - loss: 0.1786 - val_loss: 0.1663
# Epoch 2/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1577 - val_loss: 0.1070
# Epoch 3/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0898 - val_loss: 0.1156
# Epoch 4/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1826 - val_loss: 0.0466
# Epoch 5/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1361 - val_loss: 0.0548
# Epoch 6/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2093 - val_loss: 0.0589
# Epoch 7/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1718 - val_loss: 0.0601
# Epoch 8/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.2275 - val_loss: 0.1142
# Epoch 9/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1552 - val_loss: 0.0695
# Epoch 10/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2342 - val_loss: 0.0552
# 123/123 [==============================] - 2s 11ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
# Empty DataFrame
# Columns: [loss, threshold, anomaly, bps_out]
# Index: []
# (5666, 1)
# (3966, 1) (1700, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 7s 36ms/step - loss: 0.1982 - val_loss: 0.1098
# Epoch 2/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1669 - val_loss: 0.2007
# Epoch 3/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1007 - val_loss: 0.0809
# Epoch 4/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2061 - val_loss: 0.1982
# Epoch 5/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1494 - val_loss: 0.0376
# Epoch 6/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2267 - val_loss: 0.0672
# Epoch 7/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1815 - val_loss: 0.0757
# Epoch 8/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2056 - val_loss: 0.0588
# Epoch 9/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1787 - val_loss: 0.1640
# Epoch 10/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2194 - val_loss: 0.0902
# 123/123 [==============================] - 2s 10ms/step
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-15 22:18:00  0.300015        0.3     True  2.373367
# 2022-08-15 22:19:00  0.300228        0.3     True  2.374022
# 2022-08-15 22:21:00  0.300354        0.3     True  2.374749
# 2022-08-15 22:22:00  0.300432        0.3     True  2.376113
# 2022-08-15 22:23:00  0.300629        0.3     True  2.376751
# (6118, 1)
# (4282, 1) (1836, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 120/120 [==============================] - 8s 36ms/step - loss: 0.1847 - val_loss: 0.1103
# Epoch 2/10
# 120/120 [==============================] - 4s 30ms/step - loss: 0.1502 - val_loss: 0.0719
# Epoch 3/10
# 120/120 [==============================] - 4s 31ms/step - loss: 0.0958 - val_loss: 0.0781
# Epoch 4/10
# 120/120 [==============================] - 4s 30ms/step - loss: 0.1895 - val_loss: 0.0588
# Epoch 5/10
# 120/120 [==============================] - 4s 30ms/step - loss: 0.1578 - val_loss: 0.1185
# Epoch 6/10
# 120/120 [==============================] - 4s 29ms/step - loss: 0.2045 - val_loss: 0.0871
# Epoch 7/10
# 120/120 [==============================] - 4s 30ms/step - loss: 0.2159 - val_loss: 0.1154
# Epoch 8/10
# 120/120 [==============================] - 4s 30ms/step - loss: 0.2790 - val_loss: 0.0628
# Epoch 9/10
# 120/120 [==============================] - 4s 30ms/step - loss: 0.2458 - val_loss: 0.1209
# Epoch 10/10
# 120/120 [==============================] - 4s 30ms/step - loss: 0.2319 - val_loss: 0.0805
# 133/133 [==============================] - 2s 10ms/step
#  1/57 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 57/57 [==============================] - 1s 10ms/step
# Empty DataFrame
# Columns: [loss, threshold, anomaly, bps_out]
# Index: []
# (5662, 1)
# (3963, 1) (1699, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 7s 37ms/step - loss: 0.1704 - val_loss: 0.0986
# Epoch 2/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1508 - val_loss: 0.1035
# Epoch 3/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1015 - val_loss: 0.1184
# Epoch 4/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1892 - val_loss: 0.0923
# Epoch 5/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1642 - val_loss: 0.0604
# Epoch 6/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2404 - val_loss: 0.0703
# Epoch 7/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.5764 - val_loss: 0.0886
# Epoch 8/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.4472 - val_loss: 0.0601
# Epoch 9/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.3412 - val_loss: 0.0709
# Epoch 10/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2879 - val_loss: 0.0589
# 123/123 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-15 22:11:00  0.300189        0.3     True  2.369892
# 2022-08-15 22:12:00  0.300644        0.3     True  2.371264
# 2022-08-15 22:13:00  0.301026        0.3     True  2.371993
# 2022-08-15 22:14:00  0.301425        0.3     True  2.372616
# 2022-08-15 22:16:00  0.301905        0.3     True  2.373356
# (5662, 1)
# (3963, 1) (1699, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 8s 37ms/step - loss: 0.1835 - val_loss: 0.1474
# Epoch 2/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1516 - val_loss: 0.0852
# Epoch 3/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0903 - val_loss: 0.0632
# Epoch 4/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1887 - val_loss: 0.0605
# Epoch 5/10
# 111/111 [==============================] - 4s 32ms/step - loss: 0.1236 - val_loss: 0.1174
# Epoch 6/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.2102 - val_loss: 0.0663
# Epoch 7/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1539 - val_loss: 0.0881
# Epoch 8/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2548 - val_loss: 0.0568
# Epoch 9/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1882 - val_loss: 0.0424
# Epoch 10/10
# 111/111 [==============================] - 4s 32ms/step - loss: 0.2527 - val_loss: 0.0518
# 123/123 [==============================] - 2s 11ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-16 07:54:00  0.300042        0.3     True  2.773272
# 2022-08-16 07:56:00  0.300188        0.3     True  2.773987
# 2022-08-16 07:57:00  0.300267        0.3     True  2.775325
# 2022-08-16 07:58:00  0.300473        0.3     True  2.776106
# 2022-08-16 07:59:00  0.300716        0.3     True  2.776676
# (5718, 1)
# (4002, 1) (1716, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 112/112 [==============================] - 7s 42ms/step - loss: 0.1932 - val_loss: 0.1382
# Epoch 2/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.1606 - val_loss: 0.0818
# Epoch 3/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.1132 - val_loss: 0.0778
# Epoch 4/10
# 112/112 [==============================] - 4s 33ms/step - loss: 0.2258 - val_loss: 0.1549
# Epoch 5/10
# 112/112 [==============================] - 4s 32ms/step - loss: 0.3280 - val_loss: 0.0941
# Epoch 6/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.2899 - val_loss: 0.0550
# Epoch 7/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.2832 - val_loss: 0.0746
# Epoch 8/10
# 112/112 [==============================] - 4s 34ms/step - loss: 0.2812 - val_loss: 0.0430
# Epoch 9/10
# 112/112 [==============================] - 4s 32ms/step - loss: 0.2431 - val_loss: 0.0894
# Epoch 10/10
# 112/112 [==============================] - 4s 33ms/step - loss: 0.2818 - val_loss: 0.0488
# 125/125 [==============================] - 2s 11ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
# Empty DataFrame
# Columns: [loss, threshold, anomaly, bps_out]
# Index: []
# (5666, 1)
# (3966, 1) (1700, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 7s 38ms/step - loss: 0.1972 - val_loss: 0.1950
# Epoch 2/10
# 111/111 [==============================] - 4s 32ms/step - loss: 0.1681 - val_loss: 0.1090
# Epoch 3/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0987 - val_loss: 0.1232
# Epoch 4/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1950 - val_loss: 0.0741
# Epoch 5/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1421 - val_loss: 0.1073
# Epoch 6/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2499 - val_loss: 0.0452
# Epoch 7/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2357 - val_loss: 0.1456
# Epoch 8/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2965 - val_loss: 0.0602
# Epoch 9/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2080 - val_loss: 0.0508
# Epoch 10/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2293 - val_loss: 0.0697
# 123/123 [==============================] - 2s 10ms/step
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-16 09:03:00  0.300012        0.3     True  2.822689
# 2022-08-16 09:04:00  0.300207        0.3     True  2.823418
# 2022-08-16 09:06:00  0.300320        0.3     True  2.824137
# 2022-08-16 09:07:00  0.300394        0.3     True  2.825474
# 2022-08-16 09:08:00  0.300572        0.3     True  2.826111
# (5742, 1)
# (4019, 1) (1723, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 113/113 [==============================] - 7s 37ms/step - loss: 0.1908 - val_loss: 0.1743
# Epoch 2/10
# 113/113 [==============================] - 3s 29ms/step - loss: 0.1605 - val_loss: 0.1888
# Epoch 3/10
# 113/113 [==============================] - 3s 30ms/step - loss: 0.1260 - val_loss: 0.0737
# Epoch 4/10
# 113/113 [==============================] - 3s 29ms/step - loss: 0.1683 - val_loss: 0.1266
# Epoch 5/10
# 113/113 [==============================] - 3s 30ms/step - loss: 0.1551 - val_loss: 0.0851
# Epoch 6/10
# 113/113 [==============================] - 3s 29ms/step - loss: 0.2565 - val_loss: 0.1365
# Epoch 7/10
# 113/113 [==============================] - 3s 29ms/step - loss: 0.2698 - val_loss: 0.0561
# Epoch 8/10
# 113/113 [==============================] - 3s 30ms/step - loss: 0.2837 - val_loss: 0.1171
# Epoch 9/10
# 113/113 [==============================] - 3s 30ms/step - loss: 0.2414 - val_loss: 0.1362
# Epoch 10/10
# 113/113 [==============================] - 3s 30ms/step - loss: 0.2555 - val_loss: 0.0512
# 125/125 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
# Empty DataFrame
# Columns: [loss, threshold, anomaly, bps_out]
# Index: []
# (5711, 1)
# (3997, 1) (1714, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 112/112 [==============================] - 7s 36ms/step - loss: 0.1740 - val_loss: 0.1713
# Epoch 2/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.1530 - val_loss: 0.0740
# Epoch 3/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.0806 - val_loss: 0.1001
# Epoch 4/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.1451 - val_loss: 0.1074
# Epoch 5/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.0922 - val_loss: 0.0732
# Epoch 6/10
# 112/112 [==============================] - 3s 29ms/step - loss: 0.1795 - val_loss: 0.1007
# Epoch 7/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.1229 - val_loss: 0.1261
# Epoch 8/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2076 - val_loss: 0.0987
# Epoch 9/10
# 112/112 [==============================] - 3s 29ms/step - loss: 0.1791 - val_loss: 0.0823
# Epoch 10/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2400 - val_loss: 0.0592
# 124/124 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-16 05:04:00  0.300003        0.3     True  2.657117
# 2022-08-16 05:06:00  0.300110        0.3     True  2.657722
# 2022-08-16 05:07:00  0.300148        0.3     True  2.659190
# 2022-08-16 05:08:00  0.300326        0.3     True  2.659795
# 2022-08-16 05:09:00  0.300496        0.3     True  2.660560
# (5662, 1)
# (3963, 1) (1699, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 7s 37ms/step - loss: 0.1816 - val_loss: 0.0982
# Epoch 2/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1580 - val_loss: 0.0879
# Epoch 3/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.0931 - val_loss: 0.1290
# Epoch 4/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1968 - val_loss: 0.0805
# Epoch 5/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1130 - val_loss: 0.1272
# Epoch 6/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2177 - val_loss: 0.1069
# Epoch 7/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1561 - val_loss: 0.0980
# Epoch 8/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2563 - val_loss: 0.0985
# Epoch 9/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2055 - val_loss: 0.0607
# Epoch 10/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2515 - val_loss: 0.0628
# 123/123 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-15 18:48:00  0.300003        0.3     True  2.230078
# 2022-08-15 18:49:00  0.300320        0.3     True  2.230725
# 2022-08-15 18:51:00  0.300533        0.3     True  2.231464
# 2022-08-15 18:52:00  0.300691        0.3     True  2.232850
# 2022-08-15 18:53:00  0.301010        0.3     True  2.233590
# (5662, 1)
# (3963, 1) (1699, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 7s 39ms/step - loss: 0.1777 - val_loss: 0.0922
# Epoch 2/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1614 - val_loss: 0.0631
# Epoch 3/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1100 - val_loss: 0.0739
# Epoch 4/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1918 - val_loss: 0.1021
# Epoch 5/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1495 - val_loss: 0.0585
# Epoch 6/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2432 - val_loss: 0.0705
# Epoch 7/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1884 - val_loss: 0.1361
# Epoch 8/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2392 - val_loss: 0.0690
# Epoch 9/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1891 - val_loss: 0.1113
# Epoch 10/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2689 - val_loss: 0.0520
# 123/123 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
# Empty DataFrame
# Columns: [loss, threshold, anomaly, bps_out]
# Index: []
# (5665, 1)
# (3965, 1) (1700, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 8s 37ms/step - loss: 0.1981 - val_loss: 0.1203
# Epoch 2/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1601 - val_loss: 0.0971
# Epoch 3/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.0959 - val_loss: 0.1452
# Epoch 4/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1853 - val_loss: 0.0969
# Epoch 5/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1279 - val_loss: 0.0836
# Epoch 6/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1961 - val_loss: 0.0560
# Epoch 7/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1763 - val_loss: 0.0455
# Epoch 8/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2647 - val_loss: 0.0446
# Epoch 9/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2362 - val_loss: 0.0665
# Epoch 10/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2454 - val_loss: 0.1036
# 123/123 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-15 14:13:00  0.300053        0.3     True  2.038969
# 2022-08-15 14:14:00  0.300460        0.3     True  2.039652
# 2022-08-15 14:15:00  0.300769        0.3     True  2.040308
# 2022-08-15 14:17:00  0.300988        0.3     True  2.041732
# 2022-08-15 14:18:00  0.301410        0.3     True  2.042276
# (5664, 1)
# (3964, 1) (1700, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 7s 36ms/step - loss: 0.1867 - val_loss: 0.1340
# Epoch 2/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1563 - val_loss: 0.0700
# Epoch 3/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.0868 - val_loss: 0.0869
# Epoch 4/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1737 - val_loss: 0.2040
# Epoch 5/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1106 - val_loss: 0.0888
# Epoch 6/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2056 - val_loss: 0.0608
# Epoch 7/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1635 - val_loss: 0.0422
# Epoch 8/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2621 - val_loss: 0.0566
# Epoch 9/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2106 - val_loss: 0.0417
# Epoch 10/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.2460 - val_loss: 0.1169
# 123/123 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 11ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-15 10:34:00  0.300122        0.3     True  1.887630
# 2022-08-15 10:36:00  0.300561        0.3     True  1.888264
# 2022-08-15 10:37:00  0.300915        0.3     True  1.889630
# 2022-08-15 10:38:00  0.301408        0.3     True  1.890332
# 2022-08-15 10:39:00  0.301914        0.3     True  1.891054
# (5662, 1)
# (3963, 1) (1699, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 8s 40ms/step - loss: 0.1882 - val_loss: 0.1961
# Epoch 2/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1650 - val_loss: 0.0659
# Epoch 3/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.0853 - val_loss: 0.0657
# Epoch 4/10
# 111/111 [==============================] - 4s 32ms/step - loss: 0.1780 - val_loss: 0.0753
# Epoch 5/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.0965 - val_loss: 0.0571
# Epoch 6/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1484 - val_loss: 0.0564
# Epoch 7/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1198 - val_loss: 0.0939
# Epoch 8/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.1732 - val_loss: 0.0492
# Epoch 9/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1289 - val_loss: 0.0691
# Epoch 10/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.2144 - val_loss: 0.0466
# 123/123 [==============================] - 2s 11ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-16 04:27:00  0.300002        0.3     True  2.631487
# 2022-08-16 04:28:00  0.300310        0.3     True  2.632226
# 2022-08-16 04:29:00  0.300649        0.3     True  2.632873
# 2022-08-16 04:31:00  0.300905        0.3     True  2.633612
# 2022-08-16 04:32:00  0.301110        0.3     True  2.634998
# (5663, 1)
# (3964, 1) (1699, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 7s 37ms/step - loss: 0.1865 - val_loss: 0.1483
# Epoch 2/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1641 - val_loss: 0.0657
# Epoch 3/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.0872 - val_loss: 0.1025
# Epoch 4/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1809 - val_loss: 0.0530
# Epoch 5/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1151 - val_loss: 0.0634
# Epoch 6/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1828 - val_loss: 0.1371
# Epoch 7/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1509 - val_loss: 0.0912
# Epoch 8/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.2536 - val_loss: 0.0661
# Epoch 9/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2073 - val_loss: 0.1028
# Epoch 10/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2215 - val_loss: 0.0519
# 123/123 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
# Empty DataFrame
# Columns: [loss, threshold, anomaly, bps_out]
# Index: []
# (5662, 1)
# (3963, 1) (1699, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 8s 44ms/step - loss: 0.2056 - val_loss: 0.1233
# Epoch 2/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1719 - val_loss: 0.0649
# Epoch 3/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1214 - val_loss: 0.0738
# Epoch 4/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1891 - val_loss: 0.0554
# Epoch 5/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1725 - val_loss: 0.1402
# Epoch 6/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2971 - val_loss: 0.6850
# Epoch 7/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.9982 - val_loss: 1.4045
# Epoch 8/10
# 111/111 [==============================] - 3s 29ms/step - loss: 0.8129 - val_loss: 1.4424
# Epoch 9/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.8051 - val_loss: 1.4603
# Epoch 10/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.8014 - val_loss: 1.4759
# 123/123 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-15 07:16:00  1.672787        0.3     True  1.748854
# 2022-08-15 07:17:00  1.673644        0.3     True  1.750163
# 2022-08-15 07:18:00  1.674526        0.3     True  1.750693
# 2022-08-15 07:19:00  1.675401        0.3     True  1.751737
# 2022-08-15 07:21:00  1.676266        0.3     True  1.752267
# (5662, 1)
# (3963, 1) (1699, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 111/111 [==============================] - 7s 38ms/step - loss: 0.1758 - val_loss: 0.1572
# Epoch 2/10
# 111/111 [==============================] - 4s 32ms/step - loss: 0.1529 - val_loss: 0.1073
# Epoch 3/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0973 - val_loss: 0.0719
# Epoch 4/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1719 - val_loss: 0.0980
# Epoch 5/10
# 111/111 [==============================] - 4s 34ms/step - loss: 0.1242 - val_loss: 0.0596
# Epoch 6/10
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1983 - val_loss: 0.0591
# Epoch 7/10
# 111/111 [==============================] - 4s 32ms/step - loss: 0.2123 - val_loss: 0.0811
# Epoch 8/10
# 111/111 [==============================] - 4s 32ms/step - loss: 0.2672 - val_loss: 0.0626
# Epoch 9/10
# 111/111 [==============================] - 4s 33ms/step - loss: 0.2533 - val_loss: 0.0705
# Epoch 10/10
# 111/111 [==============================] - 3s 31ms/step - loss: 0.2371 - val_loss: 0.0682
# 123/123 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-15 17:57:00  0.300125        0.3     True  2.236233
# 2022-08-15 17:58:00  0.300555        0.3     True  2.236822
# 2022-08-15 17:59:00  0.300950        0.3     True  2.237565
# 2022-08-15 18:00:00  0.301273        0.3     True  2.238268
# 2022-08-15 18:02:00  0.301548        0.3     True  2.239796
# (5718, 1)
# (4002, 1) (1716, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 112/112 [==============================] - 7s 36ms/step - loss: 0.1920 - val_loss: 0.1279
# Epoch 2/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.1579 - val_loss: 0.0688
# Epoch 3/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.1270 - val_loss: 0.0623
# Epoch 4/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2067 - val_loss: 0.0617
# Epoch 5/10
# 112/112 [==============================] - 3s 31ms/step - loss: 0.1917 - val_loss: 0.0571
# Epoch 6/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2859 - val_loss: 0.0543
# Epoch 7/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2186 - val_loss: 0.0790
# Epoch 8/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2716 - val_loss: 0.0979
# Epoch 9/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2012 - val_loss: 0.1187
# Epoch 10/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2400 - val_loss: 0.1013
# 125/125 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-15 23:33:00  0.300057        0.3     True  2.433279
# 2022-08-15 23:34:00  0.300226        0.3     True  2.434038
# 2022-08-15 23:35:00  0.300343        0.3     True  2.434657
# 2022-08-15 23:37:00  0.300409        0.3     True  2.436140
# 2022-08-15 23:38:00  0.300575        0.3     True  2.436781
# (5705, 1)
# (3993, 1) (1712, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 112/112 [==============================] - 7s 38ms/step - loss: 0.1956 - val_loss: 0.1152
# Epoch 2/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.1575 - val_loss: 0.1132
# Epoch 3/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.0944 - val_loss: 0.1351
# Epoch 4/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.1844 - val_loss: 0.1069
# Epoch 5/10
# 112/112 [==============================] - 3s 31ms/step - loss: 0.1299 - val_loss: 0.0660
# Epoch 6/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.1709 - val_loss: 0.0625
# Epoch 7/10
# 112/112 [==============================] - 4s 31ms/step - loss: 0.1538 - val_loss: 0.0611
# Epoch 8/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2382 - val_loss: 0.1119
# Epoch 9/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.1617 - val_loss: 0.0503
# Epoch 10/10
# 112/112 [==============================] - 3s 29ms/step - loss: 0.2416 - val_loss: 0.0897
# 124/124 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-15 19:23:00  0.300057        0.3     True  2.255689
# 2022-08-15 19:24:00  0.300385        0.3     True  2.256405
# 2022-08-15 19:25:00  0.300621        0.3     True  2.257161
# 2022-08-15 19:26:00  0.300824        0.3     True  2.257812
# 2022-08-15 19:27:00  0.300966        0.3     True  2.258555
# (6384, 1)
# (4468, 1) (1916, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 125/125 [==============================] - 8s 38ms/step - loss: 0.1683 - val_loss: 0.0996
# Epoch 2/10
# 125/125 [==============================] - 4s 32ms/step - loss: 0.1467 - val_loss: 0.0865
# Epoch 3/10
# 125/125 [==============================] - 4s 29ms/step - loss: 0.0854 - val_loss: 0.0703
# Epoch 4/10
# 125/125 [==============================] - 4s 29ms/step - loss: 0.1530 - val_loss: 0.0954
# Epoch 5/10
# 125/125 [==============================] - 4s 30ms/step - loss: 0.1201 - val_loss: 0.1705
# Epoch 6/10
# 125/125 [==============================] - 4s 30ms/step - loss: 0.2069 - val_loss: 0.0561
# Epoch 7/10
# 125/125 [==============================] - 4s 31ms/step - loss: 0.3064 - val_loss: 0.0606
# Epoch 8/10
# 125/125 [==============================] - 4s 30ms/step - loss: 0.2608 - val_loss: 0.0460
# Epoch 9/10
# 125/125 [==============================] - 4s 30ms/step - loss: 0.2790 - val_loss: 0.0931
# Epoch 10/10
# 125/125 [==============================] - 4s 30ms/step - loss: 0.2588 - val_loss: 0.0547
# 139/139 [==============================] - 2s 10ms/step
#  1/59 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 59/59 [==============================] - 1s 10ms/step
# Empty DataFrame
# Columns: [loss, threshold, anomaly, bps_out]
# Index: []
# (5715, 1)
# (4000, 1) (1715, 1)
# /tmp/ipykernel_2718960/2241545429.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bps_out'] = scaler.transform(train[['bps_out']])
# /tmp/ipykernel_2718960/2241545429.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bps_out'] = scaler.transform(test[['bps_out']])
# Epoch 1/10
# 112/112 [==============================] - 8s 37ms/step - loss: 0.2097 - val_loss: 0.1185
# Epoch 2/10
# 112/112 [==============================] - 3s 29ms/step - loss: 0.1631 - val_loss: 0.1117
# Epoch 3/10
# 112/112 [==============================] - 4s 32ms/step - loss: 0.1099 - val_loss: 0.0818
# Epoch 4/10
# 112/112 [==============================] - 3s 31ms/step - loss: 0.2184 - val_loss: 0.0929
# Epoch 5/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.1689 - val_loss: 0.0623
# Epoch 6/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2075 - val_loss: 0.0500
# Epoch 7/10
# 112/112 [==============================] - 4s 31ms/step - loss: 0.2232 - val_loss: 0.1279
# Epoch 8/10
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2969 - val_loss: 0.0470
# Epoch 9/10
# 112/112 [==============================] - 3s 29ms/step - loss: 0.2234 - val_loss: 0.0707
# Epoch 10/10
# 112/112 [==============================] - 3s 29ms/step - loss: 0.2082 - val_loss: 0.0460
# 125/125 [==============================] - 2s 10ms/step
#  1/53 [..............................] - ETA: 1s
# /home/innerwave/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 53/53 [==============================] - 1s 10ms/step
#                          loss  threshold  anomaly   bps_out
# date
# 2022-08-16 07:55:00  0.300194        0.3     True  2.817206
# 2022-08-16 07:57:00  0.300372        0.3     True  2.818569
# 2022-08-16 07:58:00  0.300474        0.3     True  2.819310
# 2022-08-16 07:59:00  0.300654        0.3     True  2.819960
# 2022-08-16 08:00:00  0.300862        0.3     True  2.820723
